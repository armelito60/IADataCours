# %% [markdown]
# # <center>Projet Deep Learning - Exercice de classification</center>

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
import random
from tensorflow import keras
from tensorflow.keras import layers, Input
from tensorflow.keras.models import Sequential, Model
from keras.layers.core import Dense, Flatten
from tensorflow.keras.layers import InputLayer
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# On va afficher 5 images random présentes dans le fichier.

# %%
plt.figure(figsize=(20,20))
img_folder=os.path.join(r'nov2021_train')
for i in range(5):
    file = random.choice(os.listdir(img_folder))
    image_path= os.path.join(img_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %% [markdown]
# ##### Création des données d'image et des étiquettes à partir des images du dossier
#
# - Le dossier source est le paramètre d'entrée contenant les images des différentes classes.
#
# - Lire le fichier image du dossier et le convertir au bon format de couleur.
#
# - Redimensionnez l'image en fonction de la dimension d'entrée requise pour le modèle.
#
# - Convertir l'image en un tableau Numpy avec float32 comme type de données.
#
# - Normaliser le tableau d'images pour avoir des valeurs réduites entre 0 et 1 de 0 à 255 pour une distribution de données similaire, ce qui permet une convergence plus rapide.

# %%
# Modification de la dimension des images 
IMG_WIDTH=200
IMG_HEIGHT=200

def create_dataset(img_folder):
   
    img_data_array=[]
    class_name=[]
   
    for dir1 in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):
       
            image_path= os.path.join(img_folder, dir1,  file)
            image= cv2.imread(image_path, cv2.COLOR_BGR2RGB)
            image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            image=np.array(image)
            image = image.astype('float32')
            image /= 255 
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array, class_name
# extract the image array and class name
img_data, class_name = create_dataset(img_folder)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14176/1417347143.py in <module>
#      21     return img_data_array, class_name
#      22 # extract the image array and class name
# ---> 23 img_data, class_name = create_dataset(img_folder)
#
# ~\AppData\Local\Temp/ipykernel_14176/1417347143.py in create_dataset(img_folder)
#       9
#      10     for dir1 in os.listdir(img_folder):
# ---> 11         for file in os.listdir(os.path.join(img_folder, dir1)):
#      12
#      13             image_path= os.path.join(img_folder, dir1,  file)
#
# NotADirectoryError: [WinError 267] Nom de répertoire non valide: 'nov2021_train\\000000.jpg'
