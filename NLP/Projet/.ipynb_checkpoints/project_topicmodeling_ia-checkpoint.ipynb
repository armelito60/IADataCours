# %% [markdown]
# # <center>Projet Topic Modeling</center>

# %% [markdown]
# During the Natural Language Processing course, text representation algorithms have been introduced. However they don't suffice to the creation of complete NLP systems.

# %% [markdown]
# Most of them usually rely on text pre-processing at first -- in other words, they rely on a specific data pipeline that is tied to the final task you are trying to solve.

# %% [markdown]
# As a result, we will try in this notebook to create a pipeline from scratch given a specific final task.

# %% [markdown]
# # Resources you'll need

# %% [markdown]
# ## Machine Learning libraries

# %% [markdown]
# Lots of ML libraries exist in the wild. You have general libraries such as [scikit-learn](https://scikit-learn.org/stable/), domain related libraries such as [nltk](https://www.nltk.org/) or hyper specific implementation of optimized algorithms such as annoy [annoy](https://pypi.org/project/annoy/).

# %% [markdown]
# In this notebook, you'll need to rely on the following packages:
#
#    - [scikit-learn](https://scikit-learn.org/stable/): all purpose machine learning resource if they aren't neural based.
#    - [nltk](https://www.nltk.org/): natural language toolkit -- implements lots of preprocessing steps and text transformation.
#    - [gensim](https://radimrehurek.com/gensim/): library designed to be easy to use for both topic modeling and text representation.
#    - [spacy](https://spacy.io/): industrialization machine learning systems. Provide lots of pretrained weights for various models.

# %% [markdown]
# Usually, a simple pip install is sufficient for them to work. If you have already installed it, feel free to create a dedicated virtual environment, which is really a good practice. If you want to know more regarding that, you can rely on this [here](https://virtualenvwrapper.readthedocs.io/en/latest/).

# %% [markdown]
# ## Data & final task definition

# %% [markdown]
# Given the [News dataset](https://www.kaggle.com/rmisra/news-category-dataset/download) (also available alongside this notebook), you'll have to build a simple topic modeling system that will identify the topics of the news headlines.

# %% [markdown]
# Those headlines have already been labelled. Here are the categories and document counts of this dataset:
#
# * POLITICS: 32739
#
# * WELLNESS: 17827
#
# * ENTERTAINMENT: 16058
#
# * TRAVEL: 9887
#
# * STYLE & BEAUTY: 9649
#
# * PARENTING: 8677
#
# * HEALTHY LIVING: 6694
#
# * QUEER VOICES: 6314
#
# * FOOD & DRINK: 6226
#
# * BUSINESS: 5937
#
# * COMEDY: 5175
#
# * SPORTS: 4884
#
# * BLACK VOICES: 4528
#
# * HOME & LIVING: 4195
#
# * PARENTS: 3955
#
# * THE WORLDPOST: 3664
#
# * WEDDINGS: 3651
#
# * WOMEN: 3490
#
# * IMPACT: 3459
#
# * DIVORCE: 3426
#
# * CRIME: 3405
#
# * MEDIA: 2815
#
# * WEIRD NEWS: 2670
#
# * GREEN: 2622
#
# * WORLDPOST: 2579
#
# * RELIGION: 2556
#
# * STYLE: 2254
#
# * SCIENCE: 2178
#
# * WORLD NEWS: 2177
#
# * TASTE: 2096
#
# * TECH: 2082
#
# * MONEY: 1707
#
# * ARTS: 1509
#
# * FIFTY: 1401
#
# * GOOD NEWS: 1398
#
# * ARTS & CULTURE: 1339
#
# * ENVIRONMENT: 1323
#
# * COLLEGE: 1144
#
# * LATINO VOICES: 1129
#
# * CULTURE & ARTS: 1030
#
# * EDUCATION: 1004

# %% [markdown]
# # Exploring the dataset

# %%
import pandas as pd
import numpy as np
import itertools
import itertools
import os
import re
import secrets
import string
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import style

import pandas as pd
import spacy

from itertools import chain

from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec, Phrases, KeyedVectors
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess
from nltk.corpus import wordnet
# from pattern.en import pluralize, singularize
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from tqdm import tqdm
from wordcloud import WordCloud

from spacy.parts_of_speech import IDS as POS_map

# %% [markdown]
# You can load the dataset using pandas and the [.read_json()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html) method. Try loading your dataset here:

# %%
dataset = pd.read_json("News_Category_Dataset_v2.json", lines=True, dtype={"headline": str})

# %% [markdown]
# ------

# %% [markdown]
# A good way to get the grasp of your corpus is to count the occurences of words across it. For convenience, we've defined a dummy function that splits words by checking where spaces are and... Simply that. This is the most basic form of word identification in text that could be used.

# %%
def dummy_word_split(texts):
    """Function identifying words in a sentence in a really dummy way.
        
        Argument:
            - texts (list of str): a list of raw texts in which we'd like to identify words
            
        Return:
            - list of list containing each word separately.
    """
    texts_out = []
    for text in texts:
        texts_out.append(text.split(" "))
        
    return texts_out

# %%
splitted_texts = dummy_word_split(dataset["headline"].tolist())

# %%
splitted_texts[0] + splitted_texts[1]
# Out:
# ['There',
#  'Were',
#  '2',
#  'Mass',
#  'Shootings',
#  'In',
#  'Texas',
#  'Last',
#  'Week,',
#  'But',
#  'Only',
#  '1',
#  'On',
#  'TV',
#  'Will',
#  'Smith',
#  'Joins',
#  'Diplo',
#  'And',
#  'Nicky',
#  'Jam',
#  'For',
#  'The',
#  '2018',
#  'World',
#  "Cup's",
#  'Official',
#  'Song']

# %% [markdown]
# Now, let's define a function that counts word occurences and highlight what are the most important words of our corpus:

# %%
def compute_word_occurences(texts):
    """You have to define this function yourself. """
    
    words = itertools.chain.from_iterable(texts)
    
    word_count = pd.Series(words).value_counts()
    word_count = pd.DataFrame({"Word": word_count.index, "Count": word_count.values})

    return word_count

# %% [markdown]
# Once this is done, display the top 20 most occuring words in your texts.

# %%
compute_word_occurences(splitted_texts).head(1000)
# Out:
#          Word  Count
# 0         The  47803
# 1          To  38569
# 2           A  24839
# 3          In  24141
# 4          Of  22956
# ..        ...    ...
# 995        30    258
# 996   Netflix    258
# 997      Park    258
# 998  Mistakes    257
# 999     Probe    257
#
# [1000 rows x 2 columns]

# %% [markdown]
# Does it make sense, and can you leverage such results?

# %% [markdown]
# # Actual pipeline

# %% [markdown]
# As you have seen above, the results obtained from a simple word count aren't so great. Similar words doesn't add up (such as run and running), and you have a lot of noise included. Words such as *the*, *you*, *an* could be removed for instance.

# %% [markdown]
# Actually, a lot can be done. Let's check that out.

# %% [markdown]
# ----------

# %% [markdown]
# ## What does the pipeline look like?

# %% [markdown]
# A NLP data pipeline often relies on the following elements. Some can be added, some can be removed, but they all look like this at some point:

# %% [markdown]
# 1. **Ensuring data quality.** You have to make sure that there's no N/A in your data and that everything is in the good format shape. Having this as the entrance of your pipeline will save you a lot of time in the long run, so try defining it thoroughly.
#
#
# 2. **Filtering texts from unwanted characters**. Especially if you get data from web, you'll end up with HTML tags or encoding stuff that you don't need in your texts. Before applying anything to them, you need to get them cleaned up. Here, try removing the dates and the punctuation for instance.
#
#
# 3. **Unify your texts**. (*This is topic modeling specific*). You don't want to make the difference between a word at the beginning of a phrase of in the middle of it here. You should unify all your words by lowercasing them and deaccenting them as well.
#
#
# 4. **Converting sentences to lists of words**. Some words aren't needed for our analyses, such as *your*, *my*, etc. In order to remove them easily, you have to convert your sentences to lists of words. You can use the dummy function defined above but I'd advised against it. Try finding a function that does that smoothly in [gensim.utils](https://radimrehurek.com/gensim/utils.html)!
#
#
# 5. **Remove useless words**. You need to remove useless words from your corpus. You have two approaches: [use a hard defined list of stopwords](https://www.analyticsvidhya.com/blog/2019/08/how-to-remove-stopwords-text-normalization-nltk-spacy-gensim-python/) or rely on TF-IDF to identify useless words. The first is the simplest, the second might yield better results!
#
#
# 6. **Creating n-grams**. If you look at New York, it is composed of two words. As a result, a word count wouldn't really return a true count for *New York* per se. In NLP, we represent New York as New_York, which is considered a single word. The n-gram creation consists in identifying words that occur together often and regrouping them. It boosts interpretability for topic modeling in this case.
#
#
# 7. **Stemming / Lemmatization**. Shouldn't run, running, runnable be grouped and counted as a single word when we're identifying discussion topics? Yes, they should. Stemming is the process of cutting words to their word root (run- for instance) quite brutally while lemmatization will do the same by identifying the kind of word it is working on. You should convert the corpus words into those truncated representations to have a more realistic word count.
#
#
# 8. **Part of speech tagging**. POS helps in the identification of verbs, nouns, adjectives, etc. For topic models, it is a good idea to work only on verbs and nouns. Adjectives don't convey info about the actual underlying topic discussed at hand.

# %% [markdown]
# ## Let's create it!

# %% [markdown]
# Now it's your turn. Try to implement each step of the pipeline, and compare the word counts obtained earlier and the one obtained after preprocessing your texts.

# %% [markdown]
# ### Ensuring data quality

# %%
def check_data_quality(texts):
    """Check wheter all the dataset is conform to the expected behaviour."""
    assert all([isinstance(t, str) for t in texts]), "Input data contains something different than strings."
    assert all([t != np.nan for t in texts]), "Input data contains NaN values."
    
    return True

# %%
def force_format(texts):
    return [str(t) for t in texts]

# %%
texts = force_format(dataset["headline"])

# %%
print(f"Is the dataset passing our data quality check?\n{check_data_quality(texts)}")
# Out:
# Is the dataset passing our data quality check?
# True

# %% [markdown]
# ### Filtering texts

# %% [markdown]
# https://regex101.com/

# %%
def filter_text(texts_in):
    """Removes incorrect patterns from a list of texts, such as hyperlinks, bullet points and so on"""
    
    texts_out = re.sub(r'https?:\/\/[A-Za-z0-9_.-~\-]*', ' ', texts_in, flags=re.MULTILINE)
    texts_out = re.sub(r'[(){}\[\]<>]', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&amp;#.*;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&gt;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'â€™', "'", texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'\s+', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&#x200B;', ' ', texts_out, flags=re.MULTILINE)
    # Mail regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r"(?i)(?:[a-z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+\/=?^_`{|}~-]+)*|\"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*\")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9]))\.){3}(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9])|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+\.[a-zA-Z0-9-_.]+', '', texts_out, flags=re.MULTILINE)
    # Phone regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r"\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}", '', texts_out, flags=re.MULTILINE)
    # Remove names in twitter
    texts_out = re.sub(r'@\S+( |\n)', '', texts_out, flags=re.MULTILINE)

    # Remove starts commonly used on social media
    texts_out = re.sub(r'\*', '', texts_out, flags=re.MULTILINE)
    return texts_out

# %%
texts = [filter_text(t) for t in texts]

# %% [markdown]
# ### Unifying texts & converting sentences to list of words

# %%
def sent_to_words(sentences):
    """Converts sentences to words.

    Convert sentences in lists of words while removing the accents and the punctuation.

    @param:
        sentences: a list of strings, the sentences we want to convert
    @return
        A list of words' lists.
    """
    for sentence in tqdm(sentences):
        yield (simple_preprocess(str(sentence), deacc=True))

# %%
texts = list(sent_to_words(texts))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 200853/200853 [00:05<00:00, 36180.39it/s]

# %%
texts
# Out:
# [['there',
#   'were',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   'world',
#   'cup',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'for', 'the', 'first', 'time', 'at', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonald',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'he',
#   'like',
#   'to',
#   'do',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oyster',
#   'growing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trump',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trump',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'there',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trump',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trump',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'father',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesn',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter', 'and', 'it', 'was', 'universally', 'entertaining'],
#  ['mystery',
#   'wolf',
#   'like',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houston',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trump', 'new', 'maga', 'themed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonald'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'iran',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'he',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adult',
#   'themed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bee',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesn',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesn',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayer',
#   'weird',
#   'new',
#   'low',
#   'budget',
#   'video',
#   'is',
#   'meme',
#   'worthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nra',
#   'backed',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trump',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member',
#   'of',
#   'the',
#   'far',
#   'right',
#   'proud',
#   'boys',
#   'menaced',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['here',
#   'what',
#   'happens',
#   'when',
#   'catholic',
#   'hospital',
#   'won',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trump',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'here',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinstein', 'perp', 'walk'],
#  ['the', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'desk',
#   'makeover',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupaul',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   'pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writer',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'won',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvel',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the',
#   'biggest',
#   'flaw',
#   'in',
#   'trump',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nunes',
#   'linked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['ireland',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   'females',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'won',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trump',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'it',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambor',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'co',
#   'stars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'let',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'anti',
#   'abortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trump',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trump',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebook',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'it',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['you',
#   're',
#   'going',
#   'to',
#   'use',
#   'that',
#   'self',
#   'checkout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'who',
#   've',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'right',
#   'to',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can', 'you', 'believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldn',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['self',
#   'driving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wide',
#   'eyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['far',
#   'right',
#   'and',
#   'anti',
#   'establishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italy',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'can',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'same', 'sex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngest',
#   'ever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohen',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louis',
#   'dreyfus',
#   'to',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'host',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trump',
#   'themed',
#   'reddit',
#   'forum'],
#  ['calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'off',
#   'duty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'country',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'he',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons',
#   'why',
#   'started',
#   'conversation',
#   'who',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohio',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasn',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'at',
#   'risk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'brien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'weren',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'he',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'don',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'liar'],
#  ['trump', 'blocking', 'people', 'on', 'twitter', 'is', 'judge', 'rules'],
#  ['mostly',
#   'non',
#   'christian',
#   'militia',
#   'won',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbard',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishment',
#   'backed',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'iran',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeo',
#   'threats',
#   'with',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'she', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'that',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runner',
#   'up',
#   'reveals',
#   'they',
#   're',
#   'dating'],
#  ['colbert',
#   'just',
#   'can',
#   'resist',
#   'turning',
#   'trump',
#   'nickname',
#   'into',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trump',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age'],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'we',
#   're',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissian',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'store',
#   'donations',
#   'to',
#   'nra',
#   'backed',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'she',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trump',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bullet',
#   'riddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governor',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaad',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'in',
#   'store',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governor',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'co',
#   'workers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trump',
#   'kim',
#   'jong',
#   'un',
#   'coin'],
#  ['giuliani',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'it',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'cease',
#   'and',
#   'desist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trump',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bug',
#   'flavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'don',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planet',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'anti',
#   'spanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'am'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trump',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['ex',
#   'trump',
#   'adviser',
#   'calls',
#   'president',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'one',
#   'third',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghan',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   'year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'won',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teen', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['time',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonald',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuela',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   're',
#   'elected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europe',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isn',
#   'enough',
#   'after',
#   'america',
#   'withdrawal'],
#  ['far',
#   'right',
#   'mob',
#   'attacks',
#   'year',
#   'old',
#   'liberal',
#   'greek',
#   'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rice',
#   'mother',
#   'is',
#   'opening',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'son',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'word', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   'it',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'he',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomo', 're', 'election'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'theroux',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'can',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats',
#   'plan',
#   'big',
#   'anti',
#   'corruption',
#   'theme',
#   'for',
#   'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   'of',
#   'the',
#   'internet',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'don',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'no',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spider',
#   'man',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isn',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'driver',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['year',
#   'old',
#   'boy',
#   'is',
#   'superhero',
#   'to',
#   'alabama',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabj',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['year',
#   'old',
#   'gay',
#   'man',
#   'proves',
#   'you',
#   're',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'primary',
#   'didn',
#   'receive',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'better',
#   'deal'],
#  ['majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'don',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'in',
#   'country',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasury',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trump',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmar',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'gov',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'fey',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwin',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argento',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carrey',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'he',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   'year',
#   'now',
#   'he',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   'report'],
#  ['trump',
#   'misspells',
#   'melania',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   'things',
#   'you',
#   'don',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sit',
#   'in',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryan',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['ex',
#   'russian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolf',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'mueller',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbourne', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'that',
#   'where',
#   'he',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'country',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
#   'boy',
#   'we',
#   'are',
#   'in',
#   'love'],
#  ['alec',
#   'baldwin',
#   'and',
#   'wife',
#   'hilaria',
#   'welcome',
#   'another',
#   'baby',
#   'boy'],
#  ['kate',
#   'mckinnon',
#   'breaks',
#   'out',
#   'another',
#   'impression',
#   'of',
#   'rudy',
#   'giuliani'],
#  ['how',
#   'did',
#   'smallville',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'with',
#   'sex',
#   'cult',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['trump',
#   'white',
#   'house',
#   'kills',
#   'off',
#   'yanny',
#   'laurel',
#   'debate',
#   'with',
#   'ridiculous',
#   'clip'],
#  ['jennifer',
#   'aniston',
#   'to',
#   'play',
#   'lesbian',
#   'president',
#   'in',
#   'netflix',
#   'first',
#   'ladies'],
#  ['break',
#   'out',
#   'the',
#   'book',
# ...
#   'people',
#   'back',
#   'to',
#   'work'],
#  ['jim',
#   'parsons',
#   'yes',
#   'we',
#   'still',
#   'need',
#   'more',
#   'queer',
#   'stories',
#   'onscreen'],
#  ['trump',
#   'accuser',
#   'wins',
#   'democratic',
#   'nomination',
#   'for',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'by',
#   'cia',
#   'has',
#   'information',
#   'to',
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trump',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'might',
#   've',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'council',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauer',
#   'accusers',
#   'after',
#   'months',
#   'long',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didn',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warren',
#   'pick',
#   'wins',
#   'ohio',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['at',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trump',
#   'themed',
#   'merch',
#   'ahead',
#   'of',
#   'mother',
#   'day'],
#  ['don',
#   'blankenship',
#   'defeat',
#   'is',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peele',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['here',
#   'look',
#   'at',
#   'orlando',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trump',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'state',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'scapegoat',
#   'for',
#   'trump',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayor',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'at',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trump',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trump',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacare',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'century',
#   'long',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trump',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'won',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'planet', 'in', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['ex',
#   'convict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trump', 'iran', 'deal', 'exit', 'is', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'non',
#   'binary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambino',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'aren',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'they',
#   're',
#   'dead'],
#  ['donald',
#   'glover',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   'th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrette',
#   'abby',
#   'has',
#   'heart',
#   'wrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahu',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahu',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japan',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'york',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'general',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trump',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy', 'matrimony', 'there', 'was', 'proposal', 'at', 'the', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'at', 'met', 'gala', 'as', 'queer', 'superhero'],
#  ['kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'he',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'on',
#   'air',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivo',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   'ted',
#   'after',
#   'years'],
#  ['solange', 'durag', 'was', 'the', 'true', 'mvp', 'at', 'the', 'met', 'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudy',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   'met',
#   'gala'],
#  ['bob',
#   'marley',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'anti',
#   'bullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husband',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushner',
#   'backed',
#   'bill',
#   'could',
#   'be',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'first',
#   'class',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pence',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'president',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'reilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hide',
#   'and',
#   'seek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   'queer',
#   'icons',
#   'as',
#   'you',
#   've',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwin',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccain',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trump',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trump',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'can',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'they',
#   're',
#   'straight',
#   'out',
#   'of',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# ## Remove useless words

# %%
from spacy.lang.en.stop_words import STOP_WORDS as en_stop

## TF-IDF pour identifier les stopwords
tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words=en_stop, ngram_range=(1,1))
tvec_weights = tvec.fit_transform(dataset['headline'].dropna())
weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)

## Liste pré-définis de stopwords à éliminer
for lists in texts:
    for word in en_stop:
        try:
            lists.remove(word)
        except Exception as e:
            e =""
            
### COMPTER LES MOTS A LA FIN DES DEUX METHODES ET LES COMPARER
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %% [markdown]
# ### Creating n-grams

# %%
def create_bigrams(texts, bigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify bigrams in texts and return the texts with bigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

def create_trigrams(texts, trigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify trigrams in texts and return the texts with trigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

# %%
texts = create_bigrams(texts)

# %%
texts
# Out:
# ['mass_shootings texas week tv',
#  'smith joins diplo nicky jam world_cup official song',
#  'hugh grant marries time age',
#  'jim_carrey blasts castrato adam schiff democrats new artwork',
#  'julianna margulies uses donald_trump poop bags pick dog',
#  'morgan_freeman devastated sexual_harassment claims undermine legacy',
#  'donald_trump lovin new mcdonald jingle tonight bit',
#  'watch amazon prime new week',
#  'mike myers reveals like fourth austin powers film',
#  'watch hulu new week',
#  'justin_timberlake visits texas school_shooting victims',
#  'south_korean president meets north_korea kim_jong un talk trump summit',
#  'way life risk remote oyster growing region called robots',
#  'trump crackdown immigrant parents puts kids strained system',
#  'trump son concerned fbi obtained wiretaps putin ally met trump_jr',
#  'edward_snowden trump loves vladimir_putin',
#  'booyah obama photographer hilariously trolls trump spy claim',
#  'ireland votes repeal abortion amendment landslide referendum',
#  'ryan_zinke looks reel critics grand pivot to conservation',
#  'trump scottish golf resort pays women significantly men report',
#  'weird father_day gifts dad doesn_know wants he',
#  'twitter universally entertaining',
#  'mystery wolf like animal reportedly shot montana baffles wildlife officials',
#  'north_korea open talks trump cancels summit',
#  'men detonate bomb inside indian restaurant near toronto authorities',
#  'thousands travel home ireland to vote abortion access',
#  'irish voters set liberalize abortion laws landslide exit poll signals',
#  'warriors coach steve kerr calls nfl ban protests fake patriotism',
#  'historic victory barbados elects female prime_minister',
#  'police killed black americans moment colin_kaepernick protested',
#  'jack johnson pardoned taboo sex criminalized',
#  'bet chairman ceo debra lee stepping',
#  'rachel dolezal faces felony charges welfare fraud',
#  'bishop michael curry joins christian march white_house to reclaim jesus',
#  'kanye_west spent photo whitney_houston bathroom album cover',
#  'morgan_freeman dropped marketing campaigns harassment accusations',
#  'chinese exclusion act help understand immigration politics today',
#  'trump new maga themed swimwear sinks twitter',
#  'seth_meyers funny regret trump cancels north_korea summit',
#  'colbert wants turn nyc subway rides new terrible punishment',
#  'man faces charges pulling knife stun gun muslim students mcdonald',
#  'jimmy_kimmel knows iran supreme leader watches tom jerry',
#  'people injured indiana school_shooting',
#  'people rattled nigerian man looks_like chadwick boseman',
#  'david cross proves terrible apologizing',
#  'sesame_street creators sue makers upcoming adult themed puppet film',
#  'missed saddest death avengers_infinity war',
#  'george_takei accuser walks story drugging sexual_assault',
#  'samantha_bee parents think america basically war zone',
#  'pete davidson says mental_illness doesn ruin romance',
#  'james_corden adam_levine pulled carpool_karaoke',
#  'emilia clarke dishes final game_thrones scene',
#  'hollywood doesn need difficult men great tv',
#  'harvey_weinstein accusers thought arrested',
#  'harvey_weinstein turns police alleged sex crimes',
#  'john_mayer weird new low budget video meme worthy masterpiece',
#  'boba fett getting star_wars movie',
#  'trump suggests north_korea summit happen',
#  'roger stone pressed damaging emails hillary_clinton wikileaks report',
#  'publix suspends contributions nra backed politician amid protests',
#  'twitter bots delivered donald_trump victory research paper says',
#  'bag wet socks apparently living white_house press briefing room',
#  'member far_right proud boys menaced twitter user doorstep',
#  'things the nra blamed the texas school_shooting',
#  'happens catholic hospital won try save',
#  'trump new executive_orders easier fire federal workers',
#  'monsanto bayer set merge care',
#  'joy watching harvey_weinstein perp walk',
#  'funniest_tweets women week',
#  'queer_eye star bobby berk gave desk makeover incredible',
#  'older gay_men try new gay slang hilarious video',
#  'rupaul_drag race teaching straight people queer culture',
#  'fish market buys freedom fred pound octopus',
#  'north_korea threatens trump summit warns nuclear showdown',
#  'investigation finds russian missile shot flight mh',
#  'north_korea demolishes tunnels nuclear test site reports',
#  'kim_jong un baited trump canceling north_korea summit',
#  'michelle_obama reveals cover upcoming memoir',
#  'late_night writer breathless royal_wedding recap need',
#  'morgan_freeman accused inappropriate behavior sexual_harassment',
#  'jets chairman christopher johnson won fine players anthem protests',
#  'andy_cohen taylor_swift katy_perry drama',
#  'infinity_war writers try clear marvel problematic timeline',
#  'david blaine chews glass lets james_corden puncture cheek',
#  'amy_poehler parks recreation revival amazing',
#  'colbert exposes biggest flaw trump latest conspiracy_theory',
#  'seth_meyers gives donald_trump valuable marketing advice',
#  'launches auto import probe china vows defend interests',
#  'women pulled stops land dream job',
#  'wife asked husband fenty highlighter got pack highlighters hairbrush',
#  'trump roasted rushing defend tomi_lahren ignoring real victims',
#  'trump abruptly cancels north_korea summit kim_jong un',
#  'devin_nunes linked winery faced suit alleged coke prostitute yacht party',
#  'immigrant children accuse border_patrol abuse neglect report shows',
#  'ireland historic vote legalizing abortion haunted trump brexit',
#  'trump lawyer attended doj meeting confidential fbi informant',
#  'senate advances court_pick said planned_parenthood kills females year',
#  'rudy_giuliani trump won interview mueller spygate report',
#  'kentucky attorney running judge dies day primary win',
#  'chrissy_teigen taunts donald_trump twitter blocking ruling',
#  'koch network going trump favorite congressmen',
#  'trump posthumously pardons boxer jack johnson',
#  'ellen tears ashton_kutcher donates million wildlife fund',
#  'ariana_grande reveals bee tattoo honor manchester attack',
#  'kim_kardashian wished kanye_west happy anniversary fine pretty cute',
#  'chris_hemsworth dances wrecking ball kids living_room',
#  'moses farrow defends woody_allen accuses mia farrow abuse',
#  'gwyneth_paltrow says brad_pitt threatened kill harvey_weinstein',
#  'stephen king reveals donald_trump blocked twitter',
#  'fans jessica walter addressed verbal harassment jeffrey tambor',
#  'jessica walter discusses jeffrey tambor alleged harassment male co_stars brush',
#  'harvey_weinstein expected turn to nypd sex crimes',
#  'samantha_bee torches ice let shut fk',
#  'scott_pruitt twice introduced anti_abortion bills giving men property rights fetuses',
#  'twitter critics mercilessly mock trump canceling summit kim',
#  'civil_rights groups rip senate bill revising sexual_harassment policy',
#  'alabama sues exclude undocumented_immigrants census count',
#  'cynthia_nixon vows fighting predictably losing party endorsement',
#  'white_house officials reportedly considered ignoring new climate research',
#  'read trump letter kim_jong un canceling north_korea summit',
#  'south_korea responds trump sudden cancellation kim_jong un summit',
#  'facebook new ad rules prove basically charge regulating elections',
#  'border agent fatally_shoots migrant woman texas',
#  'trump opens door gun industry sell firearms abroad',
#  'stormy_daniels day declared west hollywood adult star gets key city',
#  'going use self checkout machine you like',
#  'ways family road_trips easier parents ve',
#  'jake_tapper shreds donald_trump long list conspiracy_theories',
#  'new_york daily_news rips nfl anthem kneeling ban',
#  'judge ruled immigrant right hearing',
#  'house democrats offer internships students affected gun_violence',
#  'tig notaro tells ellen_degeneres sons passion trash',
#  'stormy_daniels thanks wonderful gay dads west hollywood hands keys city',
#  'believe queer_eye season drops month',
#  'gay man denied marriage license kim_davis loses bid unseat',
#  'anna kournikova dancing bouncing baby cutest thing',
#  'trump says nfl_players unwilling stand anthem maybe shouldn country',
#  'facebook accused reading texts accessing microphones lawsuit',
#  'self_driving uber fatal accident seconds react crash',
#  'amazon admits alexa device eavesdropped portland family',
#  'man discovers handgun impaled bumper car',
#  'rescue cat hilarious wide eyed expression scan confirms pregnant',
#  'weirdest promposals include teen faked birth',
#  'trump american far_right stoke hate canada',
#  'far_right anti establishment parties set form italy new government',
#  'sarah_silverman sees reason louis continue artist',
#  'southern baptist leader said abused women pray removed post',
#  'americans support sex_marriage',
#  'brynn cartelli youngest winner voice',
#  'betsy_devos stirs uproar saying schools ice undocumented kids',
#  'sandy_hook families fbi agent sue alex_jones defamation',
#  'high_school teacher defeats kentucky house majority leader gop_primary',
#  'lupe valdez makes_history texas winning democratic nod governor',
#  'report michael_cohen business partner cooperating prosecutors',
#  'brandi chastain totally agrees hall_fame plaque looks_like her',
#  'scientists turn dna technology to search loch ness monster',
#  'late_night writer vows red hats trump_supporters',
#  'julia_louis dreyfus receive mark twain prize american humor',
#  'michelle_obama shares intimate wedding photo tribute husband barack',
#  'spot trevor_noah black_panther daily host stealth cameo revealed',
#  'donald glover fans execute stunning coup donald_trump themed reddit forum',
#  'calls boycott restaurant duty cop allegedly assaults black women',
#  'survivor rwandan genocide country female neurosurgeon',
#  'stacey abrams wins democratic_primary georgia governor',
#  'trevor_noah reveals question ask donald_trump dared',
#  'michelle_obama reflects scary time princeton sweet throwback snap',
#  'reasons started conversation responsible finishing',
#  'lourdes leon gives major madonna vibes moody new ad_campaign pics',
#  'ways netflix tricks watching shows movies',
#  'brad_pitt ryan_reynolds demeaning thing exchange deadpool cameo',
#  'robert_de niro bans trump nobu restaurant',
#  'ariana_grande shuts fan blaming heartbreaking mac miller split',
#  'parents slam dogs scenes grooming children sexual_abuse',
#  'dave grohl wants apologize to world massive jerk trump',
#  'emilia clarke introduced prince_william pretty embarrassing way',
#  'sarah paulson takes impressions level tonight',
#  'ready party taken seriously',
#  'gina ortiz jones wins democratic runoff texas congressional race',
#  'fighter pilot amy mcgrath wins democratic_primary kentucky swing district',
#  'trump rallies conservatives promise abortion curbs',
#  'aclu suing strike ohio congressional map',
#  'latest school_shooting hasn stirred the gun debate',
#  'donald_trump tweet rescues roseanne family season_finale',
#  'ellen grills mark wahlberg shirtless instagram selfies',
#  'idris_elba star new hunchback notre_dame netflix',
#  'maryland police charge church leaders past abuse risk teen girls',
#  'nfl bans kneeling national_anthem',
#  'conan_brien muscles royal_wedding spoof ads',
#  'house_republicans report progress immigration deal',
#  'democrats weren invited review classified documents fbi informant',
#  'gop_candidate pointed gun teenager advances georgia governor primary runoff',
#  'walking definition entitled millennial swears an entitled millennial',
#  'democrats push included classified briefing fbi informant',
#  'machines don steal jobs increasingly rob our work humanity',
#  'trump praises tomi_lahren restaurant crowd tosses water insults',
#  'sarah sanders bothers called liar',
#  'trump blocking people twitter judge_rules',
#  'non christian militia won iraqi christians parliamentary seats christians want trump intervene',
#  'tulsi gabbard syria views cost support hawaii teachers union',
#  'jared_kushner received security clearance reports',
#  'arizona gop congressional_candidate compares abortion holocaust',
#  'gun reform advocate lucy mcbath heads runoff georgia house seat',
#  'star_wars burlesque storms west_coast sexy stormtroopers',
#  'establishment backed moderate wins heated democratic house primary texas',
#  'senators unveil bill crack sexual_harassment',
#  'trips new_york city long weekend',
#  'disney reveals opening seasons star_wars theme_park lands',
#  'latest entries the comedy wildlife photo awards cheer',
#  'bad lip_reading reveals said royal_wedding',
#  'australian archbishop convicted covering child sex_abuse',
#  'commander says iran people respond pompeo threats punch mouth',
#  'mark_zuckerberg extends facebook apology tour european gig',
#  'ariana_grande tweets message support manchester bombing anniversary',
#  'katy_perry says single american_idol',
#  'cops watch powerful monologue on racism',
#  'amazon selling cops facial recognition tool bad potentially racist',
#  'miley_cyrus comes like wrecking ball prank sleeping jimmy_kimmel',
#  'vanessa bayer feared porn stars skit donald_trump snl',
#  'adam_rippon wins dancing_stars destined',
#  'emilia clarke try imitate chewbacca',
#  'maddie poppe wins american_idol runner reveals dating',
#  'colbert resist turning trump nickname pee tape joke',
#  'seth_meyers forced tweak donald_trump latest twitter rant time',
#  'boy says teacher told fault police shoot him age',
#  'cops accused racism detaining black man vegetation',
#  'white cop shouts black suspect pretend like going shoot',
#  'florida police report dead standoff panama city apartment complex',
#  'donald glover board lando calrissian pansexuality solo',
#  'charlize_theron play megyn_kelly film roger_ailes',
#  'shoppers boycott publix store donations nra backed candidate',
#  'bill de_blasio tells nypd stop arresting people smoking pot street',
#  'dhs head says unaware intel russia interference boost trump',
#  'lawmaker introduces crowdfunding bill pay trump border_wall',
#  'gop lawmakers soon allowed review classified info russia_investigation',
#  'james_corden reveals worst the royal_wedding ceremony',
#  'ariana_grande reportedly dating snl star pete davidson',
#  'jim_carrey pens new pledge allegiance students bullet riddled schools',
#  'ellen gets david spade open dating younger women',
#  'ceasefire jimmy_kimmel shreds sean_hannity dummies fox_friends',
#  'spoof royal_wedding video sees ceremony taking different turn',
#  'georgia gop governor primary focuses guns immigration',
#  'glaad movie report_finds troubling drop lgbtq representation',
#  'sephora offers store beauty classes trans nonbinary community',
#  'georgia governor primary highlights competing visions democratic_party',
#  'california moves let schools co workers red flag dangerous gun_owners',
#  'talking grievance health_care outsider kentucky dem found inside track',
#  'problems commemorative trump kim_jong un coin',
#  'giuliani new stance russian collusion illegal',
#  'onion hilariously trolls michael_cohen cease desist note',
#  'democrats want boost school funding to address teacher walkouts',
#  'emails lawmakers shrug trump lax cellphone security',
#  'try stink bug flavored jelly bellys don',
#  'power outage triggers extreme zombie activity alert florida city',
#  'congress wall_street favor banks post record profits',
#  'white_house sinkhole probably metaphor',
#  'reporter shoved barred epa meeting water contaminants',
#  'garry kasparov donald_trump russian connections aeroflot',
#  'lonely planet european destinations aim overtourism',
#  'attorney aaron schlossberg insists anti spanish rant person',
#  'minutes reporter reveals trump chilling reason slamming press',
#  'trump reportedly rejects phone security measures inconvenient',
#  'federal_court sides transgender teen gavin grimm bathroom fight',
#  'ex trump adviser calls president claims informant spied campaign embarrassing',
#  'vietnam test happens abandons climate diplomacy',
#  'americans_think trump successfully draining swamp',
#  'msnbc host hugh hewitt suggests trench coat control gun_control',
#  'bishop michael curry harry_meghan love brought different worlds',
#  'sarah paulson unapologetic year age gap girlfriend holland taylor',
#  'texans sides gun debate agree on safe storage on support',
#  'family gay man found critically injured near amtrak route wants answers',
#  'caitlyn_jenner trump worst president lgbtq_rights',
#  'boy_scout allegedly booted store company won support homos',
#  'instagram adding mute button sake sanity',
#  'publix censors teen summa cum laude graduation cake',
#  'sexist passengers female pilot perfect_response',
#  'time takes_aim mcdonald walmart sexual_harassment complaints',
#  'venezuela socialist leader nicolas maduro elected amid allegations irregularities',
#  'iran says europe support nuclear_deal isn america withdrawal',
#  'far_right mob attacks year_old liberal greek mayor',
#  'shawn mendes khalid perform parkland survivors billboard_music awards',
#  'tamir_rice mother opening youth center honor son memory',
#  'judge_orders texas voter_registration easier updating dmv info',
#  'kelly_clarkson calls moments action honor of texas shooting_victims billboard awards',
#  'kendrick_lamar stops white fan rapping word onstage',
#  'gay man says pope_francis told god like loves you like that',
#  'unusual asteroid interstellar guest solar system',
#  'started suicide prevention site age going strong',
#  'roger stone says prepared conjured mueller indictment',
#  'hillary_clinton endorse andrew_cuomo election',
#  'supreme_court lot harder sue employer',
#  'blake farenthold hired illegally new lobbyist job',
#  'bill konigsberg explores new gay experience latest book',
#  'game shows biggest hurdles lgbtq athletes exist the field',
#  'chrissy_teigen gets_real life childbirth',
#  'suits creator pens heartfelt open_letter attending royal_wedding',
#  'movies coming netflix week',
#  'obamas coming netflix queue',
#  'sorry ben_affleck way justin_theroux giant rat tattoo',
#  'hillary_clinton tips russian hat trump yale commencement_speech',
#  'giuliani says mueller talk trump trump hears fbi source',
#  'democrats plan big anti corruption theme midterms',
#  'kelly_clarkson rejects moment silence calls change billboard_music awards',
#  'asked american public settle the internet dumbest debates',
#  'fox_news viewers don like lifelong republican robert_mueller',
#  'trump team moves lift ban extreme hunting tactics alaska',
#  'howard stern tells trump sexualized ivanka makes david_letterman cringe',
#  'supreme_court helping companies away sexual_harassment',
#  'deadpool steals spot box_office avengers_infinity war',
#  'westworld subtly tease baby theory',
#  'donald glover tells ellen circle star_wars moment his son',
#  'marvel exec tried stop jarring infinity_war death',
#  'jake_gyllenhaal set star villain spider_man sequel',
#  'janet_jackson black woman receive billboard icon award',
#  'isn pakistan bitch video captures driver racist rant',
#  'grey gardens ladies the unwitting godmothers reality_tv archetypes',
#  'year_old boy superhero alabama homeless population',
#  'john_oliver best time mocking the royal_wedding',
#  'john_oliver needles dangerously unregulated rehab industry',
#  'jemele hill honored nabj journalist year',
#  'french digital minister comes gay fight homophobia',
#  'belgian transgender ballet drama wins big cannes_film festival',
#  'year_old gay man proves old attend pride',
#  'super_pacs meddled west_virginia senate primary didn receive penny west virginians',
#  'airline passenger arrested_allegedly harassing woman peeing seat',
#  'mike pompeo promises crush iran achieve better deal',
#  'majestic islands europe tourists don_know',
#  'cuba confirms killed country deadliest plane_crash',
#  'china putting trade war hold treasury steve mnuchin says',
#  'trump economic adviser says amazon threats lane',
#  'dems trump admin find common ground helping victims myanmar genocide',
#  'giuliani says mueller wrap trump obstruction probe september report',
#  'german broadcaster criticized racist coverage royal_wedding',
#  'kathryn newton boldest teen tv ready grow',
#  'stephanie kelton biggest idea washington',
#  'texas gov campaign cancels shotgun giveaway santa fe school_shooting',
#  'tina_fey sarah_palin leads snl chorus lamenting trump',
#  'day american gushing snl goes smart aleck royal_wedding',
#  'starbucks says sit cafes buying',
#  'alec_baldwin trump faces ominous sopranos scenario snl finale',
#  'asia argento fiery speech closes cannes raped harvey_weinstein',
#  'tina_fey tries mean_girls musical snl',
#  'parents school_shooting victims decry moronic gop platitudes',
#  'trump real americans tough russia_probe',
#  'chrissy_teigen john_legend announce baby_boy adorable photo',
#  'texas lt gov dan patrick touts need arm teachers',
#  'david hogg calls media stop naming santa fe school shooter',
#  'trump sets showdown doj claims campaign surveillance',
#  'jim_carrey latest painting slams kent state goldilocks ar',
#  'oliver north blames school shootings ritalin',
#  'jimmy_kimmel tricks royal fans reviewing wedding the big day',
#  'jimmy_fallon reveals viewers biggest wedding fails',
#  'protesters throw fiesta razz lawyer ranted spanish speakers',
#  'watch amazon prime new week',
#  'ferrell molly shannon cover royal_wedding cord and tish',
#  'artist known cedric the entertainer arrived',
#  'mark kelly trump rolled nra guns parkland',
#  'gop_candidate set trust pays kids marrying white people',
#  'houston police_chief says sick inaction gun_control',
#  'history the national_anthem sports',
#  'bbc trolls president trump bigly huge royal_wedding crowd',
#  'victims the santa fe high_school shooting',
#  'ceo took pay cut employees year battling amazon',
#  'trump_jr met emissary gulf princes offering help with campaign report',
#  'trump misspells melania welcome home tweet twitter roars',
#  'jimmy_kimmel shreds cowardly trump lawmakers texas school_shooting',
#  'bill_maher reveals things don_know michael_cohen',
#  'watch hulu new week',
#  'students stage sit gun_control outside paul_ryan office arrested',
#  'trump knew scary appearance bill_gates daughter',
#  'ex russian spy sergei skripal discharged uk hospital poisoning incident',
#  'cuba plane_crash reportedly kills',
#  'trump reassures north_korea threatens total decimation deal',
#  'ariana_grande gives fans singing time surprise lives',
#  'cambridge_analytica files chapter bankruptcy facebook privacy row',
#  'santa fe high schoolers held gun_violence protest month shooting',
#  'michelle_wolf netflix trailer gives closer look new',
#  'jeff_sessions uses exceptional power immigration courts limit judges authority',
#  'gop_rep introduces bill demand white_house apologize mccain',
#  'colbert super graphic way describing deep mueller_probe goes',
#  'jack osbourne wife files divorce',
#  'meek_mill backs trump event prison reform',
#  'new trump rule cut federal funds clinics providing abortions',
#  'twitter_users joke trump wants prison reform headed',
#  'single chilean bishop offers resign country sex_abuse scandal',
#  'ariana_grande calls manchester attack worst humanity year_later',
#  'chrissy_teigen spills details new baby_boy love',
#  'alec_baldwin wife hilaria welcome baby_boy',
#  'kate_mckinnon breaks impression rudy_giuliani',
#  'smallville allison mack involved sex cult place',
#  'trump white_house kills yanny laurel debate ridiculous clip',
#  'jennifer_aniston play lesbian president netflix ladies',
#  'break book shadows the charmed reboot trailer',
#  'dave matthews band violinist boyd tinsley accused_sexual misconduct',
#  'people single book jimmy_kimmel',
#  'ellen_degeneres hilariously explains saved meghan_markle life',
#  'lawyer ranted spanish speakers faces office eviction disciplinary complaint',
#  'hannity flips mueller_probe direct threat american republic',
#  'democrats want answers global health security head sudden departure',
#  'gun_owners non gun_owners actually agree lot gun reforms',
#  'twitter_users pan ted_cruz tweets prayers santa fe school_shooting victims',
#  'states ban bump_stocks enforce law',
#  'liberal billionaire tom steyer base',
#  'sen dean heller campaign paid social_media influencer son',
#  'interior dept dodges watchdog questions zinke alaska senators',
#  'blake_lively teases ryan_reynolds hugh_jackman bromance',
#  'happytime murders adult themed movie puppets',
#  'photo daniel_radcliffe holding guns crazy slippers magical meme',
#  'bill_gates says trump didn_know difference hpv hiv',
#  'bachelorette bios are terrible',
#  'steven tyler admits hitting daughter liv famous pal watched',
#  'hospice overdosed patients hasten deaths health_care executive admits',
#  'kimmel brings house giving trump latest tweet new ending',
#  'wwf wrestler severely beaten outside california home',
#  'robert wilkie picked new va secretary surprise announcement',
#  'trump new domestic gag rule strip funds planned_parenthood',
#  'rudy_giuliani reverses trump team position says president obstruct justice',
#  'social anxiety doesn attention deserves',
#  'deadpool breaking box_office records',
#  'obamacare premiums way higher year didn be',
#  'comprehensive list don jr doesn_know infamous meeting',
#  'report manafort son law cuts plea deal cooperate government',
#  'trump briefly responds santa fe school_shooting pivoting',
#  'late_night writer shreds roseanne better racist',
#  'trump nasa chief apparently changed tune climate_change',
#  'freedom_caucus sinks key paul_ryan welfare reform agenda',
#  'transphobic congressional hopeful berates person inside public restroom',
#  'singer ryan amador says loverboy second coming',
#  'newest head cracker hear brainstorm green needle',
#  'meditation like human way clearing browser cache',
#  'funniest_tweets women week',
#  'italy looks befriend russia populist parties try to form government',
#  'business groups quietly killing bill bring sexual_abuse claims light',
#  'kushner family reportedly close getting bailout flagship tower',
#  'trump says ll charity royal_wedding ll',
#  'federal prosecutors trying turn trump_inauguration protesters felons',
#  'republican immigration fight derails food_stamp bill',
#  'retiring lawmakers added million campaign treasuries election',
#  'facing farm bill vote problems gop_leaders deal',
#  'methodists surprise gay minister world best pastor certificates theft diploma',
#  'china marks milestone quest space superpower',
#  'stephen_colbert wants mueller trump special anniversary gift',
#  'trump stormy_daniels disclosure leaves questions payments cohen',
#  'enjoy animated history tina_fey snl return',
#  'controversial way california schools handling students misbehavior',
#  'deaf activist points marvel diversity problem isn race',
#  'magnum trailer lots close shaves big mustache',
#  'gina haspel confirmed cia_director aid democrats',
#  'boulder city_council unanimously votes ban assault weapons high capacity magazines',
#  'chrissy_teigen john_legend welcome baby_boy',
#  'terrifying clip shows run tree thunderstorms',
#  'mitch_mcconnell taps anti_lgbtq bigot religious_freedom panel',
#  'seth_meyers gives donald_trump unexpected advice north_korea',
#  'devin_nunes fundraising fbi attacks tells potential donors trump says hero',
#  'mexican_president warns donald_trump ve_got st',
#  'fox_news female ceo named sexual_harassment complaints',
#  'battle save dying soil',
#  'latino man insulted starbucks barista writes slur cup',
#  'snl cast member claims trump faked bizarre phone rehearsals',
#  'jimmy_kimmel comes clean owe donald_trump apology',
#  'trevor_noah skewers betsy_devos fake profit university ad',
#  'serena_williams explains father didn walk her aisle',
#  'star_wars writer confirms donald glover character pansexual solo',
#  'medical professionals fact check grey_anatomy sex scenes',
#  'amy_schumer nails meghan_markle fairytale wedding actually sucks',
#  'michael keaton ends kent state commencement_speech batman',
#  'black profiled share story',
#  'black actresses cannes protest racism french film industry',
#  'michael_jordan denies rumors doesn date black women',
#  'scam pacs ripped conservatives pro police anti_abortion messages prosecutors',
#  'mtv suspends catfish probes nev schulman sexual_misconduct claims',
#  'trump ice increasingly arresting immigrants criminal convictions',
#  'special_counsel hits roger stone social_media advisor subpoenas',
#  'whitney_houston sexually abused dee dee warwick cannes documentary',
#  'patton_oswalt joker theory change watch dark_knight',
#  'josh holt american captive venezuela begs help in prison videos',
#  'obama photographer taunts donald_trump calling immigrants animals',
#  'backstreet boys release new song don breaking heart',
#  'prince knight puts gay inclusive twist traditional fairy tales',
#  'gay_conversion therapy survivor recalls month nightmare powerful video',
#  'gq expertly spoofs vanity_fair annual comedy issue cover',
#  'rudy_giuliani offers head spinning new defense trump',
#  'cynthia_nixon fix subway ads shred cuomo mta commuters rejoice',
#  'farm bill huge blow animals',
#  'emails interior expected learn public input bears ears review',
#  'whistleblower leaked michael_cohen financials potential cover report',
#  'kidnapper accused alligator hold man captive',
#  'miss america pageant headed women email scandal',
#  'north_korea threatens reconsider trump summit cancels south_korea talks',
#  'chemical_weapons likely syria watchdog finds',
#  'hundreds israel protest killings palestinians gaza border',
#  'researchers uncover secret pages diary anne frank',
#  'stephen piscotty returns bereavement hit mom tribute home run',
#  'senate intelligence_committee backs gina haspel lead cia',
#  'pennsylvania congressional delegation longer men',
#  'lando calrissian star_wars spinoff starring donald glover isn happening',
#  'fake donald_trump sean_hannity pillow talk late',
#  'rapper arrested disorderly conduct public drunkenness',
#  'conservatives cook farm bill gambit vote hardline immigration bill',
#  'novartis lawyer resigns michael_cohen deal',
#  'isn birth_control emoji',
#  'white_house eliminates cyber czar post appointee leaves',
#  'emily list backed lawyer wins democratic_primary pennsylvania swing district',
#  'robin_williams biographer tells sweet story comic store visit',
#  'republicans attacking nancy_pelosi non house races',
#  'empire military takes the gates of hell',
#  'longtime trump lawyer slams giuliani polarizing figure shouldn deal mueller',
#  'bet_awards nominations dj khaled screaming',
#  'beirut pride canceled organizer detained authorities',
#  'manhattan district attorney vows stop prosecuting minor marijuana cases',
#  'larry_nassar victims receive million michigan_state settlement',
#  'trump_jr left open possibility dad knew trump_tower meeting time',
#  'tom_cruise ankle break scene goes laughs mission impossible trailer',
#  'lives steven tyler',
#  'louisiana lawmakers approve restoring voting_rights people probation parole',
#  'thandie newton cannes dress celebration black star_wars characters',
#  'trump paid cohen financial disclosure confirms',
#  'american citizen freed egypt jail',
#  'fox_news said settle group discrimination lawsuits million',
#  'tweeters hard pass rnc dinner photo donald_trump prize',
#  'facebook removed million fake accounts quarter',
#  'pink badass response troll said looked old',
#  'san_francisco adopt software app to help automatically clear old marijuana convictions',
#  'younger star sutton foster returns broadway roots new_album',
#  'senate hot seat scott_pruitt dodges questions mounting scandals',
#  'idaho inches closer electing nation native_american governor',
#  'pro abortion rights progressive wins nebraska democratic house primary',
#  'ryan_reynolds crashes colbert deadpool crack rated trump jokes',
#  'ryan_reynolds genuinely hurt trading playground insults josh brolin',
#  'terry crews movement emancipation proclamation',
#  'christopher wylie warns senators cambridge_analytica steve_bannon want culture war',
#  'san_francisco ban single use plastic straws',
#  'john travolta sure isn greased lightning cannes dance floor',
#  'senate panel releases details trump_tower meeting probe',
#  'report contradicts michigan governor candidate test animal treatment',
#  'republican welfare plan keeping wages',
#  'years_ago today michael_jackson moonwalked tv time',
#  'hilary_duff publicly drags neighbor keeps night',
#  'jim_carrey jabs stooge donald_trump north_korea new artwork',
#  'trump failure report stormy_daniels payoff referred to prosecutors',
#  'bohemian rhapsody trailer slammed ignoring freddie mercury sexuality',
#  'fergie rides new_york city subway the',
#  'pauley perrette responds cbs statement multiple assaults claim',
#  'trump refers immigrants animals',
#  'angry white dude rant people speaking spanish nyc goes_viral',
#  'democratic lawmaker gives scott_pruitt brutal reality_check senate hearing',
#  'trump picks mitch_mcconnell brother law gordon hartogensis lead pension agency',
#  'fbi search cia leak suspect turned photos of sex assault unconscious friend',
#  'trump pick census role says citizenship question political',
#  'jared_kushner agitated infuriated meeting russians focused adoptions',
#  'sarah_huckabee sanders unusually honest seth_meyers spoof briefing',
#  'kris_jenner assistant according_to kris_jenner',
#  'chris_pratt bryce dallas howard need service raptor flight',
#  'surprise shows coming netflix',
#  'rex_tillerson warns grads living alternative realities',
#  'democrats force vote net_neutrality rules',
#  'larry_nassar blames victims says victimized newly released videos',
#  'video_shows year_old autism taunted abused bus_driver',
#  'yanny laurel real answer',
#  'populist cleric muqtada al sadr likely win iraq parliamentary election',
#  'palestinian family says month_old died israeli tear gas gaza protest crackdown graphic',
#  'sichuan airlines co pilot sucked halfway broken windshield',
#  'retail group spoofs ferris bueller ad bashing donald_trump tariffs',
#  'washington officials state cover postage mail ballots year',
#  'people think civil politics opponents disagree',
#  'cambridge_analytica investigated justice_department fbi report',
#  'adorable video kids shows activism literally easy as pie',
#  'white_house blames deadly gaza violence hamas propaganda',
#  'gina haspel says cia shouldn conducted interrogation program',
#  'tesla autopilot engaged horrific mph crash driver tells police',
#  'selling planes iran saved lives exiting nuclear_deal harder',
#  'speech fallen officers trump touts policies rails sanctuary_cities',
#  'eric greitens team pushes inquiry prosecutor charged',
#  'elizabeth_warren pledges big money turn heat gerrymandering',
#  'gay_conversion therapy illegal maryland',
#  'fox_news judicial analyst defends timeline mueller_probe',
#  'stephen_colbert uses oprah analogy ridicule trump hannity bedtime chats',
#  'trailer the queen biopic bohemian rhapsody',
#  'seth_meyers shreds trump scandals drain swamp devoid meaning',
#  'jim_carrey new blood dripping portrait takes_aim national disgrace nra',
#  'scott_pruitt got security day epa new documents',
#  'rabid anti_muslim ex fbi agent training texas police',
#  'khloe_kardashian explains chose true daughter',
#  'game gina haspel track confirmed cia_director',
#  'topher grace hated preparing play david_duke spike_lee blackkklansman',
#  'sarah paulson deeply nerdy rihanna filming ocean',
#  'blake farenthold says won repay sexual_harassment settlement',
#  'spike_lee gets major love blackkklansman cannes rips trump',
#  'twitter_users hilariously skewered terrible stock photos jobs',
#  'ivanka jared jerusalem visit slammed twitter',
#  'adam_rippon honors mom stunning dancing with stars performance',
#  'tomi_lahren hits genealogist researched family misses point',
#  'georgia gop gov candidate wants round immigrants deportation bus',
#  'daddy little ghoul new_york daily_news rips ivanka_trump embassy opening',
#  'death keeven robinson black louisiana man police custody ruled homicide',
#  'colbert savages peace treaty barbie collusion ken embassy opening',
#  'twitter_users roast experts twice salary saved',
#  'woman challenging white male dominated tech industry the inside',
#  'keith richards explains got rid trump nearly years_ago',
#  'damon wayans completely rips clayne crawford twitter outburst',
#  'like han solo scoundrel solo star_wars story forgot',
#  'pauley perrette reveals multiple physical assaults ncis exit',
#  'ariana_grande jimmy_fallon sweet music cardboard instruments',
#  'trevor_noah don watch fox_news',
#  'seattle passes controversial new tax city biggest companies combat housing crisis',
#  'uber ends forced arbitration individual cases sexual_assault harassment',
#  'meet openly trans man graduate spelman college',
#  'canceled renewed tv_shows',
#  'teen claims visited heaven near death experience',
#  'willow smith tells shocked jada_pinkett smith self harmed preteen',
#  'new farming technique drastically water catching',
#  'kristen_stewart ditches heels cannes red_carpet defying flats rule',
#  'david duchovny addresses nuttiest fan theories the files',
#  'judge overturns california right die law',
#  'debbie_wasserman schultz nra shy terrorist organization',
#  'cardi responds girls song controversy apologizes to lgbtq_community',
#  'emotional support spider goat banned american_airlines',
#  'people agree voice saying yanny laurel',
#  'the_world deepest ocean trench safe plastic bags',
#  'open new embassy jerusalem nations prefer to wait peace deal',
#  'israeli forces kill dozens palestinians protests intensify embassy jerusalem',
#  'facebook suspends apps amid data misuse investigation',
#  'senator harry_reid diagnosed pancreatic_cancer',
#  'new federal regulator takes_aim facebook',
#  'apology white_house dying mccain dig',
#  'south_dakota congressional_candidate said terrorist attack help win primary',
#  'ryan coogler love women wakanda spinoff',
#  'coffee shop refuses serve man racist rant woman niqab',
#  'supreme_court invalidates federal ban sports gambling',
#  'huge congrats fox_news getting guest journos to peddle bret baier book',
#  'movies coming netflix week',
#  'prosecutor drops felony invasion privacy charge missouri gov eric greitens',
#  'israeli soccer_team beitar jerusalem add trump to',
#  'vermont lawmakers pass gender_neutral bathroom_bill send powerful_message',
#  'rita ora girls deemed tone_deaf harmful lgbtq pop artists',
#  'embassy jerusalem opens doors protests rage nearby',
#  'john_oliver reveals secret figuring going trump mind',
#  'super mario looks_like hair people freaked',
#  'channing_tatum mother_day message ex jenna_dewan love',
#  'star justin hartley says sexually_harassed fan',
#  'lois lanes pay_tribute late margot kidder led the way',
#  'onion story blake farenthold gets new job lobbying congress',
#  'iowa gov says slowing signing country strictest abortion ban',
#  'cannes_film festival promises greater gender_equality times activism',
#  'childish gambino america hits spot week',
#  'jon_stewart dave_chappelle perform standup tour',
#  'coach tells hurt ufc fighter continue says',
#  'melania_trump recovering kidney surgery',
#  'jon tester vulnerable senate democrat isn voting like',
#  'taraji_henson kelvin hayden engaged mother_day',
#  'young dolph gives baristas fired playing song paid',
#  'come bed explores intimacy experiencing sexual_assault',
#  'trump changed burger order little healthier',
#  'michael avenatti posts photos cohen qatari investor accused of bribery',
#  'donald_trump lashes called leaks twitter_users pounce',
#  'trump orders help chinese phone maker china approves money for trump project',
#  'hundreds protest cities poor_people campaign',
#  'rihanna best response asked attending the royal_wedding',
#  'lifetime harry_meghan royal romance good',
#  'game_changing westworld brain capsule reveal beginning',
#  'margot kidder actress played lois lane superman dead',
#  'tomi_lahren gets owned genealogist remarks low skilled immigrants',
#  'harrison_ford crashes new han solo actor interview life',
#  'kylie_jenner ex bodyguard tim chung denies actually stormi father',
#  'seann william scott replaces clayne crawford renewed lethal weapon',
#  'zach woods officially mvp silicon_valley',
#  'ryan_reynolds went south_korean singing disguised unicorn',
#  'billie lourd honors having tough mother_day photo carrie_fisher',
#  'pink asks year_old concertgoer sing blown away',
#  'pastor thinks jews going hell speaks jerusalem embassy opening',
#  'chili hit data breach credit debit card information compromised',
#  'trump called waffle_house hero james shaw jr thank disarming shooter',
#  'fox_news host trump fulfilled biblical prophecy moving embassy jerusalem',
#  'keyless cars killed dozen people report',
#  'rare conjoined fawns scientists double',
#  'killed dozens injured indonesia church bombings',
#  'iran president says country remain nuclear_deal',
#  'lindsey_graham trump officials owe mccain apology disgusting insult',
#  'amy_schumer goes girl raunch on saturday_night live',
#  'americans iran_deal depends ask',
#  'like attending nra convention the fake_news media',
#  'possible autopilot use probed tesla crashes mph',
#  'michael bloomberg slams epidemic political lies danger democracy',
#  'massive cookout thrown park cops called black family bbq',
#  'michael che stepmom melissa_mccarthy embarrasses weekend_update',
#  'handmaid_tale meets sex city funny terrifying snl spoof',
#  'video_shows security guard choking black teen accused shoplifting new_york',
#  'trump praises late mom mother_day skips mention melania',
#  'trump promises help chinese company violated sanctions iran',
#  'sarah_huckabee sanders berated staffers mccain leak',
#  'parkland dad pointed message oliver north nra new president',
#  'john_bolton trump sanctions european companies possible iran',
#  'michelle_obama shares_adorable throwback pic touching mother_day tribute',
#  'tomi_lahren claims low skilled immigrants country based',
#  'stalking cheetahs oblivious family scare exit car safari park',
#  'der spiegel cover portrays trump finger flipping europe',
#  'italian tribunal lifts ban silvio berlusconi holding public office',
#  'north_korea plans dismantle nuclear test sites end',
#  'knife attack paris leaves_dead injured',
#  'watch hulu new week',
#  'watch amazon prime new week',
#  'late unveils spoof line trump themed mother_day gifts',
#  'brooklyn nine finds new tv home stars fans rejoice',
#  'smith shares inspiring tale fresh prince of bel air',
#  'lgbtq groups new oklahoma adoption law discriminatory',
#  'mueller reportedly investigating foreign linked donors trump_inauguration fund',
#  'stephen_colbert mocks proposal hang trump pence portraits post offices',
#  'boston dynamics robot dog available sale soon',
#  'southern baptist leader apologizes past hurtful comments women',
#  'george soros progressive groups spend millions to elect reformist prosecutors',
#  'incredible photos world need protect',
#  'avengers_infinity war directors reveal died survived screen',
#  'uber silences women sexual assaults',
#  'marvel introduces official chinese superheroes',
#  'big_bang theory pays sweetest tribute stephen_hawking deleted scene',
#  'bill_maher shreds donald_trump likens mob boss',
#  'amazon holding seattle hostage',
#  'jim_carrey taunts psycho mike_pence biting new portrait',
#  'chadwick boseman lauds student protesters howard commencement_speech',
#  'want understand straight incels talk_to gay',
#  'gathering military spouses puts white white_house',
#  'game host prematurely congratulates contestant mortifying fail',
#  'women cannes red_carpet to protest inequality film',
#  'men charged hate_crimes beating gay_couple',
#  'trump_administration rolls protections transgender prison inmates',
#  'michael_cohen reportedly paid advise time_warner merger',
#  'metoo statehouse men gone the harassment culture isn',
#  'austin bars police_department selling old guns public',
#  'masterclass parody dubbing movie swear words falcon great',
#  'democrats don regret making easier confirm judges',
#  'donald glover fan cast solo',
#  'seth_meyers skewers idea donald_trump winning the nobel_peace prize',
#  'chuck_schumer turns melania_trump best campaign donald_trump',
#  'trailer axed tremors reboot kevin bacon offers glimpse',
#  'frightened rabbit singer scott hutchison dead',
#  'suspect custody shooting california high_school injured',
#  'colbert names official job unqualified white_house staffer',
#  'trevor_noah gives michael_cohen biting new breaking_bad themed nickname',
#  'moral atlanta robbin season the snatching',
#  'pose character finds community new_york ball scene',
#  'accused golden_state killer faces additional murder counts',
#  'jimmy_kimmel roasts donald_trump spoof nobel_peace prize ceremony video',
#  'sarah_palin says mccain regrets perpetual gut punch',
#  'killed australia worst mass_shooting',
#  'deadpool david_beckham hug feud deadpool teaser',
#  'opposition gives trump hot lawyer',
#  'dogs help prepare babies cats help prepare you for teenagers',
#  'john_mccain wife rebukes white_house official mocked dying',
#  'rupaul_drag race queens turn time cher rusical',
#  'trump_administration axes funding nasa system monitors greenhouse gases',
#  'police search suspected serial_killer dumping ground',
#  'kevin mchale think zero surprise came',
#  'pennsylvania house race embodies fight the future the democratic_party',
#  'hackers tried breach tennessee county server election_night report',
#  'gay teacher suspended showing photo future wife sues texas district',
#  'school_district allegedly lgbtq student read bible punishment',
#  'trump launched war christmas people having',
#  'elle fanning makes punk music debut talk_to girls parties',
#  'jake_tapper rips retired gen tom mcinerney insulting john_mccain',
#  'fox cuts_ties guest cited john_mccain defend torture',
#  'trump attempt example immigrant caravan backfiring',
#  'celebrities reading weird texts moms mother_day treat',
#  'stormy_daniels actress doppelganger',
#  'oldest known man america says smokes dozen cigars day',
#  'tweeters erupt trump aide cruel taunt john_mccain dying',
#  'mark_hamill weds sheldon amy big_bang theory fans geek',
#  'epa hid scott_pruitt dinner climate denier accused child sex_abuse',
#  'meghan mccain takes swipe white_house aide mocks father cancer',
#  'need talk white people calling cops people color',
#  'woman calls police black family bbqing lake oakland',
#  'tim allen man standing coming year canceled',
#  'joe_biden berates white_house joke john_mccain health',
#  'michael avenatti warns michael_cohen documents release',
#  'fox_friends host mocks ny_times isis coverage unaware beat fox story',
#  'congressional_candidate says fk nra new tv ad',
#  'tsa tells sikh man remove turban finds canadian politician',
#  'john_stamos shows new baby bob saget lori loughlin',
#  'woman sent texts date says love excessive thing',
#  'little extortion guy figured stormy_daniels old lawyer actually_pretty',
#  'katie porter survived domestic_abuse her campaign',
#  'trump plan prescription drug prices looks_like promised',
#  'giuliani says cohen spoke trump big dollar clients',
#  'russian troll facebook ads barely targeted swing states',
#  'ted_cruz staff usaid met group called apartheid called injustice',
#  'plan family_vacation according_to travel experts',
#  'boston dynamics created running robot coming',
#  'cornell student delivers thesis underwear professor questions outfit',
#  'funniest_tweets women week',
#  'israel reportedly fires dozens rockets syria',
#  'israel launches airstrikes syria iranian attacks',
#  'right die advocate david goodall ends life listening to ode to joy',
#  'americans held north_korea return united_states',
#  'dozens dead torrential rains cause dam burst kenya',
#  'spotify stops promoting kelly music sexual_assault allegations',
#  'trump kim_jong un likely meet month singapore',
#  'homeland_security denies report secretary drafted resignation letter',
#  'cecile richards running office future never',
#  'aclu says kris_kobach giving incorrect information voter_registration',
#  'ryan_murphy donate pose profits to trans queer groups',
#  'rick morty renewed whopping episodes',
#  'ryan_reynolds warns deadpool fans don fking word',
#  'nurse charged death ex trump adviser mcmaster father',
#  'trump going indiana to slam joe donnelly don_expect democrat to hit',
#  'rick moranis appear netflix sctv documentary',
#  'facing challenge right gop_lawmaker pulls support immigration bill',
#  'john_mccain urges senate reject gina haspel nomination cia',
#  'months later rio cops supposedly closing marielle franco killers',
#  'queer_eye star tan france doesn poorly dressed fans style advice',
#  'women coming eric schneiderman job',
#  'man pleads_guilty bacon vandalism tennessee islamic center',
#  'mike_pence robert_mueller russia_probe wrap',
#  'ready older kevin justin hartley is',
#  'net_neutrality rules end june fcc says',
#  'democratic candidate maryland governor dies cardiac arrest',
#  'officer puts man chokehold outside north_carolina waffle_house',
#  'trevor_noah don blankenship nutty concession speech',
#  'brooklyn nine canceled twitter mourns',
#  'quiet struggle chuck_schumer the left',
#  'gabby douglas utterly unrecognizable undercover boss',
#  'girls accused plotting kill classmate',
#  'curious case the russian oligarch national_park service latrines',
#  'watch rudy_giuliani completely torpedo rudy_giuliani trump arguments',
#  'fox business guest defends torture worked john_mccain',
#  'tom abby queer_eye remarried',
#  'pakistan passes historic transgender rights bill',
#  'phil mudd flips questions cia torture didn america it',
#  'facebook ads house dems russia ran election',
#  'kim_kardashian says tristan thompson blocked defended khloe',
#  'kenan thompson says ll stay snl long as possible',
#  'jennifer_garner mom problems hilarious rap video ellen',
#  'dick_cheney suggests restarting torture interrogation program',
#  'greta gerwig loudly critiqued feel pretty moviegoer live tweeted',
#  'devin_nunes gets meeting secret russia_probe source threatening doj',
#  'queer_eye star karamo brown engaged director ian jordan',
#  'jet launched apple store incredible deals',
#  'tom hardy completely unrecognizable al capone new movie',
#  'woman alleges rapper young lo raped trapped chris_brown home',
#  'republicans fill court seat denied obama years',
#  'man wanted white_supremacists kill black neighbor burn cross yard fbi',
#  'trump announces details meeting kim_jong un',
#  'samantha_bee delivers blistering takedown ny ag eric schneiderman',
#  'jim_carrey scathing portrait trump joker nightmares',
#  'michelle_wolf renews hostilities sarah_huckabee sanders',
#  'fans erupt fate elias koteas olinsky chicago',
#  'people street apologize old teachers on jimmy_kimmel live',
#  'stephen_colbert porn_star math michael_cohen donald_trump',
#  'pollen bomb allergy sufferer worst_nightmare',
#  'jennifer_lopez dances danceable songs tonight',
#  'white yale student calls cops black schoolmate napping dorm common room',
#  'rudy_giuliani quits law firm wild week interviews',
#  'teddy geiger makes public appearance coming transgender',
#  'ariana_grande mac miller reportedly break',
#  'avengers leaks support year_old interview marvel directors',
#  'good excuse racist impact michigan medicaid proposal',
#  'fcc complaints minutes interview stormy_daniels',
#  'americans jailed korea home trump situation worse',
#  'alex strangelove gay teen comedy doesn turn away sex',
#  'woman says took home kittens find bobcats',
#  'video bear eating ice_cream dairy queen leads charges zoo owners',
#  'iranian lawmakers mock trump mental capacity burn flag pulls nuke deal',
#  'europeans scramble save iran_deal trump withdraws',
#  'north_korea releases american political prisoners advance historic summit',
#  'establishment gop notches win ohio primary vacant house seat',
#  'eric schneiderman praised movement days abuse_allegations emerged',
#  'trevor_noah unloads supposed advocate women eric schneiderman',
#  'year comey_firing scope mueller_probe expands lawyer shell company',
#  'trump inspired businessman wins indiana gop senate primary',
#  'gop rival says tammy baldwin team terrorists silence on trump cia pick',
#  'jobs program people work',
#  'jim parsons yes need queer stories onscreen',
#  'trump accuser wins democratic nomination ohio legislature',
#  'mastermind waterboarded cia information share gina haspel',
#  'conservative senate democrat backs trump agenda defeats progressive challenger',
#  'taylor_swift ve katy_perry kimye feud lives',
#  'kim_kardashian history fashion council influencer award',
#  'nbc says believes matt_lauer accusers months long investigation',
#  'russians ability change voter data didn report says',
#  'elizabeth_warren pick wins ohio democratic gubernatorial primary',
#  'kkk leader found_guilty firing gun charlottesville rally',
#  'protesters decrying torture dragged gina haspel senate hearing',
#  'hired firm linked michael_cohen to inside scoop trump',
#  'rnc selling sickening donald_trump themed merch ahead mother_day',
#  'don blankenship defeat relief families upper big branch miners',
#  'colbert shreds trump broken promises talking',
#  'new ambassador germany offends hosts hours day',
#  'jordan_peele new nightmare coming year',
#  'backstreet boys dressed the spice girls larger life',
#  'seth_meyers decodes teen slang reveals giuliani means',
#  'look orlando interim pulse_nightclub memorial',
#  'trevor_noah turns donald_trump knives comment reggae magic',
#  'senators force vote ultimately reverse fcc restore net_neutrality',
#  'ny legislature plan place consider replacements eric schneiderman',
#  'ambassadors write letter opposing gina haspel nomination',
#  'california authority says state new homes solar powered',
#  'ny governor assigns investigation eric schneiderman abuse_allegations',
#  'refugee caravan scapegoat trump border crackdown',
#  'pennsylvania latest state fund urban gun_violence prevention',
#  'denver mayor son caught_tape berating cop faggot',
#  'progressive prosecutors win primaries north_carolina',
#  'novartis money paid trump lawyer',
#  'hypocrisy melania_trump online safety booklet pointed page page',
#  'uninsured rate worsening years obamacare gains',
#  'bernie_sanders plan revive labor unions',
#  'jim_carrey bestows scott_pruitt savage nickname latest painting',
#  'male allies abusers',
#  'mormon church end century long relationship boy_scouts',
#  'snack addiction killing orangutans',
#  'trump pick cia_director won torture program morally wrong',
#  'anderson_cooper burns moronic michael_cohen russia cash claims',
#  'pinata maker apologizes hanging black figures likeness lynchings',
#  'caliphate trump planet ruins',
#  'gay_marriage opponent ousted gop incumbent north_carolina',
#  'espn eliminates public editor role calling outdated',
#  'michael_cohen selling access trump says group paid shell company',
#  'mitch_mcconnell mocks blankenship twitter big cloud cocaine',
#  'ex convict don blankenship loses patrick morrisey west_virginia senate_race',
#  'ohio voters pass gerrymandering reform measure',
#  'trump iran_deal exit win russia',
#  'cynthia_nixon wants new_yorkers vote homo for the cuomo',
#  'ontario canada issued non binary birth certificate',
#  'child sexual predator roman polanski calls movement total hypocrisy',
#  'america producer reveals new details childish gambino viral_video',
#  'terry crews black men aren allowed victims dead',
#  'donald glover america eyes jim crow historian',
#  'fox_news judicial analyst issues dark warning trump michael_cohen',
#  'black women bishops making history predominantly white church',
#  'geena davis th husband reza jarrahy divorcing',
#  'pauley perrette abby heart wrenching farewell ncis',
#  'lethal weapon fires clayne crawford character gets shot',
#  'selena_gomez pokes_fun met_gala spray tan mishap',
#  'protest leader nikol pashinian elected prime_minister armenia',
#  'kim_jong un secretly met xi jinping',
#  'netanyahu bombastic iran claims found perfect audience trump',
#  'netanyahu chef blasted serving japan prime_minister dessert shoe',
#  'world_leaders condemn trump withdrawing iran_nuclear deal',
#  'senate_republicans shun don blankenship day west_virginia primary',
#  'new_york harvey_weinstein probe set continue despite attorney_general exit',
#  'trump announce break iran_nuclear deal',
#  'politicians schneiderman resign physical abuse_allegations',
#  'joe_scarborough trump legal strategy like monkey throwing poo wall',
#  'kirsten_dunst jesse plemons welcome baby_boy',
#  'holy matrimony proposal met_gala',
#  'nordstrom rack president apologizes store accuses black men theft',
#  'giuliani says trump lawyer michael_cohen incriminating information president',
#  'lena waithe stuns met_gala queer superhero',
#  'kelly accusers ask permission to use bathroom',
#  'trump reportedly tells macron pulling iran_nuclear deal',
#  'deportation crackdown hurting immigrant victims crime',
#  'seth_meyers says michael_cohen tried to apologize air to trump',
#  'blessing best met_gala tweets',
#  'farm bill cut food_stamps friendly farmers',
#  'know iran_nuclear deal',
#  'derby day bet wins thrilled texas woman million',
#  'democratic meddling west_virginia things watch election day',
#  'cynthia erivo met_gala nails featured sistine chapel painting black women',
#  'keanu reeves alex winter coming bill ted years',
#  'solange durag true mvp the met_gala',
#  'house republican threatens subpoena trump doj official census citizenship request',
#  'jimmy_kimmel tries hard sense rudy latest trump defense gives',
#  'religious imagery stitched the met_gala',
#  'bob marley granddaughter says cops racially profiled checking airbnb',
#  'melania_trump called anti bullying campaign ignores husband actions',
#  'trevor_noah watching rudy_giuliani like smoking weed tv',
#  'janet_jackson receive icon award billboard_music awards',
#  'white_house prepares send congress billion spending cuts package',
#  'jared_kushner backed bill shot federal prison reform',
#  'george_zimmerman accused stalking detective working trayvon_martin film',
#  'passengers lashing scott_pruitt justify class travel new epa memo says',
#  'trump country house district key progressive battleground',
#  'mike_pence brother wins primary race vice_president house seat',
#  'marines investigating avowed white_supremacist active duty',
#  'trump violate iran_nuclear deal vows to reimpose sanctions',
#  'olympic_committee ignored sexual_abuse complaints taekwondo stars lawsuit',
#  'blake_lively brought family met_gala noticing',
#  'bill_reilly offers stand to sarah sanders to handle line reporters',
#  'catholic priest praised best_dressed dude met_gala living life',
#  'jimmy_kimmel says hide seek genius dog heal nation',
#  'bank_america appears flip firearm promise loan to remington',
#  'gentleman caller presents queer icons ve_seen',
#  'eric schneiderman con man',
#  'christiane amanpour heading new pbs replacing charlie rose',
#  'madonna teases new song surprise met_gala performance',
#  'iron_man black widow captain_america thor hawkeye got matching tattoos',
#  'michael_cohen accepted firm tied russian oligarch reports',
#  'stephen_colbert hits rudy_giuliani brutal fact check',
#  'katy_perry sends olive branch taylor_swift world rejoices',
#  'jada_pinkett smith gets_real dating smith married',
#  'whoops mark_hamill spilled beans major cameo han solo movie',
#  'shawn mendes sweetly attended hailey baldwin gown met_gala',
#  'orrin hatch sorry suggested trump allowed john_mccain funeral',
#  'seth_meyers perfect line confront donald_trump lies',
#  'police hope use dna to catch zodiac killer',
#  'lili reinhart cole sprouse finally couple debut met_gala',
#  'sweetbitter captures grit glamour the restaurant world',
#  'mitch_mcconnell bends rules confirm trump judges',
#  'ryan_zinke tale fish',
#  'ny attorney_general eric schneiderman resigns amid abuse_allegations',
#  'sanctuary_cities working trump era surprising cost',
#  'shepard_smith trump pulled iran_deal decision violate',
#  'stormy_daniels finds crunchy new way chip away trump',
#  'rainbow mountains peru look_like straight dr seuss book',
#  ...]

# %% [markdown]
# ### Stemming / Lemmatization & Part-of-Speech filtering

# %% [markdown]
# ***Note***: *if you encounter an error regarding a missing spacy model, head to your CLI and enter*
# ````bash
#     python -m spacy download en_core_web_md
# ````

# %%
def lemmatize_texts(texts, 
                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'], 
                    forbidden_postags=[], 
                    as_sentence=False, 
                    get_postags=False, 
                    spacy_model=None):
    """Lemmatize a list of texts.
    
            Please refer to https://spacy.io/api/annotation for details on the allowed
        POS tags.
        @params:
            - texts_in: a list of texts, where each texts is a string
            - allowed_postags: a list of part of speech tags, in the spacy fashion
            - as_sentence: a boolean indicating whether the output should be a list of sentences instead of a list of word lists
        @return:
            - A list of texts where each entry is a list of words list or a list of sentences
        """
    texts_out = []
    
    if allowed_postags and forbidden_postags:
        raise ValueError("Can't specify both allowed and forbidden postags")

    if forbidden_postags:
        allowed_postags = list(set(POS_map.keys()).difference(set(forbidden_postags)))

    if not spacy_model:
        print("Loading spacy model")
        spacy_model = spacy.load('en_core_web_md')

    print("Beginning lemmatization process")
    total_steps = len(texts)

    docs = spacy_model.pipe(texts)

    for i, doc in tqdm(enumerate(docs), total=total_steps):
        if get_postags:
            texts_out.append(["_".join([token.lemma_, token.pos_]) for token in doc if token.pos_ in allowed_postags])
        else:
            texts_out.append(
                [token.lemma_ for token in doc if token.pos_ in allowed_postags])
    
    if as_sentence:
        texts_out = [" ".join(text) for text in texts_out]
        
    return texts_out

# %%
l_texts = lemmatize_texts(texts[:1000],
                allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV', 'X', 'PROPN'], 
                get_postags=False)
# Out:
# Loading spacy model
#   0%|                                                                                         | 0/1000 [00:00<?, ?it/s]
# Beginning lemmatization process
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 529.20it/s]

# %%
str1 = ""
for text in l_texts:
    str1 += " ".join(text)
    str1 += " /£$/ " 
l_texts = str1.split(" /£$/ ")
l_texts
# Out:
# ['mass_shooting texas week tv',
#  'smith join diplo nicky jam world_cup official song',
#  'hugh grant marrie time age',
#  'jim_carrey blast castrato adam schiff democrats new artwork',
#  'julianna margulies use donald_trump poop bag pick dog',
#  'morgan_freeman devastate sexual_harassment claim undermine legacy',
#  'donald_trump lovin new mcdonald jingle tonight bit',
#  'watch amazon prime new week',
#  'mike myers reveal fourth austin power film',
#  'watch hulu new week',
#  'justin_timberlake visit texas school_shoote victim',
#  'south_korean president meet north_korea kim_jong un talk trump summit',
#  'way life risk remote oyster grow region call robot',
#  'trump crackdown immigrant parent put kid strain system',
#  'trump son concern fbi obtain wiretap putin ally meet trump_jr',
#  'trump love vladimir_putin',
#  'booyah obama photographer hilariously troll trump spy claim',
#  'ireland vote repeal abortion amendment landslide referendum',
#  'ryan_zinke look reel critic grand pivot conservation',
#  'trump scottish golf resort pay woman significantly man report',
#  'weird father_day gift dad doesn_know want',
#  'twitter universally entertaining',
#  'mystery wolf animal reportedly shoot montana baffle wildlife official',
#  'open talk trump cancel summit',
#  'man detonate bomb indian restaurant toronto authority',
#  'thousand travel home ireland vote abortion access',
#  'irish voter set liberalize abortion law landslide exit poll signal',
#  'warrior coach steve kerr call nfl ban protest fake patriotism',
#  'historic victory barbado elect female prime_minister',
#  'police kill black americans moment colin_kaepernick protest',
#  'jack johnson pardon taboo sex criminalize',
#  'bet chairman ceo debra lee step',
#  'rachel dolezal face felony charge welfare fraud',
#  'bishop michael curry join christian march white_house reclaim jesus',
#  'kanye_west spend photo whitney_houston bathroom album cover',
#  'morgan_freeman drop marketing campaign harassment accusation',
#  'chinese exclusion act help understand immigration politic today',
#  'trump new maga theme swimwear sink twitter',
#  'seth_meyer funny regret trump cancel north_korea summit',
#  'colbert want turn nyc subway ride new terrible punishment',
#  'man face charge pull knife stun gun muslim students mcdonald',
#  'jimmy_kimmel know iran supreme leader watch tom jerry',
#  'people injure indiana school_shoote',
#  'people rattle nigerian man looks_like chadwick boseman',
#  'david cross prove terrible apologizing',
#  'sesame_street creator sue maker upcome adult theme puppet film',
#  'miss sad death avengers_infinity war',
#  'george_takei accuser walk story drug sexual_assault',
#  'samantha_bee parent think america basically war zone',
#  'pete davidson say mental_illness doesn ruin romance',
#  'james_corden adam_levine pull carpool_karaoke',
#  'emilia clarke dish final game_throne scene',
#  'hollywood doesn need difficult man great tv',
#  'harvey_weinstein accuser think arrest',
#  'harvey_weinstein turn police allege sex crime',
#  'john_mayer weird new low budget video meme worthy masterpiece',
#  'boba fett get star_war movie',
#  'trump suggest north_korea summit happen',
#  'roger stone press damaging email hillary_clinton wikileaks report',
#  'publix suspend contribution nra back politician protest',
#  'twitter bot deliver donald_trump victory research paper say',
#  'bag wet sock apparently live white_house press briefing room',
#  'member proud boy menace twitter user doorstep',
#  'thing nra blame texas school_shoote',
#  'happen catholic hospital win try save',
#  'trump new executive_order easy fire federal worker',
#  'monsanto bayer set merge care',
#  'joy watch harvey_weinstein perp walk',
#  'funniest_tweet woman week',
#  'queer_eye star bobby berk give desk makeover incredible',
#  'old gay_man try new gay slang hilarious video',
#  'rupaul_drag race teach straight people queer culture',
#  'fish market buy freedom fred pound octopus',
#  'north_korea threaten trump summit warn nuclear showdown',
#  'investigation find russian missile shoot flight mh',
#  'north_korea demolish tunnel nuclear test site report',
#  'kim_jong un bait trump cancel north_korea summit',
#  'michelle_obama reveal cover upcoming memoir',
#  'late_night writer breathless royal_wedde recap need',
#  'morgan_freeman accuse inappropriate behavior sexual_harassment',
#  'jet chairman christopher johnson win fine player anthem protest',
#  'andy_cohen taylor_swift katy_perry drama',
#  'infinity_war writer try clear marvel problematic timeline',
#  'david blaine chew glass let james_corden puncture cheek',
#  'amy_poehler park recreation revival amazing',
#  'colbert expose big flaw trump late conspiracy_theory',
#  'seth_meyer give donald_trump valuable marketing advice',
#  'launch auto import probe china vow defend interest',
#  'woman pull stop land dream job',
#  'wife ask husband fenty highlighter get pack highlighter hairbrush',
#  'trump roasted rushing defend tomi_lahren ignore real victim',
#  'trump abruptly cancel north_korea summit un',
#  'devin_nune link winery face suit allege coke prostitute yacht party',
#  'immigrant child accuse border_patrol abuse neglect report show',
#  'ireland historic vote legalize abortion haunt trump brexit',
#  'trump lawyer attend doj meeting confidential fbi informant',
#  'senate advance court_pick say planned_parenthood kill female year',
#  'rudy_giuliani trump win interview mueller spygate report',
#  'kentucky attorney run judge die day primary win',
#  'chrissy_teigen taunt donald_trump twitter block ruling',
#  'koch network go trump favorite congressman',
#  'trump posthumously pardon boxer jack johnson',
#  'ellen tear ashton_kutcher donate wildlife fund',
#  'ariana_grande reveal bee tattoo honor manchester attack',
#  'kim_kardashian wish kanye_west happy anniversary fine pretty cute',
#  'chris_hemsworth dance wreck ball kid living_room',
#  'moses farrow defend woody_allen accuse mia farrow abuse',
#  'gwyneth_paltrow say brad_pitt threaten kill harvey_weinstein',
#  'stephen king reveal donald_trump block twitter',
#  'fan jessica walter address verbal harassment jeffrey tambor',
#  'jessica walter discuss jeffrey tambor allege harassment male co_star brush',
#  'harvey_weinstein expect turn nypd sex crime',
#  'samantha_bee torch ice let shut',
#  'scott_pruitt twice introduce anti_abortion bill give man property right fetus',
#  'twitter critic mercilessly mock trump cancel summit kim',
#  'civil_right group rip senate bill revise sexual_harassment policy',
#  'alabama sue exclude undocumented_immigrant census count',
#  'cynthia_nixon vow fight predictably lose party endorsement',
#  'white_house official reportedly consider ignore new climate research',
#  'read trump letter kim_jong un cancel north_korea summit',
#  'south_korea respond trump sudden cancellation kim_jong un summit',
#  'facebook new ad rule prove basically charge regulate election',
#  'border agent fatally_shoot migrant woman texas',
#  'trump open door gun industry sell firearm abroad',
#  'stormy_daniel day declare west hollywood adult star get key city',
#  'go use self checkout machine like',
#  'way family road_trip easy parent ve',
#  'jake_tapper shred donald_trump long list conspiracy_theorie',
#  'new_york daily_new rip nfl anthem kneel ban',
#  'judge rule immigrant right hearing',
#  'house democrats offer internship student affect gun_violence',
#  'tig notaro tell ellen_degenere son passion trash',
#  'stormy_daniel thank wonderful gay dad west hollywood hand key city',
#  'believe season drop month',
#  'gay man deny marriage license lose bid unseat',
#  'anna kournikova dance bounce baby cut thing',
#  'trump say nfl_player unwilling stand anthem maybe shouldn country',
#  'facebook accuse read text access microphone lawsuit',
#  'self_drive uber fatal accident second react crash',
#  'amazon admit alexa device eavesdrop portland family',
#  'man discover handgun impale bumper car',
#  'rescue cat hilarious wide eyed expression scan confirm pregnant',
#  'weird promposal include teen fake birth',
#  'trump american far_right stoke hate canada',
#  'anti establishment party set form italy new government',
#  'sarah_silverman see reason louis continue artist',
#  'southern baptist leader say abuse woman pray remove post',
#  'americans support',
#  'brynn cartelli young winner voice',
#  'betsy_devo stir uproar say school ice undocumented kid',
#  'sandy_hook family fbi agent sue alex_jone defamation',
#  'high_school teacher defeat kentucky house majority leader gop_primary',
#  'lupe valdez makes_history texas win democratic nod governor',
#  'report michael_cohen business partner cooperate prosecutor',
#  'brandi chastain totally agree hall_fame plaque',
#  'scientist turn dna technology search loch ness monster',
#  'late_night writer vow red hat trump_supporter',
#  'julia_louis dreyfus receive mark twain prize american humor',
#  'michelle_obama share intimate wedding photo tribute husband barack',
#  'spot trevor_noah daily host stealth cameo reveal',
#  'donald glover fan execute stunning coup donald_trump theme reddit forum',
#  'call boycott restaurant duty cop allegedly assault black woman',
#  'survivor rwandan genocide country female neurosurgeon',
#  'stacey abrams win democratic_primary georgia governor',
#  'trevor_noah reveal question ask donald_trump dare',
#  'michelle_obama reflect scary time princeton sweet throwback snap',
#  'reason start conversation responsible finish',
#  'lourdes leon give major madonna vibe moody new ad_campaign pic',
#  'way netflix trick watch show movie',
#  'brad_pitt ryan_reynold demean thing exchange deadpool cameo',
#  'robert_de niro ban trump nobu restaurant',
#  'ariana_grande shut fan blame heartbreaking mac miller split',
#  'parent slam dog scene groom child sexual_abuse',
#  'dave grohl want apologize world massive jerk trump',
#  'emilia clarke introduce prince_william pretty embarrassing way',
#  'sarah paulson take impression level tonight',
#  'ready party take seriously',
#  'gina ortiz jones win democratic runoff texas congressional race',
#  'fighter pilot amy mcgrath win democratic_primary kentucky swing district',
#  'trump rally conservative promise abortion curb',
#  'aclu sue strike ohio congressional map',
#  'late school_shoote hasn stir gun debate',
#  'donald_trump tweet rescue roseanne family season_finale',
#  'ellen grills mark wahlberg shirtless instagram selfie',
#  'idris_elba star new hunchback notre_dame netflix',
#  'maryland police charge church leader abuse risk teen girl',
#  'nfl ban kneel national_anthem',
#  'conan_brien muscle royal_wedde spoof ad',
#  'house_republicans report progress immigration deal',
#  'democrats invite review classify document fbi informant',
#  'gop_candidate pointed gun teenager advance georgia governor primary runoff',
#  'walk definition entitle millennial swear entitled millennial',
#  'democrats push include classified briefing fbi informant',
#  'machine steal job increasingly rob work humanity',
#  'trump praise tomi_lahren restaurant crowd toss water insult',
#  'sarah sanders bother call liar',
#  'trump block people twitter judge_rule',
#  'non christian militia win iraqi christians parliamentary seat christian want trump intervene',
#  'tulsi gabbard syria view cost support hawaii teachers union',
#  'jared_kushner receive security clearance report',
#  'arizona gop congressional_candidate compare abortion holocaust',
#  'gun reform advocate lucy mcbath head runoff georgia house seat',
#  'star_war burlesque storm west_coast sexy stormtrooper',
#  'establishment back moderate win heat democratic house primary texas',
#  'senator unveil bill crack sexual_harassment',
#  'trip new_york city long weekend',
#  'disney reveal open season star_war theme_park land',
#  'late entry comedy wildlife photo award cheer',
#  'bad lip_reading reveal say royal_wedde',
#  'australian archbishop convict cover child sex_abuse',
#  'commander say iran people respond pompeo threat punch mouth',
#  'mark_zuckerberg extend facebook apology tour european gig',
#  'ariana_grande tweet message support manchester bombing anniversary',
#  'katy_perry say single american_idol',
#  'cop watch powerful monologue racism',
#  'amazon sell cop facial recognition tool bad potentially racist',
#  'miley_cyru come wreck ball prank sleep jimmy_kimmel',
#  'vanessa bayer fear porn star skit donald_trump snl',
#  'adam_rippon win dancing_star destine',
#  'emilia clarke try imitate chewbacca',
#  'maddie poppe win american_idol runner reveal date',
#  'colbert resist turn trump nickname pee tape joke',
#  'seth_meyer force tweak donald_trump late twitter rant time',
#  'boy say teacher tell fault police shoot age',
#  'cop accuse racism detain black man vegetation',
#  'white cop shout black suspect pretend go shoot',
#  'florida police report dead standoff panama city apartment complex',
#  'donald glover board lando calrissian pansexuality solo',
#  'charlize_theron play megyn_kelly film roger_aile',
#  'shopper boycott publix store donation nra back candidate',
#  'bill de_blasio tell nypd stop arrest people smoke pot street',
#  'dhs head say unaware intel russia interference boost trump',
#  'lawmaker introduce crowdfunding bill pay trump border_wall',
#  'gop lawmaker soon allow review classify info russia_investigation',
#  'james_corden reveal bad royal_wedde ceremony',
#  'ariana_grande reportedly date snl star pete davidson',
#  'jim_carrey pen new pledge allegiance student bullet riddled school',
#  'ellen get david spade open date young woman',
#  'ceasefire jimmy_kimmel shred sean_hannity dummy fox_friend',
#  'spoof royal_wedde video see ceremony take different turn',
#  'georgia gop governor primary focus gun immigration',
#  'glaad movie report_find troubling drop lgbtq representation',
#  'sephora offer store beauty class trans nonbinary community',
#  'georgia governor primary highlight compete vision democratic_party',
#  'california move let school co worker red flag dangerous gun_owner',
#  'talk grievance health_care outsider kentucky dem find track',
#  'problem commemorative trump kim_jong un coin',
#  'giuliani new stance russian collusion illegal',
#  'onion hilariously troll michael_cohen desist note',
#  'democrats want boost school funding address teacher walkout',
#  'email lawmaker shrug trump lax cellphone security',
#  'try stink bug flavor jelly bellys don',
#  'power outage trigger extreme zombie activity alert florida city',
#  'congress wall_street favor bank post record profit',
#  'white_house sinkhole probably metaphor',
#  'reporter shove barred epa meeting water contaminant',
#  'garry kasparov donald_trump russian connection aeroflot',
#  'lonely planet european destination aim overtourism',
#  'attorney aaron schlossberg insist anti spanish rant person',
#  'minute reporter reveal trump chilling reason slam press',
#  'trump reportedly reject phone security measure inconvenient',
#  'federal_court side transgender teen gavin grimm bathroom fight',
#  'ex trump adviser call president claim informant spy campaign embarrassing',
#  'vietnam test happen abandon climate diplomacy',
#  'americans_think trump successfully drain swamp',
#  'msnbc host hugh hewitt suggest trench coat control gun_control',
#  'bishop michael curry harry_meghan love bring different world',
#  'sarah paulson unapologetic year age gap girlfriend holland taylor',
#  'texans side gun debate agree safe storage support',
#  'family gay man find critically injure amtrak route want answer',
#  'caitlyn_jenner trump bad president lgbtq_right',
#  'boy_scout allegedly boot store company win support homo',
#  'instagram add mute button sake sanity',
#  'publix censor teen summa cum laude graduation cake',
#  'sexist passenger female pilot perfect_response',
#  'time takes_aim mcdonald walmart sexual_harassment complaint',
#  'venezuela socialist leader nicolas maduro elect allegation irregularity',
#  'iran say europe support nuclear_deal isn america withdrawal',
#  'mob attack liberal greek mayor',
#  'shawn mendes khalid perform parkland survivor billboard_music award',
#  'tamir_rice mother open youth center honor son memory',
#  'judge_order texas voter_registration easier update dmv info',
#  'kelly_clarkson call moment action honor texas shooting_victims billboard award',
#  'kendrick_lamar stop white fan rap word onstage',
#  'gay man say pope_francis tell god love',
#  'unusual asteroid interstellar guest solar system',
#  'start suicide prevention site age go strong',
#  'roger stone say prepare conjure mueller indictment',
#  'hillary_clinton endorse andrew_cuomo election',
#  'supreme_court lot hard sue employer',
#  'blake farenthold hire illegally new lobbyist job',
#  'bill konigsberg explore new gay experience late book',
#  'game show big hurdle lgbtq athlete exist field',
#  'chrissy_teigen gets_real life childbirth',
#  'suit creator pen heartfelt open_letter attend royal_wedde',
#  'movie come netflix week',
#  'obamas come netflix queue',
#  'sorry ben_affleck way justin_theroux giant rat tattoo',
#  'hillary_clinton tip russian hat trump yale commencement_speech',
#  'giuliani say mueller talk trump trump hear fbi source',
#  'democrats plan big anti corruption theme midterm',
#  'kelly_clarkson reject moment silence call change billboard_music award',
#  'ask american public settle internet dumb debate',
#  'fox_new viewer don lifelong republican robert_mueller',
#  'trump team move lift ban extreme hunting tactic alaska',
#  'howard stern tell trump sexualize ivanka make david_letterman cringe',
#  'supreme_court help company away sexual_harassment',
#  'deadpool steal spot box_office avengers_infinity war',
#  'westworld subtly tease baby theory',
#  'donald glover tell ellen circle star_war moment son',
#  'marvel exec try stop jar infinity_war death',
#  'jake_gyllenhaal set star villain spider_man sequel',
#  'janet_jackson black woman receive billboard icon award',
#  'isn pakistan bitch video capture driver racist rant',
#  'grey garden lady unwitting godmother reality_tv archetype',
#  'boy superhero alabama homeless population',
#  'john_oliver good time mock royal_wedding',
#  'john_oliver needle dangerously unregulated rehab industry',
#  'jemele hill honor nabj journalist year',
#  'french digital minister come gay fight homophobia',
#  'belgian transgender ballet drama win big cannes_film festival',
#  'gay man prove old attend pride',
#  'super_pacs meddle west_virginia senate primary didn receive penny west virginians',
#  'airline passenger arrested_allegedly harass woman pee seat',
#  'mike pompeo promise crush iran achieve well deal',
#  'majestic island europe tourist don_know',
#  'cuba confirm kill country deadly plane_crash',
#  'china put trade war hold treasury steve mnuchin say',
#  'trump economic adviser say amazon threats lane',
#  'dems trump admin find common ground help victim myanmar genocide',
#  'giuliani say mueller wrap trump obstruction probe september report',
#  'german broadcaster criticize racist coverage royal_wedde',
#  'kathryn newton bold teen tv ready grow',
#  'stephanie kelton big idea washington',
#  'texas gov campaign cancel shotgun giveaway santa fe school_shoote',
#  'tina_fey sarah_palin lead snl chorus lament trump',
#  'day american gush snl go smart aleck royal_wedde',
#  'starbucks say sit cafe buy',
#  'alec_baldwin trump face ominous sopranos scenario snl finale',
#  'asia argento fiery speech close cannes rape harvey_weinstein',
#  'tina_fey try mean_girls musical snl',
#  'parent school_shoote victim decry moronic gop platitude',
#  'real americans tough russia_probe',
#  'chrissy_teigen john_legend announce baby_boy adorable photo',
#  'texas lt gov dan patrick tout need arm teacher',
#  'david hogg call medium stop name santa fe school shooter',
#  'trump set showdown doj claim campaign surveillance',
#  'jim_carrey late painting slam kent state goldilocks ar',
#  'oliver north blame school shooting ritalin',
#  'jimmy_kimmel trick royal fan review wedding big day',
#  'jimmy_fallon reveal viewer big wedding fail',
#  'protester throw fiesta razz lawyer rant spanish speaker',
#  'watch amazon prime new week',
#  'ferrell molly shannon cover royal_wedde cord tish',
#  'artist know cedric entertainer arrive',
#  'mark kelly trump roll nra gun parkland',
#  'gop_candidate set trust pay kid marry white people',
#  'houston police_chief say sick inaction gun_control',
#  'history national_anthem sport',
#  'bbc trolls president trump bigly huge royal_wedde crowd',
#  'victim santa fe high_school shoot',
#  'ceo take pay cut employee year battle amazon',
#  'trump_jr meet emissary gulf prince offer help campaign report',
#  'trump misspell melania welcome home tweet twitter roar',
#  'jimmy_kimmel shred cowardly trump lawmaker texas school_shoote',
#  'bill_maher reveal thing don_know michael_cohen',
#  'watch hulu new week',
#  'student stage sit paul_ryan office arrest',
#  'trump know scary appearance bill_gate daughter',
#  'ex russian spy sergei skripal discharge uk hospital poisoning incident',
#  'cuba plane_crash reportedly kill',
#  'trump reassure north_korea threaten total decimation deal',
#  'ariana_grande give fan singe time surprise live',
#  'cambridge_analytica file chapter bankruptcy facebook privacy row',
#  'santa fe high schooler hold gun_violence protest month shoot',
#  'michelle_wolf netflix trailer give close look new',
#  'jeff_session use exceptional power immigration court limit judge authority',
#  'gop_rep introduce bill demand white_house apologize mccain',
#  'colbert super graphic way describe deep mueller_probe go',
#  'jack osbourne wife file divorce',
#  'meek_mill back trump event prison reform',
#  'new trump rule cut federal fund clinic provide abortion',
#  'twitter_users joke trump want prison reform head',
#  'single chilean bishop offer resign country sex_abuse scandal',
#  'ariana_grande call manchester attack bad humanity year_later',
#  'chrissy_teigen spill detail new baby_boy love',
#  'alec_baldwin wife hilaria welcome',
#  'kate_mckinnon break impression rudy_giuliani',
#  'smallville allison mack involve sex cult place',
#  'trump white_house kill yanny laurel debate ridiculous clip',
#  'jennifer_aniston play lesbian president netflix lady',
#  'break book shadow charmed reboot trailer',
#  'dave matthews band violinist boyd tinsley accused_sexual misconduct',
#  'people single book jimmy_kimmel',
#  'ellen_degenere hilariously explain save meghan_markle life',
#  'lawyer rant spanish speaker face office eviction disciplinary complaint',
#  'hannity flip mueller_probe direct threat american republic',
#  'democrats want answer global health security head sudden departure',
#  'gun_owner non gun_owner actually agree lot gun reform',
#  'twitter_users pan ted_cruz tweet prayer santa fe school_shoote victim',
#  'state ban bump_stock enforce law',
#  'liberal billionaire tom steyer base',
#  'sen dean heller campaign pay social_media influencer son',
#  'interior dept dodge watchdog question zinke alaska senator',
#  'blake_lively tease ryan_reynolds hugh_jackman bromance',
#  'happytime murder adult theme movie puppet',
#  'photo daniel_radcliffe hold gun crazy slipper magical meme',
#  'bill_gate say trump didn_know difference hpv hiv',
#  'bachelorette bio terrible',
#  'steven tyler admit hit daughter liv famous pal watch',
#  'hospice overdose patient hasten death health_care executive admit',
#  'kimmel bring house give trump late tweet new ending',
#  'wwf wrestler severely beat california home',
#  'robert wilkie pick new va secretary surprise announcement',
#  'trump new domestic gag rule strip fund planned_parenthood',
#  'rudy_giuliani reverse trump team position say president obstruct justice',
#  'social anxiety doesn attention deserve',
#  'deadpool break box_office record',
#  'obamacare premium way high year didn',
#  'comprehensive list don jr doesn_know infamous meeting',
#  'report manafort son law cut plea deal cooperate government',
#  'trump briefly respond santa fe school_shooting pivoting',
#  'late_night writer shred roseanne well racist',
#  'trump nasa chief apparently change tune',
#  'freedom_caucus sink key paul_ryan welfare reform agenda',
#  'transphobic congressional hopeful berate person public restroom',
#  'singer ryan amador say loverboy second come',
#  'new head cracker hear brainstorm green needle',
#  'meditation human way clear browser cache',
#  'funniest_tweet woman week',
#  'italy look befriend russia populist party try form government',
#  'business group quietly kill bill bring sexual_abuse claim light',
#  'kushner family reportedly close get bailout flagship tower',
#  'trump say charity royal_wedde',
#  'federal prosecutor try turn trump_inauguration protester felon',
#  'republican immigration fight derail food_stamp bill',
#  'retire lawmaker add campaign treasury election',
#  'face farm bill vote problem gop_leader deal',
#  'methodist surprise gay minister world good pastor certificate theft diploma',
#  'china mark milestone quest space superpower',
#  'stephen_colbert want mueller trump special anniversary gift',
#  'trump stormy_daniel disclosure leave question payment cohen',
#  'enjoy animate history tina_fey snl return',
#  'controversial way california school handle student misbehavior',
#  'deaf activist point marvel diversity problem isn race',
#  'magnum trailer lot close shave big mustache',
#  'gina haspel confirm cia_director aid democrats',
#  'boulder city_council unanimously vote ban assault weapon high capacity magazine',
#  'chrissy_teigen john_legend welcome',
#  'terrifying clip show run tree thunderstorm',
#  'mitch_mcconnell tap anti_lgbtq bigot religious_freedom panel',
#  'seth_meyer give donald_trump unexpected advice',
#  'devin_nunes fundraising fbi attack tell potential donor trump say hero',
#  'mexican_president warn donald_trump ve_got st',
#  'fox_news female ceo name sexual_harassment complaint',
#  'battle save die soil',
#  'latino man insult starbucks barista write slur cup',
#  'snl cast member claim trump fake bizarre phone rehearsal',
#  'jimmy_kimmel come clean donald_trump apology',
#  'skewer betsy_devo fake profit university ad',
#  'serena_williams explain father didn walk aisle',
#  'star_war writer confirm donald glover character pansexual solo',
#  'medical professional fact check grey_anatomy sex scene',
#  'amy_schumer nails meghan_markle fairytale wedding actually suck',
#  'michael keaton end kent state commencement_speech batman',
#  'black profile share story',
#  'black actress cannes protest racism french film industry',
#  'michael_jordan deny rumor doesn date black woman',
#  'scam pacs rip conservative pro police anti_abortion message prosecutor',
#  'mtv suspend catfish probe nev schulman sexual_misconduct claim',
#  'trump ice increasingly arrest immigrant criminal conviction',
#  'special_counsel hit roger stone social_media advisor subpoena',
#  'whitney_houston sexually abuse dee dee warwick cannes documentary',
#  'patton_oswalt joker theory change watch dark_knight',
#  'josh holt american captive venezuela beg help prison video',
#  'obama photographer taunt donald_trump call immigrant animal',
#  'backstreet boy release new song don break heart',
#  'prince knight put gay inclusive twist traditional fairy tale',
#  'gay_conversion therapy survivor recall month nightmare powerful video',
#  'gq expertly spoofs vanity_fair annual comedy issue cover',
#  'rudy_giuliani offer head spin new defense trump',
#  'cynthia_nixon fix subway ad shre cuomo mta commuter rejoice',
#  'farm bill huge blow animal',
#  'email interior expect learn public input bear ear review',
#  'whistleblower leak michael_cohen financial potential cover report',
#  'kidnapper accuse alligator hold man captive',
#  'miss america pageant head woman email scandal',
#  'north_korea reconsider trump summit cancel south_korea talk',
#  'chemical_weapon likely syria watchdog find',
#  'hundred israel protest killing palestinians gaza border',
#  'researcher uncover secret page diary anne frank',
#  'stephen piscotty return bereavement hit mom tribute home run',
#  'senate intelligence_committee back gina haspel lead cia',
#  'pennsylvania congressional delegation long man',
#  'lando calrissian star_war spinoff star donald glover isn happen',
#  'fake donald_trump sean_hannity pillow talk late',
#  'rapper arrest disorderly conduct public drunkenness',
#  'conservative cook farm bill gambit vote hardline immigration bill',
#  'novartis lawyer resign michael_cohen deal',
#  'isn birth_control emoji',
#  'white_house eliminate cyber czar post appointee leave',
#  'emily list back lawyer win democratic_primary pennsylvania swing district',
#  'robin_william biographer tell sweet story comic store visit',
#  'republican attack nancy_pelosi non house race',
#  'empire military take gate hell',
#  'longtime trump lawyer slam giuliani polarizing figure shouldn deal mueller',
#  'bet_award nomination dj khaled scream',
#  'beirut pride cancel organizer detain authority',
#  'manhattan district attorney vow stop prosecute minor marijuana case',
#  'larry_nassar victim receive michigan_state settlement',
#  'trump_jr leave open possibility dad know trump_tower meeting time',
#  'ankle break scene go laugh mission impossible trailer',
#  'live steven tyler',
#  'louisiana lawmaker approve restore voting_right people probation parole',
#  'thandie newton cannes dress celebration black star_war character',
#  'trump pay cohen financial disclosure confirm',
#  'american citizen free egypt jail',
#  'fox_new say settle group discrimination lawsuit',
#  'tweeter hard pass rnc dinner photo donald_trump prize',
#  'facebook remove fake account quarter',
#  'pink badass response troll say look old',
#  'san_francisco adopt software app help automatically clear old marijuana conviction',
#  'young star sutton foster return broadway root new_album',
#  'senate hot seat scott_pruitt dodge question mount scandal',
#  'idaho inch close elect nation native_american governor',
#  'pro abortion right progressive win nebraska democratic house primary',
#  'ryan_reynolds crash colbert deadpool crack rate trump joke',
#  'ryan_reynold genuinely hurt trading playground insult josh brolin',
#  'terry crews movement emancipation proclamation',
#  'christopher wylie warn senator cambridge_analytica steve_bannon want culture war',
#  'san_francisco ban single use plastic straw',
#  'john travolta sure isn grease lightning cannes dance floor',
#  'senate panel release detail trump_tow meeting probe',
#  'report contradict michigan governor candidate test animal treatment',
#  'republican welfare plan keep wage',
#  'years_ago today michael_jackson moonwalke tv time',
#  'hilary_duff publicly drag neighbor keep night',
#  'jim_carrey jabs stooge donald_trump north_korea new artwork',
#  'trump failure report stormy_daniel payoff refer prosecutor',
#  'bohemian rhapsody trailer slam ignore freddie mercury sexuality',
#  'fergie ride new_york city subway',
#  'pauley perrette respond cbs statement multiple assault claim',
#  'trump refer immigrant animal',
#  'angry white dude rant people speak spanish nyc goes_viral',
#  'democratic lawmaker give scott_pruitt brutal reality_check senate hearing',
#  'trump pick mitch_mcconnell brother law gordon hartogensis lead pension agency',
#  'fbi search cia leak suspect turn photo sex assault unconscious friend',
#  'trump pick census role say citizenship question political',
#  'jared_kushner agitate infuriate meet russians focus adoption',
#  'sarah_huckabee sander unusually honest seth_meyers spoof briefing',
#  'kris_jenner assistant according_to kris_jenner',
#  'chris_pratt bryce dallas howard need service raptor flight',
#  'surprise show come netflix',
#  'rex_tillerson warn grad live alternative reality',
#  'democrats force vote net_neutrality rule',
#  'larry_nassar blame victim say victimize newly release video',
#  'video_show autism taunt abuse',
#  'yanny laurel real answer',
#  'populist cleric muqtada al sadr likely win iraq parliamentary election',
#  'palestinian family say month_old die israeli tear gas gaza protest crackdown graphic',
#  'sichuan airlines co pilot suck halfway break windshield',
#  'retail group spoofs ferris bueller ad bash donald_trump tariff',
#  'washington official state cover postage mail ballot year',
#  'people think civil politic opponent disagree',
#  'cambridge_analytica investigate justice_department fbi report',
#  'adorable video kid show activism literally easy pie',
#  'white_house blame deadly gaza violence hamas propaganda',
#  'gina haspel say cia shouldn conduct interrogation program',
#  'tesla autopilot engage horrific mph crash driver tell police',
#  'sell plane iran save life exit nuclear_deal hard',
#  'speech fall officer trump touts policy rail sanctuary_citie',
#  'eric greitens team push inquiry prosecutor charge',
#  'elizabeth_warren pledge big money turn heat gerrymandering',
#  'gay_conversion therapy illegal maryland',
#  'fox_news judicial analyst defend timeline mueller_probe',
#  'stephen_colbert use oprah analogy ridicule trump hannity bedtime chat',
#  'trailer queen biopic bohemian rhapsody',
#  'seth_meyer shred trump scandal drain swamp devoid meaning',
#  'jim_carrey new blood dripping portrait takes_aim national disgrace nra',
#  'scott_pruitt get security day epa new document',
#  'rabid anti_muslim ex fbi agent training texas police',
#  'khloe_kardashian explain choose true daughter',
#  'game gina haspel track confirm cia_director',
#  'topher grace hate prepare play david_duke spike_lee blackkklansman',
#  'sarah paulson deeply nerdy rihanna film ocean',
#  'blake farenthold say win repay sexual_harassment settlement',
#  'spike_lee get major love blackkklansman cannes rip trump',
#  'twitter_user hilariously skewer terrible stock photo job',
#  'ivanka jared jerusalem visit slam twitter',
#  'adam_rippon honor mom stunning dancing star performance',
#  'tomi_lahren hit genealogist research family miss point',
#  'georgia gop gov candidate want round immigrant deportation bus',
#  'daddy little ghoul new_york daily_new rip ivanka_trump embassy opening',
#  'death keeven robinson black louisiana man police custody rule homicide',
#  'colbert savage peace treaty barbie collusion ken embassy opening',
#  'twitter_user roast expert twice salary save',
#  'woman challenge white male dominate tech industry inside',
#  'keith richards explain rid trump nearly years_ago',
#  'damon wayans completely rip clayne crawford twitter outburst',
#  'han solo scoundrel solo star_war story forget',
#  'pauley perrette reveal multiple physical assault ncis exit',
#  'ariana_grande jimmy_fallon sweet music cardboard instrument',
#  'trevor_noah don watch fox_new',
#  'seattle pass controversial new tax city big company combat housing crisis',
#  'uber end force arbitration individual case sexual_assault harassment',
#  'meet openly trans man graduate spelman college',
#  'cancel renew tv_show',
#  'teen claim visit heaven death experience',
#  'willow smith tell shock jada_pinkett smith self harm preteen',
#  'new farming technique drastically water catching',
#  'kristen_stewart ditch heel cannes red_carpet defy flat rule',
#  'david duchovny address nutty fan theory file',
#  'judge overturn california right die law',
#  'debbie_wasserman schultz nra shy terrorist organization',
#  'cardi respond girl song controversy apologize lgbtq_community',
#  'emotional support spider goat ban american_airline',
#  'people agree voice say yanny laurel',
#  'the_world deep ocean trench safe plastic bag',
#  'open new embassy jerusalem nation prefer wait peace deal',
#  'israeli force kill dozen palestinians protest intensify embassy jerusalem',
#  'facebook suspend app data misuse investigation',
#  'senator harry_reid diagnose pancreatic_cancer',
#  'new federal regulator takes_aim facebook',
#  'apology white_house die mccain dig',
#  'south_dakota congressional_candidate say terrorist attack help win primary',
#  'ryan coogler love woman wakanda spinoff',
#  'coffee shop refuse serve man racist rant woman niqab',
#  'supreme_court invalidate federal ban sport gambling',
#  'huge congrat fox_new get guest journo peddle bret baier book',
#  'movie come netflix week',
#  'prosecutor drop felony invasion privacy charge missouri gov eric greitens',
#  'israeli soccer_team beitar jerusalem add trump',
#  'vermont lawmaker pass gender_neutral bathroom_bill send powerful_message',
#  'rita ora girl deem tone_deaf harmful lgbtq pop artist',
#  'embassy jerusalem open door protest rage nearby',
#  'john_oliver reveal secret figure go trump mind',
#  'super mario looks_like hair people freak',
#  'channing_tatum mother_day message jenna_dewan love',
#  'star justin hartley say sexually_harasse fan',
#  'lois lane pay_tribute late margot kidder lead way',
#  'onion story blake farenthold get new job lobbying congress',
#  'iowa gov say slow signing country strictest abortion ban',
#  'cannes_film festival promise great gender_equality time activism',
#  'childish gambino america hit spot week',
#  'jon_stewart dave_chappelle perform standup tour',
#  'coach tell hurt ufc fighter continue say',
#  'recover kidney surgery',
#  'jon tester vulnerable senate democrat isn vote',
#  'taraji_henson kelvin hayden engage mother_day',
#  'young dolph give barista fire playing song pay',
#  'come bed explore intimacy experience sexual_assault',
#  'trump change burger order little healthy',
#  'michael avenatti post photos cohen qatari investor accuse bribery',
#  'donald_trump lash call leak twitter_user pounce',
#  'trump order help chinese phone maker china approve money trump project',
#  'hundred protest city poor_people campaign',
#  'rihanna good response ask attend royal_wedde',
#  'lifetime royal romance good',
#  'game_change westworld brain capsule reveal begin',
#  'margot kidder actress play lois lane superman dead',
#  'tomi_lahren own genealogist remark low skilled immigrant',
#  'harrison_ford crash new han solo actor interview life',
#  'kylie_jenner ex bodyguard tim chung deny actually stormi father',
#  'seann william scott replace clayne crawford renew lethal weapon',
#  'zach wood officially mvp silicon_valley',
#  'ryan_reynold go south_korean singe disguise unicorn',
#  'billie lourd honor have tough mother_day photo carrie_fisher',
#  'pink ask concertgoer sing blow away',
#  'pastor think jews go hell speak jerusalem embassy opening',
#  'chili hit datum breach credit debit card information compromise',
#  'trump call waffle_house hero james shaw jr thank disarm shooter',
#  'fox_news host trump fulfil biblical prophecy move embassy jerusalem',
#  'keyless car kill dozen people report',
#  'rare conjoin fawn scientist double',
#  'kill dozen injure indonesia church bombing',
#  'iran president say country remain nuclear_deal',
#  'trump official owe mccain apology disgusting insult',
#  'amy_schumer go girl raunch saturday_night live',
#  'americans iran_deal depend ask',
#  'attend nra convention fake_news medium',
#  'possible autopilot use probed tesla crash mph',
#  'michael bloomberg slam epidemic political lie danger democracy',
#  'massive cookout throw park cop call black family bbq',
#  'michael che stepmom melissa_mccarthy embarrass weekend_update',
#  'handmaid_tale meet sex city funny terrifying snl spoof',
#  'video_show security guard choke black teen accuse shoplifting new_york',
#  'trump praise late mom mother_day skip mention melania',
#  'trump promise help chinese company violate sanction iran',
#  'sarah_huckabee sander berate staffer mccain leak',
#  'parkland dad point message oliver north nra new president',
#  'john_bolton trump sanction european company possible iran',
#  'shares_adorable throwback pic touch mother_day tribute',
#  'tomi_lahren claim low skilled immigrant country base',
#  'stalk cheetah oblivious family scare exit car safari park',
#  'der spiegel cover portray trump finger flip europe',
#  'italian tribunal lift ban silvio berlusconi hold public office',
#  'north_korea plan dismantle nuclear test site end',
#  'knife attack paris leaves_dead injure',
#  'watch hulu new week',
#  'watch amazon prime new week',
#  'late unveil spoof line trump theme mother_day gift',
#  'brooklyn find new tv home star fan rejoice',
#  'smith share inspiring tale fresh prince bel air',
#  'lgbtq group new oklahoma adoption law discriminatory',
#  'mueller reportedly investigate foreign link donor trump_inauguration fund',
#  'stephen_colbert mock proposal hang trump penny portrait post office',
#  'boston dynamics robot dog available sale soon',
#  'southern baptist leader apologize hurtful comment woman',
#  'george soros progressive group spend million elect reformist prosecutor',
#  'incredible photo world protect',
#  'avengers_infinity war director reveal die survive screen',
#  'uber silence woman sexual assault',
#  'marvel introduce official chinese superhero',
#  'big_bang theory pay sweet tribute stephen_hawke delete scene',
#  'bill_maher shred donald_trump liken mob boss',
#  'amazon hold seattle hostage',
#  'jim_carrey taunt psycho mike_pence bite new portrait',
#  'chadwick boseman laud student protester howard commencement_speech',
#  'understand straight incel talk_to gay',
#  'gather military spouse put white white_house',
#  'game host prematurely congratulate contestant mortifying fail',
#  'woman cannes red_carpet protest inequality film',
#  'man charge hate_crime beat gay_couple',
#  'trump_administration roll protection transgender prison inmate',
#  'michael_cohen reportedly pay advise time_warner merger',
#  'metoo statehouse man go harassment culture isn',
#  'austin bar police_department sell old gun public',
#  'masterclass parody dub movie swear word falcon great',
#  'democrats don regret make easy confirm judge',
#  'donald glover fan cast solo',
#  'seth_meyer skewer idea donald_trump win nobel_peace prize',
#  'chuck_schumer turn melania_trump good campaign donald_trump',
#  'trailer axe tremor kevin bacon offer glimpse',
#  'frightened rabbit singer scott hutchison dead',
#  'suspect custody shooting california high_school injure',
#  'colbert names official job unqualified white_house staffer',
#  'trevor_noah give michael_cohen bite new breaking_bad theme nickname',
#  'moral atlanta robbin season snatch',
#  'pose character find community new_york ball scene',
#  'accuse golden_state killer face additional murder count',
#  'jimmy_kimmel roast donald_trump spoof nobel_peace prize ceremony video',
#  'sarah_palin say mccain regret perpetual gut punch',
#  'kill australia worst mass_shoote',
#  'deadpool david_beckham hug feud deadpool teaser',
#  'opposition give trump hot lawyer',
#  'dog help prepare baby cat help prepare teenager',
#  'john_mccain wife rebuke white_house official mock die',
#  'rupaul_drag race queen turn time cher rusical',
#  'trump_administration axis fund nasa system monitor greenhouse gas',
#  'police search suspect serial_killer dump ground',
#  'kevin mchale think surprise come',
#  'pennsylvania house race embody fight future democratic_party',
#  'hacker try breach tennessee county server election_night report',
#  'gay teacher suspend show photo future wife sue texas district',
#  'school_district allegedly lgbtq student read bible punishment',
#  'trump launch war christmas people have',
#  'fan make punk music debut girl party',
#  'jake_tapper rip retire gen tom mcinerney insult john_mccain',
#  'fox cuts_tie guest cite john_mccain defend torture',
#  'trump attempt example immigrant caravan backfire',
#  'celebrity read weird text mom mother_day treat',
#  'stormy_daniel actress doppelganger',
#  'old know man america say smoke dozen cigar day',
#  'tweeter erupt trump aide cruel taunt john_mccain die',
#  'mark_hamill wed sheldon amy big_bang theory fan geek',
#  'epa hide dinner climate denier accuse child sex_abuse',
#  'meghan mccain take swipe white_house aide mock father cancer',
#  'need talk white people call cop people color',
#  'woman call police black family bbqe lake oakland',
#  'tim allen man stand come year cancel',
#  'berate white_house joke john_mccain health',
#  'michael avenatti warn michael_cohen document release',
#  'fox_friend host mock ny_times isis coverage unaware beat fox story',
#  'congressional_candidate say nra new tv ad',
#  'tsa tell sikh man remove turban find canadian politician',
#  'john_stamo show new baby bob saget lori loughlin',
#  'woman send text date say love excessive thing',
#  'little extortion guy figure stormy_daniel old lawyer actually_pretty',
#  'katie porter survive domestic_abuse campaign',
#  'trump plan prescription drug price looks_like promise',
#  'giuliani say cohen speak trump big dollar client',
#  'russian troll facebook ad barely target swing state',
#  'ted_cruz staff usaid meet group call apartheid call injustice',
#  'plan family_vacation according_to travel expert',
#  'boston dynamics create run robot come',
#  'cornell student deliver thesis underwear professor question outfit',
#  'funniest_tweet woman week',
#  'israel reportedly fire rockets syria',
#  'israel launch airstrike syria iranian attack',
#  'right die advocate david goodall end life listen ode joy',
#  'americans hold north_korea return united_state',
#  'dozen dead torrential rain dam burst kenya',
#  'spotify stop promote kelly music sexual_assault allegation',
#  'trump kim_jong un likely meet month singapore',
#  'homeland_security deny report secretary draft resignation letter',
#  'cecile richards run office future never',
#  'aclu say kris_kobach give incorrect information voter_registration',
#  'ryan_murphy donate pose profit trans queer group',
#  'rick morty renew whopping episode',
#  'ryan_reynolds warn deadpool fan don fking word',
#  'nurse charge death ex trump adviser mcmaster father',
#  'trump go indiana slam joe donnelly don_expect democrat hit',
#  'rick moranis appear netflix sctv documentary',
#  'face challenge right pull support immigration bill',
#  'john_mccain urge senate reject gina haspel nomination cia',
#  'month later rio cop supposedly close marielle franco killer',
#  'queer_eye star tan france doesn poorly dress fan style advice',
#  'woman come eric schneiderman job',
#  'man pleads_guilty bacon vandalism tennessee islamic center',
#  'mike_pence robert_mueller russia_probe wrap',
#  'ready old kevin justin hartley',
#  'net_neutrality rule end june fcc say',
#  'democratic candidate maryland governor die cardiac arrest',
#  'officer put man chokehold north_carolina waffle_house',
#  'don blankenship nutty concession speech',
#  'brooklyn cancel twitter mourn',
#  'quiet struggle chuck_schumer left',
#  'gabby douglas utterly unrecognizable undercover boss',
#  'girl accuse plot kill classmate',
#  'curious case russian oligarch national_park service latrine',
#  'watch rudy_giuliani completely torpedo rudy_giuliani trump argument',
#  'fox business guest defend torture work john_mccain',
#  'tom abby queer_eye remarry',
#  'pakistan pass historic transgender right bill',
#  'phil mudd flip question cia torture didn america',
#  'facebook ads house dems russia run election',
#  'kim_kardashian say tristan thompson block defend khloe',
#  'kenan thompson say stay snl long possible',
#  'jennifer_garner mom problem hilarious rap video ellen',
#  'dick_cheney suggest restart torture interrogation program',
#  'greta gerwig loudly critique feel pretty moviegoer live tweet',
#  'devin_nune meet secret russia_probe source threaten doj',
#  'queer_eye star karamo brown engage director ian jordan',
#  'jet launch apple store incredible deal',
#  'tom hardy completely unrecognizable al capone new movie',
#  'woman allege rapper young lo rape trap chris_brown home',
#  'republican fill court seat deny obama year',
#  'man want white_supremacist kill black neighbor burn cross yard fbi',
#  'trump announce detail meet kim_jong un',
#  'samantha_bee deliver blister takedown ny ag eric schneiderman',
#  'jim_carrey scathing portrait trump joker nightmare',
#  'michelle_wolf renew hostility sarah_huckabee sander',
#  'fan erupt fate elias koteas olinsky chicago',
#  'people street apologize old teacher jimmy_kimmel live',
#  'stephen_colbert porn_star math michael_cohen donald_trump',
#  'pollen bomb allergy sufferer',
#  'jennifer_lopez dance danceable song tonight',
#  'white yale student call cop black schoolmate napping dorm common room',
#  'rudy_giuliani quit law firm wild week interview',
#  'teddy geiger make public appearance come transgender',
#  'ariana_grande mac miller reportedly break',
#  'avengers leak support interview marvel director',
#  'good excuse racist impact michigan medicaid proposal',
#  'fcc complaint minute interview stormy_daniel',
#  'americans jail korea home trump situation worse',
#  'alex strangelove gay teen comedy doesn turn away sex',
#  'woman say take home kitten find bobcat',
#  'video bear eat dairy queen lead charge zoo owner',
#  'iranian lawmaker mock trump mental capacity burn flag pull nuke deal',
#  'european scramble save iran_deal trump withdraw',
#  'north_korea release american political prisoner advance historic summit',
#  'establishment gop notch win ohio primary vacant house seat',
#  'eric schneiderman praise movement day abuse_allegation emerge',
#  'trevor_noah unload suppose advocate woman eric schneiderman',
#  'year comey_fire scope mueller_probe expand lawyer shell company',
#  'trump inspire businessman win indiana gop senate primary',
#  'gop rival say tammy baldwin team terrorist silence trump cia pick',
#  'job program people work',
#  'jim parsons need queer story',
#  'trump accuser win democratic nomination ohio legislature',
#  'mastermind waterboarde cia information share gina haspel',
#  'conservative senate democrat backs trump agenda defeat progressive challenger',
#  'taylor_swift katy_perry kimye feud live',
#  'kim_kardashian history fashion council influencer award',
#  'nbc say believe matt_lauer accuser month long investigation',
#  'russians ability change voter datum didn report say',
#  'elizabeth_warren pick win ohio democratic gubernatorial primary',
#  'kkk leader found_guilty firing gun charlottesville rally',
#  'protester decry torture drag gina haspel senate hearing',
#  'hire firm link michael_cohen scoop trump',
#  'rnc sell sickening donald_trump theme merch ahead mother_day',
#  'don blankenship defeat relief family upper big branch miner',
#  'colbert shred trump break promise talk',
#  'new ambassador germany offend host hour day',
#  'jordan_peele new nightmare come year',
#  'backstreet boy dress spice girl large life',
#  'seth_meyer decode teen slang reveal giuliani mean',
#  'look orlando interim pulse_nightclub memorial',
#  'trevor_noah turn donald_trump knife comment reggae magic',
#  'senator force vote ultimately reverse fcc restore net_neutrality',
#  'ny legislature plan place consider replacement eric schneiderman',
#  'ambassador write letter oppose gina haspel nomination',
#  'california authority say state new home solar power',
#  'ny governor assign investigation eric schneiderman abuse_allegations',
#  'refugee caravan scapegoat trump border crackdown',
#  'pennsylvania late state fund urban gun_violence prevention',
#  'denver mayor son caught_tape berate cop faggot',
#  'progressive prosecutor win primary north_carolina',
#  'novartis money pay trump lawyer',
#  'hypocrisy melania_trump online safety booklet point page page',
#  'uninsured rate worsen year obamacare gain',
#  'bernie_sander plan revive labor union',
#  'jim_carrey bestow scott_pruitt savage nickname late painting',
#  'male ally abuser',
#  'mormon church end century long relationship boy_scout',
#  'snack addiction kill orangutan',
#  'trump pick cia_director win torture program morally wrong',
#  'anderson_cooper burn moronic michael_cohen russia cash claim',
#  'pinata maker apologize hang black figure likeness lynching',
#  'caliphate trump planet ruin',
#  'opponent oust gop incumbent north_carolina',
#  'espn eliminate public editor role call outdated',
#  'michael_cohen sell access trump say group pay shell company',
#  'mitch_mcconnell mock blankenship twitter big cloud cocaine',
#  'ex convict don blankenship lose patrick morrisey west_virginia',
#  'ohio voter pass gerrymander reform measure',
#  'trump iran_deal exit win russia',
#  'cynthia_nixon want new_yorker vote homo cuomo',
#  'ontario canada issue non binary birth certificate',
#  'child sexual predator roman polanski call movement total hypocrisy',
#  'america producer reveal new detail childish gambino viral_video',
#  'terry crews black man aren allow victim dead',
#  'donald glover america eyes jim crow historian',
#  'fox_news judicial analyst issue dark warn trump michael_cohen',
#  'black woman bishop make history predominantly white church',
#  'geena davis th husband reza jarrahy divorce',
#  'pauley perrette abby heart wrench farewell ncis',
#  'lethal weapon fire clayne crawford character shoot',
#  'selena_gomez pokes_fun spray tan mishap',
#  'protest leader nikol pashinian elect prime_minister armenia',
#  'kim_jong un secretly meet xi jinping',
#  'netanyahu bombastic iran claim find perfect audience trump',
#  'netanyahu chef blast serve japan prime_minister dessert shoe',
#  'world_leader condemn trump withdraw iran_nuclear deal',
#  'senate_republican shun don blankenship day west_virginia primary',
#  'new_york harvey_weinstein probe set continue attorney_general exit',
#  'trump announce break deal',
#  'politician schneiderman resign physical abuse_allegation',
#  'trump legal strategy monkey throw poo wall',
#  'kirsten_dunst jesse plemon welcome',
#  'holy matrimony proposal',
#  'nordstrom rack president apologizes store accuse black man theft',
#  'giuliani say trump lawyer michael_cohen incriminate information president',
#  'lena waithe stun queer superhero',
#  'kelly accuser ask permission use bathroom',
#  'trump reportedly tell macron pull deal',
#  'deportation crackdown hurt immigrant victim crime',
#  'seth_meyer say michael_cohen try apologize air trump',
#  'blessing well tweet',
#  'farm bill cut food_stamp friendly farmer',
#  'know iran_nuclear deal',
#  'derby day bet win thrill texas woman',
#  'democratic meddling west_virginia thing watch election day',
#  'cynthia erivo nail feature sistine chapel paint black woman',
#  'keanu reeves alex winter coming bill ted year',
#  'solange durag true mvp met_gala',
#  'house republican threaten subpoena trump doj official census citizenship request',
#  'jimmy_kimmel try hard sense rudy late trump defense give',
#  'religious imagery stitch met_gala',
#  'bob marley granddaughter say cop racially profile check airbnb',
#  'melania_trump call anti bullying campaign ignore husband action',
#  'watch rudy_giuliani smoking weed tv',
#  'janet_jackson receive icon award billboard_music award',
#  'white_house prepare send congress spending cut package',
#  'jared_kushner back bill shoot federal prison reform',
#  'george_zimmerman accuse stalk detective work trayvon_martin film',
#  'passenger lash scott_pruitt justify class travel new epa memo say',
#  'trump country house district key progressive battleground',
#  'mike_pence brother win primary race vice_president house seat',
#  'marine investigate avowed white_supremacist active duty',
#  'trump violate iran_nuclear deal vow reimpose sanction',
#  'olympic_committee ignore sexual_abuse complaint taekwondo star lawsuit',
#  'blake_lively bring family notice',
#  'bill_reilly offer stand sarah sander handle line reporter',
#  'catholic priest praise best_dresse dude live life',
#  'jimmy_kimmel say hide seek genius dog heal nation',
#  'bank_america appear flip firearm promise loan remington',
#  'gentleman caller present queer icon ve_seen',
#  'eric schneiderman con man',
#  'christiane amanpour head new pbs replace charlie rise',
#  'madonna tease new song surprise performance',
#  'iron_man black widow captain_america thor hawkeye match tattoo',
#  'michael_cohen accept firm tie russian oligarch report',
#  'stephen_colbert hit rudy_giuliani brutal fact check',
#  'katy_perry send olive branch taylor_swift world rejoice',
#  'jada_pinkett smith gets_real dating smith marry',
#  'mark_hamill spill bean major cameo han solo movie',
#  'shawn mendes sweetly attend hailey baldwin gown met_gala',
#  'orrin hatch sorry suggest trump allow john_mccain funeral',
#  'seth_meyer perfect line confront donald_trump lie',
#  'police hope use dna catch zodiac killer',
#  'lili reinhart cole sprouse finally couple debut met_gala',
#  'sweetbitter capture grit glamour restaurant world',
#  'mitch_mcconnell bend rule confirm trump judge',
#  'ryan_zinke tale fish',
#  'ny attorney_general eric schneiderman resign abuse_allegation',
#  'sanctuary_citie work trump era surprising cost',
#  'shepard_smith trump pull iran_deal decision violate',
#  'stormy_daniel find crunchy new way chip away trump',
#  'rainbow mountains peru straight dr seuss book',
#  ...]

# %% [markdown]
# ## Latent Dirichlet Allocation

# %% [markdown]
# Nous allons utiliser LDA qui est un type de Machine Learning non supervisé (ce qu'on recherche dans notre cas).

# %% [markdown]
# Nous pouvons voir les mots les plus fréquents et les plus rares dans les titres des nouvelles en fonction du score idf. Plus la valeur est faible, plus le mot est fréquent dans les titres de l'actualité.

# %% [markdown]
# ### Déterminer le meilleur modèle LDA

# %%
lda_texts = l_texts

# %%
vect = TfidfVectorizer(stop_words=en_stop)
vect_text = vect.fit_transform(lda_texts).todense()
print(vect_text.shape)
# Out:
# (1001, 3076)
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ll', 've'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '

# %%
vocab = np.array(vect.get_feature_names())
vocab
# Out:
# array(['aaron', 'abandon', 'abby', ..., 'zombie', 'zone', 'zoo'],
#       dtype='<U23')

# %% [markdown]
# On va définir nos paramètres de recherche, initialiser le modèle et la classe de Grid Search puis faire la Grid Search.

# %%
search_params = {'n_components': [5, 15, 25, 35, 45], 'learning_decay': [.5, .7, .9]}
lda = LDA()
model = GridSearchCV(lda, param_grid=search_params)
model.fit(vect_text)
# Out:
# GridSearchCV(estimator=LatentDirichletAllocation(),
#              param_grid={'learning_decay': [0.5, 0.7, 0.9],
#                          'n_components': [5, 15, 25, 35, 45]})

# %% [markdown]
# Affichage du meilleur modèle avec ses meilleurs paramètres associés.

# %%
# Best Model
best_lda_model = model.best_estimator_

# Model Parameters
print("Best Model's Params: ", model.best_params_)

# Log Likelihood Score
print("Best Log Likelihood Score: ", model.best_score_)

# Perplexity
print("Model Perplexity: ", best_lda_model.perplexity(vect_text))
# Out:
# Best Model's Params:  {'learning_decay': 0.7, 'n_components': 5}
# Best Log Likelihood Score:  -7668.426861015015
# Model Perplexity:  19633.50669099935

# %%
# Tweak the two parameters below
number_topics = 5
number_words = 8

# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1, learning_decay=0.9)
lda.fit(vect_text)


import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

# feed the LDA model into the pyLDAvis instance
lda_viz = gensimvis.prepare(lda, vect_text, vectorizer, mds='tsne')
lda_viz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-956ff437d71b> in <module>
#       8
#       9
# ---> 10 import pyLDAvis.gensim_models as gensimvis
#      11 pyLDAvis.enable_notebook()
#      12
#
# ModuleNotFoundError: No module named 'pyLDAvis'

# %%
#lda_top = lda_model.fit_transform(vect_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a1e04daeab23> in <module>
# ----> 1 lda_top = lda_model.fit_transform(vect_text)
#
# NameError: name 'lda_model' is not defined

# %%
print(lda_top.shape)  # (no_of_doc,no_of_topics)
print(lda_top)

# %% [markdown]
# Notez que la somme des valeurs d'une ligne particulière est égale à 1, car chaque valeur représente le % de contribution du sujet correspondant dans le document.

# %% [markdown]
# On va utiliser par la suite GridSearch pour déterminer le meilleur modèle de LDA.

# %%
# composition of doc 0 for eg
print("Document 0: ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")

# %% [markdown]
# Nous voyons que le Topic 4 est principalement présent dans le document 0.

# %%
# les mots les plus importants pour chaque topic
vocab = vect.get_feature_names()

for i, comp in enumerate(lda_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")

# %% [markdown]
# Nous allons utiliser plusieurs de métriques de clustering permettant de mesurer la qualité du modèle et ensuite le comparer aux autres utilisés.

# %%
# Construct the k-means clusters
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
clusters = KMeans(n_clusters=10, random_state=100).fit_predict(vect_text)
# Build the Singular Value Decomposition(SVD) model
svd_model = TruncatedSVD(n_components=2)  # 2 components
lda_output_svd = svd_model.fit_transform(vect_text)
# X and Y axes of the plot using SVD decomposition
x = lda_output_svd[:, 0]
y = lda_output_svd[:, 1]
# Weights for the 15 columns of lda_output, for each component
print("Component's weights: \n", np.round(svd_model.components_, 2))
# Percentage of total information in 'lda_output' explained by the two components
print("Perc of Variance Explained: \n", np.round(svd_model.explained_variance_ratio_, 2))

# %%
# Plot
plt.figure(figsize=(12, 12))
plt.scatter(x, y, c=clusters)
plt.xlabel('Component 2')
plt.xlabel('Component 1')
plt.title("Segregation of Topic Clusters", )
