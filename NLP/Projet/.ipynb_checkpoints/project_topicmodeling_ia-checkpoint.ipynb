# %% [markdown]
# # <center>Projet Topic Modeling</center>

# %% [markdown]
# During the Natural Language Processing course, text representation algorithms have been introduced. However they don't suffice to the creation of complete NLP systems.

# %% [markdown]
# Most of them usually rely on text pre-processing at first -- in other words, they rely on a specific data pipeline that is tied to the final task you are trying to solve.

# %% [markdown]
# As a result, we will try in this notebook to create a pipeline from scratch given a specific final task.

# %% [markdown]
# # Exploring the dataset

# %%
import pandas as pd
import numpy as np
import nltk

import pyLDAvis
import itertools
import itertools
import os
import re
import secrets
import string
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import gensim
import gensim.corpora as corpora
import gensim.corpora as corpora
import pandas as pd
import spacy
import plotly.graph_objs as go
import plotly.express as px

from matplotlib import style
from sklearn.cluster import MiniBatchKMeans
from itertools import chain

from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec, Phrases, KeyedVectors
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess

from nltk.corpus import wordnet
from nltk.corpus import stopwords

from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_samples, silhouette_score, davies_bouldin_score, calinski_harabasz_score
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, ward
from sklearn.metrics import silhouette_score

from tqdm import tqdm

from wordcloud import WordCloud

from pyclustering.cluster.kmeans import kmeans
from pyclustering.cluster.kmeans import kmeans_observer
from pyclustering.cluster.kmeans import kmeans_visualizer

from spacy.parts_of_speech import IDS as POS_map
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# C:\Logiciels\Anaconda\lib\site-packages\h5py\__init__.py:46: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# You can load the dataset using pandas and the [.read_json()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html) method. Try loading your dataset here:

# %%
dataset = pd.read_json("News_Category_Dataset_v2.json", lines=True, dtype={"headline": str})

# %% [markdown]
# ------

# %% [markdown]
# A good way to get the grasp of your corpus is to count the occurences of words across it. For convenience, we've defined a dummy function that splits words by checking where spaces are and... Simply that. This is the most basic form of word identification in text that could be used.

# %%
def dummy_word_split(texts):
    """Function identifying words in a sentence in a really dummy way.
        
        Argument:
            - texts (list of str): a list of raw texts in which we'd like to identify words
            
        Return:
            - list of list containing each word separately.
    """
    texts_out = []
    for text in texts:
        texts_out.append(text.split(" "))
        
    return texts_out

# %%
splitted_texts = dummy_word_split(dataset["headline"].tolist())

# %%
splitted_texts[0] + splitted_texts[1]
# Out:
# ['There',
#  'Were',
#  '2',
#  'Mass',
#  'Shootings',
#  'In',
#  'Texas',
#  'Last',
#  'Week,',
#  'But',
#  'Only',
#  '1',
#  'On',
#  'TV',
#  'Will',
#  'Smith',
#  'Joins',
#  'Diplo',
#  'And',
#  'Nicky',
#  'Jam',
#  'For',
#  'The',
#  '2018',
#  'World',
#  "Cup's",
#  'Official',
#  'Song']

# %% [markdown]
# Now, let's define a function that counts word occurences and highlight what are the most important words of our corpus:

# %%
def compute_word_occurences(texts):
    """You have to define this function yourself. """
    
    words = itertools.chain.from_iterable(texts)
    
    word_count = pd.Series(words).value_counts()
    word_count = pd.DataFrame({"Word": word_count.index, "Count": word_count.values})

    return word_count

# %% [markdown]
# Once this is done, display the top 20 most occuring words in your texts.

# %%
compute_word_occurences(splitted_texts).head(1000)
# Out:
#          Word  Count
# 0         The  47803
# 1          To  38569
# 2           A  24839
# 3          In  24141
# 4          Of  22956
# ..        ...    ...
# 995  Father's    258
# 996   Netflix    258
# 997      Park    258
# 998   Culture    257
# 999  Mistakes    257
#
# [1000 rows x 2 columns]

# %% [markdown]
# Does it make sense, and can you leverage such results?

# %% [markdown]
# # Actual pipeline

# %% [markdown]
# As you have seen above, the results obtained from a simple word count aren't so great. Similar words doesn't add up (such as run and running), and you have a lot of noise included. Words such as *the*, *you*, *an* could be removed for instance.

# %% [markdown]
# Actually, a lot can be done. Let's check that out.

# %% [markdown]
# ----------

# %% [markdown]
# ## What does the pipeline look like?

# %% [markdown]
# A NLP data pipeline often relies on the following elements. Some can be added, some can be removed, but they all look like this at some point:

# %% [markdown]
# 1. **Ensuring data quality.** You have to make sure that there's no N/A in your data and that everything is in the good format shape. Having this as the entrance of your pipeline will save you a lot of time in the long run, so try defining it thoroughly.
#
#
# 2. **Filtering texts from unwanted characters**. Especially if you get data from web, you'll end up with HTML tags or encoding stuff that you don't need in your texts. Before applying anything to them, you need to get them cleaned up. Here, try removing the dates and the punctuation for instance.
#
#
# 3. **Unify your texts**. (*This is topic modeling specific*). You don't want to make the difference between a word at the beginning of a phrase of in the middle of it here. You should unify all your words by lowercasing them and deaccenting them as well.
#
#
# 4. **Converting sentences to lists of words**. Some words aren't needed for our analyses, such as *your*, *my*, etc. In order to remove them easily, you have to convert your sentences to lists of words. You can use the dummy function defined above but I'd advised against it. Try finding a function that does that smoothly in [gensim.utils](https://radimrehurek.com/gensim/utils.html)!
#
#
# 5. **Remove useless words**. You need to remove useless words from your corpus. You have two approaches: [use a hard defined list of stopwords](https://www.analyticsvidhya.com/blog/2019/08/how-to-remove-stopwords-text-normalization-nltk-spacy-gensim-python/) or rely on TF-IDF to identify useless words. The first is the simplest, the second might yield better results!
#
#
# 6. **Creating n-grams**. If you look at New York, it is composed of two words. As a result, a word count wouldn't really return a true count for *New York* per se. In NLP, we represent New York as New_York, which is considered a single word. The n-gram creation consists in identifying words that occur together often and regrouping them. It boosts interpretability for topic modeling in this case.
#
#
# 7. **Stemming / Lemmatization**. Shouldn't run, running, runnable be grouped and counted as a single word when we're identifying discussion topics? Yes, they should. Stemming is the process of cutting words to their word root (run- for instance) quite brutally while lemmatization will do the same by identifying the kind of word it is working on. You should convert the corpus words into those truncated representations to have a more realistic word count.
#
#
# 8. **Part of speech tagging**. POS helps in the identification of verbs, nouns, adjectives, etc. For topic models, it is a good idea to work only on verbs and nouns. Adjectives don't convey info about the actual underlying topic discussed at hand.

# %% [markdown]
# ## Let's create it!

# %% [markdown]
# Now it's your turn. Try to implement each step of the pipeline, and compare the word counts obtained earlier and the one obtained after preprocessing your texts.

# %% [markdown]
# ### Ensuring data quality

# %%
def check_data_quality(texts):
    """Check wheter all the dataset is conform to the expected behaviour."""
    assert all([isinstance(t, str) for t in texts]), "Input data contains something different than strings."
    assert all([t != np.nan for t in texts]), "Input data contains NaN values."
    
    return True

# %%
def force_format(texts):
    return [str(t) for t in texts]

# %%
texts = force_format(dataset["headline"])

# %%
print(f"Is the dataset passing our data quality check?\n{check_data_quality(texts)}")
# Out:
# Is the dataset passing our data quality check?
# True

# %% [markdown]
# ### Filtering texts

# %% [markdown]
# https://regex101.com/

# %%
def filter_text(texts_in):
    """Removes incorrect patterns from a list of texts, such as hyperlinks, bullet points and so on"""
    
    texts_out = re.sub(r'https?:\/\/[A-Za-z0-9_.-~\-]*', ' ', texts_in, flags=re.MULTILINE)
    texts_out = re.sub(r'[(){}\[\]<>]', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&amp;#.*;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&gt;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'â€™', "'", texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'\s+', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&#x200B;', ' ', texts_out, flags=re.MULTILINE)
    # Mail regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r"(?i)(?:[a-z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+\/=?^_`{|}~-]+)*|\"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*\")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9]))\.){3}(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9])|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+\.[a-zA-Z0-9-_.]+', '', texts_out, flags=re.MULTILINE)
    # Phone regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r"\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}", '', texts_out, flags=re.MULTILINE)
    # Remove names in twitter
    texts_out = re.sub(r'@\S+( |\n)', '', texts_out, flags=re.MULTILINE)

    # Remove starts commonly used on social media
    texts_out = re.sub(r'\*', '', texts_out, flags=re.MULTILINE)
    return texts_out

# %%
texts = [filter_text(t) for t in texts]

# %% [markdown]
# ### Unifying texts & converting sentences to list of words

# %%
def sent_to_words(sentences):
    """Converts sentences to words.

    Convert sentences in lists of words while removing the accents and the punctuation.

    @param:
        sentences: a list of strings, the sentences we want to convert
    @return
        A list of words' lists.
    """
    for sentence in tqdm(sentences):
        yield (simple_preprocess(str(sentence), deacc=True))

# %%
texts = list(sent_to_words(texts))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 200853/200853 [00:05<00:00, 35319.56it/s]

# %%
texts
# Out:
# [['there',
#   'were',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   'world',
#   'cup',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'for', 'the', 'first', 'time', 'at', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonald',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'he',
#   'like',
#   'to',
#   'do',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oyster',
#   'growing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trump',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trump',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'there',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trump',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trump',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'father',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesn',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter', 'and', 'it', 'was', 'universally', 'entertaining'],
#  ['mystery',
#   'wolf',
#   'like',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houston',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trump', 'new', 'maga', 'themed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonald'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'iran',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'he',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adult',
#   'themed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bee',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesn',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesn',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayer',
#   'weird',
#   'new',
#   'low',
#   'budget',
#   'video',
#   'is',
#   'meme',
#   'worthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nra',
#   'backed',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trump',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member',
#   'of',
#   'the',
#   'far',
#   'right',
#   'proud',
#   'boys',
#   'menaced',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['here',
#   'what',
#   'happens',
#   'when',
#   'catholic',
#   'hospital',
#   'won',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trump',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'here',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinstein', 'perp', 'walk'],
#  ['the', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'desk',
#   'makeover',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupaul',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   'pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writer',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'won',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvel',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the',
#   'biggest',
#   'flaw',
#   'in',
#   'trump',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nunes',
#   'linked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['ireland',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   'females',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'won',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trump',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'it',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambor',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'co',
#   'stars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'let',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'anti',
#   'abortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trump',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trump',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebook',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'it',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['you',
#   're',
#   'going',
#   'to',
#   'use',
#   'that',
#   'self',
#   'checkout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'who',
#   've',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'right',
#   'to',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can', 'you', 'believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldn',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['self',
#   'driving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wide',
#   'eyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['far',
#   'right',
#   'and',
#   'anti',
#   'establishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italy',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'can',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'same', 'sex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngest',
#   'ever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohen',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louis',
#   'dreyfus',
#   'to',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'host',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trump',
#   'themed',
#   'reddit',
#   'forum'],
#  ['calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'off',
#   'duty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'country',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'he',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons',
#   'why',
#   'started',
#   'conversation',
#   'who',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohio',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasn',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'at',
#   'risk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'brien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'weren',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'he',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'don',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'liar'],
#  ['trump', 'blocking', 'people', 'on', 'twitter', 'is', 'judge', 'rules'],
#  ['mostly',
#   'non',
#   'christian',
#   'militia',
#   'won',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbard',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishment',
#   'backed',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'iran',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeo',
#   'threats',
#   'with',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'she', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'that',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runner',
#   'up',
#   'reveals',
#   'they',
#   're',
#   'dating'],
#  ['colbert',
#   'just',
#   'can',
#   'resist',
#   'turning',
#   'trump',
#   'nickname',
#   'into',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trump',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age'],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'we',
#   're',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissian',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'store',
#   'donations',
#   'to',
#   'nra',
#   'backed',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'she',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trump',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bullet',
#   'riddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governor',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaad',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'in',
#   'store',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governor',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'co',
#   'workers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trump',
#   'kim',
#   'jong',
#   'un',
#   'coin'],
#  ['giuliani',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'it',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'cease',
#   'and',
#   'desist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trump',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bug',
#   'flavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'don',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planet',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'anti',
#   'spanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'am'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trump',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['ex',
#   'trump',
#   'adviser',
#   'calls',
#   'president',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'one',
#   'third',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghan',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   'year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'won',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teen', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['time',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonald',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuela',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   're',
#   'elected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europe',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isn',
#   'enough',
#   'after',
#   'america',
#   'withdrawal'],
#  ['far',
#   'right',
#   'mob',
#   'attacks',
#   'year',
#   'old',
#   'liberal',
#   'greek',
#   'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rice',
#   'mother',
#   'is',
#   'opening',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'son',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'word', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   'it',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'he',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomo', 're', 'election'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'theroux',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'can',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats',
#   'plan',
#   'big',
#   'anti',
#   'corruption',
#   'theme',
#   'for',
#   'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   'of',
#   'the',
#   'internet',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'don',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'no',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spider',
#   'man',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isn',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'driver',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['year',
#   'old',
#   'boy',
#   'is',
#   'superhero',
#   'to',
#   'alabama',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabj',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['year',
#   'old',
#   'gay',
#   'man',
#   'proves',
#   'you',
#   're',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'primary',
#   'didn',
#   'receive',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'better',
#   'deal'],
#  ['majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'don',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'in',
#   'country',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasury',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trump',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmar',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'gov',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'fey',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwin',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argento',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carrey',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'he',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   'year',
#   'now',
#   'he',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   'report'],
#  ['trump',
#   'misspells',
#   'melania',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   'things',
#   'you',
#   'don',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sit',
#   'in',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryan',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['ex',
#   'russian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolf',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'mueller',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbourne', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'that',
#   'where',
#   'he',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'country',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
#   'boy',
#   'we',
#   'are',
#   'in',
#   'love'],
#  ['alec',
#   'baldwin',
#   'and',
#   'wife',
#   'hilaria',
#   'welcome',
#   'another',
#   'baby',
#   'boy'],
#  ['kate',
#   'mckinnon',
#   'breaks',
#   'out',
#   'another',
#   'impression',
#   'of',
#   'rudy',
#   'giuliani'],
#  ['how',
#   'did',
#   'smallville',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'with',
#   'sex',
#   'cult',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['trump',
#   'white',
#   'house',
#   'kills',
#   'off',
#   'yanny',
#   'laurel',
#   'debate',
#   'with',
#   'ridiculous',
#   'clip'],
#  ['jennifer',
#   'aniston',
#   'to',
#   'play',
#   'lesbian',
#   'president',
#   'in',
#   'netflix',
#   'first',
#   'ladies'],
#  ['break',
#   'out',
#   'the',
#   'book',
# ...
#   'people',
#   'back',
#   'to',
#   'work'],
#  ['jim',
#   'parsons',
#   'yes',
#   'we',
#   'still',
#   'need',
#   'more',
#   'queer',
#   'stories',
#   'onscreen'],
#  ['trump',
#   'accuser',
#   'wins',
#   'democratic',
#   'nomination',
#   'for',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'by',
#   'cia',
#   'has',
#   'information',
#   'to',
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trump',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'might',
#   've',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'council',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauer',
#   'accusers',
#   'after',
#   'months',
#   'long',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didn',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warren',
#   'pick',
#   'wins',
#   'ohio',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['at',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trump',
#   'themed',
#   'merch',
#   'ahead',
#   'of',
#   'mother',
#   'day'],
#  ['don',
#   'blankenship',
#   'defeat',
#   'is',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peele',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['here',
#   'look',
#   'at',
#   'orlando',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trump',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'state',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'scapegoat',
#   'for',
#   'trump',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayor',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'at',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trump',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trump',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacare',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'century',
#   'long',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trump',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'won',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'planet', 'in', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['ex',
#   'convict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trump', 'iran', 'deal', 'exit', 'is', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'non',
#   'binary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambino',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'aren',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'they',
#   're',
#   'dead'],
#  ['donald',
#   'glover',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   'th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrette',
#   'abby',
#   'has',
#   'heart',
#   'wrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahu',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahu',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japan',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'york',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'general',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trump',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy', 'matrimony', 'there', 'was', 'proposal', 'at', 'the', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'at', 'met', 'gala', 'as', 'queer', 'superhero'],
#  ['kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'he',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'on',
#   'air',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivo',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   'ted',
#   'after',
#   'years'],
#  ['solange', 'durag', 'was', 'the', 'true', 'mvp', 'at', 'the', 'met', 'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudy',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   'met',
#   'gala'],
#  ['bob',
#   'marley',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'anti',
#   'bullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husband',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushner',
#   'backed',
#   'bill',
#   'could',
#   'be',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'first',
#   'class',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pence',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'president',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'reilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hide',
#   'and',
#   'seek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   'queer',
#   'icons',
#   'as',
#   'you',
#   've',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwin',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccain',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trump',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trump',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'can',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'they',
#   're',
#   'straight',
#   'out',
#   'of',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# ## Remove useless words

# %%
en_stops = set(stopwords.words('english'))

## TF-IDF pour identifier les stopwords
tvec = TfidfVectorizer(min_df=.0025, max_df=.1, stop_words=en_stops, ngram_range=(1,1))
tvec_weights = tvec.fit_transform(dataset['headline'].dropna())
weights = np.asarray(tvec_weights.mean(axis=0)).ravel().tolist()
weights_df = pd.DataFrame({'term': tvec.get_feature_names(), 'weight': weights})
weights_df.sort_values(by='weight', ascending=False).head(20)

## Liste pré-définis de stopwords à éliminer
for lists in texts:
    for word in en_stops:
        try:
            lists.remove(word)
        except Exception as e:
            e =""

### COMPTER LES MOTS A LA FIN DES DEUX METHODES ET LES COMPARER
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
texts
# Out:
# [['mass', 'shootings', 'texas', 'last', 'week', 'tv'],
#  ['smith',
#   'joins',
#   'diplo',
#   'nicky',
#   'jam',
#   'world',
#   'cup',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'first', 'time', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'democrats',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'pick',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'lovin',
#   'new',
#   'mcdonald',
#   'jingle',
#   'tonight',
#   'show',
#   'bit'],
#  ['watch', 'amazon', 'prime', 'new', 'week'],
#  ['mike', 'myers', 'reveals', 'like', 'fourth', 'austin', 'powers', 'film'],
#  ['watch', 'hulu', 'new', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'talk',
#   'trump',
#   'summit'],
#  ['way',
#   'life',
#   'risk',
#   'remote',
#   'oyster',
#   'growing',
#   'region',
#   'called',
#   'robots'],
#  ['trump',
#   'crackdown',
#   'immigrant',
#   'parents',
#   'puts',
#   'kids',
#   'already',
#   'strained',
#   'system'],
#  ['trump',
#   'son',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'putin',
#   'ally',
#   'met',
#   'trump',
#   'jr'],
#  ['edward', 'snowden', 'one', 'trump', 'loves', 'vladimir', 'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trump',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'repeal',
#   'abortion',
#   'amendment',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'reel',
#   'back',
#   'critics',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trump',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'men',
#   'report'],
#  ['weird', 'father', 'day', 'gifts', 'dad', 'know', 'wants', 'he'],
#  ['twitter', 'universally', 'entertaining'],
#  ['mystery',
#   'wolf',
#   'like',
#   'animal',
#   'reportedly',
#   'shot',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north', 'korea', 'still', 'open', 'talks', 'trump', 'cancels', 'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'ireland',
#   'to',
#   'vote',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'liberalize',
#   'abortion',
#   'laws',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'least',
#   'black',
#   'americans',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack', 'johnson', 'pardoned', 'taboo', 'sex', 'still', 'criminalized'],
#  ['bet', 'chairman', 'ceo', 'debra', 'lee', 'stepping'],
#  ['rachel', 'dolezal', 'faces', 'felony', 'charges', 'welfare', 'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'photo',
#   'whitney',
#   'houston',
#   'bathroom',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'marketing',
#   'campaigns',
#   'harassment',
#   'accusations'],
#  ['chinese',
#   'exclusion',
#   'act',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trump', 'new', 'maga', 'themed', 'swimwear', 'sinks', 'twitter'],
#  ['seth',
#   'meyers',
#   'funny',
#   'regret',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'new',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'muslim',
#   'students',
#   'mcdonald'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'iran',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'jerry'],
#  ['people', 'injured', 'indiana', 'school', 'shooting'],
#  ['people',
#   'rattled',
#   'much',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david', 'cross', 'proves', 'yet', 'terrible', 'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'upcoming',
#   'adult',
#   'themed',
#   'puppet',
#   'film'],
#  ['missed', 'saddest', 'death', 'avengers', 'infinity', 'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'drugging',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bee',
#   'parents',
#   'think',
#   'america',
#   'basically',
#   'war',
#   'zone'],
#  ['pete', 'davidson', 'says', 'mental', 'illness', 'ruin', 'romance'],
#  ['james', 'corden', 'adam', 'levine', 'get', 'pulled', 'carpool', 'karaoke'],
#  ['emilia', 'clarke', 'dishes', 'final', 'game', 'thrones', 'scene'],
#  ['hollywood', 'need', 'difficult', 'men', 'make', 'great', 'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'never',
#   'thought',
#   'would',
#   'arrested'],
#  ['harvey', 'weinstein', 'turns', 'police', 'alleged', 'sex', 'crimes'],
#  ['john',
#   'mayer',
#   'weird',
#   'new',
#   'low',
#   'budget',
#   'video',
#   'meme',
#   'worthy',
#   'masterpiece'],
#  ['boba', 'fett', 'getting', 'star', 'wars', 'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'damaging',
#   'emails',
#   'hillary',
#   'clinton',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'nra',
#   'backed',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'delivered',
#   'donald',
#   'trump',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['bag',
#   'wet',
#   'socks',
#   'apparently',
#   'living',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member',
#   'far',
#   'right',
#   'proud',
#   'boys',
#   'menaced',
#   'twitter',
#   'user',
#   'doorstep'],
#  ['things', 'the', 'nra', 'blamed', 'the', 'texas', 'school', 'shooting'],
#  ['happens', 'catholic', 'hospital', 'try', 'save'],
#  ['trump',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'easier',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto', 'bayer', 'set', 'merge', 'care'],
#  ['joy', 'watching', 'harvey', 'weinstein', 'perp', 'walk'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'desk',
#   'makeover',
#   'incredible'],
#  ['older', 'gay', 'men', 'try', 'new', 'gay', 'slang', 'hilarious', 'video'],
#  ['rupaul',
#   'drag',
#   'race',
#   'teaching',
#   'straight',
#   'people',
#   'queer',
#   'culture'],
#  ['fish', 'market', 'buys', 'freedom', 'fred', 'pound', 'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'call',
#   'trump',
#   'summit',
#   'warns',
#   'nuclear',
#   'showdown'],
#  ['investigation', 'finds', 'russian', 'missile', 'shot', 'flight', 'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle', 'obama', 'reveals', 'cover', 'upcoming', 'memoir', 'becoming'],
#  ['late',
#   'night',
#   'writer',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'one',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'inappropriate',
#   'behavior',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'fine',
#   'players',
#   'anthem',
#   'protests'],
#  ['andy', 'cohen', 'taylor', 'swift', 'katy', 'perry', 'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'clear',
#   'marvel',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'cheek'],
#  ['amy', 'poehler', 'parks', 'recreation', 'revival', 'would', 'amazing'],
#  ['colbert',
#   'exposes',
#   'biggest',
#   'flaw',
#   'trump',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'defend',
#   'interests'],
#  ['women', 'pulled', 'stops', 'land', 'dream', 'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'fenty',
#   'highlighter',
#   'got',
#   'pack',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'rushing',
#   'defend',
#   'tomi',
#   'lahren',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nunes',
#   'linked',
#   'winery',
#   'faced',
#   'suit',
#   'alleged',
#   'coke',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'abuse',
#   'neglect',
#   'report',
#   'shows'],
#  ['ireland',
#   'historic',
#   'vote',
#   'legalizing',
#   'abortion',
#   'haunted',
#   'trump',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'females',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'interview',
#   'mueller',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky', 'attorney', 'running', 'judge', 'dies', 'day', 'primary', 'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['koch', 'network', 'going', 'one', 'trump', 'favorite', 'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'honor',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'fine',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'kids',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'accuses',
#   'mia',
#   'farrow',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen', 'king', 'reveals', 'donald', 'trump', 'blocked', 'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'addressed',
#   'verbal',
#   'harassment',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambor',
#   'alleged',
#   'harassment',
#   'male',
#   'co',
#   'stars',
#   'brush'],
#  ['harvey', 'weinstein', 'expected', 'turn', 'to', 'nypd', 'sex', 'crimes'],
#  ['samantha', 'bee', 'torches', 'ice', 'let', 'shut', 'fk'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'anti',
#   'abortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'canceling',
#   'summit',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'keep',
#   'fighting',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trump',
#   'letter',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'trump',
#   'sudden',
#   'cancellation',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebook',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'basically',
#   'charge',
#   'regulating',
#   'elections'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'texas'],
#  ['trump', 'opens', 'door', 'gun', 'industry', 'sell', 'firearms', 'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'west',
#   'hollywood',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'city'],
#  ['going', 'use', 'self', 'checkout', 'machine', 'whether', 'you', 'like'],
#  ['ways', 'make', 'family', 'road', 'trips', 'easier', 'parents'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'long',
#   'list',
#   'conspiracy',
#   'theories'],
#  ['new', 'york', 'daily', 'news', 'rips', 'nfl', 'anthem', 'kneeling', 'ban'],
#  ['judge', 'ruled', 'one', 'immigrant', 'right', 'hearing', 'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'students',
#   'affected',
#   'gun',
#   'violence'],
#  ['tig', 'notaro', 'tells', 'ellen', 'degeneres', 'sons', 'passion', 'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'west',
#   'hollywood',
#   'hands',
#   'keys',
#   'city'],
#  ['believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'unseat'],
#  ['anna', 'kournikova', 'dancing', 'bouncing', 'baby', 'cutest', 'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'stand',
#   'anthem',
#   'maybe',
#   'country'],
#  ['facebook',
#   'accused',
#   'reading',
#   'texts',
#   'accessing',
#   'microphones',
#   'lawsuit'],
#  ['self', 'driving', 'uber', 'fatal', 'accident', 'seconds', 'react', 'crash'],
#  ['amazon', 'admits', 'alexa', 'device', 'eavesdropped', 'portland', 'family'],
#  ['man', 'discovers', 'handgun', 'impaled', 'front', 'bumper', 'car'],
#  ['rescue',
#   'cat',
#   'hilarious',
#   'wide',
#   'eyed',
#   'expression',
#   'scan',
#   'confirms',
#   'pregnant'],
#  ['weirdest', 'promposals', 'include', 'teen', 'faked', 'birth'],
#  ['trump', 'american', 'far', 'right', 'stoke', 'hate', 'canada'],
#  ['far',
#   'right',
#   'anti',
#   'establishment',
#   'parties',
#   'set',
#   'form',
#   'italy',
#   'new',
#   'government'],
#  ['sarah', 'silverman', 'sees', 'reason', 'louis', 'continue', 'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'said',
#   'abused',
#   'women',
#   'pray',
#   'removed',
#   'post'],
#  ['americans', 'ever', 'support', 'sex', 'marriage'],
#  ['brynn', 'cartelli', 'becomes', 'youngest', 'ever', 'winner', 'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'saying',
#   'schools',
#   'call',
#   'ice',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'texas',
#   'winning',
#   'democratic',
#   'nod',
#   'governor'],
#  ['report',
#   'michael',
#   'cohen',
#   'business',
#   'partner',
#   'cooperating',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'hall',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louis',
#   'dreyfus',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'tribute',
#   'husband',
#   'barack'],
#  ['spot',
#   'trevor',
#   'noah',
#   'black',
#   'panther',
#   'daily',
#   'show',
#   'host',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'donald',
#   'trump',
#   'themed',
#   'reddit',
#   'forum'],
#  ['calls',
#   'boycott',
#   'restaurant',
#   'duty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'rwandan',
#   'genocide',
#   'country',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey', 'abrams', 'wins', 'democratic', 'primary', 'georgia', 'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'question',
#   'ask',
#   'donald',
#   'trump',
#   'else',
#   'dared'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'scary',
#   'time',
#   'princeton',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons', 'started', 'conversation', 'responsible', 'finishing'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways', 'netflix', 'tricks', 'watching', 'shows', 'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'one',
#   'demeaning',
#   'thing',
#   'exchange',
#   'deadpool',
#   'cameo'],
#  ['robert', 'de', 'niro', 'bans', 'trump', 'every', 'nobu', 'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'fan',
#   'blaming',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'grooming',
#   'children',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'apologize',
#   'to',
#   'world',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'prince',
#   'william',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'next',
#   'level',
#   'tonight',
#   'show'],
#  ['still', 'ready', 'party', 'taken', 'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump', 'rallies', 'conservatives', 'promise', 'abortion', 'curbs'],
#  ['aclu', 'suing', 'strike', 'ohio', 'congressional', 'map'],
#  ['latest', 'school', 'shooting', 'really', 'stirred', 'the', 'gun', 'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'family',
#   'season',
#   'finale'],
#  ['ellen', 'grills', 'mark', 'wahlberg', 'shirtless', 'instagram', 'selfies'],
#  ['idris', 'elba', 'star', 'new', 'hunchback', 'notre', 'dame', 'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'past',
#   'abuse',
#   'risk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'national', 'anthem'],
#  ['conan', 'brien', 'muscles', 'royal', 'wedding', 'spoof', 'ads'],
#  ['house', 'republicans', 'report', 'progress', 'immigration', 'deal'],
#  ['democrats',
#   'invited',
#   'review',
#   'classified',
#   'documents',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'pointed',
#   'gun',
#   'teenager',
#   'advances',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'entitled',
#   'millennial',
#   'swears',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'included',
#   'classified',
#   'briefing',
#   'fbi',
#   'informant'],
#  ['machines',
#   'always',
#   'steal',
#   'jobs',
#   'increasingly',
#   'rob',
#   'our',
#   'work',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'bothers', 'called', 'liar'],
#  ['trump', 'blocking', 'people', 'twitter', 'judge', 'rules'],
#  ['mostly',
#   'non',
#   'christian',
#   'militia',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'christians',
#   'want',
#   'trump',
#   'intervene'],
#  ['tulsi',
#   'gabbard',
#   'syria',
#   'views',
#   'cost',
#   'support',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'runoff',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'sexy',
#   'stormtroopers'],
#  ['establishment',
#   'backed',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'texas'],
#  ['senators', 'unveil', 'bill', 'crack', 'sexual', 'harassment'],
#  ['trips', 'take', 'new', 'york', 'city', 'long', 'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['latest',
#   'entries',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'cheer'],
#  ['bad', 'lip', 'reading', 'reveals', 'really', 'said', 'royal', 'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'covering',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'iran',
#   'people',
#   'respond',
#   'pompeo',
#   'threats',
#   'punch',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'support',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'single', 'american', 'idol'],
#  ['call', 'cops', 'watch', 'powerful', 'monologue', 'on', 'racism'],
#  ['amazon',
#   'selling',
#   'cops',
#   'facial',
#   'recognition',
#   'tool',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'like',
#   'wrecking',
#   'ball',
#   'prank',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'porn',
#   'stars',
#   'skit',
#   'donald',
#   'trump',
#   'snl'],
#  ['adam', 'rippon', 'wins', 'dancing', 'stars', 'destined'],
#  ['emilia', 'clarke', 'never', 'try', 'imitate', 'chewbacca', 'ever'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'runner',
#   'reveals',
#   'dating'],
#  ['colbert', 'resist', 'turning', 'trump', 'nickname', 'pee', 'tape', 'joke'],
#  ['seth',
#   'meyers',
#   'forced',
#   'tweak',
#   'donald',
#   'trump',
#   'latest',
#   'twitter',
#   'rant',
#   'time'],
#  ['boy', 'says', 'teacher', 'told', 'fault', 'police', 'shoot', 'him', 'age'],
#  ['cops', 'accused', 'racism', 'detaining', 'black', 'man', 'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'going',
#   'shoot'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'standoff',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald', 'glover', 'board', 'lando', 'calrissian', 'pansexuality', 'solo'],
#  ['charlize', 'theron', 'play', 'megyn', 'kelly', 'film', 'roger', 'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'store',
#   'donations',
#   'nra',
#   'backed',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'stop',
#   'arresting',
#   'people',
#   'smoking',
#   'pot',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'still',
#   'somehow',
#   'unaware',
#   'intel',
#   'russia',
#   'interference',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'pay',
#   'trump',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'soon',
#   'allowed',
#   'review',
#   'classified',
#   'info',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'worst',
#   'part',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'allegiance',
#   'students',
#   'bullet',
#   'riddled',
#   'schools'],
#  ['ellen', 'gets', 'david', 'spade', 'open', 'dating', 'younger', 'women'],
#  ['ceasefire',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'dummies',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'different',
#   'turn'],
#  ['georgia', 'gop', 'governor', 'primary', 'focuses', 'guns', 'immigration'],
#  ['glaad',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'offers',
#   'store',
#   'beauty',
#   'classes',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governor',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'let',
#   'schools',
#   'co',
#   'workers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'health',
#   'care',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'inside',
#   'track'],
#  ['problems', 'commemorative', 'trump', 'kim', 'jong', 'un', 'coin'],
#  ['giuliani', 'new', 'stance', 'russian', 'collusion', 'illegal'],
#  ['onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'cease',
#   'desist',
#   'note'],
#  ['democrats',
#   'want',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['emails', 'lawmakers', 'shrug', 'trump', 'lax', 'cellphone', 'security'],
#  ['try', 'stink', 'bug', 'flavored', 'jelly', 'bellys'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'florida',
#   'city'],
#  ['congress', 'wall', 'street', 'favor', 'banks', 'post', 'record', 'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'epa',
#   'meeting',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'russian',
#   'connections',
#   'aeroflot'],
#  ['lonely',
#   'planet',
#   'top',
#   'european',
#   'destinations',
#   'take',
#   'aim',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'anti',
#   'spanish',
#   'rant',
#   'person'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trump',
#   'chilling',
#   'reason',
#   'slamming',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'bathroom',
#   'fight'],
#  ['ex',
#   'trump',
#   'adviser',
#   'calls',
#   'president',
#   'claims',
#   'informant',
#   'spied',
#   'campaign',
#   'embarrassing'],
#  ['vietnam', 'test', 'happens', 'abandons', 'climate', 'diplomacy'],
#  ['one',
#   'third',
#   'americans',
#   'think',
#   'trump',
#   'successfully',
#   'draining',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'meghan',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'unapologetic',
#   'year',
#   'age',
#   'gap',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'sides',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'on',
#   'support'],
#  ['family',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'worst',
#   'president',
#   'ever',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'store',
#   'company',
#   'support',
#   'homos'],
#  ['instagram', 'adding', 'mute', 'button', 'sake', 'sanity'],
#  ['publix', 'censors', 'teen', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['say', 'sexist', 'passengers', 'female', 'pilot', 'perfect', 'response'],
#  ['time',
#   'takes',
#   'aim',
#   'mcdonald',
#   'walmart',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuela',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'elected',
#   'amid',
#   'allegations',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europe',
#   'support',
#   'nuclear',
#   'deal',
#   'enough',
#   'america',
#   'withdrawal'],
#  ['far',
#   'right',
#   'mob',
#   'attacks',
#   'year',
#   'old',
#   'liberal',
#   'greek',
#   'mayor'],
#  ['shawn',
#   'mendes',
#   'khalid',
#   'perform',
#   'parkland',
#   'survivors',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rice',
#   'mother',
#   'opening',
#   'youth',
#   'center',
#   'honor',
#   'son',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'moments',
#   'action',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'word', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'god',
#   'made',
#   'like',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual', 'asteroid', 'could', 'interstellar', 'guest', 'solar', 'system'],
#  ['started',
#   'suicide',
#   'prevention',
#   'site',
#   'age',
#   'still',
#   'going',
#   'strong'],
#  ['roger', 'stone', 'says', 'prepared', 'conjured', 'mueller', 'indictment'],
#  ['hillary', 'clinton', 'endorse', 'andrew', 'cuomo', 'election'],
#  ['supreme', 'court', 'made', 'lot', 'harder', 'sue', 'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'hired',
#   'illegally',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'new',
#   'side',
#   'gay',
#   'experience',
#   'latest',
#   'book'],
#  ['alone',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'real',
#   'life',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'attending',
#   'royal',
#   'wedding'],
#  ['movies', 'coming', 'netflix', 'week'],
#  ['obamas', 'coming', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'justin',
#   'theroux',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'trump',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'talk',
#   'trump',
#   'trump',
#   'hears',
#   'fbi',
#   'source'],
#  ['democrats', 'plan', 'big', 'anti', 'corruption', 'theme', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'silence',
#   'calls',
#   'change',
#   'billboard',
#   'music',
#   'awards'],
#  ['asked',
#   'american',
#   'public',
#   'settle',
#   'the',
#   'internet',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'lift',
#   'ban',
#   'extreme',
#   'hunting',
#   'tactics',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['supreme',
#   'court',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'spot',
#   'box',
#   'office',
#   'avengers',
#   'infinity',
#   'war'],
#  ['westworld', 'subtly', 'tease', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'his',
#   'son'],
#  ['marvel', 'exec', 'tried', 'stop', 'jarring', 'infinity', 'war', 'death'],
#  ['jake', 'gyllenhaal', 'set', 'star', 'villain', 'spider', 'man', 'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['pakistan', 'bitch', 'video', 'captures', 'driver', 'racist', 'rant'],
#  ['grey',
#   'gardens',
#   'ladies',
#   'the',
#   'unwitting',
#   'godmothers',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['year', 'old', 'boy', 'superhero', 'alabama', 'homeless', 'population'],
#  ['john', 'oliver', 'best', 'time', 'mocking', 'the', 'royal', 'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele', 'hill', 'honored', 'nabj', 'journalist', 'year'],
#  ['french', 'digital', 'minister', 'comes', 'gay', 'fight', 'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'cannes',
#   'film',
#   'festival'],
#  ['year',
#   'old',
#   'gay',
#   'man',
#   'proves',
#   'never',
#   'old',
#   'attend',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'meddled',
#   'west',
#   'virginia',
#   'senate',
#   'primary',
#   'receive',
#   'penny',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'allegedly',
#   'harassing',
#   'woman',
#   'peeing',
#   'seat'],
#  ['mike', 'pompeo', 'promises', 'crush', 'iran', 'achieve', 'better', 'deal'],
#  ['majestic', 'islands', 'europe', 'tourists', 'know', 'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'country',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['china',
#   'putting',
#   'trade',
#   'war',
#   'hold',
#   'treasury',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trump', 'top', 'economic', 'adviser', 'says', 'amazon', 'threats', 'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'myanmar',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'wrap',
#   'trump',
#   'obstruction',
#   'probe',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'racist',
#   'coverage',
#   'royal',
#   'wedding'],
#  ['kathryn', 'newton', 'boldest', 'teen', 'tv', 'ready', 'grow'],
#  ['stephanie', 'kelton', 'biggest', 'idea', 'washington'],
#  ['texas',
#   'gov',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'fey',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'trump'],
#  ['day',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'sit',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwin',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'snl',
#   'finale'],
#  ['asia',
#   'argento',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'raped',
#   'harvey',
#   'weinstein'],
#  ['tina', 'fey', 'tries', 'mean', 'girls', 'musical', 'snl'],
#  ['parents',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump', 'real', 'americans', 'get', 'tough', 'russia', 'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'baby',
#   'boy',
#   'adorable',
#   'photo'],
#  ['texas', 'lt', 'gov', 'dan', 'patrick', 'touts', 'need', 'arm', 'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'media',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump', 'sets', 'showdown', 'doj', 'claims', 'campaign', 'surveillance'],
#  ['jim',
#   'carrey',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'reviewing',
#   'wedding',
#   'the',
#   'big',
#   'day'],
#  ['jimmy', 'fallon', 'reveals', 'viewers', 'biggest', 'wedding', 'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'razz',
#   'lawyer',
#   'ranted',
#   'spanish',
#   'speakers'],
#  ['watch', 'amazon', 'prime', 'new', 'week'],
#  ['ferrell',
#   'molly',
#   'shannon',
#   'cover',
#   'royal',
#   'wedding',
#   'cord',
#   'and',
#   'tish'],
#  ['artist', 'formerly', 'known', 'cedric', 'the', 'entertainer', 'arrived'],
#  ['mark', 'kelly', 'trump', 'rolled', 'nra', 'nothing', 'guns', 'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'trust',
#   'pays',
#   'kids',
#   'marrying',
#   'white',
#   'people'],
#  ['houston', 'police', 'chief', 'says', 'sick', 'inaction', 'gun', 'control'],
#  ['history', 'the', 'national', 'anthem', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['victims', 'the', 'santa', 'fe', 'high', 'school', 'shooting'],
#  ['ceo',
#   'took',
#   'pay',
#   'cut',
#   'give',
#   'employees',
#   'year',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'emissary',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'report'],
#  ['trump',
#   'misspells',
#   'melania',
#   'name',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill', 'maher', 'reveals', 'things', 'know', 'michael', 'cohen'],
#  ['watch', 'hulu', 'new', 'week'],
#  ['students',
#   'stage',
#   'sit',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryan',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'scary',
#   'amount',
#   'appearance',
#   'bill',
#   'gates',
#   'daughter'],
#  ['ex',
#   'russian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'uk',
#   'hospital',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'surprise',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'chapter',
#   'bankruptcy',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'shooting'],
#  ['michelle',
#   'wolf',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'closer',
#   'look',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'immigration',
#   'courts',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'mccain'],
#  ['colbert',
#   'super',
#   'graphic',
#   'way',
#   'describing',
#   'deep',
#   'mueller',
#   'probe',
#   'goes'],
#  ['jack', 'osbourne', 'wife', 'files', 'divorce'],
#  ['meek', 'mill', 'backs', 'trump', 'event', 'prison', 'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter', 'users', 'joke', 'trump', 'wants', 'prison', 'reform', 'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'resign',
#   'country',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'worst',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'new',
#   'baby',
#   'boy',
#   'love'],
#  ['alec', 'baldwin', 'wife', 'hilaria', 'welcome', 'another', 'baby', 'boy'],
#  ['kate', 'mckinnon', 'breaks', 'another', 'impression', 'rudy', 'giuliani'],
#  ['smallville',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'sex',
#   'cult',
#   'first',
#   'place'],
#  ['trump',
#   'white',
#   'house',
#   'kills',
#   'yanny',
#   'laurel',
#   'debate',
#   'ridiculous',
#   'clip'],
#  ['jennifer',
#   'aniston',
#   'play',
#   'lesbian',
#   'president',
#   'netflix',
#   'first',
#   'ladies'],
#  ['break', 'book', 'shadows', 'the', 'charmed', 'reboot', 'trailer'],
#  ['former',
#   'dave',
#   'matthews',
#   'band',
#   'violinist',
#   'boyd',
#   'tinsley',
#   'accused',
#   'sexual',
#   'misconduct'],
#  ['many', 'people', 'name', 'single', 'book', 'jimmy', 'kimmel'],
#  ['ellen',
#   'degeneres',
#   'hilariously',
#   'explains',
#   'saved',
#   'meghan',
#   'markle',
#   'life'],
#  ['lawyer',
#   'ranted',
#   'spanish',
#   'speakers',
#   'faces',
#   'office',
#   'eviction',
#   'disciplinary',
#   'complaint'],
#  ['hannity',
#   'flips',
#   'mueller',
#   'probe',
#   'direct',
#   'threat',
#   'american',
#   'republic'],
#  ['top',
#   'democrats',
#   'want',
#   'answers',
#   'global',
#   'health',
#   'security',
#   'head',
#   'sudden',
#   'departure'],
#  ['gun',
#   'owners',
#   'non',
#   'gun',
#   'owners',
#   'actually',
#   'agree',
#   'lot',
#   'gun',
#   'reforms'],
#  ['twitter',
#   'users',
#   'pan',
#   'ted',
#   'cruz',
#   'tweets',
#   'prayers',
#   'santa',
#   'fe',
#   'school',
#   'shooting',
#   'victims'],
#  ['states', 'ban', 'bump', 'stocks', 'enforce', 'law'],
#  ['liberal', 'billionaire', 'tom', 'steyer', 'base'],
#  ['sen',
#   'dean',
#   'heller',
#   'campaign',
#   'paid',
#   'social',
#   'media',
#   'influencer',
#   'son'],
#  ['interior',
#   'dept',
#   'dodges',
#   'watchdog',
#   'questions',
#   'zinke',
#   'call',
#   'alaska',
#   'senators'],
#  ['blake',
#   'lively',
#   'teases',
#   'ryan',
#   'reynolds',
#   'hugh',
#   'jackman',
#   'bromance'],
#  ['happytime', 'murders', 'adult', 'themed', 'movie', 'puppets'],
#  ['photo',
#   'daniel',
#   'radcliffe',
#   'holding',
#   'guns',
#   'crazy',
#   'slippers',
#   'becomes',
#   'magical',
#   'meme'],
#  ['bill', 'gates', 'says', 'trump', 'know', 'difference', 'hpv', 'hiv'],
#  ['bachelorette', 'bios', 'are', 'terrible'],
#  ['steven',
#   'tyler',
#   'admits',
#   'hitting',
#   'daughter',
#   'liv',
#   'famous',
#   'pal',
#   'watched'],
#  ['hospice',
#   'overdosed',
#   'patients',
#   'hasten',
#   'deaths',
#   'former',
#   'health',
#   'care',
#   'executive',
#   'admits'],
#  ['kimmel',
#   'brings',
#   'house',
#   'giving',
#   'trump',
#   'latest',
#   'tweet',
#   'new',
#   'ending'],
#  ['former',
#   'wwf',
#   'wrestler',
#   'severely',
#   'beaten',
#   'outside',
#   'california',
#   'home'],
#  ['robert',
#   'wilkie',
#   'picked',
#   'new',
#   'va',
#   'secretary',
#   'surprise',
#   'announcement'],
#  ['trump',
#   'new',
#   'domestic',
#   'gag',
#   'rule',
#   'would',
#   'strip',
#   'funds',
#   'planned',
#   'parenthood'],
#  ['rudy',
#   'giuliani',
#   'reverses',
#   'trump',
#   'team',
#   'position',
#   'says',
#   'president',
#   'obstruct',
#   'justice'],
#  ['social', 'anxiety', 'get', 'attention', 'deserves'],
#  ['deadpool', 'already', 'breaking', 'box', 'office', 'records'],
#  ['obamacare', 'premiums', 'way', 'higher', 'next', 'year', 'be'],
#  ['comprehensive', 'list', 'everything', 'jr', 'know', 'infamous', 'meeting'],
#  ['report',
#   'manafort',
#   'former',
#   'son',
#   'law',
#   'cuts',
#   'plea',
#   'deal',
#   'cooperate',
#   'government'],
#  ['trump',
#   'briefly',
#   'responds',
#   'santa',
#   'fe',
#   'school',
#   'shooting',
#   'pivoting'],
#  ['late', 'night', 'writer', 'shreds', 'roseanne', 'better', 'ever', 'racist'],
#  ['trump',
#   'nasa',
#   'chief',
#   'apparently',
#   'changed',
#   'tune',
#   'climate',
#   'change'],
#  ['freedom',
#   'caucus',
#   'sinks',
#   'key',
#   'part',
#   'paul',
#   'ryan',
#   'welfare',
#   'reform',
#   'agenda'],
#  ['transphobic',
#   'congressional',
#   'hopeful',
#   'berates',
#   'person',
#   'inside',
#   'public',
#   'restroom'],
#  ['singer', 'ryan', 'amador', 'says', 'loverboy', 'second', 'coming'],
#  ['newest', 'head', 'cracker', 'hear', 'brainstorm', 'green', 'needle'],
#  ['meditation', 'like', 'human', 'way', 'clearing', 'browser', 'cache'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['italy',
#   'looks',
#   'befriend',
#   'russia',
#   'populist',
#   'parties',
#   'try',
#   'to',
#   'form',
#   'government'],
#  ['business',
#   'groups',
#   'might',
#   'quietly',
#   'killing',
#   'bill',
#   'would',
#   'bring',
#   'sexual',
#   'abuse',
#   'claims',
#   'light'],
#  ['kushner',
#   'family',
#   'reportedly',
#   'close',
#   'getting',
#   'bailout',
#   'flagship',
#   'tower'],
#  ['trump', 'says', 'give', 'charity', 'royal', 'wedding', 'll', 'see'],
#  ['federal',
#   'prosecutors',
#   'still',
#   'trying',
#   'turn',
#   'trump',
#   'inauguration',
#   'protesters',
#   'felons'],
#  ['republican', 'immigration', 'fight', 'derails', 'food', 'stamp', 'bill'],
#  ['retiring',
#   'lawmakers',
#   'added',
#   'million',
#   'campaign',
#   'treasuries',
#   'since',
#   'last',
#   'election'],
#  ['facing',
#   'farm',
#   'bill',
#   'vote',
#   'problems',
#   'gop',
#   'leaders',
#   'may',
#   'make',
#   'deal'],
#  ['methodists',
#   'surprise',
#   'gay',
#   'minister',
#   'world',
#   'best',
#   'pastor',
#   'certificates',
#   'theft',
#   'diploma'],
#  ['china',
#   'marks',
#   'another',
#   'milestone',
#   'quest',
#   'become',
#   'space',
#   'superpower'],
#  ['stephen',
#   'colbert',
#   'wants',
#   'mueller',
#   'give',
#   'trump',
#   'special',
#   'anniversary',
#   'gift'],
#  ['trump',
#   'stormy',
#   'daniels',
#   'disclosure',
#   'still',
#   'leaves',
#   'questions',
#   'payments',
#   'cohen'],
#  ['please', 'enjoy', 'animated', 'history', 'tina', 'fey', 'snl', 'return'],
#  ['controversial',
#   'way',
#   'california',
#   'schools',
#   'handling',
#   'students',
#   'misbehavior'],
#  ['deaf', 'activist', 'points', 'marvel', 'diversity', 'problem', 'race'],
#  ['magnum', 'trailer', 'lots', 'close', 'shaves', 'big', 'mustache'],
#  ['gina', 'haspel', 'confirmed', 'cia', 'director', 'aid', 'democrats'],
#  ['boulder',
#   'city',
#   'council',
#   'unanimously',
#   'votes',
#   'ban',
#   'assault',
#   'weapons',
#   'high',
#   'capacity',
#   'magazines'],
#  ['chrissy', 'teigen', 'john', 'legend', 'welcome', 'baby', 'boy'],
#  ['terrifying', 'clip', 'shows', 'never', 'run', 'tree', 'thunderstorms'],
#  ['mitch',
#   'mcconnell',
#   'taps',
#   'anti',
#   'lgbtq',
#   'bigot',
#   'religious',
#   'freedom',
#   'panel'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'unexpected',
#   'advice',
#   'north',
#   'korea'],
#  ['devin',
#   'nunes',
#   'fundraising',
#   'fbi',
#   'attacks',
#   'tells',
#   'potential',
#   'donors',
#   'trump',
#   'says',
#   'hero'],
#  ['former',
#   'mexican',
#   'president',
#   'warns',
#   'donald',
#   'trump',
#   'got',
#   'get',
#   'st',
#   'together'],
#  ['fox',
#   'news',
#   'first',
#   'female',
#   'ceo',
#   'named',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['battle', 'save', 'dying', 'soil'],
#  ['latino',
#   'man',
#   'insulted',
#   'starbucks',
#   'barista',
#   'writes',
#   'slur',
#   'cup'],
#  ['snl',
#   'cast',
#   'member',
#   'claims',
#   'trump',
#   'faked',
#   'bizarre',
#   'phone',
#   'call',
#   'rehearsals'],
#  ['jimmy',
#   'kimmel',
#   'comes',
#   'clean',
#   'may',
#   'owe',
#   'donald',
#   'trump',
#   'apology'],
#  ['trevor',
#   'noah',
#   'skewers',
#   'betsy',
#   'devos',
#   'fake',
#   'profit',
#   'university',
#   'ad'],
#  ['serena', 'williams', 'explains', 'father', 'walk', 'her', 'aisle'],
#  ['star',
#   'wars',
#   'writer',
#   'confirms',
#   'donald',
#   'glover',
#   'character',
#   'pansexual',
#   'solo'],
#  ['medical',
#   'professionals',
#   'fact',
#   'check',
#   'grey',
#   'anatomy',
#   'sex',
#   'scenes'],
#  ['amy',
#   'schumer',
#   'nails',
#   'meghan',
#   'markle',
#   'fairytale',
#   'wedding',
#   'actually',
#   'sucks'],
#  ['michael',
#   'keaton',
#   'ends',
#   'kent',
#   'state',
#   'commencement',
#   'speech',
#   'batman'],
#  ['black', 'profiled', 'share', 'story'],
#  ['black',
#   'actresses',
#   'cannes',
#   'protest',
#   'racism',
#   'french',
#   'film',
#   'industry'],
#  ['michael', 'jordan', 'denies', 'rumors', 'date', 'black', 'women'],
#  ['scam',
#   'pacs',
#   'ripped',
#   'conservatives',
#   'pro',
#   'police',
#   'anti',
#   'abortion',
#   'messages',
#   'prosecutors'],
#  ['mtv',
#   'suspends',
#   'catfish',
#   'probes',
#   'nev',
#   'schulman',
#   'sexual',
#   'misconduct',
#   'claims'],
#  ['trump',
#   'ice',
#   'increasingly',
#   'arresting',
#   'immigrants',
#   'without',
#   'criminal',
#   'convictions'],
#  ['special',
#   'counsel',
#   'hits',
#   'roger',
#   'stone',
#   'social',
#   'media',
#   'advisor',
#   'subpoenas'],
#  ['whitney',
#   'houston',
#   'sexually',
#   'abused',
#   'dee',
#   'dee',
#   'warwick',
#   'cannes',
#   'documentary'],
#  ['patton', 'oswalt', 'joker', 'theory', 'change', 'watch', 'dark', 'knight'],
#  ['josh',
#   'holt',
#   'american',
#   'captive',
#   'venezuela',
#   'begs',
#   'help',
#   'in',
#   'prison',
#   'videos'],
#  ['obama',
#   'photographer',
#   'taunts',
#   'donald',
#   'trump',
#   'calling',
#   'immigrants',
#   'animals'],
#  ['backstreet', 'boys', 'release', 'new', 'song', 'go', 'breaking', 'heart'],
#  ['prince',
#   'knight',
#   'puts',
#   'gay',
#   'inclusive',
#   'twist',
#   'traditional',
#   'fairy',
#   'tales'],
#  ['gay',
#   'conversion',
#   'therapy',
#   'survivor',
#   'recalls',
#   'month',
#   'nightmare',
#   'powerful',
#   'video'],
#  ['gq',
#   'expertly',
#   'spoofs',
#   'vanity',
#   'fair',
#   'annual',
#   'comedy',
#   'issue',
#   'cover'],
#  ['rudy', 'giuliani', 'offers', 'head', 'spinning', 'new', 'defense', 'trump'],
#  ['cynthia',
#   'nixon',
#   'fix',
#   'subway',
#   'ads',
#   'shred',
#   'cuomo',
#   'mta',
#   'commuters',
#   'rejoice'],
#  ['farm', 'bill', 'could', 'huge', 'blow', 'animals'],
#  ['emails',
#   'show',
#   'interior',
#   'expected',
#   'learn',
#   'nothing',
#   'public',
#   'input',
#   'bears',
#   'ears',
#   'review'],
#  ['whistleblower',
#   'leaked',
#   'michael',
#   'cohen',
#   'financials',
#   'potential',
#   'cover',
#   'report'],
#  ['kidnapper', 'accused', 'using', 'alligator', 'hold', 'man', 'captive'],
#  ['miss', 'america', 'pageant', 'headed', 'women', 'email', 'scandal'],
#  ['north',
#   'korea',
#   'threatens',
#   'reconsider',
#   'trump',
#   'summit',
#   'cancels',
#   'south',
#   'korea',
#   'talks'],
#  ['chemical', 'weapons', 'likely', 'used', 'syria', 'watchdog', 'finds'],
#  ['hundreds',
#   'israel',
#   'beyond',
#   'protest',
#   'killings',
#   'palestinians',
#   'gaza',
#   'border'],
#  ['researchers', 'uncover', 'secret', 'pages', 'diary', 'anne', 'frank'],
#  ['stephen',
#   'piscotty',
#   'returns',
#   'bereavement',
#   'hit',
#   'mom',
#   'tribute',
#   'home',
#   'run'],
#  ['senate',
#   'intelligence',
#   'committee',
#   'backs',
#   'gina',
#   'haspel',
#   'lead',
#   'cia'],
#  ['pennsylvania', 'congressional', 'delegation', 'longer', 'men'],
#  ['lando',
#   'calrissian',
#   'star',
#   'wars',
#   'spinoff',
#   'starring',
#   'donald',
#   'glover',
#   'happening'],
#  ['fake',
#   'donald',
#   'trump',
#   'sean',
#   'hannity',
#   'pillow',
#   'talk',
#   'late',
#   'show'],
#  ['rapper', 'arrested', 'disorderly', 'conduct', 'public', 'drunkenness'],
#  ['conservatives',
#   'cook',
#   'farm',
#   'bill',
#   'gambit',
#   'get',
#   'vote',
#   'hardline',
#   'immigration',
#   'bill'],
#  ['top', 'novartis', 'lawyer', 'resigns', 'michael', 'cohen', 'deal'],
#  ['birth', 'control', 'emoji'],
#  ['white',
#   'house',
#   'eliminates',
#   'cyber',
#   'czar',
#   'post',
#   'first',
#   'appointee',
#   'leaves'],
#  ['emily',
#   'list',
#   'backed',
#   'lawyer',
#   'wins',
#   'democratic',
#   'primary',
#   'pennsylvania',
#   'swing',
#   'district'],
#  ['robin',
#   'williams',
#   'biographer',
#   'tells',
#   'sweet',
#   'story',
#   'comic',
#   'store',
#   'visit'],
#  ['republicans',
#   'attacking',
#   'nancy',
#   'pelosi',
#   'even',
#   'non',
#   'house',
#   'races'],
# ...
#   'probe',
#   'source',
#   'threatening',
#   'doj'],
#  ['queer',
#   'eye',
#   'star',
#   'karamo',
#   'brown',
#   'engaged',
#   'director',
#   'ian',
#   'jordan'],
#  ['jet', 'launched', 'apple', 'store', 'incredible', 'deals'],
#  ['tom',
#   'hardy',
#   'completely',
#   'unrecognizable',
#   'al',
#   'capone',
#   'new',
#   'movie'],
#  ['woman',
#   'alleges',
#   'rapper',
#   'young',
#   'lo',
#   'raped',
#   'trapped',
#   'chris',
#   'brown',
#   'home'],
#  ['republicans', 'fill', 'court', 'seat', 'denied', 'obama', 'years'],
#  ['man',
#   'wanted',
#   'white',
#   'supremacists',
#   'kill',
#   'black',
#   'neighbor',
#   'burn',
#   'cross',
#   'yard',
#   'fbi'],
#  ['trump', 'announces', 'details', 'meeting', 'kim', 'jong', 'un'],
#  ['samantha',
#   'bee',
#   'delivers',
#   'blistering',
#   'takedown',
#   'former',
#   'ny',
#   'ag',
#   'eric',
#   'schneiderman'],
#  ['jim',
#   'carrey',
#   'scathing',
#   'portrait',
#   'trump',
#   'joker',
#   'give',
#   'nightmares'],
#  ['michelle', 'wolf', 'renews', 'hostilities', 'sarah', 'huckabee', 'sanders'],
#  ['fans', 'erupt', 'fate', 'elias', 'koteas', 'olinsky', 'chicago'],
#  ['people',
#   'street',
#   'apologize',
#   'old',
#   'teachers',
#   'on',
#   'jimmy',
#   'kimmel',
#   'live'],
#  ['stephen',
#   'colbert',
#   'porn',
#   'star',
#   'math',
#   'michael',
#   'cohen',
#   'donald',
#   'trump'],
#  ['pollen', 'bomb', 'every', 'allergy', 'sufferer', 'worst', 'nightmare'],
#  ['jennifer',
#   'lopez',
#   'dances',
#   'least',
#   'danceable',
#   'songs',
#   'tonight',
#   'show'],
#  ['white',
#   'yale',
#   'student',
#   'calls',
#   'cops',
#   'black',
#   'schoolmate',
#   'napping',
#   'dorm',
#   'common',
#   'room'],
#  ['rudy', 'giuliani', 'quits', 'law', 'firm', 'wild', 'week', 'interviews'],
#  ['teddy',
#   'geiger',
#   'makes',
#   'first',
#   'public',
#   'appearance',
#   'since',
#   'coming',
#   'transgender'],
#  ['ariana', 'grande', 'mac', 'miller', 'reportedly', 'break'],
#  ['avengers',
#   'leaks',
#   'get',
#   'support',
#   'year',
#   'old',
#   'interview',
#   'marvel',
#   'directors'],
#  ['good', 'excuse', 'racist', 'impact', 'michigan', 'medicaid', 'proposal'],
#  ['fcc', 'complaints', 'minutes', 'interview', 'stormy', 'daniels'],
#  ['americans',
#   'jailed',
#   'korea',
#   'home',
#   'trump',
#   'may',
#   'made',
#   'others',
#   'situation',
#   'worse'],
#  ['alex', 'strangelove', 'gay', 'teen', 'comedy', 'turn', 'away', 'sex'],
#  ['woman', 'says', 'took', 'home', 'kittens', 'find', 'bobcats'],
#  ['video',
#   'bear',
#   'eating',
#   'ice',
#   'cream',
#   'dairy',
#   'queen',
#   'leads',
#   'charges',
#   'zoo',
#   'owners'],
#  ['iranian',
#   'lawmakers',
#   'mock',
#   'trump',
#   'mental',
#   'capacity',
#   'burn',
#   'flag',
#   'pulls',
#   'nuke',
#   'deal'],
#  ['europeans', 'scramble', 'save', 'iran', 'deal', 'trump', 'withdraws'],
#  ['north',
#   'korea',
#   'releases',
#   'american',
#   'political',
#   'prisoners',
#   'advance',
#   'historic',
#   'summit'],
#  ['establishment',
#   'gop',
#   'notches',
#   'win',
#   'ohio',
#   'primary',
#   'vacant',
#   'house',
#   'seat'],
#  ['eric',
#   'schneiderman',
#   'praised',
#   'movement',
#   'days',
#   'abuse',
#   'allegations',
#   'emerged'],
#  ['trevor',
#   'noah',
#   'unloads',
#   'supposed',
#   'advocate',
#   'women',
#   'eric',
#   'schneiderman'],
#  ['year',
#   'comey',
#   'firing',
#   'scope',
#   'mueller',
#   'probe',
#   'expands',
#   'lawyer',
#   'shell',
#   'company'],
#  ['trump',
#   'inspired',
#   'businessman',
#   'wins',
#   'indiana',
#   'gop',
#   'senate',
#   'primary'],
#  ['gop',
#   'rival',
#   'says',
#   'tammy',
#   'baldwin',
#   'team',
#   'terrorists',
#   'silence',
#   'on',
#   'trump',
#   'cia',
#   'pick'],
#  ['jobs', 'program', 'might', 'get', 'people', 'back', 'work'],
#  ['jim', 'parsons', 'yes', 'still', 'need', 'queer', 'stories', 'onscreen'],
#  ['trump',
#   'accuser',
#   'wins',
#   'democratic',
#   'nomination',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'cia',
#   'information',
#   'share',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'backs',
#   'trump',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'might',
#   'made',
#   'katy',
#   'perry',
#   'kimye',
#   'feud',
#   'lives'],
#  ['kim',
#   'kardashian',
#   'make',
#   'history',
#   'fashion',
#   'council',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'believes',
#   'matt',
#   'lauer',
#   'accusers',
#   'months',
#   'long',
#   'investigation'],
#  ['russians', 'ability', 'change', 'voter', 'data', 'report', 'says'],
#  ['elizabeth',
#   'warren',
#   'pick',
#   'wins',
#   'ohio',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'firing',
#   'gun',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['hired',
#   'firm',
#   'linked',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'inside',
#   'scoop',
#   'trump'],
#  ['rnc',
#   'selling',
#   'sickening',
#   'donald',
#   'trump',
#   'themed',
#   'merch',
#   'ahead',
#   'mother',
#   'day'],
#  ['blankenship',
#   'defeat',
#   'relief',
#   'families',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert', 'shreds', 'trump', 'broken', 'promises', 'talking'],
#  ['new', 'ambassador', 'germany', 'offends', 'hosts', 'hours', 'first', 'day'],
#  ['jordan', 'peele', 'new', 'nightmare', 'coming', 'next', 'year'],
#  ['backstreet', 'boys', 'dressed', 'the', 'spice', 'girls', 'larger', 'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'giuliani',
#   'really',
#   'means'],
#  ['look', 'orlando', 'interim', 'pulse', 'nightclub', 'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trump',
#   'knives',
#   'comment',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'plan',
#   'place',
#   'consider',
#   'replacements',
#   'eric',
#   'schneiderman'],
#  ['former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'state',
#   'new',
#   'homes',
#   'must',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['refugee', 'caravan', 'became', 'scapegoat', 'trump', 'border', 'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver', 'mayor', 'son', 'caught', 'tape', 'berating', 'cop', 'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'north', 'carolina'],
#  ['novartis', 'get', 'money', 'paid', 'trump', 'lawyer'],
#  ['hypocrisy',
#   'melania',
#   'trump',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'page',
#   'page'],
#  ['uninsured', 'rate', 'worsening', 'years', 'obamacare', 'gains'],
#  ['bernie', 'sanders', 'plan', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'savage',
#   'nickname',
#   'latest',
#   'painting'],
#  ['male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'end',
#   'century',
#   'long',
#   'relationship',
#   'boy',
#   'scouts'],
#  ['snack', 'addiction', 'killing', 'orangutans'],
#  ['trump',
#   'pick',
#   'cia',
#   'director',
#   'say',
#   'torture',
#   'program',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'hanging',
#   'black',
#   'figures',
#   'likeness',
#   'lynchings'],
#  ['caliphate', 'trump', 'planet', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'ousted',
#   'gop',
#   'incumbent',
#   'north',
#   'carolina'],
#  ['espn', 'eliminates', 'public', 'editor', 'role', 'calling', 'outdated'],
#  ['michael',
#   'cohen',
#   'selling',
#   'access',
#   'trump',
#   'says',
#   'group',
#   'paid',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'twitter',
#   'big',
#   'cloud',
#   'cocaine'],
#  ['ex',
#   'convict',
#   'blankenship',
#   'loses',
#   'patrick',
#   'morrisey',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trump', 'iran', 'deal', 'exit', 'win', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'vote',
#   'homo',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'issued',
#   'first',
#   'non',
#   'binary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'childish',
#   'gambino',
#   'viral',
#   'video'],
#  ['terry', 'crews', 'black', 'men', 'allowed', 'victims', 'dead'],
#  ['donald', 'glover', 'america', 'eyes', 'jim', 'crow', 'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'trump',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'making',
#   'history',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena', 'davis', 'th', 'husband', 'reza', 'jarrahy', 'divorcing'],
#  ['pauley', 'perrette', 'abby', 'heart', 'wrenching', 'farewell', 'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'character',
#   'gets',
#   'shot'],
#  ['selena', 'gomez', 'pokes', 'fun', 'met', 'gala', 'spray', 'tan', 'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'xi', 'jinping'],
#  ['netanyahu',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'perfect',
#   'audience',
#   'trump'],
#  ['netanyahu',
#   'chef',
#   'blasted',
#   'serving',
#   'japan',
#   'prime',
#   'minister',
#   'dessert',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'withdrawing',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'blankenship',
#   'day',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'york',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'continue',
#   'despite',
#   'attorney',
#   'general',
#   'exit'],
#  ['trump', 'announce', 'whether', 'break', 'iran', 'nuclear', 'deal'],
#  ['politicians',
#   'call',
#   'schneiderman',
#   'resign',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trump',
#   'legal',
#   'strategy',
#   'like',
#   'monkey',
#   'throwing',
#   'poo',
#   'wall'],
#  ['kirsten', 'dunst', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy', 'matrimony', 'proposal', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'incriminating',
#   'information',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'met', 'gala', 'queer', 'superhero'],
#  ['kelly', 'accusers', 'say', 'ask', 'permission', 'to', 'use', 'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'pulling',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['deportation', 'crackdown', 'hurting', 'immigrant', 'victims', 'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'get',
#   'to',
#   'apologize',
#   'air',
#   'to',
#   'trump'],
#  ['blessing', 'best', 'met', 'gala', 'tweets'],
#  ['farm', 'bill', 'would', 'cut', 'food', 'stamps', 'friendly', 'farmers'],
#  ['know', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'west',
#   'virginia',
#   'things',
#   'watch',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivo',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'alex',
#   'winter',
#   'coming',
#   'back',
#   'bill',
#   'ted',
#   'years'],
#  ['solange', 'durag', 'true', 'mvp', 'the', 'met', 'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'hard',
#   'make',
#   'sense',
#   'rudy',
#   'latest',
#   'trump',
#   'defense',
#   'gives'],
#  ['religious', 'imagery', 'stitched', 'throughout', 'the', 'met', 'gala'],
#  ['bob',
#   'marley',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'checking',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'anti',
#   'bullying',
#   'campaign',
#   'ignores',
#   'husband',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'like',
#   'smoking',
#   'weed',
#   'tv'],
#  ['janet',
#   'jackson',
#   'receive',
#   'icon',
#   'award',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['jared',
#   'kushner',
#   'backed',
#   'bill',
#   'could',
#   'last',
#   'shot',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'stalking',
#   'detective',
#   'working',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'scott',
#   'pruitt',
#   'justify',
#   'first',
#   'class',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['trump',
#   'country',
#   'house',
#   'district',
#   'became',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pence',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'vice',
#   'president',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'active',
#   'duty'],
#  ['trump',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'family',
#   'met',
#   'gala',
#   'without',
#   'even',
#   'noticing'],
#  ['bill',
#   'reilly',
#   'offers',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'best',
#   'dressed',
#   'dude',
#   'met',
#   'gala',
#   'living',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hide',
#   'seek',
#   'genius',
#   'dog',
#   'heal',
#   'nation'],
#  ['bank',
#   'america',
#   'appears',
#   'flip',
#   'firearm',
#   'promise',
#   'loan',
#   'to',
#   'remington'],
#  ['gentleman', 'caller', 'presents', 'queer', 'icons', 'never', 'seen'],
#  ['eric', 'schneiderman', 'always', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'firm',
#   'tied',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen', 'colbert', 'hits', 'rudy', 'giuliani', 'brutal', 'fact', 'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'taylor',
#   'swift',
#   'world',
#   'rejoices'],
#  ['jada', 'pinkett', 'smith', 'gets', 'real', 'dating', 'smith', 'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'spilled',
#   'beans',
#   'major',
#   'cameo',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'hailey',
#   'baldwin',
#   'gown',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'sorry',
#   'suggested',
#   'trump',
#   'allowed',
#   'john',
#   'mccain',
#   'funeral'],
#  ['seth', 'meyers', 'perfect', 'line', 'confront', 'donald', 'trump', 'lies'],
#  ['police', 'hope', 'use', 'dna', 'to', 'catch', 'zodiac', 'killer'],
#  ['lili',
#   'reinhart',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'met',
#   'gala'],
#  ['sweetbitter', 'captures', 'grit', 'glamour', 'the', 'restaurant', 'world'],
#  ['mitch', 'mcconnell', 'bends', 'rules', 'confirm', 'trump', 'judges'],
#  ['ryan', 'zinke', 'tale', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary', 'cities', 'working', 'trump', 'era', 'surprising', 'cost'],
#  ['shepard',
#   'smith',
#   'say',
#   'trump',
#   'pulled',
#   'iran',
#   'deal',
#   'made',
#   'decision',
#   'violate'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'crunchy',
#   'new',
#   'way',
#   'chip',
#   'away',
#   'trump'],
#  ['rainbow',
#   'mountains',
#   'peru',
#   'look',
#   'like',
#   'straight',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# ### Creating n-grams

# %%
def create_bigrams(texts, bigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify bigrams in texts and return the texts with bigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

def create_trigrams(texts, trigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify trigrams in texts and return the texts with trigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

# %%
texts = create_bigrams(texts)

# %%
texts
# Out:
# ['mass_shootings texas last week tv',
#  'smith joins diplo nicky jam world_cup official song',
#  'hugh grant marries first_time age',
#  'jim_carrey blasts castrato adam schiff democrats new artwork',
#  'julianna margulies uses donald_trump poop bags pick dog',
#  'morgan_freeman devastated sexual_harassment claims could undermine legacy',
#  'donald_trump lovin new mcdonald jingle tonight_show bit',
#  'watch amazon prime new week',
#  'mike myers reveals like fourth austin powers film',
#  'watch hulu new week',
#  'justin_timberlake visits texas school_shooting victims',
#  'south_korean president meets north_korea kim_jong un talk trump summit',
#  'way life risk remote oyster growing region called robots',
#  'trump crackdown immigrant parents puts kids already strained system',
#  'trump son concerned fbi obtained wiretaps putin ally met trump_jr',
#  'edward_snowden one trump loves vladimir_putin',
#  'booyah obama photographer hilariously trolls trump spy claim',
#  'ireland votes repeal abortion amendment landslide referendum',
#  'ryan_zinke looks reel back critics grand pivot to conservation',
#  'trump scottish golf resort pays women significantly less men report',
#  'weird father_day gifts dad know wants he',
#  'twitter universally entertaining',
#  'mystery wolf like animal reportedly shot montana baffles wildlife officials',
#  'north_korea still open talks trump cancels summit',
#  'men detonate bomb inside indian restaurant near toronto authorities say',
#  'thousands travel home ireland to vote abortion access',
#  'irish voters set liberalize abortion laws landslide exit poll signals',
#  'warriors coach steve kerr calls nfl ban protests fake patriotism',
#  'historic victory barbados elects first female prime_minister',
#  'police killed least black americans moment colin_kaepernick protested',
#  'jack johnson pardoned taboo sex still criminalized',
#  'bet chairman ceo debra lee stepping',
#  'rachel dolezal faces felony charges welfare fraud',
#  'bishop michael curry joins christian march white_house to reclaim jesus',
#  'kanye_west spent photo whitney_houston bathroom album cover',
#  'morgan_freeman dropped marketing campaigns harassment accusations',
#  'chinese exclusion act help us understand immigration politics today',
#  'trump new maga themed swimwear sinks twitter',
#  'seth_meyers funny regret trump cancels north_korea summit',
#  'colbert wants turn nyc subway rides new terrible punishment',
#  'man faces charges pulling knife stun gun muslim students mcdonald',
#  'jimmy_kimmel knows iran supreme leader watches tom jerry',
#  'people injured indiana school_shooting',
#  'people rattled much nigerian man looks_like chadwick boseman',
#  'david cross proves yet terrible apologizing',
#  'sesame_street creators sue makers upcoming adult themed puppet film',
#  'missed saddest death avengers_infinity war',
#  'george_takei accuser walks_back story drugging sexual_assault',
#  'samantha_bee parents think america basically war zone',
#  'pete davidson says mental_illness ruin romance',
#  'james_corden adam_levine get pulled carpool_karaoke',
#  'emilia clarke dishes final game_thrones scene',
#  'hollywood need difficult men make great tv',
#  'harvey_weinstein accusers say never_thought would arrested',
#  'harvey_weinstein turns police alleged sex crimes',
#  'john_mayer weird new low budget video meme worthy masterpiece',
#  'boba fett getting star_wars movie',
#  'trump suggests north_korea summit could still happen',
#  'roger stone pressed damaging emails hillary_clinton wikileaks report',
#  'publix suspends contributions nra backed politician amid protests',
#  'twitter bots may delivered donald_trump victory research paper says',
#  'bag wet socks apparently living white_house press briefing room',
#  'member far_right proud boys menaced twitter user doorstep',
#  'things the nra blamed the texas school_shooting',
#  'happens catholic hospital try save',
#  'trump new executive_orders make easier fire federal workers',
#  'monsanto bayer set merge care',
#  'joy watching harvey_weinstein perp walk',
#  'funniest_tweets women week',
#  'queer_eye star bobby berk gave desk makeover incredible',
#  'older gay_men try new gay slang hilarious video',
#  'rupaul_drag race teaching straight people queer culture',
#  'fish market buys freedom fred pound octopus',
#  'north_korea threatens call trump summit warns nuclear showdown',
#  'investigation finds russian missile shot flight mh',
#  'north_korea demolishes tunnels nuclear test site reports say',
#  'kim_jong un baited trump canceling north_korea summit',
#  'michelle_obama reveals cover upcoming memoir becoming',
#  'late_night writer breathless royal_wedding recap one need',
#  'morgan_freeman accused inappropriate behavior sexual_harassment',
#  'jets chairman christopher johnson fine players anthem protests',
#  'andy_cohen taylor_swift katy_perry drama',
#  'infinity_war writers try clear marvel problematic timeline',
#  'david blaine chews glass lets james_corden puncture cheek',
#  'amy_poehler parks recreation revival would amazing',
#  'colbert exposes biggest flaw trump latest conspiracy_theory',
#  'seth_meyers gives donald_trump valuable marketing advice',
#  'launches auto import probe china vows defend interests',
#  'women pulled stops land dream job',
#  'wife asked husband fenty highlighter got pack highlighters hairbrush',
#  'trump roasted rushing defend tomi_lahren ignoring real victims',
#  'trump abruptly cancels north_korea summit kim_jong un',
#  'devin_nunes linked winery faced suit alleged coke prostitute yacht party',
#  'immigrant children accuse border_patrol abuse neglect report shows',
#  'ireland historic vote legalizing abortion haunted trump brexit',
#  'trump lawyer attended doj meeting confidential fbi informant',
#  'senate advances court_pick said planned_parenthood kills females year',
#  'rudy_giuliani trump interview mueller get spygate report',
#  'kentucky attorney running judge dies day primary win',
#  'chrissy_teigen taunts donald_trump twitter blocking ruling',
#  'koch network going one trump favorite congressmen',
#  'trump posthumously pardons boxer jack johnson',
#  'ellen tears ashton_kutcher donates million wildlife fund',
#  'ariana_grande reveals bee tattoo honor manchester attack',
#  'kim_kardashian wished kanye_west happy anniversary fine pretty cute',
#  'chris_hemsworth dances wrecking ball kids living_room',
#  'moses farrow defends woody_allen accuses mia farrow abuse',
#  'gwyneth_paltrow says brad_pitt threatened kill harvey_weinstein',
#  'stephen king reveals donald_trump blocked twitter',
#  'fans back jessica walter addressed verbal harassment jeffrey tambor',
#  'jessica walter discusses jeffrey tambor alleged harassment male co_stars brush',
#  'harvey_weinstein expected turn to nypd sex crimes',
#  'samantha_bee torches ice let shut fk',
#  'scott_pruitt twice introduced anti_abortion bills giving men property rights fetuses',
#  'twitter critics mercilessly mock trump canceling summit kim',
#  'civil_rights groups rip senate bill revising sexual_harassment policy',
#  'alabama sues exclude undocumented_immigrants census count',
#  'cynthia_nixon vows keep fighting predictably losing party endorsement',
#  'white_house officials reportedly considered ignoring new climate research',
#  'read trump letter kim_jong un canceling north_korea summit',
#  'south_korea responds trump sudden cancellation kim_jong un summit',
#  'facebook new ad rules prove basically charge regulating elections',
#  'border agent fatally_shoots migrant woman texas',
#  'trump opens door gun industry sell firearms abroad',
#  'stormy_daniels day declared west hollywood adult star gets key city',
#  'going use self checkout machine whether you like',
#  'ways_make family road_trips easier parents',
#  'jake_tapper shreds donald_trump long list conspiracy_theories',
#  'new_york daily_news rips nfl anthem kneeling ban',
#  'judge ruled one immigrant right hearing others',
#  'house_democrats offer internships students affected gun_violence',
#  'tig notaro tells ellen_degeneres sons passion trash',
#  'stormy_daniels thanks wonderful gay dads west hollywood hands keys city',
#  'believe queer_eye season drops next month',
#  'gay man denied marriage license kim_davis loses bid unseat',
#  'anna kournikova dancing bouncing baby cutest thing',
#  'trump says nfl_players unwilling stand anthem maybe country',
#  'facebook accused reading texts accessing microphones lawsuit',
#  'self_driving uber fatal accident seconds react crash',
#  'amazon admits alexa device eavesdropped portland family',
#  'man discovers handgun impaled front bumper car',
#  'rescue cat hilarious wide eyed expression scan confirms pregnant',
#  'weirdest promposals include teen faked birth',
#  'trump american far_right stoke hate canada',
#  'far_right anti establishment parties set form italy new government',
#  'sarah_silverman sees reason louis continue artist',
#  'southern baptist leader said abused women pray removed post',
#  'americans ever support sex_marriage',
#  'brynn cartelli becomes youngest ever winner voice',
#  'betsy_devos stirs uproar saying schools call ice undocumented kids',
#  'sandy_hook families fbi agent sue alex_jones defamation',
#  'high_school teacher defeats kentucky house majority leader gop_primary',
#  'lupe valdez makes_history texas winning democratic nod governor',
#  'report michael_cohen business partner cooperating prosecutors',
#  'brandi chastain totally agrees hall_fame plaque looks nothing like her',
#  'scientists turn dna technology to search loch ness monster',
#  'late_night writer vows take red hats back trump_supporters',
#  'julia_louis dreyfus receive mark twain prize american humor',
#  'michelle_obama shares intimate wedding photo tribute husband barack',
#  'spot trevor_noah black_panther daily_show host stealth cameo revealed',
#  'donald glover fans execute stunning coup donald_trump themed reddit forum',
#  'calls boycott restaurant duty cop allegedly assaults black women',
#  'survivor rwandan genocide country first female neurosurgeon',
#  'stacey abrams wins democratic_primary georgia governor',
#  'trevor_noah reveals question ask donald_trump else dared',
#  'michelle_obama reflects scary time princeton sweet throwback snap',
#  'reasons started conversation responsible finishing',
#  'lourdes leon gives_us major madonna vibes moody new ad_campaign pics',
#  'ways netflix tricks watching shows movies',
#  'brad_pitt made ryan_reynolds one demeaning thing exchange deadpool cameo',
#  'robert_de niro bans trump every nobu restaurant',
#  'ariana_grande shuts fan blaming heartbreaking mac miller split',
#  'parents slam show dogs scenes grooming children sexual_abuse',
#  'dave grohl wants apologize to world massive jerk trump',
#  'emilia clarke introduced prince_william pretty embarrassing way',
#  'sarah paulson takes impressions next_level tonight_show',
#  'still ready party taken seriously',
#  'gina ortiz jones wins democratic runoff texas congressional race',
#  'fighter pilot amy mcgrath wins democratic_primary kentucky swing district',
#  'trump rallies conservatives promise abortion curbs',
#  'aclu suing strike ohio congressional map',
#  'latest school_shooting really stirred the gun debate',
#  'donald_trump tweet rescues roseanne family season_finale',
#  'ellen grills mark wahlberg shirtless instagram selfies',
#  'idris_elba star new hunchback notre_dame netflix',
#  'maryland police charge church leaders past abuse risk teen girls',
#  'nfl bans kneeling national_anthem',
#  'conan_brien muscles royal_wedding spoof ads',
#  'house_republicans report progress immigration deal',
#  'democrats invited review classified documents fbi informant',
#  'gop_candidate pointed gun teenager advances georgia governor primary runoff',
#  'walking definition entitled millennial swears an entitled millennial',
#  'democrats push included classified briefing fbi informant',
#  'machines always steal jobs increasingly rob our work humanity',
#  'trump praises tomi_lahren restaurant crowd tosses water insults',
#  'sarah sanders bothers called liar',
#  'trump blocking people twitter judge_rules',
#  'mostly non christian militia iraqi christians parliamentary seats christians want trump intervene',
#  'tulsi gabbard syria views cost support hawaii teachers union',
#  'jared_kushner received security clearance reports',
#  'arizona gop congressional_candidate compares abortion holocaust',
#  'gun reform advocate lucy mcbath heads runoff georgia house seat',
#  'star_wars burlesque show storms west_coast sexy stormtroopers',
#  'establishment backed moderate wins heated democratic house primary texas',
#  'senators unveil bill crack sexual_harassment',
#  'trips take new_york city long weekend',
#  'disney reveals opening seasons star_wars theme_park lands',
#  'latest entries the comedy wildlife photo awards cheer',
#  'bad lip_reading reveals really said royal_wedding',
#  'australian archbishop convicted covering child sex_abuse',
#  'commander says iran people respond pompeo threats punch mouth',
#  'mark_zuckerberg extends facebook apology tour european gig',
#  'ariana_grande tweets message support manchester bombing anniversary',
#  'katy_perry says single american_idol',
#  'call cops watch powerful monologue on racism',
#  'amazon selling cops facial recognition tool bad potentially racist move',
#  'miley_cyrus comes like wrecking ball prank sleeping jimmy_kimmel',
#  'vanessa bayer feared porn stars skit donald_trump snl',
#  'adam_rippon wins dancing_stars destined',
#  'emilia clarke never try imitate chewbacca ever',
#  'maddie poppe wins american_idol runner reveals dating',
#  'colbert resist turning trump nickname pee tape joke',
#  'seth_meyers forced tweak donald_trump latest twitter rant time',
#  'boy says teacher told fault police shoot him age',
#  'cops accused racism detaining black man vegetation',
#  'white cop shouts black suspect pretend like going shoot',
#  'florida police report dead standoff panama city apartment complex',
#  'donald glover board lando calrissian pansexuality solo',
#  'charlize_theron play megyn_kelly film roger_ailes',
#  'shoppers boycott publix store donations nra backed candidate',
#  'bill de_blasio tells nypd stop arresting people smoking pot street',
#  'dhs head says still somehow unaware intel russia interference boost trump',
#  'lawmaker introduces crowdfunding bill pay trump border_wall',
#  'gop lawmakers soon allowed review classified info russia_investigation',
#  'james_corden reveals worst part the royal_wedding ceremony',
#  'ariana_grande reportedly dating snl star pete davidson',
#  'jim_carrey pens new pledge allegiance students bullet riddled schools',
#  'ellen gets david spade open dating younger women',
#  'ceasefire jimmy_kimmel shreds sean_hannity dummies fox_friends',
#  'spoof royal_wedding video sees ceremony taking different turn',
#  'georgia gop governor primary focuses guns immigration',
#  'glaad movie report_finds troubling drop lgbtq representation',
#  'sephora offers store beauty classes trans nonbinary community',
#  'georgia governor primary highlights competing visions democratic_party',
#  'california moves let schools co workers red flag dangerous gun_owners',
#  'talking grievance health_care outsider kentucky dem found inside track',
#  'problems commemorative trump kim_jong un coin',
#  'giuliani new stance russian collusion illegal',
#  'onion hilariously trolls michael_cohen cease desist note',
#  'democrats want boost school funding to address teacher walkouts',
#  'emails lawmakers shrug trump lax cellphone security',
#  'try stink bug flavored jelly bellys',
#  'power outage triggers extreme zombie activity alert florida city',
#  'congress wall_street favor banks post record profits',
#  'white_house sinkhole probably metaphor something',
#  'reporter shoved others barred epa meeting water contaminants',
#  'garry kasparov donald_trump russian connections aeroflot',
#  'lonely planet top european destinations take aim overtourism',
#  'attorney aaron schlossberg insists anti spanish rant person',
#  'minutes reporter reveals trump chilling reason slamming press',
#  'trump reportedly rejects phone security measures inconvenient',
#  'federal_court sides transgender teen gavin grimm bathroom fight',
#  'ex trump adviser calls president claims informant spied campaign embarrassing',
#  'vietnam test happens abandons climate diplomacy',
#  'one third americans_think trump successfully draining swamp',
#  'msnbc host hugh hewitt suggests trench coat control gun_control',
#  'bishop michael curry harry_meghan love brought different worlds together',
#  'sarah paulson unapologetic year age gap girlfriend holland taylor',
#  'texans sides gun debate agree on safe storage on support',
#  'family gay man found critically injured near amtrak route wants answers',
#  'caitlyn_jenner trump worst president ever lgbtq_rights',
#  'boy_scout allegedly booted store company support homos',
#  'instagram adding mute button sake sanity',
#  'publix censors teen summa cum laude graduation cake',
#  'say sexist passengers female pilot perfect_response',
#  'time takes_aim mcdonald walmart sexual_harassment complaints',
#  'venezuela socialist leader nicolas maduro elected amid allegations irregularities',
#  'iran says europe support nuclear_deal enough america withdrawal',
#  'far_right mob attacks year_old liberal greek mayor',
#  'shawn mendes khalid perform parkland survivors billboard_music awards',
#  'tamir_rice mother opening youth center honor son memory',
#  'judge_orders texas make voter_registration easier updating dmv info',
#  'kelly_clarkson calls moments action honor of texas shooting_victims billboard awards',
#  'kendrick_lamar stops white fan rapping word onstage',
#  'gay man says pope_francis told god made like loves you like that',
#  'unusual asteroid could interstellar guest solar system',
#  'started suicide prevention site age still going strong',
#  'roger stone says prepared conjured mueller indictment',
#  'hillary_clinton endorse andrew_cuomo election',
#  'supreme_court made lot harder sue employer',
#  'blake farenthold may hired illegally new lobbyist job',
#  'bill konigsberg explores new side gay experience latest book',
#  'alone game shows biggest hurdles lgbtq athletes exist the field',
#  'chrissy_teigen somehow gets even real_life childbirth',
#  'suits creator pens heartfelt open_letter attending royal_wedding',
#  'movies coming netflix week',
#  'obamas coming netflix queue',
#  'sorry ben_affleck make way justin_theroux giant rat tattoo',
#  'hillary_clinton tips russian hat trump yale commencement_speech',
#  'giuliani says mueller talk trump trump hears fbi source',
#  'democrats plan big anti corruption theme midterms',
#  'kelly_clarkson rejects moment silence calls change billboard_music awards',
#  'asked american public settle the internet dumbest debates',
#  'fox_news viewers really like lifelong republican robert_mueller',
#  'trump team moves lift ban extreme hunting tactics alaska',
#  'howard stern tells trump sexualized ivanka makes david_letterman cringe',
#  'supreme_court helping companies get_away sexual_harassment',
#  'deadpool steals spot box_office avengers_infinity war',
#  'westworld subtly tease baby theory',
#  'donald glover tells ellen full circle star_wars moment his son',
#  'marvel exec tried stop jarring infinity_war death',
#  'jake_gyllenhaal set star villain spider_man sequel',
#  'janet_jackson becomes_first black woman receive billboard icon award',
#  'pakistan bitch video captures driver racist rant',
#  'grey gardens ladies the unwitting godmothers reality_tv archetypes',
#  'year_old boy superhero alabama homeless population',
#  'john_oliver best time mocking the royal_wedding',
#  'john_oliver needles dangerously unregulated rehab industry',
#  'jemele hill honored nabj journalist year',
#  'french digital minister comes gay fight homophobia',
#  'belgian transgender ballet drama wins big cannes_film festival',
#  'year_old gay man proves never old attend first pride',
#  'super_pacs meddled west_virginia senate primary receive penny west virginians',
#  'airline passenger arrested_allegedly harassing woman peeing seat',
#  'mike pompeo promises crush iran achieve better deal',
#  'majestic islands europe tourists know yet',
#  'cuba confirms killed country deadliest plane_crash since',
#  'china putting trade war hold treasury steve mnuchin says',
#  'trump top economic adviser says amazon threats lane',
#  'dems trump admin find common ground helping victims myanmar genocide',
#  'giuliani says mueller wrap trump obstruction probe september report',
#  'german broadcaster criticized racist coverage royal_wedding',
#  'kathryn newton boldest teen tv ready grow',
#  'stephanie kelton biggest idea washington',
#  'texas gov campaign cancels shotgun giveaway santa fe school_shooting',
#  'tina_fey sarah_palin leads snl chorus lamenting trump',
#  'day american gushing snl goes smart aleck royal_wedding',
#  'starbucks says anyone sit cafes even without buying anything',
#  'alec_baldwin trump faces ominous sopranos scenario snl finale',
#  'asia argento fiery speech closes cannes raped harvey_weinstein',
#  'tina_fey tries mean_girls musical snl',
#  'parents school_shooting victims decry moronic gop platitudes',
#  'trump real americans get tough russia_probe',
#  'chrissy_teigen john_legend announce name baby_boy adorable photo',
#  'texas lt gov dan patrick touts need arm teachers',
#  'david hogg calls media stop naming santa fe school shooter',
#  'trump sets showdown doj claims campaign surveillance',
#  'jim_carrey latest painting slams kent state goldilocks ar',
#  'oliver north blames school shootings ritalin',
#  'jimmy_kimmel tricks royal fans reviewing wedding the big day',
#  'jimmy_fallon reveals viewers biggest wedding fails',
#  'protesters throw fiesta razz lawyer ranted spanish speakers',
#  'watch amazon prime new week',
#  'ferrell molly shannon cover royal_wedding cord and tish',
#  'artist formerly known cedric the entertainer arrived',
#  'mark kelly trump rolled nra nothing guns parkland',
#  'gop_candidate set trust pays kids marrying white people',
#  'houston police_chief says sick inaction gun_control',
#  'history the national_anthem sports',
#  'bbc trolls president trump bigly huge royal_wedding crowd',
#  'victims the santa fe high_school shooting',
#  'ceo took pay cut give employees year battling amazon',
#  'trump_jr met emissary gulf princes offering help with campaign report',
#  'trump misspells melania name welcome home tweet twitter roars',
#  'jimmy_kimmel shreds cowardly trump lawmakers texas school_shooting',
#  'bill_maher reveals things_know michael_cohen',
#  'watch hulu new week',
#  'students stage sit gun_control outside paul_ryan office get arrested',
#  'trump knew scary amount appearance bill_gates daughter',
#  'ex russian spy sergei skripal discharged uk hospital poisoning incident',
#  'cuba plane_crash reportedly kills',
#  'trump reassures north_korea threatens total decimation without deal',
#  'ariana_grande gives fans singing one last time surprise lives',
#  'cambridge_analytica files chapter bankruptcy facebook privacy row',
#  'santa fe high schoolers held gun_violence protest month shooting',
#  'michelle_wolf netflix trailer gives_us closer look new show',
#  'jeff_sessions uses exceptional power immigration courts limit judges authority',
#  'gop_rep introduces bill_would demand white_house apologize mccain',
#  'colbert super graphic way describing deep mueller_probe goes',
#  'jack osbourne wife files divorce',
#  'meek_mill backs trump event prison reform',
#  'new trump rule would cut federal funds clinics providing abortions',
#  'twitter_users joke trump wants prison reform headed',
#  'every_single chilean bishop offers resign country sex_abuse scandal',
#  'ariana_grande calls manchester attack worst humanity one year_later',
#  'chrissy_teigen spills first details new baby_boy love',
#  'alec_baldwin wife hilaria welcome another baby_boy',
#  'kate_mckinnon breaks another impression rudy_giuliani',
#  'smallville allison mack get involved sex cult first place',
#  'trump white_house kills yanny laurel debate ridiculous clip',
#  'jennifer_aniston play lesbian president netflix first ladies',
#  'break book shadows the charmed reboot trailer',
#  'former dave matthews band violinist boyd tinsley accused_sexual misconduct',
#  'many people name single book jimmy_kimmel',
#  'ellen_degeneres hilariously explains saved meghan_markle life',
#  'lawyer ranted spanish speakers faces office eviction disciplinary complaint',
#  'hannity flips mueller_probe direct threat american republic',
#  'top democrats want answers global health security head sudden departure',
#  'gun_owners non gun_owners actually agree lot gun reforms',
#  'twitter_users pan ted_cruz tweets prayers santa fe school_shooting victims',
#  'states ban bump_stocks enforce law',
#  'liberal billionaire tom steyer base',
#  'sen dean heller campaign paid social_media influencer son',
#  'interior dept dodges watchdog questions zinke call alaska senators',
#  'blake_lively teases ryan_reynolds hugh_jackman bromance',
#  'happytime murders adult themed movie puppets',
#  'photo daniel_radcliffe holding guns crazy slippers becomes magical meme',
#  'bill_gates says trump know difference hpv hiv',
#  'bachelorette bios are terrible',
#  'steven tyler admits hitting daughter liv famous pal watched',
#  'hospice overdosed patients hasten deaths former health_care executive admits',
#  'kimmel brings house giving trump latest tweet new ending',
#  'former wwf wrestler severely beaten outside california home',
#  'robert wilkie picked new va secretary surprise announcement',
#  'trump new domestic gag rule would strip funds planned_parenthood',
#  'rudy_giuliani reverses trump team position says president obstruct justice',
#  'social anxiety get attention deserves',
#  'deadpool already breaking box_office records',
#  'obamacare premiums way higher next_year be',
#  'comprehensive list everything jr know infamous meeting',
#  'report manafort former son law cuts plea deal cooperate government',
#  'trump briefly responds santa fe school_shooting pivoting',
#  'late_night writer shreds roseanne better ever racist',
#  'trump nasa chief apparently changed tune climate_change',
#  'freedom_caucus sinks key part paul_ryan welfare reform agenda',
#  'transphobic congressional hopeful berates person inside public restroom',
#  'singer ryan amador says loverboy second coming',
#  'newest head cracker hear brainstorm green needle',
#  'meditation like human way clearing browser cache',
#  'funniest_tweets women week',
#  'italy looks befriend russia populist parties try to form government',
#  'business groups might quietly killing bill_would bring sexual_abuse claims light',
#  'kushner family reportedly close getting bailout flagship tower',
#  'trump says give charity royal_wedding ll see',
#  'federal prosecutors still trying turn trump_inauguration protesters felons',
#  'republican immigration fight derails food_stamp bill',
#  'retiring lawmakers added million campaign treasuries since last election',
#  'facing farm bill vote problems gop_leaders may make deal',
#  'methodists surprise gay minister world best pastor certificates theft diploma',
#  'china marks another milestone quest become space superpower',
#  'stephen_colbert wants mueller give trump special anniversary gift',
#  'trump stormy_daniels disclosure still leaves questions payments cohen',
#  'please enjoy animated history tina_fey snl return',
#  'controversial way california schools handling students misbehavior',
#  'deaf activist points marvel diversity problem race',
#  'magnum trailer lots close shaves big mustache',
#  'gina haspel confirmed cia_director aid democrats',
#  'boulder city_council unanimously votes ban assault weapons high capacity magazines',
#  'chrissy_teigen john_legend welcome baby_boy',
#  'terrifying clip shows never run tree thunderstorms',
#  'mitch_mcconnell taps anti_lgbtq bigot religious_freedom panel',
#  'seth_meyers gives donald_trump unexpected advice north_korea',
#  'devin_nunes fundraising fbi attacks tells potential donors trump says hero',
#  'former mexican_president warns donald_trump got get st together',
#  'fox_news first female ceo named sexual_harassment complaints',
#  'battle save dying soil',
#  'latino man insulted starbucks barista writes slur cup',
#  'snl cast member claims trump faked bizarre phone_call rehearsals',
#  'jimmy_kimmel comes clean may owe donald_trump apology',
#  'trevor_noah skewers betsy_devos fake profit university ad',
#  'serena_williams explains father walk her aisle',
#  'star_wars writer confirms donald glover character pansexual solo',
#  'medical professionals fact check grey_anatomy sex scenes',
#  'amy_schumer nails meghan_markle fairytale wedding actually sucks',
#  'michael keaton ends kent state commencement_speech batman',
#  'black profiled share story',
#  'black actresses cannes protest racism french film industry',
#  'michael_jordan denies rumors date black women',
#  'scam pacs ripped conservatives pro police anti_abortion messages prosecutors',
#  'mtv suspends catfish probes nev schulman sexual_misconduct claims',
#  'trump ice increasingly arresting immigrants without criminal convictions',
#  'special_counsel hits roger stone social_media advisor subpoenas',
#  'whitney_houston sexually abused dee dee warwick cannes documentary',
#  'patton_oswalt joker theory change watch dark_knight',
#  'josh holt american captive venezuela begs help in prison videos',
#  'obama photographer taunts donald_trump calling immigrants animals',
#  'backstreet boys release new_song go breaking heart',
#  'prince knight puts gay inclusive twist traditional fairy tales',
#  'gay_conversion therapy survivor recalls month nightmare powerful video',
#  'gq expertly spoofs vanity_fair annual comedy issue cover',
#  'rudy_giuliani offers head spinning new defense trump',
#  'cynthia_nixon fix subway ads shred cuomo mta commuters rejoice',
#  'farm bill could huge blow animals',
#  'emails show interior expected learn nothing public input bears ears review',
#  'whistleblower leaked michael_cohen financials potential cover report',
#  'kidnapper accused using alligator hold man captive',
#  'miss america pageant headed women email scandal',
#  'north_korea threatens reconsider trump summit cancels south_korea talks',
#  'chemical_weapons likely used syria watchdog finds',
#  'hundreds israel beyond protest killings palestinians gaza border',
#  'researchers uncover secret pages diary anne frank',
#  'stephen piscotty returns bereavement hit mom tribute home run',
#  'senate intelligence_committee backs gina haspel lead cia',
#  'pennsylvania congressional delegation longer men',
#  'lando calrissian star_wars spinoff starring donald glover happening',
#  'fake donald_trump sean_hannity pillow talk late_show',
#  'rapper arrested disorderly conduct public drunkenness',
#  'conservatives cook farm bill gambit get vote hardline immigration bill',
#  'top novartis lawyer resigns michael_cohen deal',
#  'birth_control emoji',
#  'white_house eliminates cyber czar post first appointee leaves',
#  'emily list backed lawyer wins democratic_primary pennsylvania swing district',
#  'robin_williams biographer tells sweet story comic store visit',
#  'republicans attacking nancy_pelosi even non house races',
#  'empire nothing military takes us the gates of hell',
#  'longtime trump lawyer slams giuliani polarizing figure deal mueller',
#  'bet_awards nominations dj khaled must screaming',
#  'beirut pride canceled organizer detained authorities',
#  'manhattan district attorney vows stop prosecuting minor marijuana cases',
#  'larry_nassar victims receive million michigan_state settlement',
#  'trump_jr left open possibility dad knew trump_tower meeting time',
#  'tom_cruise ankle break scene goes laughs mission impossible trailer',
#  'many lives steven tyler',
#  'louisiana lawmakers approve restoring voting_rights people probation parole',
#  'thandie newton cannes dress celebration black star_wars characters',
#  'trump paid cohen financial disclosure confirms',
#  'american citizen freed egypt jail',
#  'fox_news said settle group discrimination lawsuits million',
#  'tweeters take hard pass rnc dinner photo donald_trump prize',
#  'facebook removed million fake accounts first quarter',
#  'pink badass response troll said looked old',
#  'san_francisco adopt software app to help automatically clear old marijuana convictions',
#  'younger star sutton foster returns broadway roots new_album',
#  'senate hot seat scott_pruitt dodges questions mounting scandals',
#  'idaho inches closer electing nation first native_american governor',
#  'pro abortion rights progressive wins nebraska democratic house primary',
#  'ryan_reynolds crashes colbert deadpool crack rated trump jokes',
#  'ryan_reynolds genuinely hurt trading playground insults josh brolin',
#  'terry crews movement emancipation proclamation',
#  'christopher wylie warns senators cambridge_analytica steve_bannon want culture war',
#  'san_francisco may ban single use plastic straws',
#  'john travolta sure greased lightning cannes dance floor',
#  'senate panel releases details trump_tower meeting probe',
#  'report contradicts michigan governor candidate test animal treatment',
#  'republican welfare plan keeping wages',
#  'years_ago today michael_jackson moonwalked tv first_time',
#  'hilary_duff publicly drags neighbor keeps night',
#  'jim_carrey jabs stooge donald_trump north_korea new artwork',
#  'trump failure report stormy_daniels payoff referred to prosecutors',
#  'bohemian rhapsody trailer slammed ignoring freddie mercury sexuality',
#  'fergie rides new_york city subway never the',
#  'pauley perrette responds cbs statement multiple assaults claim',
#  'trump refers immigrants animals',
#  'angry white dude rant people speaking spanish nyc goes_viral',
#  'democratic lawmaker gives scott_pruitt brutal reality_check senate hearing',
#  'trump picks mitch_mcconnell brother law gordon hartogensis lead pension agency',
#  'fbi search cia leak suspect turned photos of sex assault unconscious friend',
#  'former trump pick top census role says citizenship question political',
#  'jared_kushner agitated infuriated meeting russians focused adoptions',
#  'sarah_huckabee sanders unusually honest seth_meyers spoof briefing',
#  'become kris_jenner assistant according_to kris_jenner',
#  'chris_pratt bryce dallas howard really need service raptor flight',
#  'surprise shows coming netflix may',
#  'rex_tillerson warns grads living alternative realities',
#  'democrats force vote keep net_neutrality rules',
#  'larry_nassar blames victims says victimized newly released videos',
#  'video_shows year_old autism taunted abused bus_driver',
#  'yanny laurel real answer',
#  'populist cleric muqtada al sadr likely win iraq parliamentary election',
#  'palestinian family says month_old died israeli tear gas gaza protest crackdown graphic',
#  'sichuan airlines co pilot sucked halfway broken windshield',
#  'retail group spoofs ferris bueller ad bashing donald_trump tariffs',
#  'washington officials_say state cover postage mail ballots year',
#  'people think civil politics opponents disagree',
#  'cambridge_analytica investigated justice_department fbi report',
#  'adorable video kids shows activism literally easy as pie',
#  'white_house blames deadly gaza violence hamas propaganda',
#  'gina haspel says cia conducted interrogation program',
#  'tesla autopilot engaged horrific mph crash driver tells police',
#  'selling planes iran could saved lives exiting nuclear_deal make harder',
#  'speech fallen officers trump touts policies rails sanctuary_cities',
#  'eric greitens team pushes inquiry prosecutor charged',
#  'elizabeth_warren pledges big money turn heat gerrymandering',
#  'gay_conversion therapy illegal maryland',
#  'fox_news judicial analyst defends timeline mueller_probe',
#  'stephen_colbert uses oprah analogy ridicule trump hannity bedtime chats',
#  'first trailer the queen biopic bohemian rhapsody',
#  'seth_meyers shreds trump scandals drain swamp devoid meaning',
#  'jim_carrey new blood dripping portrait takes_aim national disgrace nra',
#  'scott_pruitt got security day epa new documents show',
#  'rabid anti_muslim ex fbi agent training texas police',
#  'khloe_kardashian explains chose true daughter name',
#  'game gina haspel track confirmed cia_director',
#  'topher grace really hated preparing play david_duke spike_lee blackkklansman',
#  'sarah paulson deeply nerdy around rihanna filming ocean',
#  'blake farenthold says repay sexual_harassment settlement',
#  'spike_lee gets major love blackkklansman cannes rips trump',
#  'twitter_users hilariously skewered terrible stock photos jobs',
#  'ivanka jared jerusalem visit slammed twitter',
#  'adam_rippon honors mom stunning dancing with stars performance',
#  'tomi_lahren hits_back genealogist researched family misses point',
#  'georgia gop gov candidate wants round immigrants deportation bus',
#  'daddy little ghoul new_york daily_news rips ivanka_trump embassy opening',
#  'death keeven robinson black louisiana man police custody ruled homicide',
#  'colbert savages peace treaty barbie collusion ken embassy opening',
#  'twitter_users roast experts_say twice salary saved',
#  'woman challenging white male dominated tech industry the inside',
#  'keith richards explains got rid trump nearly years_ago',
#  'damon wayans completely rips clayne crawford twitter outburst',
#  'like han solo scoundrel solo star_wars story forgot',
#  'pauley perrette reveals multiple physical assaults ncis exit',
#  'ariana_grande jimmy_fallon make sweet music cardboard instruments',
#  'trevor_noah watch fox_news neither',
#  'seattle passes controversial new tax city biggest companies combat housing crisis',
#  'uber ends forced arbitration individual cases sexual_assault harassment',
#  'meet first_openly trans man graduate spelman college',
#  'canceled renewed tv_shows',
#  'teen claims visited heaven near death experience',
#  'willow smith tells shocked jada_pinkett smith self harmed preteen',
#  'new farming technique using drastically less water catching',
#  'kristen_stewart ditches heels cannes red_carpet defying flats rule',
#  'david duchovny addresses nuttiest fan theories the files',
#  'judge overturns california right die law',
#  'debbie_wasserman schultz nra shy terrorist organization',
#  'cardi responds girls song controversy apologizes to lgbtq_community',
#  'emotional support spider goat banned american_airlines',
#  'people agree whether voice saying yanny laurel',
#  'even bottom the_world deepest ocean trench safe plastic bags',
#  'open new embassy jerusalem nations prefer to wait peace deal',
#  'israeli forces kill dozens palestinians protests intensify embassy jerusalem',
#  'facebook suspends apps amid data misuse investigation',
#  'former senator harry_reid diagnosed pancreatic_cancer',
#  'new federal regulator takes_aim facebook',
#  'still apology white_house dying mccain dig',
#  'south_dakota congressional_candidate said terrorist attack would help win primary',
#  'ryan coogler would love see women wakanda spinoff',
#  'coffee shop refuses serve man racist rant woman niqab',
#  'supreme_court invalidates federal ban sports gambling',
#  'huge congrats fox_news getting guest journos to peddle bret baier book',
#  'movies coming netflix week',
#  'prosecutor drops felony invasion privacy charge missouri gov eric greitens',
#  'israeli soccer_team beitar jerusalem add trump to name',
#  'vermont lawmakers pass gender_neutral bathroom_bill send powerful_message',
#  'rita ora girls deemed tone_deaf harmful lgbtq pop artists',
#  'embassy jerusalem opens doors protests rage nearby',
#  'john_oliver reveals secret figuring going trump mind',
#  'super mario looks_like without hair people freaked',
#  'channing_tatum mother_day message ex jenna_dewan full love',
#  'us star justin hartley says sexually_harassed fan',
#  'lois lanes pay_tribute late margot kidder led the way',
#  'onion story blake farenthold gets new job lobbying congress',
#  'iowa gov says slowing signing country strictest abortion ban',
#  'cannes_film festival promises greater gender_equality times activism',
#  'childish gambino america hits spot first week',
#  'jon_stewart dave_chappelle perform standup tour together',
#  'coach tells hurt ufc fighter continue says done',
#  'melania_trump recovering kidney surgery',
#  'jon tester vulnerable senate democrat voting like one',
#  'taraji_henson kelvin hayden get engaged mother_day',
#  'young dolph gives baristas fired playing song get paid',
#  'come back bed explores intimacy experiencing sexual_assault',
#  'trump changed burger order make little healthier',
#  'michael avenatti posts photos cohen qatari investor accused of bribery',
#  'donald_trump lashes called leaks twitter_users pounce',
#  'trump orders help chinese phone maker china approves money for trump project',
#  'hundreds protest cities_across poor_people campaign',
#  'rihanna best response asked attending the royal_wedding',
#  'lifetime harry_meghan royal romance good',
#  'game_changing westworld brain capsule reveal beginning',
#  'margot kidder actress played lois lane superman dead',
#  'tomi_lahren gets owned genealogist remarks low skilled immigrants',
#  'harrison_ford crashes new han solo actor interview get life',
#  'kylie_jenner ex bodyguard tim chung denies actually stormi father',
#  'seann william scott replaces clayne crawford renewed lethal weapon',
#  'zach woods officially mvp silicon_valley',
#  'ryan_reynolds went south_korean singing show disguised unicorn',
#  'billie lourd honors tough mother_day photo carrie_fisher',
#  'pink asks year_old concertgoer sing blown away',
#  'pastor thinks jews going hell speaks jerusalem embassy opening',
#  'chili hit data breach credit debit card information compromised',
#  'trump called waffle_house hero james shaw jr thank disarming shooter',
#  'fox_news host trump fulfilled biblical prophecy moving embassy jerusalem',
#  'keyless cars killed dozen people since report',
#  'rare conjoined fawns scientists double take',
#  'least_killed dozens injured indonesia church bombings',
#  'iran president says country could remain nuclear_deal without',
#  'lindsey_graham trump officials owe mccain apology disgusting insult',
#  'amy_schumer goes_full girl raunch on saturday_night live',
#  'americans make iran_deal depends ask',
#  'like attending nra convention part the fake_news media',
#  'possible autopilot use probed tesla crashes mph',
#  'michael bloomberg slams epidemic political lies danger democracy',
#  'massive cookout thrown park cops called black family bbq',
#  'michael che stepmom melissa_mccarthy embarrasses weekend_update',
#  'handmaid_tale meets sex city funny terrifying snl spoof',
#  'video_shows security guard choking black teen accused shoplifting new_york',
#  'trump praises late mom mother_day skips mention melania',
#  'trump promises help chinese company violated sanctions iran',
#  'sarah_huckabee sanders berated staffers mccain leak',
#  'parkland dad pointed message oliver north nra new president',
#  'john_bolton trump sanctions european companies possible iran',
#  'michelle_obama shares_adorable throwback pic touching mother_day tribute',
#  'tomi_lahren claims low skilled immigrants country based',
#  'stalking cheetahs give oblivious family scare exit car safari park',
#  'der spiegel cover portrays trump finger flipping europe',
#  'italian tribunal lifts ban silvio berlusconi holding public office',
#  'north_korea plans dismantle nuclear test sites end may',
#  'knife attack paris leaves_dead several injured',
#  'watch hulu new week',
#  'watch amazon prime new week',
#  'late_show unveils spoof line trump themed mother_day gifts',
#  'brooklyn nine nine finds new tv home stars fans rejoice',
#  'smith shares inspiring tale became fresh prince of bel air',
#  'lgbtq groups call new oklahoma adoption law discriminatory',
#  'mueller reportedly investigating foreign linked donors trump_inauguration fund',
#  'stephen_colbert mocks proposal hang trump pence portraits post offices',
#  'boston dynamics robot dog may available sale soon',
#  'southern baptist leader apologizes past hurtful comments women',
#  'george soros progressive groups spend millions to elect reformist prosecutors',
#  'incredible photos show world need protect',
#  'avengers_infinity war directors reveal died survived screen',
#  'uber silences women sexual assaults',
#  'marvel introduces first official chinese superheroes',
#  'big_bang theory pays sweetest tribute stephen_hawking deleted scene',
#  'bill_maher shreds donald_trump likens mob boss',
#  'amazon holding seattle hostage',
#  'jim_carrey taunts psycho mike_pence biting new portrait',
#  'chadwick boseman lauds student protesters howard commencement_speech',
#  'want understand straight incels talk_to gay one',
#  'gathering military spouses puts white white_house',
#  'game show host prematurely congratulates contestant mortifying fail',
#  'women take cannes red_carpet to protest inequality film',
#  'men charged hate_crimes beating gay_couple',
#  'trump_administration rolls back protections transgender prison inmates',
#  'michael_cohen reportedly paid advise time_warner merger',
#  'metoo statehouse least men gone the harassment culture',
#  'austin bars police_department selling old guns public',
#  'masterclass parody dubbing movie swear words falcon great',
#  'democrats say regret making easier confirm judges',
#  'donald glover fan would cast solo',
#  'seth_meyers skewers idea donald_trump winning the nobel_peace prize',
#  'chuck_schumer turns melania_trump best campaign donald_trump',
#  'trailer axed tremors reboot kevin bacon offers glimpse could',
#  'frightened rabbit singer scott hutchison dead',
#  'suspect custody shooting california high_school injured',
#  'colbert names official job unqualified white_house staffer',
#  'trevor_noah gives michael_cohen biting new breaking_bad themed nickname',
#  'moral atlanta robbin season sometimes get the top snatching others',
#  'pose character finds community new_york ball scene',
#  'accused golden_state killer faces four additional murder counts',
#  'jimmy_kimmel roasts donald_trump spoof nobel_peace prize ceremony video',
#  'sarah_palin says mccain regrets perpetual gut punch',
#  'killed may australia worst mass_shooting since',
#  'deadpool david_beckham hug feud deadpool teaser',
#  'opposition gives trump hot lawyer',
#  'dogs may help prepare babies cats help prepare you for teenagers',
#  'john_mccain wife rebukes white_house official mocked dying anyway',
#  'rupaul_drag race queens turn back time cher rusical',
#  'trump_administration axes funding nasa system monitors greenhouse gases',
#  'police search suspected serial_killer dumping ground',
#  'kevin mchale think zero surprise came',
#  'pennsylvania house race embodies fight the future the democratic_party',
#  'hackers tried breach tennessee county server election_night report',
#  'gay teacher suspended showing photo future wife sues texas district',
#  'school_district allegedly made lgbtq student read bible punishment',
#  'trump launched war christmas may people',
#  'elle fanning makes punk music debut talk_to girls parties',
#  'jake_tapper rips retired gen tom mcinerney insulting john_mccain',
#  'fox cuts_ties guest cited john_mccain defend torture',
#  'trump attempt make example immigrant caravan backfiring',
#  'celebrities reading weird texts moms mother_day treat',
#  'stormy_daniels actress doppelganger',
#  'oldest known man america says smokes dozen cigars day',
#  'tweeters erupt trump aide cruel taunt john_mccain dying anyway',
#  'mark_hamill weds sheldon amy big_bang theory fans geek',
#  'epa hid scott_pruitt dinner climate denier accused child sex_abuse',
#  'meghan mccain takes swipe white_house aide mocks father cancer',
#  'need talk white people calling cops people color',
#  'woman calls police black family bbqing lake oakland',
#  'tim allen last man standing coming_back one year canceled',
#  'joe_biden berates white_house joke john_mccain health',
#  'michael avenatti warns michael_cohen still documents release',
#  'fox_friends host mocks ny_times isis coverage unaware beat fox story',
#  'congressional_candidate says fk nra new tv ad',
#  'tsa tells sikh man remove turban finds canadian politician',
#  'john_stamos shows new baby bob saget lori loughlin',
#  'woman sent texts first date says love excessive thing',
#  'little extortion guy figured stormy_daniels old lawyer actually pretty',
#  'katie porter survived domestic_abuse used her campaign',
#  'trump plan prescription drug prices looks nothing like promised',
#  'giuliani says cohen never spoke trump big dollar clients',
#  'russian troll facebook ads barely targeted swing states',
#  'ted_cruz staff usaid met group called apartheid called injustice',
#  'plan family_vacation according_to travel experts',
#  'boston dynamics created running robot coming',
#  'cornell student delivers thesis underwear professor questions outfit',
#  'funniest_tweets women week',
#  'israel reportedly fires dozens rockets syria',
#  'israel launches airstrikes syria iranian attacks',
#  'right die advocate david goodall ends life listening to ode to joy',
#  'americans held north_korea return united_states',
#  'dozens dead torrential rains cause dam burst kenya',
#  'spotify stops promoting kelly music sexual_assault allegations',
#  'trump kim_jong un likely meet next month singapore',
#  'homeland_security denies report secretary drafted resignation letter',
#  'cecile richards running office future never_say never',
#  'aclu says kris_kobach still giving incorrect information voter_registration',
#  'ryan_murphy donate pose profits to trans queer groups',
#  'rick morty renewed whopping episodes',
#  'ryan_reynolds warns deadpool fans say fking word',
#  'nurse charged death ex trump adviser mcmaster father',
#  'trump going indiana to slam joe donnelly expect democrat to hit back',
#  'rick moranis appear netflix sctv documentary',
#  'facing challenge right gop_lawmaker pulls support immigration bill',
#  'john_mccain urges senate reject gina haspel nomination cia',
#  'months later rio cops supposedly closing marielle franco killers',
#  'queer_eye star tan france give poorly dressed fans style advice',
#  'women coming eric schneiderman job',
#  'man pleads_guilty bacon vandalism tennessee islamic center',
#  'mike_pence robert_mueller russia_probe wrap',
#  'ready older kevin us justin hartley is',
#  'net_neutrality rules end june fcc says',
#  'democratic candidate maryland governor dies cardiac arrest',
#  'officer puts man chokehold outside north_carolina waffle_house',
#  'trevor_noah get_enough blankenship nutty concession speech',
#  'brooklyn nine nine canceled twitter mourns',
#  'quiet struggle chuck_schumer the left',
#  'gabby douglas utterly unrecognizable undercover boss',
#  'girls accused plotting kill classmate',
#  'curious case the russian oligarch national_park service latrines',
#  'watch rudy_giuliani completely torpedo rudy_giuliani trump arguments',
#  'fox business guest defends torture worked john_mccain',
#  'tom abby queer_eye remarried',
#  'pakistan passes historic transgender rights bill',
#  'phil mudd flips questions cia torture america it',
#  'facebook ads house dems say russia ran election',
#  'kim_kardashian says tristan thompson blocked defended khloe',
#  'kenan thompson says stay snl long as possible',
#  'jennifer_garner mom problems hilarious rap video ellen',
#  'dick_cheney suggests restarting torture interrogation program',
#  'greta gerwig loudly critiqued feel pretty moviegoer live tweeted',
#  'devin_nunes gets meeting secret russia_probe source threatening doj',
#  'queer_eye star karamo brown engaged director ian jordan',
#  'jet launched apple store incredible deals',
#  'tom hardy completely unrecognizable al capone new movie',
#  'woman alleges rapper young lo raped trapped chris_brown home',
#  'republicans fill court seat denied obama years',
#  'man wanted white_supremacists kill black neighbor burn cross yard fbi',
#  'trump announces details meeting kim_jong un',
#  'samantha_bee delivers blistering takedown former ny ag eric schneiderman',
#  'jim_carrey scathing portrait trump joker give nightmares',
#  'michelle_wolf renews hostilities sarah_huckabee sanders',
#  'fans erupt fate elias koteas olinsky chicago',
#  'people street apologize old teachers on jimmy_kimmel live',
#  'stephen_colbert porn_star math michael_cohen donald_trump',
#  'pollen bomb every allergy sufferer worst_nightmare',
#  'jennifer_lopez dances least danceable songs tonight_show',
#  'white yale student calls cops black schoolmate napping dorm common room',
#  'rudy_giuliani quits law firm wild week interviews',
#  'teddy geiger makes first public appearance since coming transgender',
#  'ariana_grande mac miller reportedly break',
#  'avengers leaks get support year_old interview marvel directors',
#  'good excuse racist impact michigan medicaid proposal',
#  'fcc complaints minutes interview stormy_daniels',
#  'americans jailed korea home trump may made others situation worse',
#  'alex strangelove gay teen comedy turn away sex',
#  'woman says took home kittens find bobcats',
#  'video bear eating ice_cream dairy queen leads charges zoo owners',
#  'iranian lawmakers mock trump mental capacity burn flag pulls nuke deal',
#  'europeans scramble save iran_deal trump withdraws',
#  'north_korea releases american political prisoners advance historic summit',
#  'establishment gop notches win ohio primary vacant house seat',
#  'eric schneiderman praised movement days abuse_allegations emerged',
#  'trevor_noah unloads supposed advocate women eric schneiderman',
#  'year comey_firing scope mueller_probe expands lawyer shell company',
#  'trump inspired businessman wins indiana gop senate primary',
#  'gop rival says tammy baldwin team terrorists silence on trump cia pick',
#  'jobs program might get people back work',
#  'jim parsons yes still need queer stories onscreen',
#  'trump accuser wins democratic nomination ohio legislature',
#  'mastermind waterboarded cia information share gina haspel',
#  'conservative senate democrat backs trump agenda defeats progressive challenger',
#  'taylor_swift might made katy_perry kimye feud lives',
#  'kim_kardashian make history fashion council first influencer award',
#  'nbc says believes matt_lauer accusers months long investigation',
#  'russians ability change voter data report says',
#  'elizabeth_warren pick wins ohio democratic gubernatorial primary',
#  'kkk leader found_guilty firing gun charlottesville rally',
#  'protesters decrying torture dragged gina haspel senate hearing',
#  'hired firm linked michael_cohen to get inside scoop trump',
#  'rnc selling sickening donald_trump themed merch ahead mother_day',
#  'blankenship defeat relief families upper big branch miners',
#  'colbert shreds trump broken promises talking',
#  'new ambassador germany offends hosts hours first day',
#  'jordan_peele new nightmare coming next_year',
#  'backstreet boys dressed the spice girls larger life',
#  'seth_meyers decodes teen slang reveals giuliani really_means',
#  'look orlando interim pulse_nightclub memorial',
#  'trevor_noah turns donald_trump knives comment reggae magic',
#  'senators force vote may ultimately reverse fcc restore net_neutrality',
#  'ny legislature plan place consider replacements eric schneiderman',
#  'former ambassadors write letter opposing gina haspel nomination',
#  'california authority says state new homes must solar powered',
#  'ny governor assigns investigation eric schneiderman abuse_allegations',
#  'refugee caravan became scapegoat trump border crackdown',
#  'pennsylvania becomes latest state fund urban gun_violence prevention',
#  'denver mayor son caught_tape berating cop faggot',
#  'progressive prosecutors win primaries north_carolina',
#  'novartis get money paid trump lawyer',
#  'hypocrisy melania_trump online safety booklet pointed page page',
#  'uninsured rate worsening years obamacare gains',
#  'bernie_sanders plan revive labor unions',
#  'jim_carrey bestows scott_pruitt savage nickname latest painting',
#  'male allies become abusers',
#  'mormon church end century long relationship boy_scouts',
#  'snack addiction killing orangutans',
#  'trump pick cia_director say torture program morally wrong',
#  'anderson_cooper burns moronic michael_cohen russia cash claims',
#  'pinata maker apologizes hanging black figures likeness lynchings',
#  'caliphate trump planet ruins',
#  'gay_marriage opponent ousted gop incumbent north_carolina',
#  'espn eliminates public editor role calling outdated',
#  'michael_cohen selling access trump says group paid shell company',
#  'mitch_mcconnell mocks blankenship twitter big cloud cocaine',
#  'ex convict blankenship loses patrick morrisey west_virginia senate_race',
#  'ohio voters pass gerrymandering reform measure',
#  'trump iran_deal exit win russia',
#  'cynthia_nixon wants new_yorkers vote homo for the cuomo',
#  'ontario canada issued first non binary birth certificate',
#  'child sexual predator roman polanski calls movement total hypocrisy',
#  'america producer reveals new details childish gambino viral_video',
#  'terry crews black men allowed victims dead',
#  'donald glover america eyes jim crow historian',
#  'fox_news judicial analyst issues dark warning trump michael_cohen',
#  'black women bishops making history predominantly white church',
#  'geena davis th husband reza jarrahy divorcing',
#  'pauley perrette abby heart wrenching farewell ncis',
#  'lethal weapon fires clayne crawford character gets shot',
#  'selena_gomez pokes_fun met_gala spray tan mishap',
#  'protest leader nikol pashinian elected prime_minister armenia',
#  'kim_jong un secretly met xi jinping',
#  'netanyahu bombastic iran claims found perfect audience trump',
#  'netanyahu chef blasted serving japan prime_minister dessert shoe',
#  'world_leaders condemn trump withdrawing iran_nuclear deal',
#  'senate_republicans shun blankenship day west_virginia primary',
#  'new_york harvey_weinstein probe set continue despite attorney_general exit',
#  'trump announce whether break iran_nuclear deal',
#  'politicians call schneiderman resign physical abuse_allegations',
#  'joe_scarborough trump legal strategy like monkey throwing poo wall',
#  'kirsten_dunst jesse plemons welcome baby_boy',
#  'holy matrimony proposal met_gala',
#  'nordstrom rack president apologizes store accuses three black men theft',
#  'giuliani says trump lawyer michael_cohen incriminating information president',
#  'lena waithe stuns met_gala queer superhero',
#  'kelly accusers say ask permission to use bathroom',
#  'trump reportedly tells macron pulling iran_nuclear deal',
#  'deportation crackdown hurting immigrant victims crime',
#  'seth_meyers says michael_cohen tried get to apologize air to trump',
#  'blessing best met_gala tweets',
#  'farm bill_would cut food_stamps friendly farmers',
#  'know iran_nuclear deal',
#  'derby day bet wins thrilled texas woman million',
#  'democratic meddling west_virginia things watch election day',
#  'cynthia erivo met_gala nails featured sistine chapel painting black women',
#  'keanu reeves alex winter coming_back bill ted years',
#  'solange durag true mvp the met_gala',
#  'top house republican threatens subpoena trump doj official census citizenship request',
#  'jimmy_kimmel tries hard make_sense rudy latest trump defense gives',
#  'religious imagery stitched throughout the met_gala',
#  'bob marley granddaughter says cops racially profiled checking airbnb',
#  'melania_trump called anti bullying campaign ignores husband actions',
#  'trevor_noah watching rudy_giuliani like smoking weed tv',
#  'janet_jackson receive icon award billboard_music awards',
#  'white_house prepares send congress billion spending cuts package',
#  'jared_kushner backed bill could last shot federal prison reform',
#  'george_zimmerman accused stalking detective working trayvon_martin film',
#  'passengers lashing scott_pruitt justify first class travel new epa memo says',
#  'trump country house district became key progressive battleground',
#  'mike_pence brother wins primary race vice_president former house seat',
#  'marines investigating avowed white_supremacist active duty',
#  'trump violate iran_nuclear deal vows to reimpose sanctions',
#  'olympic_committee ignored sexual_abuse complaints taekwondo stars lawsuit',
#  'blake_lively brought family met_gala without even noticing',
#  'bill_reilly offers stand next to sarah sanders to handle line reporters',
#  'catholic priest praised best_dressed dude met_gala living life',
#  'jimmy_kimmel says hide seek genius dog heal nation',
#  'bank_america appears flip firearm promise loan to remington',
#  'gentleman caller presents queer icons never_seen',
#  'eric schneiderman always con man',
#  'christiane amanpour heading new pbs show replacing charlie rose',
#  'madonna teases new_song surprise met_gala performance',
#  'iron_man black widow captain_america thor hawkeye got matching tattoos',
#  'michael_cohen accepted firm tied russian oligarch reports',
#  'stephen_colbert hits rudy_giuliani brutal fact check',
#  'katy_perry sends olive branch taylor_swift world rejoices',
#  'jada_pinkett smith gets_real dating smith married',
#  'whoops mark_hamill spilled beans major cameo han solo movie',
#  'shawn mendes sweetly attended hailey baldwin gown met_gala',
#  'orrin hatch sorry suggested trump allowed john_mccain funeral',
#  'seth_meyers perfect line confront donald_trump lies',
#  'police hope use dna to catch zodiac killer',
#  'lili reinhart cole sprouse finally make couple debut met_gala',
#  'sweetbitter captures grit glamour the restaurant world',
#  'mitch_mcconnell bends rules confirm trump judges',
#  'ryan_zinke tale_two fish',
#  'ny attorney_general eric schneiderman resigns amid abuse_allegations',
#  'sanctuary_cities working trump era surprising cost',
#  'shepard_smith say trump pulled iran_deal made decision violate',
#  'stormy_daniels finds crunchy new way chip away trump',
#  'rainbow mountains peru look_like straight dr seuss book',
#  ...]

# %% [markdown]
# ### Stemming / Lemmatization & Part-of-Speech filtering

# %%
def lemmatize_texts(texts, 
                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'], 
                    forbidden_postags=[], 
                    as_sentence=False, 
                    get_postags=False, 
                    spacy_model=None):
    """Lemmatize a list of texts.
    
            Please refer to https://spacy.io/api/annotation for details on the allowed
        POS tags.
        @params:
            - texts_in: a list of texts, where each texts is a string
            - allowed_postags: a list of part of speech tags, in the spacy fashion
            - as_sentence: a boolean indicating whether the output should be a list of sentences instead of a list of word lists
        @return:
            - A list of texts where each entry is a list of words list or a list of sentences
        """
    texts_out = []
    
    if allowed_postags and forbidden_postags:
        raise ValueError("Can't specify both allowed and forbidden postags")

    if forbidden_postags:
        allowed_postags = list(set(POS_map.keys()).difference(set(forbidden_postags)))

    if not spacy_model:
        print("Loading spacy model")
        spacy_model = spacy.load('en_core_web_md')

    print("Beginning lemmatization process")
    total_steps = len(texts)

    docs = spacy_model.pipe(texts)

    for i, doc in tqdm(enumerate(docs), total=total_steps):
        if get_postags:
            texts_out.append(["_".join([token.lemma_, token.pos_]) for token in doc if token.pos_ in allowed_postags])
        else:
            texts_out.append(
                [token.lemma_ for token in doc if token.pos_ in allowed_postags])
    
    if as_sentence:
        texts_out = [" ".join(text) for text in texts_out]
        
    return texts_out

# %%
l_texts = lemmatize_texts(texts[:1000],
                allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV', 'X', 'PROPN'], 
                get_postags=False)
# Out:
# Loading spacy model
# Beginning lemmatization process
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:01<00:00, 579.17it/s]

# %% [markdown]
# ## Vectorisation

# %%
# Passage d'une liste de liste de mot à une liste de string
# Cela permettra de transformer notre corpus 
str1 = ""
vectorized_texts = l_texts

for text in vectorized_texts:
    str1 += " ".join(text)
    str1 += " /£$/ " 
vectorized_texts = str1.split(" /£$/ ")

vect = TfidfVectorizer(stop_words='english', max_features=1000)
vect_text = vect.fit_transform(vectorized_texts)
print(vect_text.shape)
# Out:
# (1001, 1000)

# %%
vect_text
# Out:
# <1001x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4491 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## KMeans

# %% [markdown]
# On va créer une fonction qui permet de trouver le nombre de cluster optimal.
# On affichera une graphique du nombre de cluster en fonction de SSE (la somme de l'erreur au carré / l'inertie).

# %% [markdown]
# ### KMeans - Métriques de clustering

# %% [markdown]
# #### Davies Bouldin Score

# %%
# Davies Bouldin Score
kmeans_text = vect_text

iters = range(5, 45, 2)
db = []
for n_clusters in iters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(kmeans_text)
    centers = clusterer.cluster_centers_

    score = davies_bouldin_score(kmeans_text.todense(), preds)
    db.append(score)
    print("For n_clusters = {}, Davies Bouldin Score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, db, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('Davies Bouldin Score')
ax.set_title('Davies Bouldin Score by Cluster Center Plot')
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 5, Davies Bouldin Score is 5.77374896571969
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 7, Davies Bouldin Score is 5.432385950695713
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 9, Davies Bouldin Score is 5.643803814597337
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 11, Davies Bouldin Score is 5.346937846795848
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 13, Davies Bouldin Score is 5.232284363718342
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 15, Davies Bouldin Score is 6.426624650072197
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 17, Davies Bouldin Score is 5.150677040257463
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 19, Davies Bouldin Score is 5.624570795791433
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 21, Davies Bouldin Score is 5.91904832003889
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 23, Davies Bouldin Score is 5.603345297532561
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 25, Davies Bouldin Score is 4.82411646669337
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 27, Davies Bouldin Score is 5.443272264620396
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 29, Davies Bouldin Score is 5.143862282886381
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 31, Davies Bouldin Score is 5.008783219040344
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 33, Davies Bouldin Score is 4.62627197502758
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 35, Davies Bouldin Score is 5.1270479746051985
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 37, Davies Bouldin Score is 4.753714896055977
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 39, Davies Bouldin Score is 4.6231724298698245
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 41, Davies Bouldin Score is 4.803166512606656
# For n_clusters = 43, Davies Bouldin Score is 4.572745451329385
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# Text(0.5, 1.0, 'Davies Bouldin Score by Cluster Center Plot')

# %% [markdown]
# #### Calinski Harabasz Score

# %%
# Calinski Harabasz Score
kmeans_text = vect_text

iters = range(5, 50, 2)
calinski = []
for n_clusters in iters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(kmeans_text)
    centers = clusterer.cluster_centers_

    score = calinski_harabasz_score(kmeans_text.todense(), preds)
    calinski.append(score)
    print("For n_clusters = {}, Calinski Harabasz score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, calinski, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('Calinski Harabasz Score')
ax.set_title('Calinski Harabasz Score by Cluster Center Plot')
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 5, Calinski Harabasz score is 6.3974925422420394
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 7, Calinski Harabasz score is 5.611140041837405
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 9, Calinski Harabasz score is 4.901320273177859
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 11, Calinski Harabasz score is 4.811586649992078
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 13, Calinski Harabasz score is 4.986059243392754
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 15, Calinski Harabasz score is 4.285254066516138
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 17, Calinski Harabasz score is 4.301635131803427
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 19, Calinski Harabasz score is 4.050789919840551
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 21, Calinski Harabasz score is 4.0261543646045785
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 23, Calinski Harabasz score is 3.8264651153621854
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 25, Calinski Harabasz score is 3.680681432004126
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 27, Calinski Harabasz score is 3.681322910916424
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 29, Calinski Harabasz score is 3.647193947085335
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 31, Calinski Harabasz score is 3.477139987170069
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 33, Calinski Harabasz score is 3.4340199971910907
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 35, Calinski Harabasz score is 3.333755654830926
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 37, Calinski Harabasz score is 3.1786609238993537
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 39, Calinski Harabasz score is 3.2355943110793746
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 41, Calinski Harabasz score is 3.207852288568998
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 43, Calinski Harabasz score is 3.3932545844770683
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 45, Calinski Harabasz score is 3.157892776470675
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 47, Calinski Harabasz score is 3.101607005594994
# For n_clusters = 49, Calinski Harabasz score is 3.072200623338339
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# Text(0.5, 1.0, 'Calinski Harabasz Score by Cluster Center Plot')

# %% [markdown]
# #### Silhouette Score

# %%
# Silhouette score
kmeans_text = vect_text

iters = range(5, 50, 2)
silhouette = []
for n_clusters in iters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(kmeans_text)
    centers = clusterer.cluster_centers_

    score = silhouette_score(kmeans_text.todense(), preds)
    silhouette.append(score)
    print("For n_clusters = {}, silhouette score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, silhouette, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('silhouette score')
ax.set_title('silhouette score by Cluster Center Plot')
# Out:
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 5, silhouette score is 0.010964374244313468
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 7, silhouette score is 0.012152786372487831
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 9, silhouette score is 0.013504726063980142
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 11, silhouette score is 0.01439599879476797
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 13, silhouette score is 0.014629092856859713
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 15, silhouette score is 0.01552152258299053
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 17, silhouette score is 0.016985501208911725
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 19, silhouette score is 0.017204694778505846
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 21, silhouette score is 0.01979882039873557
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 23, silhouette score is 0.01916998606380859
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 25, silhouette score is 0.020606090078692633
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 27, silhouette score is 0.019484489333900314
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 29, silhouette score is 0.02197038408279634
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 31, silhouette score is 0.023916320942036773
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 33, silhouette score is 0.022001651995368052
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 35, silhouette score is 0.02094771894708938
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 37, silhouette score is 0.02419171114164856
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 39, silhouette score is 0.023888394099998194
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 41, silhouette score is 0.02479951034046997
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 43, silhouette score is 0.02439283329043358
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 45, silhouette score is 0.022142373698585363
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# For n_clusters = 47, silhouette score is 0.025789475392975873
# For n_clusters = 49, silhouette score is 0.02749385172137904
# C:\Logiciels\Anaconda\lib\site-packages\sklearn\utils\validation.py:585: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(
# Text(0.5, 1.0, 'silhouette score by Cluster Center Plot')

# %% [markdown]
# Les métriques Calinski-Harabaz et silhouette score ne permettent pas de déterminer le nombre optimal de sujets. Plus le nombre de sujets augmente, plus les valeurs de ces métriques diminuent, ce qui signifie que les clusters deviennent moins bons du point de vue de ces métriques. La métrique cDBI se comporte différemment en fonction du nombre de sujets.

# %% [markdown]
# ### KMeans - Visualisation de données

# %%
kmeans = KMeans(n_clusters=13,random_state=42)
y_kmeans = kmeans.fit_predict(vect_text.toarray())

from sklearn.decomposition import PCA

X_pca = PCA(2).fit_transform(vect_text.toarray())

plt.figure(figsize=(12,10))
plt.scatter(X_pca[:,0],X_pca[:,1], c=y_kmeans, edgecolor='none', alpha=0.7, s=40,
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.title("Clusters")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Latent Dirichlet Allocation

# %% [markdown]
# Nous allons utiliser LDA qui est un type de Machine Learning non supervisé (ce qu'on recherche dans notre cas).
#
# L'objectif est de récupérer les paramètres des distributions dirichlet qui représentent la distribution des sujets dans les documents et la distribution des mots dans les sujets.

# %% [markdown]
# ### LDA - Métrique de clustering

# %%
# Creation du dictionnaire 
id2word = corpora.Dictionary(l_texts)
# Creation du corpus
texts = l_texts
# Fréquence des termes du document
corpus = [id2word.doc2bow(text) for text in texts]

# %%
# Construction du modèle LDA
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=10, 
                                       random_state=100,
                                       chunksize=100,
                                       passes=10,
                                       per_word_topics=True)

# %%
from gensim.models import CoherenceModel
# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=l_texts, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.6235367897508648

# %% [markdown]
# Notre approche pour trouver le nombre optimal de sujets consiste à construire de nombreux modèles LDA avec différentes valeurs du nombre de sujets (k) et à choisir celui qui donne la valeur de cohérence la plus élevée.
#
# Le choix d'un 'k' qui marque la fin d'une croissance rapide de la cohérence des sujets offre généralement des sujets significatifs et interprétables. Le choix d'une valeur encore plus élevée peut parfois fournir des sous-thèmes plus granulaires.
#
# Si vous voyez les mêmes mots-clés répétés dans plusieurs sujets, c'est probablement un signe que le 'k' est trop grand.
# La fonction compute_coherence_values() (voir ci-dessous) entraîne plusieurs modèles LDA et fournit les modèles et leurs scores de cohérence correspondants.

# %% [markdown]
# #### Cohérence score

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.LdaMulticore(corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=l_texts, start=2, limit=40, step=6)

# %%
# Affichage du graphe

limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Affichage des scores de cohérence
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %% [markdown]
# On voit qu'à partir de 32 topics, la cohérence diminue donc on peut considérer que pour ce modèle, 32 topics est l'idéal.

# %% [markdown]
# ### LDA - Visualisation des données

# %%
vect = CountVectorizer(stop_words='english', max_features=1000)
vect_text = vect.fit_transform(vectorized_texts)
print(vect_text.shape)

# %%
# Tweak the two parameters below
number_topics = 20
number_words = 8

# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1, learning_decay=0.9)
lda.fit(vect_text)


import pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# feed the LDA model into the pyLDAvis instance
lda_viz = pyLDAvis.sklearn.prepare(lda, vect_text, vect, mds='tsne')
lda_viz

# %% [markdown]
# ## Hierarchical Clustering: Agglomerative algorithms

# %% [markdown]
# Cette technique est basée sur la "fusion" des points de données individuels qui sont proches les uns des autres pour former des groupes plus grands, jusqu'à ce que le nombre donné de clusters (paramètre n_clusters) soit atteint.

# %%
# Silhouette Score
ac_text = vect_text

iters = range(5, 50, 2)
silhouette = []
for n_clusters in iters:
    ac = AgglomerativeClustering(n_clusters=n_clusters)
    preds = ac.fit_predict(ac_text.todense())

    score = silhouette_score(ac_text, preds)
    silhouette.append(score)
    print("For n_clusters = {}, Silhouette score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, silhouette, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('Silhouette Score')
ax.set_title('Silhouette Score by Cluster Center Plot')

# %%
# Calinski Harabasz Score
ac_text = vect_text

iters = range(5, 30, 2)
calinski = []
for n_clusters in iters:
    ac = AgglomerativeClustering(n_clusters=n_clusters)
    preds = ac.fit_predict(ac_text.todense())

    score = calinski_harabasz_score(ac_text.todense(), preds)
    calinski.append(score)
    print("For n_clusters = {}, Calinski Harabasz Score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, calinski, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('Calinski Harabasz Score')
ax.set_title('Calinski Harabasz Score by Cluster Center Plot')

# %%
# Davies Bouldin Score
db_text = vect_text

iters = range(5, 30, 2)
db = []
for n_clusters in iters:
    ac = AgglomerativeClustering(n_clusters=n_clusters)
    preds = ac.fit_predict(db_text.todense())

    score = davies_bouldin_score(db_text.todense(), preds)
    db.append(score)
    print("For n_clusters = {}, Davies Bouldin Score is {}".format(n_clusters, score))
        
f, ax = plt.subplots(1, 1)
ax.plot(iters, db, marker='o')
ax.set_xlabel('Cluster Centers')
ax.set_xticks(iters)
ax.set_xticklabels(iters)
ax.set_ylabel('Davies Bouldin Score')
ax.set_title('Davies Bouldin Score by Cluster Center Plot')

# %% [markdown]
# ### Hierarchical Clustering: Agglomerative algorithms - Visualisation

# %%
import seaborn as sns
X_pca = PCA(2).fit_transform(vect_text.toarray())
agglom = AgglomerativeClustering(n_clusters=5, linkage='average').fit(ac_text.todense())

y_agglom = agglom.labels_
plt.figure(figsize=(12, 8))
sns.scatterplot(X_pca[:,0],X_pca[:,1], hue=y_agglom, 
                palette=sns.color_palette('hls', 5))
plt.title('Agglomerative with 5 Clusters')
plt.show()

# %% [markdown]
# ## Comparaison des modèles

# %% [markdown]
# Ci-dessous va être affichés les différents scores de chaque métrique pour les modèles optimaux.

# %%
# Agglomerative Clustering
ac = AgglomerativeClustering(n_clusters=15)
preds = ac.fit_predict(ac_text.todense())

# KMeans
clusterer = KMeans(n_clusters=15)
preds = clusterer.fit_predict(kmeans_text)

# LDA
lda = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=20, 
                                       random_state=100,
                                       chunksize=100,
                                       passes=10,
                                       per_word_topics=True)

silhouette_score_ac = silhouette_score(ac_text, preds)
davies_bouldin_score_ac = davies_bouldin_score(ac_text.todense(), preds)
calinski_harabasz_score_ac = calinski_harabasz_score(ac_text.todense(), preds)

silhouette_score_km = silhouette_score(kmeans_text, preds)
davies_bouldin_score_km = davies_bouldin_score(kmeans_text.todense(), preds)
calinski_harabasz_score_km = calinski_harabasz_score(kmeans_text.todense(), preds)

coherencemodel = CoherenceModel(model=lda, texts=l_texts, dictionary=id2word, coherence='c_v')
coherence_score_lda = coherencemodel.get_coherence()

print('Silhouette Score AC :', silhouette_score_ac)
print('Silhouette Score KMeans :', silhouette_score_km)
print('Davies Bouldin Score AC :', davies_bouldin_score_ac)
print('Davies Bouldin Score KMeans :', davies_bouldin_score_km)
print('Calinski Harabasz Score AC :', calinski_harabasz_score_ac)
print('Calinski Harabasz Score KMeans :', calinski_harabasz_score_km)
print('Coherence Score LDA :', coherence_score_lda)

# %%
ar = np.array([[round(silhouette_score_km, 3), round(calinski_harabasz_score_km, 3), 'No results'], 
               [round(silhouette_score_ac, 3), round(calinski_harabasz_score_ac, 3), 'No results'], 
               ['No results', 'No results', round(coherence_score_lda, 3)]])
df = pd.DataFrame(ar, index = ['KMeans', 'Agglomerative Clustering', 'LDA'], 
                      columns = ['Silhouette Score', 'Calinski Harabasz Score','Coherence Score'])
df
