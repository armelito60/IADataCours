# %% [markdown]
# # <center>Natural Language Processing Hands-on #2</center>

# %% [markdown]
# During the Natural Language Processing course, text representation algorithms have been introduced. However they don't suffice to the creation of complete NLP systems.

# %% [markdown]
# Most of them usually rely on text pre-processing at first -- in other words, they rely on a specific data pipeline that is tied to the final task you are trying to solve.

# %% [markdown]
# As a result, we will try in this notebook to create a pipeline from scratch given a specific final task.

# %% [markdown]
# # Resources you'll need

# %% [markdown]
# ## Machine Learning libraries

# %% [markdown]
# Lots of ML libraries exist in the wild. You have general libraries such as [scikit-learn](https://scikit-learn.org/stable/), domain related libraries such as [nltk](https://www.nltk.org/) or hyper specific implementation of optimized algorithms such as annoy [annoy](https://pypi.org/project/annoy/).

# %% [markdown]
# In this notebook, you'll need to rely on the following packages:
#
#    - [scikit-learn](https://scikit-learn.org/stable/): all purpose machine learning resource if they aren't neural based.
#    - [nltk](https://www.nltk.org/): natural language toolkit -- implements lots of preprocessing steps and text transformation.
#    - [gensim](https://radimrehurek.com/gensim/): library designed to be easy to use for both topic modeling and text representation.
#    - [spacy](https://spacy.io/): industrialization machine learning systems. Provide lots of pretrained weights for various models.

# %% [markdown]
# Usually, a simple pip install is sufficient for them to work. If you have already installed it, feel free to create a dedicated virtual environment, which is really a good practice. If you want to know more regarding that, you can rely on this [here](https://virtualenvwrapper.readthedocs.io/en/latest/).

# %% [markdown]
# ## Data & final task definition

# %% [markdown]
# Given the [News dataset](https://www.kaggle.com/rmisra/news-category-dataset/download) (also available alongside this notebook), you'll have to build a simple topic modeling system that will identify the topics of the news headlines.

# %% [markdown]
# Those headlines have already been labelled. Here are the categories and document counts of this dataset:
#
# * POLITICS: 32739
#
# * WELLNESS: 17827
#
# * ENTERTAINMENT: 16058
#
# * TRAVEL: 9887
#
# * STYLE & BEAUTY: 9649
#
# * PARENTING: 8677
#
# * HEALTHY LIVING: 6694
#
# * QUEER VOICES: 6314
#
# * FOOD & DRINK: 6226
#
# * BUSINESS: 5937
#
# * COMEDY: 5175
#
# * SPORTS: 4884
#
# * BLACK VOICES: 4528
#
# * HOME & LIVING: 4195
#
# * PARENTS: 3955
#
# * THE WORLDPOST: 3664
#
# * WEDDINGS: 3651
#
# * WOMEN: 3490
#
# * IMPACT: 3459
#
# * DIVORCE: 3426
#
# * CRIME: 3405
#
# * MEDIA: 2815
#
# * WEIRD NEWS: 2670
#
# * GREEN: 2622
#
# * WORLDPOST: 2579
#
# * RELIGION: 2556
#
# * STYLE: 2254
#
# * SCIENCE: 2178
#
# * WORLD NEWS: 2177
#
# * TASTE: 2096
#
# * TECH: 2082
#
# * MONEY: 1707
#
# * ARTS: 1509
#
# * FIFTY: 1401
#
# * GOOD NEWS: 1398
#
# * ARTS & CULTURE: 1339
#
# * ENVIRONMENT: 1323
#
# * COLLEGE: 1144
#
# * LATINO VOICES: 1129
#
# * CULTURE & ARTS: 1030
#
# * EDUCATION: 1004

# %% [markdown]
# # Exploring the dataset

# %%
import pandas as pd
import itertools

# %% [markdown]
# You can load the dataset using pandas and the [.read_json()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_json.html) method. Try loading your dataset here:

# %%
dataset = pd.read_json("News_Category_Dataset_v2.json", lines=True, dtype={"headline": str})

# %% [markdown]
# ------

# %% [markdown]
# A good way to get the grasp of your corpus is to count the occurences of words across it. For convenience, we've defined a dummy function that splits words by checking where spaces are and... Simply that. This is the most basic form of word identification in text that could be used.

# %%
def dummy_word_split(texts):
    """Function identifying words in a sentence in a really dummy way.
        
        Argument:
            - texts (list of str): a list of raw texts in which we'd like to identify words
            
        Return:
            - list of list containing each word separately.
    """
    texts_out = []
    for text in texts:
        texts_out.append(text.split(" "))
        
    return texts_out

# %%
splitted_texts = dummy_word_split(dataset["headline"].tolist())

# %%
splitted_texts[0] + splitted_texts[1]
# Out:
# ['There',
#  'Were',
#  '2',
#  'Mass',
#  'Shootings',
#  'In',
#  'Texas',
#  'Last',
#  'Week,',
#  'But',
#  'Only',
#  '1',
#  'On',
#  'TV',
#  'Will',
#  'Smith',
#  'Joins',
#  'Diplo',
#  'And',
#  'Nicky',
#  'Jam',
#  'For',
#  'The',
#  '2018',
#  'World',
#  "Cup's",
#  'Official',
#  'Song']

# %% [markdown]
# Now, let's define a function that counts word occurences and highlight what are the most important words of our corpus:

# %%
def compute_word_occurences(texts):
    """You have to define this function yourself. """
    
    words = itertools.chain.from_iterable(texts)
    
    word_count = pd.Series(words).value_counts()
    word_count = pd.DataFrame({"Word": word_count.index, "Count": word_count.values})

    return word_count

# %% [markdown]
# Once this is done, display the top 20 most occuring words in your texts.

# %%
compute_word_occurences(splitted_texts).head(1000)
# Out:
#           Word  Count
# 0          The  47803
# 1           To  38569
# 2            A  24839
# 3           In  24141
# 4           Of  22956
# ..         ...    ...
# 995         30    258
# 996       Cake    258
# 997       Park    258
# 998  Companies    257
# 999   Mistakes    257
#
# [1000 rows x 2 columns]

# %% [markdown]
# Does it make sense, and can you leverage such results?

# %% [markdown]
# # Actual pipeline

# %% [markdown]
# As you have seen above, the results obtained from a simple word count aren't so great. Similar words doesn't add up (such as run and running), and you have a lot of noise included. Words such as *the*, *you*, *an* could be removed for instance.

# %% [markdown]
# Actually, a lot can be done. Let's check that out.

# %% [markdown]
# ----------

# %% [markdown]
# ## What does the pipeline look like?

# %% [markdown]
# A NLP data pipeline often relies on the following elements. Some can be added, some can be removed, but they all look like this at some point:

# %% [markdown]
# 1. **Ensuring data quality.** You have to make sure that there's no N/A in your data and that everything is in the good format shape. Having this as the entrance of your pipeline will save you a lot of time in the long run, so try defining it thoroughly.
#
#
# 2. **Filtering texts from unwanted characters**. Especially if you get data from web, you'll end up with HTML tags or encoding stuff that you don't need in your texts. Before applying anything to them, you need to get them cleaned up. Here, try removing the dates and the punctuation for instance.
#
#
# 3. **Unify your texts**. (*This is topic modeling specific*). You don't want to make the difference between a word at the beginning of a phrase of in the middle of it here. You should unify all your words by lowercasing them and deaccenting them as well.
#
#
# 4. **Converting sentences to lists of words**. Some words aren't needed for our analyses, such as *your*, *my*, etc. In order to remove them easily, you have to convert your sentences to lists of words. You can use the dummy function defined above but I'd advised against it. Try finding a function that does that smoothly in [gensim.utils](https://radimrehurek.com/gensim/utils.html)!
#
#
# 5. **Remove useless words**. You need to remove useless words from your corpus. You have two approaches: [use a hard defined list of stopwords](https://www.analyticsvidhya.com/blog/2019/08/how-to-remove-stopwords-text-normalization-nltk-spacy-gensim-python/) or rely on TF-IDF to identify useless words. The first is the simplest, the second might yield better results!
#
#
# 6. **Creating n-grams**. If you look at New York, it is composed of two words. As a result, a word count wouldn't really return a true count for *New York* per se. In NLP, we represent New York as New_York, which is considered a single word. The n-gram creation consists in identifying words that occur together often and regrouping them. It boosts interpretability for topic modeling in this case.
#
#
# 7. **Stemming / Lemmatization**. Shouldn't run, running, runnable be grouped and counted as a single word when we're identifying discussion topics? Yes, they should. Stemming is the process of cutting words to their word root (run- for instance) quite brutally while lemmatization will do the same by identifying the kind of word it is working on. You should convert the corpus words into those truncated representations to have a more realistic word count.
#
#
# 8. **Part of speech tagging**. POS helps in the identification of verbs, nouns, adjectives, etc. For topic models, it is a good idea to work only on verbs and nouns. Adjectives don't convey info about the actual underlying topic discussed at hand.

# %% [markdown]
# ## Let's create it!

# %%
import itertools
import os
import re
import secrets
import string

import pandas as pd
import spacy

from itertools import chain

from gensim.models.callbacks import CallbackAny2Vec
from gensim.models import Word2Vec, Phrases, KeyedVectors
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess
from nltk.corpus import wordnet
# from pattern.en import pluralize, singularize
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer
from tqdm import tqdm

from spacy.parts_of_speech import IDS as POS_map

# %% [markdown]
# Now it's your turn. Try to implement each step of the pipeline, and compare the word counts obtained earlier and the one obtained after preprocessing your texts.

# %% [markdown]
# ### Ensuring data quality

# %%
def check_data_quality(texts):
    """Check wheter all the dataset is conform to the expected behaviour."""
    assert all([isinstance(t, str) for t in texts]), "Input data contains something different than strings."
    assert all([t != np.nan for t in texts]), "Input data contains NaN values."
    
    return True

# %%
def force_format(texts):
    return [str(t) for t in texts]

# %%
texts = force_format(dataset["headline"])

# %%
print(f"Is the dataset passing our data quality check?\n{check_data_quality(texts)}")
# Out:
# Is the dataset passing our data quality check?
# True

# %% [markdown]
# ### Filtering texts

# %% [markdown]
# https://regex101.com/

# %%
def filter_text(texts_in):
    """Removes incorrect patterns from a list of texts, such as hyperlinks, bullet points and so on"""
    
    texts_out = re.sub(r'https?:\/\/[A-Za-z0-9_.-~\-]*', ' ', texts_in, flags=re.MULTILINE)
    texts_out = re.sub(r'[(){}\[\]<>]', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&amp;#.*;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&gt;', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'â€™', "'", texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'\s+', ' ', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'&#x200B;', ' ', texts_out, flags=re.MULTILINE)
    # Mail regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r"(?i)(?:[a-z0-9!#$%&'*+\/=?^_`{|}~-]+(?:\.[a-z0-9!#$%&'*+\/=?^_`{|}~-]+)*|\"(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21\x23-\x5b\x5d-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])*\")@(?:(?:[a-z0-9](?:[a-z0-9-]*[a-z0-9])?\.)+[a-z0-9](?:[a-z0-9-]*[a-z0-9])?|\[(?:(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9]))\.){3}(?:(2(5[0-5]|[0-4][0-9])|1[0-9][0-9]|[1-9]?[0-9])|[a-z0-9-]*[a-z0-9]:(?:[\x01-\x08\x0b\x0c\x0e-\x1f\x21-\x5a\x53-\x7f]|\\[\x01-\x09\x0b\x0c\x0e-\x7f])+)\])", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r'[a-zA-Z0-9-_.]+@[a-zA-Z0-9-_.]+\.[a-zA-Z0-9-_.]+', '', texts_out, flags=re.MULTILINE)
    # Phone regex
    # This regex is correct but WAY TOO LONG to process. So we skip it with a simpler version
    # texts_out = re.sub(r".*?(\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}).*?", '', texts_out, flags=re.MULTILINE)
    texts_out = re.sub(r"\(?\d{3}\D{0,3}\d{3}\D{0,3}\d{4}", '', texts_out, flags=re.MULTILINE)
    # Remove names in twitter
    texts_out = re.sub(r'@\S+( |\n)', '', texts_out, flags=re.MULTILINE)

    # Remove starts commonly used on social media
    texts_out = re.sub(r'\*', '', texts_out, flags=re.MULTILINE)
    return texts_out

# %%
texts = [filter_text(t) for t in texts]

# %% [markdown]
# ### Unifying texts & converting sentences to list of words

# %%
def sent_to_words(sentences):
    """Converts sentences to words.

    Convert sentences in lists of words while removing the accents and the punctuation.

    @param:
        sentences: a list of strings, the sentences we want to convert
    @return
        A list of words' lists.
    """
    for sentence in tqdm(sentences):
        yield (simple_preprocess(str(sentence), deacc=True))

# %%
texts = list(sent_to_words(texts))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200853/200853 [00:06<00:00, 32374.27it/s]

# %%
texts
# Out:
# [['there',
#   'were',
#   'mass',
#   'shootings',
#   'in',
#   'texas',
#   'last',
#   'week',
#   'but',
#   'only',
#   'on',
#   'tv'],
#  ['will',
#   'smith',
#   'joins',
#   'diplo',
#   'and',
#   'nicky',
#   'jam',
#   'for',
#   'the',
#   'world',
#   'cup',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'for', 'the', 'first', 'time', 'at', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'and',
#   'democrats',
#   'in',
#   'new',
#   'artwork'],
#  ['julianna',
#   'margulies',
#   'uses',
#   'donald',
#   'trump',
#   'poop',
#   'bags',
#   'to',
#   'pick',
#   'up',
#   'after',
#   'her',
#   'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'that',
#   'sexual',
#   'harassment',
#   'claims',
#   'could',
#   'undermine',
#   'legacy'],
#  ['donald',
#   'trump',
#   'is',
#   'lovin',
#   'new',
#   'mcdonald',
#   'jingle',
#   'in',
#   'tonight',
#   'show',
#   'bit'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['mike',
#   'myers',
#   'reveals',
#   'he',
#   'like',
#   'to',
#   'do',
#   'fourth',
#   'austin',
#   'powers',
#   'film'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'un',
#   'to',
#   'talk',
#   'trump',
#   'summit'],
#  ['with',
#   'its',
#   'way',
#   'of',
#   'life',
#   'at',
#   'risk',
#   'this',
#   'remote',
#   'oyster',
#   'growing',
#   'region',
#   'called',
#   'in',
#   'robots'],
#  ['trump',
#   'crackdown',
#   'on',
#   'immigrant',
#   'parents',
#   'puts',
#   'more',
#   'kids',
#   'in',
#   'an',
#   'already',
#   'strained',
#   'system'],
#  ['trump',
#   'son',
#   'should',
#   'be',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'of',
#   'putin',
#   'ally',
#   'who',
#   'met',
#   'with',
#   'trump',
#   'jr'],
#  ['edward',
#   'snowden',
#   'there',
#   'no',
#   'one',
#   'trump',
#   'loves',
#   'more',
#   'than',
#   'vladimir',
#   'putin'],
#  ['booyah',
#   'obama',
#   'photographer',
#   'hilariously',
#   'trolls',
#   'trump',
#   'spy',
#   'claim'],
#  ['ireland',
#   'votes',
#   'to',
#   'repeal',
#   'abortion',
#   'amendment',
#   'in',
#   'landslide',
#   'referendum'],
#  ['ryan',
#   'zinke',
#   'looks',
#   'to',
#   'reel',
#   'back',
#   'some',
#   'critics',
#   'with',
#   'grand',
#   'pivot',
#   'to',
#   'conservation'],
#  ['trump',
#   'scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'less',
#   'than',
#   'men',
#   'report'],
#  ['weird',
#   'father',
#   'day',
#   'gifts',
#   'your',
#   'dad',
#   'doesn',
#   'know',
#   'he',
#   'wants',
#   'but',
#   'he',
#   'does'],
#  ['twitter', 'and', 'it', 'was', 'universally', 'entertaining'],
#  ['mystery',
#   'wolf',
#   'like',
#   'animal',
#   'reportedly',
#   'shot',
#   'in',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north',
#   'korea',
#   'still',
#   'open',
#   'to',
#   'talks',
#   'after',
#   'trump',
#   'cancels',
#   'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'near',
#   'toronto',
#   'authorities',
#   'say'],
#  ['thousands',
#   'travel',
#   'home',
#   'to',
#   'ireland',
#   'to',
#   'vote',
#   'on',
#   'abortion',
#   'access'],
#  ['irish',
#   'voters',
#   'set',
#   'to',
#   'liberalize',
#   'abortion',
#   'laws',
#   'in',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'on',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['in',
#   'historic',
#   'victory',
#   'barbados',
#   'elects',
#   'first',
#   'female',
#   'prime',
#   'minister'],
#  ['police',
#   'killed',
#   'at',
#   'least',
#   'black',
#   'americans',
#   'from',
#   'the',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack',
#   'johnson',
#   'was',
#   'pardoned',
#   'but',
#   'taboo',
#   'sex',
#   'is',
#   'still',
#   'being',
#   'criminalized'],
#  ['bet', 'chairman', 'and', 'ceo', 'debra', 'lee', 'is', 'stepping', 'down'],
#  ['rachel',
#   'dolezal',
#   'faces',
#   'felony',
#   'charges',
#   'for',
#   'welfare',
#   'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'to',
#   'white',
#   'house',
#   'to',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'on',
#   'photo',
#   'of',
#   'whitney',
#   'houston',
#   'bathroom',
#   'for',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'from',
#   'marketing',
#   'campaigns',
#   'after',
#   'harassment',
#   'accusations'],
#  ['how',
#   'the',
#   'chinese',
#   'exclusion',
#   'act',
#   'can',
#   'help',
#   'us',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['trump', 'new', 'maga', 'themed', 'swimwear', 'sinks', 'on', 'twitter'],
#  ['seth',
#   'meyers',
#   'has',
#   'funny',
#   'regret',
#   'after',
#   'trump',
#   'cancels',
#   'north',
#   'korea',
#   'summit'],
#  ['colbert',
#   'wants',
#   'to',
#   'turn',
#   'nyc',
#   'subway',
#   'rides',
#   'into',
#   'new',
#   'and',
#   'terrible',
#   'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'after',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'on',
#   'muslim',
#   'students',
#   'at',
#   'mcdonald'],
#  ['jimmy',
#   'kimmel',
#   'knows',
#   'why',
#   'iran',
#   'supreme',
#   'leader',
#   'watches',
#   'tom',
#   'and',
#   'jerry'],
#  ['people', 'injured', 'in', 'indiana', 'school', 'shooting'],
#  ['people',
#   'are',
#   'rattled',
#   'by',
#   'how',
#   'much',
#   'this',
#   'nigerian',
#   'man',
#   'looks',
#   'like',
#   'chadwick',
#   'boseman'],
#  ['david',
#   'cross',
#   'proves',
#   'yet',
#   'again',
#   'that',
#   'he',
#   'terrible',
#   'at',
#   'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'of',
#   'upcoming',
#   'adult',
#   'themed',
#   'puppet',
#   'film'],
#  ['what',
#   'you',
#   'missed',
#   'about',
#   'the',
#   'saddest',
#   'death',
#   'in',
#   'avengers',
#   'infinity',
#   'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'back',
#   'story',
#   'of',
#   'drugging',
#   'and',
#   'sexual',
#   'assault'],
#  ['samantha',
#   'bee',
#   'parents',
#   'think',
#   'america',
#   'is',
#   'basically',
#   'war',
#   'zone'],
#  ['pete',
#   'davidson',
#   'says',
#   'his',
#   'mental',
#   'illness',
#   'doesn',
#   'ruin',
#   'romance'],
#  ['james',
#   'corden',
#   'and',
#   'adam',
#   'levine',
#   'get',
#   'pulled',
#   'over',
#   'during',
#   'carpool',
#   'karaoke'],
#  ['emilia',
#   'clarke',
#   'dishes',
#   'on',
#   'her',
#   'final',
#   'game',
#   'of',
#   'thrones',
#   'scene'],
#  ['hollywood',
#   'doesn',
#   'need',
#   'difficult',
#   'men',
#   'to',
#   'make',
#   'great',
#   'tv'],
#  ['harvey',
#   'weinstein',
#   'accusers',
#   'say',
#   'they',
#   'never',
#   'thought',
#   'he',
#   'would',
#   'be',
#   'arrested'],
#  ['harvey',
#   'weinstein',
#   'turns',
#   'himself',
#   'in',
#   'to',
#   'police',
#   'for',
#   'alleged',
#   'sex',
#   'crimes'],
#  ['john',
#   'mayer',
#   'weird',
#   'new',
#   'low',
#   'budget',
#   'video',
#   'is',
#   'meme',
#   'worthy',
#   'masterpiece'],
#  ['now',
#   'boba',
#   'fett',
#   'is',
#   'getting',
#   'his',
#   'own',
#   'star',
#   'wars',
#   'movie'],
#  ['trump', 'suggests', 'north', 'korea', 'summit', 'could', 'still', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'for',
#   'damaging',
#   'emails',
#   'about',
#   'hillary',
#   'clinton',
#   'from',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'to',
#   'nra',
#   'backed',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter',
#   'bots',
#   'may',
#   'have',
#   'delivered',
#   'donald',
#   'trump',
#   'victory',
#   'research',
#   'paper',
#   'says'],
#  ['bag',
#   'of',
#   'wet',
#   'socks',
#   'is',
#   'apparently',
#   'living',
#   'in',
#   'the',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member',
#   'of',
#   'the',
#   'far',
#   'right',
#   'proud',
#   'boys',
#   'menaced',
#   'twitter',
#   'user',
#   'on',
#   'his',
#   'doorstep'],
#  ['all',
#   'the',
#   'things',
#   'the',
#   'nra',
#   'has',
#   'blamed',
#   'for',
#   'the',
#   'texas',
#   'school',
#   'shooting'],
#  ['here',
#   'what',
#   'happens',
#   'when',
#   'catholic',
#   'hospital',
#   'won',
#   'try',
#   'to',
#   'save',
#   'you'],
#  ['trump',
#   'new',
#   'executive',
#   'orders',
#   'make',
#   'it',
#   'easier',
#   'to',
#   'fire',
#   'federal',
#   'workers'],
#  ['monsanto',
#   'and',
#   'bayer',
#   'are',
#   'set',
#   'to',
#   'merge',
#   'here',
#   'why',
#   'you',
#   'should',
#   'care'],
#  ['the', 'joy', 'of', 'watching', 'harvey', 'weinstein', 'perp', 'walk'],
#  ['the', 'funniest', 'tweets', 'from', 'women', 'this', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'me',
#   'desk',
#   'makeover',
#   'and',
#   'it',
#   'was',
#   'incredible'],
#  ['older',
#   'gay',
#   'men',
#   'try',
#   'out',
#   'new',
#   'gay',
#   'slang',
#   'in',
#   'this',
#   'hilarious',
#   'video'],
#  ['how',
#   'rupaul',
#   'drag',
#   'race',
#   'is',
#   'teaching',
#   'straight',
#   'people',
#   'about',
#   'queer',
#   'culture'],
#  ['fish',
#   'market',
#   'buys',
#   'freedom',
#   'for',
#   'fred',
#   'the',
#   'pound',
#   'octopus'],
#  ['north',
#   'korea',
#   'threatens',
#   'again',
#   'to',
#   'call',
#   'off',
#   'trump',
#   'summit',
#   'warns',
#   'of',
#   'nuclear',
#   'showdown'],
#  ['investigation',
#   'finds',
#   'russian',
#   'missile',
#   'shot',
#   'down',
#   'flight',
#   'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'at',
#   'nuclear',
#   'test',
#   'site',
#   'reports',
#   'say'],
#  ['how',
#   'kim',
#   'jong',
#   'un',
#   'baited',
#   'trump',
#   'into',
#   'canceling',
#   'the',
#   'north',
#   'korea',
#   'summit'],
#  ['michelle',
#   'obama',
#   'reveals',
#   'cover',
#   'for',
#   'upcoming',
#   'memoir',
#   'becoming'],
#  ['late',
#   'night',
#   'writer',
#   'breathless',
#   'royal',
#   'wedding',
#   'recap',
#   'is',
#   'the',
#   'only',
#   'one',
#   'you',
#   'need'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'of',
#   'inappropriate',
#   'behavior',
#   'and',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'won',
#   'fine',
#   'players',
#   'for',
#   'anthem',
#   'protests'],
#  ['andy',
#   'cohen',
#   'and',
#   'taylor',
#   'swift',
#   'are',
#   'over',
#   'their',
#   'katy',
#   'perry',
#   'drama'],
#  ['infinity',
#   'war',
#   'writers',
#   'try',
#   'to',
#   'clear',
#   'up',
#   'marvel',
#   'problematic',
#   'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'and',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'his',
#   'cheek'],
#  ['amy',
#   'poehler',
#   'parks',
#   'and',
#   'recreation',
#   'revival',
#   'would',
#   'be',
#   'amazing'],
#  ['colbert',
#   'exposes',
#   'the',
#   'biggest',
#   'flaw',
#   'in',
#   'trump',
#   'latest',
#   'conspiracy',
#   'theory'],
#  ['seth',
#   'meyers',
#   'gives',
#   'donald',
#   'trump',
#   'some',
#   'valuable',
#   'marketing',
#   'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'to',
#   'defend',
#   'its',
#   'interests'],
#  ['this',
#   'women',
#   'pulled',
#   'out',
#   'all',
#   'the',
#   'stops',
#   'to',
#   'land',
#   'her',
#   'dream',
#   'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'for',
#   'fenty',
#   'highlighter',
#   'and',
#   'got',
#   'pack',
#   'of',
#   'highlighters',
#   'hairbrush'],
#  ['trump',
#   'roasted',
#   'for',
#   'rushing',
#   'to',
#   'defend',
#   'tomi',
#   'lahren',
#   'while',
#   'ignoring',
#   'real',
#   'victims'],
#  ['trump',
#   'abruptly',
#   'cancels',
#   'north',
#   'korea',
#   'summit',
#   'with',
#   'kim',
#   'jong',
#   'un'],
#  ['devin',
#   'nunes',
#   'linked',
#   'winery',
#   'faced',
#   'suit',
#   'over',
#   'alleged',
#   'coke',
#   'and',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'of',
#   'abuse',
#   'and',
#   'neglect',
#   'report',
#   'shows'],
#  ['ireland',
#   'historic',
#   'vote',
#   'on',
#   'legalizing',
#   'abortion',
#   'is',
#   'haunted',
#   'by',
#   'trump',
#   'and',
#   'brexit'],
#  ['trump',
#   'lawyer',
#   'attended',
#   'doj',
#   'meeting',
#   'on',
#   'confidential',
#   'fbi',
#   'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'who',
#   'said',
#   'planned',
#   'parenthood',
#   'kills',
#   'over',
#   'females',
#   'year'],
#  ['rudy',
#   'giuliani',
#   'trump',
#   'won',
#   'interview',
#   'with',
#   'mueller',
#   'until',
#   'we',
#   'get',
#   'spygate',
#   'report'],
#  ['kentucky',
#   'attorney',
#   'running',
#   'for',
#   'judge',
#   'dies',
#   'day',
#   'after',
#   'primary',
#   'win'],
#  ['chrissy',
#   'teigen',
#   'taunts',
#   'donald',
#   'trump',
#   'over',
#   'twitter',
#   'blocking',
#   'ruling'],
#  ['the',
#   'koch',
#   'network',
#   'is',
#   'going',
#   'after',
#   'one',
#   'of',
#   'trump',
#   'favorite',
#   'congressmen'],
#  ['trump', 'posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'up',
#   'when',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'to',
#   'her',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'in',
#   'honor',
#   'of',
#   'the',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'and',
#   'fine',
#   'it',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'with',
#   'his',
#   'kids',
#   'in',
#   'the',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'and',
#   'accuses',
#   'mia',
#   'farrow',
#   'of',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'says',
#   'brad',
#   'pitt',
#   'threatened',
#   'to',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen',
#   'king',
#   'reveals',
#   'why',
#   'donald',
#   'trump',
#   'blocked',
#   'him',
#   'on',
#   'twitter'],
#  ['fans',
#   'back',
#   'jessica',
#   'walter',
#   'after',
#   'she',
#   'addressed',
#   'verbal',
#   'harassment',
#   'by',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambor',
#   'alleged',
#   'harassment',
#   'while',
#   'male',
#   'co',
#   'stars',
#   'brush',
#   'it',
#   'off'],
#  ['harvey',
#   'weinstein',
#   'expected',
#   'to',
#   'turn',
#   'himself',
#   'in',
#   'to',
#   'the',
#   'nypd',
#   'for',
#   'sex',
#   'crimes'],
#  ['samantha',
#   'bee',
#   'torches',
#   'ice',
#   'let',
#   'shut',
#   'it',
#   'the',
#   'fk',
#   'down'],
#  ['scott',
#   'pruitt',
#   'twice',
#   'introduced',
#   'anti',
#   'abortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'over',
#   'fetuses'],
#  ['twitter',
#   'critics',
#   'mercilessly',
#   'mock',
#   'trump',
#   'for',
#   'canceling',
#   'summit',
#   'with',
#   'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'bill',
#   'revising',
#   'its',
#   'own',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'to',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'from',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'to',
#   'keep',
#   'fighting',
#   'after',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'just',
#   'ignoring',
#   'new',
#   'climate',
#   'research'],
#  ['read',
#   'trump',
#   'letter',
#   'to',
#   'kim',
#   'jong',
#   'un',
#   'canceling',
#   'north',
#   'korea',
#   'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'to',
#   'trump',
#   'sudden',
#   'cancellation',
#   'of',
#   'kim',
#   'jong',
#   'un',
#   'summit'],
#  ['facebook',
#   'new',
#   'ad',
#   'rules',
#   'prove',
#   'it',
#   'basically',
#   'in',
#   'charge',
#   'of',
#   'regulating',
#   'elections',
#   'now'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'in', 'texas'],
#  ['trump',
#   'opens',
#   'door',
#   'for',
#   'gun',
#   'industry',
#   'to',
#   'sell',
#   'more',
#   'firearms',
#   'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'in',
#   'west',
#   'hollywood',
#   'as',
#   'adult',
#   'star',
#   'gets',
#   'key',
#   'to',
#   'city'],
#  ['you',
#   're',
#   'going',
#   'to',
#   'use',
#   'that',
#   'self',
#   'checkout',
#   'machine',
#   'whether',
#   'you',
#   'like',
#   'it',
#   'or',
#   'not'],
#  ['ways',
#   'to',
#   'make',
#   'family',
#   'road',
#   'trips',
#   'easier',
#   'from',
#   'parents',
#   'who',
#   've',
#   'been',
#   'there'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'trump',
#   'with',
#   'long',
#   'list',
#   'of',
#   'his',
#   'conspiracy',
#   'theories'],
#  ['new',
#   'york',
#   'daily',
#   'news',
#   'rips',
#   'nfl',
#   'over',
#   'anthem',
#   'kneeling',
#   'ban'],
#  ['judge',
#   'ruled',
#   'one',
#   'immigrant',
#   'had',
#   'right',
#   'to',
#   'hearing',
#   'what',
#   'about',
#   'all',
#   'the',
#   'others'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'for',
#   'students',
#   'affected',
#   'by',
#   'gun',
#   'violence'],
#  ['tig',
#   'notaro',
#   'tells',
#   'ellen',
#   'degeneres',
#   'about',
#   'her',
#   'sons',
#   'passion',
#   'for',
#   'trash'],
#  ['stormy',
#   'daniels',
#   'thanks',
#   'wonderful',
#   'gay',
#   'dads',
#   'as',
#   'west',
#   'hollywood',
#   'hands',
#   'her',
#   'keys',
#   'to',
#   'city'],
#  ['can', 'you', 'believe', 'queer', 'eye', 'season', 'drops', 'next', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'by',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'to',
#   'unseat',
#   'her'],
#  ['anna',
#   'kournikova',
#   'dancing',
#   'with',
#   'her',
#   'bouncing',
#   'baby',
#   'is',
#   'the',
#   'cutest',
#   'thing'],
#  ['trump',
#   'says',
#   'nfl',
#   'players',
#   'unwilling',
#   'to',
#   'stand',
#   'for',
#   'anthem',
#   'maybe',
#   'shouldn',
#   'be',
#   'in',
#   'the',
#   'country'],
#  ['facebook',
#   'accused',
#   'of',
#   'reading',
#   'texts',
#   'and',
#   'accessing',
#   'microphones',
#   'in',
#   'lawsuit'],
#  ['self',
#   'driving',
#   'uber',
#   'in',
#   'fatal',
#   'accident',
#   'had',
#   'seconds',
#   'to',
#   'react',
#   'before',
#   'crash'],
#  ['amazon',
#   'admits',
#   'alexa',
#   'device',
#   'eavesdropped',
#   'on',
#   'portland',
#   'family'],
#  ['man',
#   'discovers',
#   'handgun',
#   'impaled',
#   'in',
#   'front',
#   'bumper',
#   'of',
#   'car'],
#  ['rescue',
#   'cat',
#   'has',
#   'hilarious',
#   'wide',
#   'eyed',
#   'expression',
#   'after',
#   'scan',
#   'confirms',
#   'she',
#   'is',
#   'pregnant'],
#  ['weirdest',
#   'promposals',
#   'of',
#   'include',
#   'teen',
#   'who',
#   'faked',
#   'his',
#   'own',
#   'birth'],
#  ['trump',
#   'and',
#   'the',
#   'american',
#   'far',
#   'right',
#   'stoke',
#   'hate',
#   'in',
#   'canada'],
#  ['far',
#   'right',
#   'and',
#   'anti',
#   'establishment',
#   'parties',
#   'set',
#   'to',
#   'form',
#   'italy',
#   'new',
#   'government'],
#  ['sarah',
#   'silverman',
#   'sees',
#   'no',
#   'reason',
#   'why',
#   'louis',
#   'can',
#   'continue',
#   'being',
#   'an',
#   'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'who',
#   'said',
#   'abused',
#   'women',
#   'should',
#   'just',
#   'pray',
#   'is',
#   'removed',
#   'from',
#   'post'],
#  ['more', 'americans', 'than', 'ever', 'support', 'same', 'sex', 'marriage'],
#  ['brynn',
#   'cartelli',
#   'becomes',
#   'youngest',
#   'ever',
#   'winner',
#   'of',
#   'the',
#   'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'by',
#   'saying',
#   'schools',
#   'can',
#   'call',
#   'ice',
#   'on',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'for',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'in',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'in',
#   'texas',
#   'by',
#   'winning',
#   'democratic',
#   'nod',
#   'for',
#   'governor'],
#  ['report',
#   'michael',
#   'cohen',
#   'business',
#   'partner',
#   'cooperating',
#   'with',
#   'prosecutors'],
#  ['brandi',
#   'chastain',
#   'totally',
#   'agrees',
#   'her',
#   'hall',
#   'of',
#   'fame',
#   'plaque',
#   'looks',
#   'nothing',
#   'like',
#   'her'],
#  ['scientists',
#   'turn',
#   'to',
#   'dna',
#   'technology',
#   'to',
#   'search',
#   'for',
#   'loch',
#   'ness',
#   'monster'],
#  ['late',
#   'night',
#   'writer',
#   'vows',
#   'to',
#   'take',
#   'red',
#   'hats',
#   'back',
#   'from',
#   'trump',
#   'supporters'],
#  ['julia',
#   'louis',
#   'dreyfus',
#   'to',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'for',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'in',
#   'tribute',
#   'to',
#   'husband',
#   'barack'],
#  ['did',
#   'you',
#   'spot',
#   'trevor',
#   'noah',
#   'in',
#   'black',
#   'panther',
#   'the',
#   'daily',
#   'show',
#   'host',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'on',
#   'donald',
#   'trump',
#   'themed',
#   'reddit',
#   'forum'],
#  ['calls',
#   'for',
#   'boycott',
#   'of',
#   'restaurant',
#   'after',
#   'off',
#   'duty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor',
#   'of',
#   'rwandan',
#   'genocide',
#   'to',
#   'be',
#   'country',
#   'first',
#   'female',
#   'neurosurgeon'],
#  ['stacey',
#   'abrams',
#   'wins',
#   'democratic',
#   'primary',
#   'for',
#   'georgia',
#   'governor'],
#  ['trevor',
#   'noah',
#   'reveals',
#   'the',
#   'question',
#   'he',
#   'ask',
#   'donald',
#   'trump',
#   'that',
#   'no',
#   'else',
#   'has',
#   'dared',
#   'to'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'on',
#   'scary',
#   'time',
#   'at',
#   'princeton',
#   'with',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons',
#   'why',
#   'started',
#   'conversation',
#   'who',
#   'responsible',
#   'for',
#   'finishing',
#   'it'],
#  ['lourdes',
#   'leon',
#   'gives',
#   'us',
#   'major',
#   'madonna',
#   'vibes',
#   'in',
#   'moody',
#   'new',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways',
#   'netflix',
#   'tricks',
#   'you',
#   'into',
#   'watching',
#   'more',
#   'shows',
#   'and',
#   'movies'],
#  ['brad',
#   'pitt',
#   'made',
#   'ryan',
#   'reynolds',
#   'do',
#   'one',
#   'demeaning',
#   'thing',
#   'in',
#   'exchange',
#   'for',
#   'deadpool',
#   'cameo'],
#  ['robert',
#   'de',
#   'niro',
#   'bans',
#   'trump',
#   'from',
#   'every',
#   'nobu',
#   'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'down',
#   'fan',
#   'blaming',
#   'her',
#   'for',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'show',
#   'dogs',
#   'scenes',
#   'as',
#   'grooming',
#   'children',
#   'for',
#   'sexual',
#   'abuse'],
#  ['dave',
#   'grohl',
#   'wants',
#   'to',
#   'apologize',
#   'to',
#   'the',
#   'world',
#   'for',
#   'massive',
#   'jerk',
#   'trump'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'herself',
#   'to',
#   'prince',
#   'william',
#   'in',
#   'pretty',
#   'embarrassing',
#   'way'],
#  ['sarah',
#   'paulson',
#   'takes',
#   'impressions',
#   'to',
#   'next',
#   'level',
#   'on',
#   'tonight',
#   'show'],
#  ['the',
#   'are',
#   'still',
#   'ready',
#   'to',
#   'party',
#   'and',
#   'be',
#   'taken',
#   'seriously'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'in',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'in',
#   'kentucky',
#   'swing',
#   'district'],
#  ['trump',
#   'rallies',
#   'conservatives',
#   'with',
#   'promise',
#   'of',
#   'more',
#   'abortion',
#   'curbs'],
#  ['the',
#   'aclu',
#   'is',
#   'suing',
#   'to',
#   'strike',
#   'down',
#   'ohio',
#   'congressional',
#   'map'],
#  ['the',
#   'latest',
#   'school',
#   'shooting',
#   'hasn',
#   'really',
#   'stirred',
#   'the',
#   'gun',
#   'debate'],
#  ['donald',
#   'trump',
#   'tweet',
#   'rescues',
#   'roseanne',
#   'and',
#   'family',
#   'in',
#   'season',
#   'finale'],
#  ['ellen',
#   'grills',
#   'mark',
#   'wahlberg',
#   'about',
#   'his',
#   'shirtless',
#   'instagram',
#   'selfies'],
#  ['idris',
#   'elba',
#   'to',
#   'star',
#   'as',
#   'the',
#   'new',
#   'hunchback',
#   'of',
#   'notre',
#   'dame',
#   'for',
#   'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'with',
#   'past',
#   'abuse',
#   'of',
#   'at',
#   'risk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'during', 'the', 'national', 'anthem'],
#  ['conan',
#   'brien',
#   'muscles',
#   'in',
#   'on',
#   'the',
#   'royal',
#   'wedding',
#   'with',
#   'his',
#   'own',
#   'spoof',
#   'ads'],
#  ['house',
#   'republicans',
#   'report',
#   'progress',
#   'on',
#   'an',
#   'immigration',
#   'deal'],
#  ['democrats',
#   'weren',
#   'invited',
#   'to',
#   'review',
#   'classified',
#   'documents',
#   'on',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'who',
#   'pointed',
#   'gun',
#   'at',
#   'teenager',
#   'advances',
#   'to',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'of',
#   'an',
#   'entitled',
#   'millennial',
#   'swears',
#   'he',
#   'not',
#   'an',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'to',
#   'be',
#   'included',
#   'in',
#   'classified',
#   'briefing',
#   'on',
#   'fbi',
#   'informant'],
#  ['machines',
#   'don',
#   'always',
#   'steal',
#   'our',
#   'jobs',
#   'increasingly',
#   'they',
#   'rob',
#   'our',
#   'work',
#   'of',
#   'humanity'],
#  ['trump',
#   'praises',
#   'tomi',
#   'lahren',
#   'after',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'it', 'bothers', 'me', 'being', 'called', 'liar'],
#  ['trump', 'blocking', 'people', 'on', 'twitter', 'is', 'judge', 'rules'],
#  ['mostly',
#   'non',
#   'christian',
#   'militia',
#   'won',
#   'of',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'now',
#   'christians',
#   'want',
#   'trump',
#   'to',
#   'intervene'],
#  ['tulsi',
#   'gabbard',
#   'syria',
#   'views',
#   'cost',
#   'her',
#   'support',
#   'of',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'his', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'to',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'to',
#   'runoff',
#   'for',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'show',
#   'storms',
#   'west',
#   'coast',
#   'with',
#   'sexy',
#   'stormtroopers'],
#  ['establishment',
#   'backed',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'in',
#   'texas'],
#  ['senators',
#   'unveil',
#   'bill',
#   'to',
#   'crack',
#   'down',
#   'on',
#   'their',
#   'sexual',
#   'harassment'],
#  ['trips',
#   'to',
#   'take',
#   'from',
#   'new',
#   'york',
#   'city',
#   'on',
#   'long',
#   'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'for',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['the',
#   'latest',
#   'entries',
#   'from',
#   'the',
#   'comedy',
#   'wildlife',
#   'photo',
#   'awards',
#   'will',
#   'cheer',
#   'you',
#   'up'],
#  ['bad',
#   'lip',
#   'reading',
#   'reveals',
#   'what',
#   'was',
#   'really',
#   'said',
#   'at',
#   'the',
#   'royal',
#   'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'of',
#   'covering',
#   'up',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'says',
#   'iran',
#   'people',
#   'will',
#   'respond',
#   'to',
#   'pompeo',
#   'threats',
#   'with',
#   'punch',
#   'in',
#   'the',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'with',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'of',
#   'support',
#   'on',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'says', 'she', 'not', 'single', 'on', 'american', 'idol'],
#  ['before',
#   'you',
#   'call',
#   'the',
#   'cops',
#   'on',
#   'him',
#   'watch',
#   'his',
#   'powerful',
#   'monologue',
#   'on',
#   'racism'],
#  ['amazon',
#   'is',
#   'selling',
#   'cops',
#   'its',
#   'facial',
#   'recognition',
#   'tool',
#   'that',
#   'bad',
#   'potentially',
#   'racist',
#   'move'],
#  ['miley',
#   'cyrus',
#   'comes',
#   'in',
#   'like',
#   'wrecking',
#   'ball',
#   'to',
#   'prank',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa',
#   'bayer',
#   'feared',
#   'doing',
#   'the',
#   'porn',
#   'stars',
#   'skit',
#   'with',
#   'donald',
#   'trump',
#   'on',
#   'snl'],
#  ['adam',
#   'rippon',
#   'wins',
#   'dancing',
#   'with',
#   'the',
#   'stars',
#   'because',
#   'it',
#   'was',
#   'destined'],
#  ['emilia',
#   'clarke',
#   'should',
#   'never',
#   'try',
#   'to',
#   'imitate',
#   'chewbacca',
#   'ever',
#   'again'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'after',
#   'runner',
#   'up',
#   'reveals',
#   'they',
#   're',
#   'dating'],
#  ['colbert',
#   'just',
#   'can',
#   'resist',
#   'turning',
#   'trump',
#   'nickname',
#   'into',
#   'pee',
#   'tape',
#   'joke'],
#  ['seth',
#   'meyers',
#   'is',
#   'forced',
#   'to',
#   'tweak',
#   'donald',
#   'trump',
#   'latest',
#   'twitter',
#   'rant',
#   'for',
#   'time'],
#  ['boy',
#   'says',
#   'teacher',
#   'told',
#   'him',
#   'it',
#   'will',
#   'be',
#   'his',
#   'fault',
#   'when',
#   'police',
#   'shoot',
#   'him',
#   'at',
#   'age'],
#  ['cops',
#   'accused',
#   'of',
#   'racism',
#   'after',
#   'detaining',
#   'black',
#   'man',
#   'over',
#   'vegetation'],
#  ['white',
#   'cop',
#   'shouts',
#   'at',
#   'black',
#   'suspect',
#   'pretend',
#   'like',
#   'we',
#   're',
#   'going',
#   'to',
#   'shoot',
#   'you'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'after',
#   'standoff',
#   'at',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald',
#   'glover',
#   'is',
#   'on',
#   'board',
#   'with',
#   'lando',
#   'calrissian',
#   'pansexuality',
#   'in',
#   'solo'],
#  ['charlize',
#   'theron',
#   'to',
#   'play',
#   'megyn',
#   'kelly',
#   'in',
#   'film',
#   'about',
#   'roger',
#   'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'over',
#   'store',
#   'donations',
#   'to',
#   'nra',
#   'backed',
#   'candidate'],
#  ['bill',
#   'de',
#   'blasio',
#   'tells',
#   'nypd',
#   'to',
#   'stop',
#   'arresting',
#   'people',
#   'for',
#   'smoking',
#   'pot',
#   'on',
#   'the',
#   'street'],
#  ['dhs',
#   'head',
#   'says',
#   'she',
#   'still',
#   'somehow',
#   'unaware',
#   'of',
#   'intel',
#   'on',
#   'russia',
#   'interference',
#   'to',
#   'boost',
#   'trump'],
#  ['lawmaker',
#   'introduces',
#   'crowdfunding',
#   'bill',
#   'to',
#   'pay',
#   'for',
#   'trump',
#   'border',
#   'wall'],
#  ['gop',
#   'lawmakers',
#   'will',
#   'soon',
#   'be',
#   'allowed',
#   'to',
#   'review',
#   'classified',
#   'info',
#   'on',
#   'russia',
#   'investigation'],
#  ['james',
#   'corden',
#   'reveals',
#   'the',
#   'worst',
#   'part',
#   'of',
#   'the',
#   'royal',
#   'wedding',
#   'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'new',
#   'pledge',
#   'of',
#   'allegiance',
#   'for',
#   'students',
#   'in',
#   'bullet',
#   'riddled',
#   'schools'],
#  ['ellen',
#   'gets',
#   'david',
#   'spade',
#   'to',
#   'open',
#   'up',
#   'about',
#   'dating',
#   'younger',
#   'women'],
#  ['ceasefire',
#   'over',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'and',
#   'those',
#   'dummies',
#   'on',
#   'fox',
#   'friends'],
#  ['spoof',
#   'royal',
#   'wedding',
#   'video',
#   'sees',
#   'ceremony',
#   'taking',
#   'very',
#   'different',
#   'turn'],
#  ['the',
#   'georgia',
#   'gop',
#   'governor',
#   'primary',
#   'focuses',
#   'on',
#   'guns',
#   'and',
#   'immigration'],
#  ['glaad',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'in',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'now',
#   'offers',
#   'in',
#   'store',
#   'beauty',
#   'classes',
#   'for',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governor',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'for',
#   'the',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'to',
#   'let',
#   'schools',
#   'co',
#   'workers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'and',
#   'health',
#   'care',
#   'an',
#   'outsider',
#   'kentucky',
#   'dem',
#   'found',
#   'the',
#   'inside',
#   'track'],
#  ['there',
#   'are',
#   'some',
#   'problems',
#   'with',
#   'this',
#   'commemorative',
#   'trump',
#   'kim',
#   'jong',
#   'un',
#   'coin'],
#  ['giuliani',
#   'new',
#   'stance',
#   'on',
#   'russian',
#   'collusion',
#   'so',
#   'what',
#   'it',
#   'not',
#   'illegal'],
#  ['the',
#   'onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'with',
#   'his',
#   'own',
#   'cease',
#   'and',
#   'desist',
#   'note'],
#  ['democrats',
#   'want',
#   'to',
#   'boost',
#   'school',
#   'funding',
#   'to',
#   'address',
#   'teacher',
#   'walkouts'],
#  ['but',
#   'her',
#   'emails',
#   'lawmakers',
#   'shrug',
#   'off',
#   'trump',
#   'lax',
#   'cellphone',
#   'security'],
#  ['we',
#   'try',
#   'stink',
#   'bug',
#   'flavored',
#   'jelly',
#   'bellys',
#   'so',
#   'you',
#   'don',
#   'have',
#   'to'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'in',
#   'florida',
#   'city'],
#  ['congress',
#   'does',
#   'wall',
#   'street',
#   'favor',
#   'as',
#   'banks',
#   'post',
#   'record',
#   'profits'],
#  ['white', 'house', 'sinkhole', 'probably', 'metaphor', 'for', 'something'],
#  ['reporter',
#   'shoved',
#   'others',
#   'barred',
#   'from',
#   'epa',
#   'meeting',
#   'on',
#   'water',
#   'contaminants'],
#  ['garry',
#   'kasparov',
#   'donald',
#   'trump',
#   'has',
#   'more',
#   'russian',
#   'connections',
#   'than',
#   'aeroflot'],
#  ['lonely',
#   'planet',
#   'top',
#   'european',
#   'destinations',
#   'of',
#   'take',
#   'aim',
#   'at',
#   'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'anti',
#   'spanish',
#   'rant',
#   'is',
#   'not',
#   'the',
#   'person',
#   'am'],
#  ['minutes',
#   'reporter',
#   'reveals',
#   'trump',
#   'chilling',
#   'reason',
#   'for',
#   'slamming',
#   'the',
#   'press'],
#  ['trump',
#   'reportedly',
#   'rejects',
#   'phone',
#   'security',
#   'measures',
#   'as',
#   'too',
#   'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'with',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'in',
#   'bathroom',
#   'fight'],
#  ['ex',
#   'trump',
#   'adviser',
#   'calls',
#   'president',
#   'claims',
#   'that',
#   'informant',
#   'spied',
#   'on',
#   'campaign',
#   'embarrassing'],
#  ['vietnam',
#   'is',
#   'test',
#   'for',
#   'what',
#   'happens',
#   'when',
#   'the',
#   'abandons',
#   'climate',
#   'diplomacy'],
#  ['just',
#   'one',
#   'third',
#   'of',
#   'americans',
#   'think',
#   'trump',
#   'is',
#   'successfully',
#   'draining',
#   'the',
#   'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'not',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'and',
#   'meghan',
#   'love',
#   'brought',
#   'different',
#   'worlds',
#   'together'],
#  ['sarah',
#   'paulson',
#   'is',
#   'unapologetic',
#   'about',
#   'year',
#   'age',
#   'gap',
#   'with',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans',
#   'on',
#   'both',
#   'sides',
#   'of',
#   'gun',
#   'debate',
#   'agree',
#   'on',
#   'safe',
#   'storage',
#   'but',
#   'not',
#   'on',
#   'how',
#   'to',
#   'support',
#   'it'],
#  ['family',
#   'of',
#   'gay',
#   'man',
#   'found',
#   'critically',
#   'injured',
#   'near',
#   'amtrak',
#   'route',
#   'wants',
#   'answers'],
#  ['caitlyn',
#   'jenner',
#   'trump',
#   'is',
#   'the',
#   'worst',
#   'president',
#   'we',
#   'have',
#   'ever',
#   'had',
#   'on',
#   'lgbtq',
#   'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'from',
#   'store',
#   'because',
#   'company',
#   'won',
#   'support',
#   'homos'],
#  ['instagram',
#   'is',
#   'adding',
#   'mute',
#   'button',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'sanity'],
#  ['publix', 'censors', 'teen', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['what',
#   'do',
#   'you',
#   'say',
#   'to',
#   'sexist',
#   'passengers',
#   'this',
#   'female',
#   'pilot',
#   'has',
#   'the',
#   'perfect',
#   'response'],
#  ['time',
#   'up',
#   'takes',
#   'aim',
#   'at',
#   'mcdonald',
#   'walmart',
#   'over',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuela',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   're',
#   'elected',
#   'amid',
#   'allegations',
#   'of',
#   'irregularities'],
#  ['iran',
#   'says',
#   'europe',
#   'support',
#   'for',
#   'nuclear',
#   'deal',
#   'isn',
#   'enough',
#   'after',
#   'america',
#   'withdrawal'],
#  ['far',
#   'right',
#   'mob',
#   'attacks',
#   'year',
#   'old',
#   'liberal',
#   'greek',
#   'mayor'],
#  ['shawn',
#   'mendes',
#   'and',
#   'khalid',
#   'perform',
#   'with',
#   'parkland',
#   'survivors',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rice',
#   'mother',
#   'is',
#   'opening',
#   'youth',
#   'center',
#   'to',
#   'honor',
#   'her',
#   'son',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'to',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'when',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'for',
#   'moments',
#   'of',
#   'action',
#   'in',
#   'honor',
#   'of',
#   'texas',
#   'shooting',
#   'victims',
#   'at',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'word', 'onstage'],
#  ['gay',
#   'man',
#   'says',
#   'pope',
#   'francis',
#   'told',
#   'him',
#   'god',
#   'made',
#   'you',
#   'like',
#   'that',
#   'and',
#   'loves',
#   'you',
#   'like',
#   'that'],
#  ['unusual',
#   'asteroid',
#   'could',
#   'be',
#   'an',
#   'interstellar',
#   'guest',
#   'to',
#   'our',
#   'solar',
#   'system'],
#  ['she',
#   'started',
#   'suicide',
#   'prevention',
#   'site',
#   'at',
#   'age',
#   'it',
#   'still',
#   'going',
#   'strong'],
#  ['roger',
#   'stone',
#   'says',
#   'he',
#   'prepared',
#   'for',
#   'conjured',
#   'up',
#   'mueller',
#   'indictment'],
#  ['hillary', 'clinton', 'to', 'endorse', 'andrew', 'cuomo', 're', 'election'],
#  ['the',
#   'supreme',
#   'court',
#   'just',
#   'made',
#   'it',
#   'lot',
#   'harder',
#   'for',
#   'you',
#   'to',
#   'sue',
#   'your',
#   'employer'],
#  ['blake',
#   'farenthold',
#   'may',
#   'have',
#   'been',
#   'hired',
#   'illegally',
#   'at',
#   'his',
#   'new',
#   'lobbyist',
#   'job'],
#  ['bill',
#   'konigsberg',
#   'explores',
#   'new',
#   'side',
#   'of',
#   'the',
#   'gay',
#   'experience',
#   'in',
#   'his',
#   'latest',
#   'book'],
#  ['alone',
#   'in',
#   'the',
#   'game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'for',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'off',
#   'the',
#   'field'],
#  ['chrissy',
#   'teigen',
#   'somehow',
#   'gets',
#   'even',
#   'more',
#   'real',
#   'about',
#   'life',
#   'after',
#   'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'about',
#   'attending',
#   'royal',
#   'wedding'],
#  ['here', 'are', 'the', 'movies', 'coming', 'to', 'netflix', 'this', 'week'],
#  ['the', 'obamas', 'are', 'coming', 'to', 'your', 'netflix', 'queue'],
#  ['sorry',
#   'ben',
#   'affleck',
#   'make',
#   'way',
#   'for',
#   'justin',
#   'theroux',
#   'giant',
#   'rat',
#   'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'at',
#   'trump',
#   'during',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'can',
#   'talk',
#   'to',
#   'trump',
#   'until',
#   'trump',
#   'hears',
#   'more',
#   'about',
#   'fbi',
#   'source'],
#  ['democrats',
#   'plan',
#   'big',
#   'anti',
#   'corruption',
#   'theme',
#   'for',
#   'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'of',
#   'silence',
#   'calls',
#   'for',
#   'change',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['we',
#   'asked',
#   'the',
#   'american',
#   'public',
#   'to',
#   'settle',
#   'of',
#   'the',
#   'internet',
#   'dumbest',
#   'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'really',
#   'don',
#   'like',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['trump',
#   'team',
#   'moves',
#   'to',
#   'lift',
#   'ban',
#   'on',
#   'extreme',
#   'hunting',
#   'tactics',
#   'in',
#   'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'how',
#   'trump',
#   'sexualized',
#   'ivanka',
#   'and',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['the',
#   'supreme',
#   'court',
#   'is',
#   'helping',
#   'companies',
#   'get',
#   'away',
#   'with',
#   'sexual',
#   'harassment'],
#  ['deadpool',
#   'steals',
#   'no',
#   'spot',
#   'at',
#   'the',
#   'box',
#   'office',
#   'from',
#   'avengers',
#   'infinity',
#   'war'],
#  ['did', 'westworld', 'subtly', 'tease', 'that', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'about',
#   'his',
#   'full',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'with',
#   'his',
#   'son'],
#  ['marvel',
#   'exec',
#   'tried',
#   'to',
#   'stop',
#   'the',
#   'most',
#   'jarring',
#   'infinity',
#   'war',
#   'death'],
#  ['jake',
#   'gyllenhaal',
#   'set',
#   'to',
#   'star',
#   'as',
#   'villain',
#   'in',
#   'spider',
#   'man',
#   'sequel'],
#  ['janet',
#   'jackson',
#   'becomes',
#   'first',
#   'black',
#   'woman',
#   'to',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['this',
#   'isn',
#   'pakistan',
#   'bitch',
#   'video',
#   'captures',
#   'driver',
#   'racist',
#   'rant'],
#  ['the',
#   'grey',
#   'gardens',
#   'ladies',
#   'were',
#   'the',
#   'unwitting',
#   'godmothers',
#   'of',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['year',
#   'old',
#   'boy',
#   'is',
#   'superhero',
#   'to',
#   'alabama',
#   'homeless',
#   'population'],
#  ['john',
#   'oliver',
#   'has',
#   'the',
#   'best',
#   'time',
#   'mocking',
#   'the',
#   'royal',
#   'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'the',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele',
#   'hill',
#   'honored',
#   'as',
#   'nabj',
#   'journalist',
#   'of',
#   'the',
#   'year'],
#  ['french',
#   'digital',
#   'minister',
#   'comes',
#   'out',
#   'as',
#   'gay',
#   'to',
#   'fight',
#   'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'at',
#   'cannes',
#   'film',
#   'festival'],
#  ['year',
#   'old',
#   'gay',
#   'man',
#   'proves',
#   'you',
#   're',
#   'never',
#   'too',
#   'old',
#   'to',
#   'attend',
#   'your',
#   'first',
#   'pride'],
#  ['super',
#   'pacs',
#   'that',
#   'meddled',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'primary',
#   'didn',
#   'receive',
#   'penny',
#   'from',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'after',
#   'allegedly',
#   'harassing',
#   'woman',
#   'and',
#   'peeing',
#   'on',
#   'seat'],
#  ['mike',
#   'pompeo',
#   'promises',
#   'to',
#   'crush',
#   'iran',
#   'and',
#   'achieve',
#   'better',
#   'deal'],
#  ['majestic',
#   'islands',
#   'in',
#   'europe',
#   'that',
#   'most',
#   'tourists',
#   'don',
#   'know',
#   'about',
#   'yet'],
#  ['cuba',
#   'confirms',
#   'killed',
#   'in',
#   'country',
#   'deadliest',
#   'plane',
#   'crash',
#   'since'],
#  ['china',
#   'putting',
#   'trade',
#   'war',
#   'on',
#   'hold',
#   'treasury',
#   'steve',
#   'mnuchin',
#   'says'],
#  ['trump',
#   'top',
#   'economic',
#   'adviser',
#   'says',
#   'amazon',
#   'threats',
#   'are',
#   'not',
#   'in',
#   'my',
#   'lane'],
#  ['dems',
#   'trump',
#   'admin',
#   'find',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'of',
#   'myanmar',
#   'genocide'],
#  ['giuliani',
#   'says',
#   'mueller',
#   'will',
#   'wrap',
#   'up',
#   'trump',
#   'obstruction',
#   'probe',
#   'by',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'for',
#   'racist',
#   'coverage',
#   'of',
#   'royal',
#   'wedding'],
#  ['kathryn',
#   'newton',
#   'the',
#   'boldest',
#   'teen',
#   'on',
#   'tv',
#   'is',
#   'ready',
#   'to',
#   'grow',
#   'up'],
#  ['stephanie', 'kelton', 'has', 'the', 'biggest', 'idea', 'in', 'washington'],
#  ['texas',
#   'gov',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'after',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina',
#   'fey',
#   'sarah',
#   'palin',
#   'leads',
#   'snl',
#   'chorus',
#   'lamenting',
#   'what',
#   'did',
#   'for',
#   'trump'],
#  ['after',
#   'day',
#   'of',
#   'american',
#   'gushing',
#   'snl',
#   'goes',
#   'smart',
#   'aleck',
#   'on',
#   'the',
#   'royal',
#   'wedding'],
#  ['starbucks',
#   'says',
#   'anyone',
#   'can',
#   'now',
#   'sit',
#   'in',
#   'its',
#   'cafes',
#   'even',
#   'without',
#   'buying',
#   'anything'],
#  ['alec',
#   'baldwin',
#   'trump',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'in',
#   'snl',
#   'finale'],
#  ['asia',
#   'argento',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'was',
#   'raped',
#   'by',
#   'harvey',
#   'weinstein',
#   'here'],
#  ['tina',
#   'fey',
#   'tries',
#   'out',
#   'for',
#   'mean',
#   'girls',
#   'the',
#   'musical',
#   'on',
#   'snl'],
#  ['parents',
#   'of',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['trump',
#   'real',
#   'americans',
#   'should',
#   'get',
#   'tough',
#   'on',
#   'russia',
#   'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'name',
#   'of',
#   'baby',
#   'boy',
#   'with',
#   'adorable',
#   'photo'],
#  ['texas',
#   'lt',
#   'gov',
#   'dan',
#   'patrick',
#   'touts',
#   'need',
#   'to',
#   'arm',
#   'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'on',
#   'media',
#   'to',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['trump',
#   'sets',
#   'up',
#   'showdown',
#   'with',
#   'doj',
#   'over',
#   'claims',
#   'of',
#   'campaign',
#   'surveillance'],
#  ['jim',
#   'carrey',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'and',
#   'her',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'on', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'into',
#   'reviewing',
#   'the',
#   'wedding',
#   'before',
#   'the',
#   'big',
#   'day'],
#  ['jimmy',
#   'fallon',
#   'reveals',
#   'his',
#   'viewers',
#   'biggest',
#   'wedding',
#   'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'to',
#   'razz',
#   'lawyer',
#   'who',
#   'ranted',
#   'at',
#   'spanish',
#   'speakers'],
#  ['what',
#   'to',
#   'watch',
#   'on',
#   'amazon',
#   'prime',
#   'that',
#   'new',
#   'this',
#   'week'],
#  ['will',
#   'ferrell',
#   'and',
#   'molly',
#   'shannon',
#   'cover',
#   'the',
#   'royal',
#   'wedding',
#   'as',
#   'cord',
#   'and',
#   'tish'],
#  ['the',
#   'artist',
#   'formerly',
#   'known',
#   'as',
#   'cedric',
#   'the',
#   'entertainer',
#   'has',
#   'arrived'],
#  ['mark',
#   'kelly',
#   'trump',
#   'rolled',
#   'over',
#   'for',
#   'nra',
#   'did',
#   'nothing',
#   'about',
#   'guns',
#   'after',
#   'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'up',
#   'trust',
#   'that',
#   'pays',
#   'his',
#   'kids',
#   'for',
#   'marrying',
#   'white',
#   'people'],
#  ['houston',
#   'police',
#   'chief',
#   'says',
#   'he',
#   'sick',
#   'of',
#   'inaction',
#   'on',
#   'gun',
#   'control'],
#  ['the', 'history', 'of', 'the', 'national', 'anthem', 'in', 'sports'],
#  ['bbc',
#   'trolls',
#   'president',
#   'trump',
#   'with',
#   'bigly',
#   'huge',
#   'royal',
#   'wedding',
#   'crowd'],
#  ['these',
#   'are',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'santa',
#   'fe',
#   'high',
#   'school',
#   'shooting'],
#  ['this',
#   'ceo',
#   'took',
#   'pay',
#   'cut',
#   'to',
#   'give',
#   'employees',
#   'year',
#   'now',
#   'he',
#   'battling',
#   'amazon'],
#  ['trump',
#   'jr',
#   'met',
#   'with',
#   'emissary',
#   'for',
#   'gulf',
#   'princes',
#   'offering',
#   'help',
#   'with',
#   'campaign',
#   'in',
#   'report'],
#  ['trump',
#   'misspells',
#   'melania',
#   'name',
#   'in',
#   'welcome',
#   'home',
#   'tweet',
#   'twitter',
#   'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'trump',
#   'lawmakers',
#   'after',
#   'texas',
#   'school',
#   'shooting'],
#  ['bill',
#   'maher',
#   'reveals',
#   'things',
#   'you',
#   'don',
#   'know',
#   'about',
#   'michael',
#   'cohen'],
#  ['what', 'to', 'watch', 'on', 'hulu', 'that', 'new', 'this', 'week'],
#  ['students',
#   'stage',
#   'sit',
#   'in',
#   'for',
#   'gun',
#   'control',
#   'outside',
#   'paul',
#   'ryan',
#   'office',
#   'get',
#   'arrested'],
#  ['trump',
#   'knew',
#   'scary',
#   'amount',
#   'about',
#   'the',
#   'appearance',
#   'of',
#   'bill',
#   'gates',
#   'daughter'],
#  ['ex',
#   'russian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'from',
#   'uk',
#   'hospital',
#   'after',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills', 'over'],
#  ['trump',
#   'reassures',
#   'north',
#   'korea',
#   'but',
#   'threatens',
#   'total',
#   'decimation',
#   'without',
#   'deal'],
#  ['ariana',
#   'grande',
#   'gives',
#   'fans',
#   'singing',
#   'one',
#   'last',
#   'time',
#   'the',
#   'surprise',
#   'of',
#   'their',
#   'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'for',
#   'chapter',
#   'bankruptcy',
#   'after',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'before',
#   'shooting'],
#  ['michelle',
#   'wolf',
#   'netflix',
#   'trailer',
#   'gives',
#   'us',
#   'closer',
#   'look',
#   'at',
#   'her',
#   'new',
#   'show'],
#  ['jeff',
#   'sessions',
#   'uses',
#   'exceptional',
#   'power',
#   'over',
#   'immigration',
#   'courts',
#   'to',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'bill',
#   'that',
#   'would',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'to',
#   'mccain'],
#  ['colbert',
#   'has',
#   'super',
#   'graphic',
#   'way',
#   'of',
#   'describing',
#   'how',
#   'deep',
#   'mueller',
#   'probe',
#   'goes',
#   'now'],
#  ['jack', 'osbourne', 'wife', 'files', 'for', 'divorce'],
#  ['meek',
#   'mill',
#   'backs',
#   'out',
#   'of',
#   'trump',
#   'event',
#   'on',
#   'prison',
#   'reform'],
#  ['new',
#   'trump',
#   'rule',
#   'would',
#   'cut',
#   'federal',
#   'funds',
#   'from',
#   'clinics',
#   'providing',
#   'abortions'],
#  ['twitter',
#   'users',
#   'joke',
#   'trump',
#   'wants',
#   'prison',
#   'reform',
#   'because',
#   'that',
#   'where',
#   'he',
#   'headed'],
#  ['every',
#   'single',
#   'chilean',
#   'bishop',
#   'offers',
#   'to',
#   'resign',
#   'over',
#   'country',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'the',
#   'worst',
#   'of',
#   'humanity',
#   'one',
#   'year',
#   'later'],
#  ['chrissy',
#   'teigen',
#   'spills',
#   'first',
#   'details',
#   'about',
#   'new',
#   'baby',
#   'boy',
#   'we',
#   'are',
#   'in',
#   'love'],
#  ['alec',
#   'baldwin',
#   'and',
#   'wife',
#   'hilaria',
#   'welcome',
#   'another',
#   'baby',
#   'boy'],
#  ['kate',
#   'mckinnon',
#   'breaks',
#   'out',
#   'another',
#   'impression',
#   'of',
#   'rudy',
#   'giuliani'],
#  ['how',
#   'did',
#   'smallville',
#   'allison',
#   'mack',
#   'get',
#   'involved',
#   'with',
#   'sex',
#   'cult',
#   'in',
#   'the',
#   'first',
#   'place'],
#  ['trump',
#   'white',
#   'house',
#   'kills',
#   'off',
#   'yanny',
#   'laurel',
#   'debate',
#   'with',
#   'ridiculous',
#   'clip'],
#  ['jennifer',
#   'aniston',
#   'to',
#   'play',
#   'lesbian',
#   'president',
#   'in',
#   'netflix',
#   'first',
#   'ladies'],
#  ['break',
#   'out',
#   'the',
#   'book',
# ...
#   'people',
#   'back',
#   'to',
#   'work'],
#  ['jim',
#   'parsons',
#   'yes',
#   'we',
#   'still',
#   'need',
#   'more',
#   'queer',
#   'stories',
#   'onscreen'],
#  ['trump',
#   'accuser',
#   'wins',
#   'democratic',
#   'nomination',
#   'for',
#   'ohio',
#   'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'by',
#   'cia',
#   'has',
#   'information',
#   'to',
#   'share',
#   'about',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'who',
#   'backs',
#   'trump',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor',
#   'swift',
#   'might',
#   've',
#   'made',
#   'up',
#   'with',
#   'katy',
#   'perry',
#   'but',
#   'her',
#   'kimye',
#   'feud',
#   'lives',
#   'on'],
#  ['kim',
#   'kardashian',
#   'to',
#   'make',
#   'history',
#   'with',
#   'fashion',
#   'council',
#   'first',
#   'influencer',
#   'award'],
#  ['nbc',
#   'says',
#   'it',
#   'believes',
#   'matt',
#   'lauer',
#   'accusers',
#   'after',
#   'months',
#   'long',
#   'investigation'],
#  ['russians',
#   'had',
#   'ability',
#   'to',
#   'change',
#   'voter',
#   'data',
#   'but',
#   'didn',
#   'report',
#   'says'],
#  ['elizabeth',
#   'warren',
#   'pick',
#   'wins',
#   'ohio',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk',
#   'leader',
#   'found',
#   'guilty',
#   'of',
#   'firing',
#   'gun',
#   'at',
#   'charlottesville',
#   'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'from',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['at',
#   'hired',
#   'firm',
#   'linked',
#   'to',
#   'michael',
#   'cohen',
#   'to',
#   'get',
#   'the',
#   'inside',
#   'scoop',
#   'on',
#   'trump'],
#  ['the',
#   'rnc',
#   'is',
#   'selling',
#   'sickening',
#   'donald',
#   'trump',
#   'themed',
#   'merch',
#   'ahead',
#   'of',
#   'mother',
#   'day'],
#  ['don',
#   'blankenship',
#   'defeat',
#   'is',
#   'relief',
#   'to',
#   'the',
#   'families',
#   'of',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert',
#   'shreds',
#   'trump',
#   'over',
#   'broken',
#   'promises',
#   'what',
#   'are',
#   'you',
#   'talking',
#   'about'],
#  ['new',
#   'ambassador',
#   'to',
#   'germany',
#   'offends',
#   'hosts',
#   'just',
#   'hours',
#   'into',
#   'his',
#   'first',
#   'day'],
#  ['jordan',
#   'peele',
#   'new',
#   'nightmare',
#   'is',
#   'coming',
#   'out',
#   'next',
#   'year'],
#  ['the',
#   'backstreet',
#   'boys',
#   'dressed',
#   'as',
#   'the',
#   'spice',
#   'girls',
#   'are',
#   'larger',
#   'than',
#   'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'what',
#   'giuliani',
#   'really',
#   'means'],
#  ['here',
#   'look',
#   'at',
#   'orlando',
#   'interim',
#   'pulse',
#   'nightclub',
#   'memorial'],
#  ['trevor',
#   'noah',
#   'turns',
#   'donald',
#   'trump',
#   'knives',
#   'comment',
#   'into',
#   'reggae',
#   'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'that',
#   'may',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'has',
#   'plan',
#   'in',
#   'place',
#   'to',
#   'consider',
#   'replacements',
#   'for',
#   'eric',
#   'schneiderman'],
#  ['more',
#   'than',
#   'former',
#   'ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california',
#   'authority',
#   'says',
#   'state',
#   'new',
#   'homes',
#   'must',
#   'be',
#   'solar',
#   'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'into',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['how',
#   'the',
#   'refugee',
#   'caravan',
#   'became',
#   'scapegoat',
#   'for',
#   'trump',
#   'border',
#   'crackdown'],
#  ['pennsylvania',
#   'becomes',
#   'latest',
#   'state',
#   'to',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver',
#   'mayor',
#   'son',
#   'caught',
#   'on',
#   'tape',
#   'berating',
#   'cop',
#   'as',
#   'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'in', 'north', 'carolina'],
#  ['what',
#   'did',
#   'at',
#   'and',
#   'novartis',
#   'get',
#   'for',
#   'the',
#   'money',
#   'they',
#   'paid',
#   'trump',
#   'lawyer'],
#  ['the',
#   'hypocrisy',
#   'of',
#   'melania',
#   'trump',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'out',
#   'page',
#   'by',
#   'page'],
#  ['the',
#   'uninsured',
#   'rate',
#   'is',
#   'worsening',
#   'after',
#   'years',
#   'of',
#   'obamacare',
#   'gains'],
#  ['bernie', 'sanders', 'has', 'plan', 'to', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'with',
#   'savage',
#   'nickname',
#   'in',
#   'latest',
#   'painting'],
#  ['when', 'male', 'allies', 'become', 'abusers'],
#  ['mormon',
#   'church',
#   'to',
#   'end',
#   'its',
#   'century',
#   'long',
#   'relationship',
#   'with',
#   'the',
#   'boy',
#   'scouts'],
#  ['our', 'snack', 'addiction', 'is', 'killing', 'orangutans'],
#  ['trump',
#   'pick',
#   'for',
#   'cia',
#   'director',
#   'won',
#   'say',
#   'torture',
#   'program',
#   'was',
#   'morally',
#   'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'over',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'for',
#   'hanging',
#   'black',
#   'figures',
#   'in',
#   'the',
#   'likeness',
#   'of',
#   'lynchings'],
#  ['the', 'caliphate', 'of', 'trump', 'and', 'planet', 'in', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'just',
#   'ousted',
#   'gop',
#   'incumbent',
#   'in',
#   'north',
#   'carolina'],
#  ['espn',
#   'eliminates',
#   'public',
#   'editor',
#   'role',
#   'calling',
#   'it',
#   'outdated'],
#  ['michael',
#   'cohen',
#   'was',
#   'selling',
#   'access',
#   'to',
#   'trump',
#   'says',
#   'group',
#   'that',
#   'paid',
#   'into',
#   'his',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'on',
#   'twitter',
#   'with',
#   'big',
#   'cloud',
#   'of',
#   'cocaine'],
#  ['ex',
#   'convict',
#   'don',
#   'blankenship',
#   'loses',
#   'to',
#   'patrick',
#   'morrisey',
#   'in',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['trump', 'iran', 'deal', 'exit', 'is', 'win', 'for', 'russia'],
#  ['cynthia',
#   'nixon',
#   'wants',
#   'new',
#   'yorkers',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'homo',
#   'not',
#   'for',
#   'the',
#   'cuomo'],
#  ['ontario',
#   'canada',
#   'just',
#   'issued',
#   'its',
#   'first',
#   'non',
#   'binary',
#   'birth',
#   'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'me',
#   'too',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['this',
#   'is',
#   'america',
#   'producer',
#   'reveals',
#   'new',
#   'details',
#   'about',
#   'childish',
#   'gambino',
#   'viral',
#   'video'],
#  ['terry',
#   'crews',
#   'black',
#   'men',
#   'aren',
#   'allowed',
#   'to',
#   'be',
#   'victims',
#   'until',
#   'they',
#   're',
#   'dead'],
#  ['donald',
#   'glover',
#   'this',
#   'is',
#   'america',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'jim',
#   'crow',
#   'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'to',
#   'trump',
#   'over',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'are',
#   'making',
#   'history',
#   'in',
#   'this',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena',
#   'davis',
#   'and',
#   'th',
#   'husband',
#   'reza',
#   'jarrahy',
#   'are',
#   'divorcing'],
#  ['pauley',
#   'perrette',
#   'abby',
#   'has',
#   'heart',
#   'wrenching',
#   'farewell',
#   'on',
#   'ncis'],
#  ['lethal',
#   'weapon',
#   'fires',
#   'clayne',
#   'crawford',
#   'and',
#   'his',
#   'character',
#   'gets',
#   'shot'],
#  ['selena',
#   'gomez',
#   'pokes',
#   'fun',
#   'at',
#   'her',
#   'met',
#   'gala',
#   'spray',
#   'tan',
#   'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'of',
#   'armenia'],
#  ['kim', 'jong', 'un', 'secretly', 'met', 'with', 'xi', 'jinping', 'again'],
#  ['netanyahu',
#   'bombastic',
#   'iran',
#   'claims',
#   'found',
#   'perfect',
#   'audience',
#   'in',
#   'trump'],
#  ['netanyahu',
#   'chef',
#   'blasted',
#   'for',
#   'serving',
#   'japan',
#   'prime',
#   'minister',
#   'dessert',
#   'in',
#   'shoe'],
#  ['world',
#   'leaders',
#   'condemn',
#   'trump',
#   'for',
#   'withdrawing',
#   'from',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'on',
#   'day',
#   'of',
#   'west',
#   'virginia',
#   'primary'],
#  ['new',
#   'york',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'to',
#   'continue',
#   'despite',
#   'attorney',
#   'general',
#   'exit'],
#  ['trump',
#   'to',
#   'announce',
#   'whether',
#   'will',
#   'break',
#   'the',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['politicians',
#   'call',
#   'for',
#   'schneiderman',
#   'to',
#   'resign',
#   'over',
#   'physical',
#   'abuse',
#   'allegations'],
#  ['joe',
#   'scarborough',
#   'trump',
#   'legal',
#   'strategy',
#   'is',
#   'like',
#   'monkey',
#   'throwing',
#   'poo',
#   'against',
#   'the',
#   'wall'],
#  ['kirsten', 'dunst', 'and', 'jesse', 'plemons', 'welcome', 'baby', 'boy'],
#  ['holy', 'matrimony', 'there', 'was', 'proposal', 'at', 'the', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'after',
#   'store',
#   'accuses',
#   'three',
#   'black',
#   'men',
#   'of',
#   'theft'],
#  ['giuliani',
#   'says',
#   'trump',
#   'lawyer',
#   'michael',
#   'cohen',
#   'has',
#   'no',
#   'incriminating',
#   'information',
#   'about',
#   'the',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'at', 'met', 'gala', 'as', 'queer', 'superhero'],
#  ['kelly',
#   'accusers',
#   'say',
#   'they',
#   'had',
#   'to',
#   'ask',
#   'permission',
#   'to',
#   'use',
#   'the',
#   'bathroom'],
#  ['trump',
#   'reportedly',
#   'tells',
#   'macron',
#   'he',
#   'pulling',
#   'out',
#   'of',
#   'iran',
#   'nuclear',
#   'deal'],
#  ['how',
#   'the',
#   'deportation',
#   'crackdown',
#   'is',
#   'hurting',
#   'immigrant',
#   'victims',
#   'of',
#   'crime'],
#  ['seth',
#   'meyers',
#   'says',
#   'michael',
#   'cohen',
#   'tried',
#   'to',
#   'get',
#   'him',
#   'to',
#   'apologize',
#   'on',
#   'air',
#   'to',
#   'trump'],
#  ['blessing', 'you', 'with', 'the', 'best', 'met', 'gala', 'tweets'],
#  ['farm',
#   'bill',
#   'would',
#   'cut',
#   'food',
#   'stamps',
#   'is',
#   'friendly',
#   'to',
#   'farmers'],
#  ['what', 'to', 'know', 'about', 'the', 'iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'in',
#   'west',
#   'virginia',
#   'and',
#   'other',
#   'things',
#   'to',
#   'watch',
#   'this',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivo',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'with',
#   'black',
#   'women'],
#  ['keanu',
#   'reeves',
#   'and',
#   'alex',
#   'winter',
#   'are',
#   'coming',
#   'back',
#   'for',
#   'bill',
#   'ted',
#   'after',
#   'years'],
#  ['solange', 'durag', 'was', 'the', 'true', 'mvp', 'at', 'the', 'met', 'gala'],
#  ['top',
#   'house',
#   'republican',
#   'threatens',
#   'to',
#   'subpoena',
#   'trump',
#   'doj',
#   'official',
#   'over',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy',
#   'kimmel',
#   'tries',
#   'so',
#   'hard',
#   'to',
#   'make',
#   'sense',
#   'of',
#   'rudy',
#   'latest',
#   'trump',
#   'defense',
#   'then',
#   'gives',
#   'up'],
#  ['the',
#   'religious',
#   'imagery',
#   'stitched',
#   'throughout',
#   'the',
#   'met',
#   'gala'],
#  ['bob',
#   'marley',
#   'granddaughter',
#   'says',
#   'cops',
#   'racially',
#   'profiled',
#   'her',
#   'while',
#   'checking',
#   'out',
#   'of',
#   'airbnb'],
#  ['melania',
#   'trump',
#   'called',
#   'out',
#   'for',
#   'anti',
#   'bullying',
#   'campaign',
#   'that',
#   'ignores',
#   'her',
#   'husband',
#   'actions'],
#  ['trevor',
#   'noah',
#   'watching',
#   'rudy',
#   'giuliani',
#   'is',
#   'like',
#   'smoking',
#   'weed',
#   'through',
#   'the',
#   'tv'],
#  ['janet',
#   'jackson',
#   'to',
#   'receive',
#   'icon',
#   'award',
#   'at',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'to',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['this',
#   'jared',
#   'kushner',
#   'backed',
#   'bill',
#   'could',
#   'be',
#   'last',
#   'shot',
#   'at',
#   'federal',
#   'prison',
#   'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'of',
#   'stalking',
#   'detective',
#   'working',
#   'on',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'out',
#   'at',
#   'scott',
#   'pruitt',
#   'justify',
#   'first',
#   'class',
#   'travel',
#   'new',
#   'epa',
#   'memo',
#   'says'],
#  ['this',
#   'trump',
#   'country',
#   'house',
#   'district',
#   'just',
#   'became',
#   'key',
#   'progressive',
#   'battleground'],
#  ['mike',
#   'pence',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'for',
#   'vice',
#   'president',
#   'former',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'on',
#   'active',
#   'duty'],
#  ['trump',
#   'to',
#   'violate',
#   'iran',
#   'nuclear',
#   'deal',
#   'vows',
#   'to',
#   'reimpose',
#   'sanctions'],
#  ['olympic',
#   'committee',
#   'ignored',
#   'sexual',
#   'abuse',
#   'complaints',
#   'against',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake',
#   'lively',
#   'brought',
#   'her',
#   'family',
#   'to',
#   'the',
#   'met',
#   'gala',
#   'without',
#   'you',
#   'even',
#   'noticing'],
#  ['bill',
#   'reilly',
#   'offers',
#   'to',
#   'stand',
#   'next',
#   'to',
#   'sarah',
#   'sanders',
#   'to',
#   'handle',
#   'out',
#   'of',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'as',
#   'best',
#   'dressed',
#   'dude',
#   'at',
#   'met',
#   'gala',
#   'for',
#   'just',
#   'living',
#   'his',
#   'life'],
#  ['jimmy',
#   'kimmel',
#   'says',
#   'hide',
#   'and',
#   'seek',
#   'genius',
#   'dog',
#   'will',
#   'heal',
#   'our',
#   'nation'],
#  ['bank',
#   'of',
#   'america',
#   'appears',
#   'to',
#   'flip',
#   'on',
#   'firearm',
#   'promise',
#   'with',
#   'loan',
#   'to',
#   'remington'],
#  ['the',
#   'gentleman',
#   'caller',
#   'presents',
#   'queer',
#   'icons',
#   'as',
#   'you',
#   've',
#   'never',
#   'seen',
#   'them',
#   'before'],
#  ['eric', 'schneiderman', 'has', 'always', 'been', 'con', 'man'],
#  ['christiane',
#   'amanpour',
#   'heading',
#   'up',
#   'new',
#   'pbs',
#   'show',
#   'replacing',
#   'charlie',
#   'rose'],
#  ['madonna',
#   'teases',
#   'new',
#   'song',
#   'at',
#   'surprise',
#   'met',
#   'gala',
#   'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'and',
#   'hawkeye',
#   'got',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'from',
#   'firm',
#   'tied',
#   'to',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen',
#   'colbert',
#   'hits',
#   'rudy',
#   'giuliani',
#   'with',
#   'brutal',
#   'fact',
#   'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'to',
#   'taylor',
#   'swift',
#   'and',
#   'the',
#   'world',
#   'rejoices'],
#  ['jada',
#   'pinkett',
#   'smith',
#   'gets',
#   'real',
#   'about',
#   'dating',
#   'will',
#   'smith',
#   'while',
#   'he',
#   'was',
#   'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'just',
#   'spilled',
#   'the',
#   'beans',
#   'on',
#   'major',
#   'cameo',
#   'in',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'to',
#   'hailey',
#   'baldwin',
#   'gown',
#   'at',
#   'the',
#   'met',
#   'gala'],
#  ['orrin',
#   'hatch',
#   'is',
#   'sorry',
#   'he',
#   'suggested',
#   'trump',
#   'should',
#   'be',
#   'allowed',
#   'at',
#   'john',
#   'mccain',
#   'funeral'],
#  ['seth',
#   'meyers',
#   'has',
#   'perfect',
#   'line',
#   'to',
#   'confront',
#   'donald',
#   'trump',
#   'lies'],
#  ['police',
#   'hope',
#   'to',
#   'use',
#   'dna',
#   'to',
#   'catch',
#   'the',
#   'zodiac',
#   'killer'],
#  ['lili',
#   'reinhart',
#   'and',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'at',
#   'met',
#   'gala'],
#  ['how',
#   'sweetbitter',
#   'captures',
#   'the',
#   'grit',
#   'and',
#   'glamour',
#   'of',
#   'the',
#   'restaurant',
#   'world'],
#  ['mitch',
#   'mcconnell',
#   'bends',
#   'the',
#   'rules',
#   'again',
#   'to',
#   'confirm',
#   'trump',
#   'judges'],
#  ['ryan', 'zinke', 'and', 'the', 'tale', 'of', 'two', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary',
#   'cities',
#   'are',
#   'working',
#   'in',
#   'the',
#   'trump',
#   'era',
#   'but',
#   'at',
#   'surprising',
#   'cost'],
#  ['shepard',
#   'smith',
#   'you',
#   'can',
#   'say',
#   'trump',
#   'pulled',
#   'out',
#   'of',
#   'iran',
#   'deal',
#   'he',
#   'made',
#   'decision',
#   'to',
#   'violate',
#   'it'],
#  ['stormy',
#   'daniels',
#   'finds',
#   'crunchy',
#   'new',
#   'way',
#   'to',
#   'chip',
#   'away',
#   'at',
#   'trump'],
#  ['these',
#   'rainbow',
#   'mountains',
#   'in',
#   'peru',
#   'look',
#   'like',
#   'they',
#   're',
#   'straight',
#   'out',
#   'of',
#   'dr',
#   'seuss',
#   'book'],
#  ...]

# %% [markdown]
# ### Removing useless words

# %%
def get_stopwords(additional_stopwords=[]):
    """Return a list of english stopwords, that can be augmented by using a stopwords file or a list of stopwords

    Args:
        filepath (str, optional): path to a text file where each line is a stopword
        additional_stopwords (list of str, optional): list of string representing stopwords
    Returns:
        List of strings representing stopwords
    """
    # Loading standard english stop words
    with open('stopwords.txt', 'r') as f:
        stop_w = f.readlines()
    stopwords = [s.rstrip() for s in stop_w]

    # Adding stop words from sklearn
    stopwords = list(text.ENGLISH_STOP_WORDS.union(stopwords))

    # Adding words from a list if specified
    if additional_stopwords:
        stopwords += additional_stopwords

    # Removing duplicates
    stopwords = list(set(stopwords))

    # Removing some \n that were included in the native stopwords of sklearn ... WHY?
    stopwords = [s.replace("\n", "") for s in stopwords]

    stopwords = sorted(stopwords, key=str.lower)

    return stopwords

# %%
stopwords = get_stopwords(additional_stopwords=["trump"])

# %%
stopwords = get_stopwords(additional_stopwords=["trump"])

texts = [[word for word in txt if word not in stopwords] for txt in tqdm(texts)]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200853/200853 [00:11<00:00, 17648.00it/s]

# %%
texts
# Out:
# [['mass', 'shootings', 'texas', 'week', 'tv'],
#  ['smith',
#   'joins',
#   'diplo',
#   'nicky',
#   'jam',
#   'world',
#   'cup',
#   'official',
#   'song'],
#  ['hugh', 'grant', 'marries', 'time', 'age'],
#  ['jim',
#   'carrey',
#   'blasts',
#   'castrato',
#   'adam',
#   'schiff',
#   'democrats',
#   'artwork'],
#  ['julianna', 'margulies', 'donald', 'poop', 'bags', 'pick', 'dog'],
#  ['morgan',
#   'freeman',
#   'devastated',
#   'sexual',
#   'harassment',
#   'claims',
#   'undermine',
#   'legacy'],
#  ['donald', 'lovin', 'mcdonald', 'jingle', 'tonight', 'bit'],
#  ['watch', 'amazon', 'prime', 'week'],
#  ['mike', 'myers', 'reveals', 'fourth', 'austin', 'powers', 'film'],
#  ['watch', 'hulu', 'week'],
#  ['justin', 'timberlake', 'visits', 'texas', 'school', 'shooting', 'victims'],
#  ['south',
#   'korean',
#   'president',
#   'meets',
#   'north',
#   'korea',
#   'kim',
#   'jong',
#   'talk',
#   'summit'],
#  ['life', 'risk', 'remote', 'oyster', 'growing', 'region', 'called', 'robots'],
#  ['crackdown', 'immigrant', 'parents', 'puts', 'kids', 'strained'],
#  ['son',
#   'concerned',
#   'fbi',
#   'obtained',
#   'wiretaps',
#   'putin',
#   'ally',
#   'met',
#   'jr'],
#  ['edward', 'snowden', 'loves', 'vladimir', 'putin'],
#  ['booyah', 'obama', 'photographer', 'hilariously', 'trolls', 'spy', 'claim'],
#  ['ireland',
#   'votes',
#   'repeal',
#   'abortion',
#   'amendment',
#   'landslide',
#   'referendum'],
#  ['ryan', 'zinke', 'reel', 'critics', 'grand', 'pivot', 'conservation'],
#  ['scottish',
#   'golf',
#   'resort',
#   'pays',
#   'women',
#   'significantly',
#   'men',
#   'report'],
#  ['weird', 'father', 'day', 'gifts', 'dad', 'doesn'],
#  ['twitter', 'universally', 'entertaining'],
#  ['mystery',
#   'wolf',
#   'animal',
#   'reportedly',
#   'shot',
#   'montana',
#   'baffles',
#   'wildlife',
#   'officials'],
#  ['north', 'korea', 'open', 'talks', 'cancels', 'summit'],
#  ['men',
#   'detonate',
#   'bomb',
#   'inside',
#   'indian',
#   'restaurant',
#   'toronto',
#   'authorities'],
#  ['thousands', 'travel', 'home', 'ireland', 'vote', 'abortion', 'access'],
#  ['irish',
#   'voters',
#   'set',
#   'liberalize',
#   'abortion',
#   'laws',
#   'landslide',
#   'exit',
#   'poll',
#   'signals'],
#  ['warriors',
#   'coach',
#   'steve',
#   'kerr',
#   'calls',
#   'nfl',
#   'ban',
#   'protests',
#   'fake',
#   'patriotism'],
#  ['historic', 'victory', 'barbados', 'elects', 'female', 'prime', 'minister'],
#  ['police',
#   'killed',
#   'black',
#   'americans',
#   'moment',
#   'colin',
#   'kaepernick',
#   'protested'],
#  ['jack', 'johnson', 'pardoned', 'taboo', 'sex', 'criminalized'],
#  ['bet', 'chairman', 'ceo', 'debra', 'lee', 'stepping'],
#  ['rachel', 'dolezal', 'faces', 'felony', 'charges', 'welfare', 'fraud'],
#  ['bishop',
#   'michael',
#   'curry',
#   'joins',
#   'christian',
#   'march',
#   'white',
#   'house',
#   'reclaim',
#   'jesus'],
#  ['kanye',
#   'west',
#   'spent',
#   'photo',
#   'whitney',
#   'houston',
#   'bathroom',
#   'album',
#   'cover'],
#  ['morgan',
#   'freeman',
#   'dropped',
#   'marketing',
#   'campaigns',
#   'harassment',
#   'accusations'],
#  ['chinese',
#   'exclusion',
#   'act',
#   'understand',
#   'immigration',
#   'politics',
#   'today'],
#  ['maga', 'themed', 'swimwear', 'sinks', 'twitter'],
#  ['seth', 'meyers', 'funny', 'regret', 'cancels', 'north', 'korea', 'summit'],
#  ['colbert', 'turn', 'nyc', 'subway', 'rides', 'terrible', 'punishment'],
#  ['man',
#   'faces',
#   'charges',
#   'pulling',
#   'knife',
#   'stun',
#   'gun',
#   'muslim',
#   'students',
#   'mcdonald'],
#  ['jimmy', 'kimmel', 'iran', 'supreme', 'leader', 'watches', 'tom', 'jerry'],
#  ['people', 'injured', 'indiana', 'school', 'shooting'],
#  ['people', 'rattled', 'nigerian', 'man', 'chadwick', 'boseman'],
#  ['david', 'cross', 'proves', 'terrible', 'apologizing'],
#  ['sesame',
#   'street',
#   'creators',
#   'sue',
#   'makers',
#   'upcoming',
#   'adult',
#   'themed',
#   'puppet',
#   'film'],
#  ['missed', 'saddest', 'death', 'avengers', 'infinity', 'war'],
#  ['george',
#   'takei',
#   'accuser',
#   'walks',
#   'story',
#   'drugging',
#   'sexual',
#   'assault'],
#  ['samantha', 'bee', 'parents', 'america', 'basically', 'war', 'zone'],
#  ['pete', 'davidson', 'mental', 'illness', 'doesn', 'ruin', 'romance'],
#  ['james', 'corden', 'adam', 'levine', 'pulled', 'carpool', 'karaoke'],
#  ['emilia', 'clarke', 'dishes', 'final', 'game', 'thrones', 'scene'],
#  ['hollywood', 'doesn', 'difficult', 'men', 'make', 'great', 'tv'],
#  ['harvey', 'weinstein', 'accusers', 'thought', 'arrested'],
#  ['harvey', 'weinstein', 'turns', 'police', 'alleged', 'sex', 'crimes'],
#  ['john',
#   'mayer',
#   'weird',
#   'low',
#   'budget',
#   'video',
#   'meme',
#   'worthy',
#   'masterpiece'],
#  ['boba', 'fett', 'star', 'wars', 'movie'],
#  ['suggests', 'north', 'korea', 'summit', 'happen'],
#  ['roger',
#   'stone',
#   'pressed',
#   'damaging',
#   'emails',
#   'hillary',
#   'clinton',
#   'wikileaks',
#   'report'],
#  ['publix',
#   'suspends',
#   'contributions',
#   'nra',
#   'backed',
#   'politician',
#   'amid',
#   'protests'],
#  ['twitter', 'bots', 'delivered', 'donald', 'victory', 'research', 'paper'],
#  ['bag',
#   'wet',
#   'socks',
#   'apparently',
#   'living',
#   'white',
#   'house',
#   'press',
#   'briefing',
#   'room'],
#  ['member', 'proud', 'boys', 'menaced', 'twitter', 'user', 'doorstep'],
#  ['things', 'nra', 'blamed', 'texas', 'school', 'shooting'],
#  ['catholic', 'hospital', 'won', 'save'],
#  ['executive', 'orders', 'make', 'easier', 'federal', 'workers'],
#  ['monsanto', 'bayer', 'set', 'merge', 'care'],
#  ['joy', 'watching', 'harvey', 'weinstein', 'perp', 'walk'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['queer',
#   'eye',
#   'star',
#   'bobby',
#   'berk',
#   'gave',
#   'desk',
#   'makeover',
#   'incredible'],
#  ['older', 'gay', 'men', 'gay', 'slang', 'hilarious', 'video'],
#  ['rupaul',
#   'drag',
#   'race',
#   'teaching',
#   'straight',
#   'people',
#   'queer',
#   'culture'],
#  ['fish', 'market', 'buys', 'freedom', 'fred', 'pound', 'octopus'],
#  ['north', 'korea', 'threatens', 'summit', 'warns', 'nuclear', 'showdown'],
#  ['investigation', 'finds', 'russian', 'missile', 'shot', 'flight', 'mh'],
#  ['north',
#   'korea',
#   'demolishes',
#   'tunnels',
#   'nuclear',
#   'test',
#   'site',
#   'reports'],
#  ['kim', 'jong', 'baited', 'canceling', 'north', 'korea', 'summit'],
#  ['michelle', 'obama', 'reveals', 'cover', 'upcoming', 'memoir'],
#  ['late', 'night', 'writer', 'breathless', 'royal', 'wedding', 'recap'],
#  ['morgan',
#   'freeman',
#   'accused',
#   'inappropriate',
#   'behavior',
#   'sexual',
#   'harassment'],
#  ['jets',
#   'chairman',
#   'christopher',
#   'johnson',
#   'won',
#   'fine',
#   'players',
#   'anthem',
#   'protests'],
#  ['andy', 'cohen', 'taylor', 'swift', 'katy', 'perry', 'drama'],
#  ['infinity', 'war', 'writers', 'clear', 'marvel', 'problematic', 'timeline'],
#  ['david',
#   'blaine',
#   'chews',
#   'glass',
#   'lets',
#   'james',
#   'corden',
#   'puncture',
#   'cheek'],
#  ['amy', 'poehler', 'parks', 'recreation', 'revival', 'amazing'],
#  ['colbert', 'exposes', 'biggest', 'flaw', 'latest', 'conspiracy', 'theory'],
#  ['seth', 'meyers', 'donald', 'valuable', 'marketing', 'advice'],
#  ['launches',
#   'auto',
#   'import',
#   'probe',
#   'china',
#   'vows',
#   'defend',
#   'interests'],
#  ['women', 'pulled', 'stops', 'land', 'dream', 'job'],
#  ['wife',
#   'asked',
#   'husband',
#   'fenty',
#   'highlighter',
#   'pack',
#   'highlighters',
#   'hairbrush'],
#  ['roasted',
#   'rushing',
#   'defend',
#   'tomi',
#   'lahren',
#   'ignoring',
#   'real',
#   'victims'],
#  ['abruptly', 'cancels', 'north', 'korea', 'summit', 'kim', 'jong'],
#  ['devin',
#   'nunes',
#   'linked',
#   'winery',
#   'faced',
#   'suit',
#   'alleged',
#   'coke',
#   'prostitute',
#   'yacht',
#   'party'],
#  ['immigrant',
#   'children',
#   'accuse',
#   'border',
#   'patrol',
#   'abuse',
#   'neglect',
#   'report',
#   'shows'],
#  ['ireland',
#   'historic',
#   'vote',
#   'legalizing',
#   'abortion',
#   'haunted',
#   'brexit'],
#  ['lawyer', 'attended', 'doj', 'meeting', 'confidential', 'fbi', 'informant'],
#  ['senate',
#   'advances',
#   'court',
#   'pick',
#   'planned',
#   'parenthood',
#   'kills',
#   'females',
#   'year'],
#  ['rudy', 'giuliani', 'won', 'interview', 'mueller', 'spygate', 'report'],
#  ['kentucky', 'attorney', 'running', 'judge', 'dies', 'day', 'primary', 'win'],
#  ['chrissy', 'teigen', 'taunts', 'donald', 'twitter', 'blocking', 'ruling'],
#  ['koch', 'network', 'favorite', 'congressmen'],
#  ['posthumously', 'pardons', 'boxer', 'jack', 'johnson'],
#  ['ellen',
#   'tears',
#   'ashton',
#   'kutcher',
#   'donates',
#   'million',
#   'wildlife',
#   'fund'],
#  ['ariana',
#   'grande',
#   'reveals',
#   'bee',
#   'tattoo',
#   'honor',
#   'manchester',
#   'attack'],
#  ['kim',
#   'kardashian',
#   'wished',
#   'kanye',
#   'west',
#   'happy',
#   'anniversary',
#   'fine',
#   'pretty',
#   'cute'],
#  ['chris',
#   'hemsworth',
#   'dances',
#   'wrecking',
#   'ball',
#   'kids',
#   'living',
#   'room'],
#  ['moses',
#   'farrow',
#   'defends',
#   'woody',
#   'allen',
#   'accuses',
#   'mia',
#   'farrow',
#   'abuse'],
#  ['gwyneth',
#   'paltrow',
#   'brad',
#   'pitt',
#   'threatened',
#   'kill',
#   'harvey',
#   'weinstein'],
#  ['stephen', 'king', 'reveals', 'donald', 'blocked', 'twitter'],
#  ['fans',
#   'jessica',
#   'walter',
#   'addressed',
#   'verbal',
#   'harassment',
#   'jeffrey',
#   'tambor'],
#  ['jessica',
#   'walter',
#   'discusses',
#   'jeffrey',
#   'tambor',
#   'alleged',
#   'harassment',
#   'male',
#   'stars',
#   'brush'],
#  ['harvey', 'weinstein', 'expected', 'turn', 'nypd', 'sex', 'crimes'],
#  ['samantha', 'bee', 'torches', 'ice', 'shut', 'fk'],
#  ['scott',
#   'pruitt',
#   'introduced',
#   'anti',
#   'abortion',
#   'bills',
#   'giving',
#   'men',
#   'property',
#   'rights',
#   'fetuses'],
#  ['twitter', 'critics', 'mercilessly', 'mock', 'canceling', 'summit', 'kim'],
#  ['civil',
#   'rights',
#   'groups',
#   'rip',
#   'senate',
#   'revising',
#   'sexual',
#   'harassment',
#   'policy'],
#  ['alabama',
#   'sues',
#   'exclude',
#   'undocumented',
#   'immigrants',
#   'census',
#   'count'],
#  ['cynthia',
#   'nixon',
#   'vows',
#   'fighting',
#   'predictably',
#   'losing',
#   'party',
#   'endorsement'],
#  ['white',
#   'house',
#   'officials',
#   'reportedly',
#   'considered',
#   'ignoring',
#   'climate',
#   'research'],
#  ['read', 'letter', 'kim', 'jong', 'canceling', 'north', 'korea', 'summit'],
#  ['south',
#   'korea',
#   'responds',
#   'sudden',
#   'cancellation',
#   'kim',
#   'jong',
#   'summit'],
#  ['facebook',
#   'ad',
#   'rules',
#   'prove',
#   'basically',
#   'charge',
#   'regulating',
#   'elections'],
#  ['border', 'agent', 'fatally', 'shoots', 'migrant', 'woman', 'texas'],
#  ['opens', 'door', 'gun', 'industry', 'sell', 'firearms', 'abroad'],
#  ['stormy',
#   'daniels',
#   'day',
#   'declared',
#   'west',
#   'hollywood',
#   'adult',
#   'star',
#   'key',
#   'city'],
#  ['checkout', 'machine'],
#  ['ways', 'make', 'family', 'road', 'trips', 'easier', 'parents', 've'],
#  ['jake',
#   'tapper',
#   'shreds',
#   'donald',
#   'long',
#   'list',
#   'conspiracy',
#   'theories'],
#  ['york', 'daily', 'news', 'rips', 'nfl', 'anthem', 'kneeling', 'ban'],
#  ['judge', 'ruled', 'immigrant', 'hearing'],
#  ['house',
#   'democrats',
#   'offer',
#   'internships',
#   'students',
#   'affected',
#   'gun',
#   'violence'],
#  ['tig', 'notaro', 'tells', 'ellen', 'degeneres', 'sons', 'passion', 'trash'],
#  ['stormy',
#   'daniels',
#   'wonderful',
#   'gay',
#   'dads',
#   'west',
#   'hollywood',
#   'hands',
#   'keys',
#   'city'],
#  ['queer', 'eye', 'season', 'drops', 'month'],
#  ['gay',
#   'man',
#   'denied',
#   'marriage',
#   'license',
#   'kim',
#   'davis',
#   'loses',
#   'bid',
#   'unseat'],
#  ['anna', 'kournikova', 'dancing', 'bouncing', 'baby', 'cutest', 'thing'],
#  ['nfl', 'players', 'unwilling', 'stand', 'anthem', 'shouldn', 'country'],
#  ['facebook',
#   'accused',
#   'reading',
#   'texts',
#   'accessing',
#   'microphones',
#   'lawsuit'],
#  ['driving', 'uber', 'fatal', 'accident', 'seconds', 'react', 'crash'],
#  ['amazon', 'admits', 'alexa', 'device', 'eavesdropped', 'portland', 'family'],
#  ['man', 'discovers', 'handgun', 'impaled', 'bumper', 'car'],
#  ['rescue',
#   'cat',
#   'hilarious',
#   'wide',
#   'eyed',
#   'expression',
#   'scan',
#   'confirms',
#   'pregnant'],
#  ['weirdest', 'promposals', 'include', 'teen', 'faked', 'birth'],
#  ['american', 'stoke', 'hate', 'canada'],
#  ['anti', 'establishment', 'parties', 'set', 'form', 'italy', 'government'],
#  ['sarah', 'silverman', 'sees', 'reason', 'louis', 'continue', 'artist'],
#  ['southern',
#   'baptist',
#   'leader',
#   'abused',
#   'women',
#   'pray',
#   'removed',
#   'post'],
#  ['americans', 'support', 'sex', 'marriage'],
#  ['brynn', 'cartelli', 'youngest', 'winner', 'voice'],
#  ['betsy',
#   'devos',
#   'stirs',
#   'uproar',
#   'schools',
#   'ice',
#   'undocumented',
#   'kids'],
#  ['sandy',
#   'hook',
#   'families',
#   'fbi',
#   'agent',
#   'sue',
#   'alex',
#   'jones',
#   'defamation'],
#  ['high',
#   'school',
#   'teacher',
#   'defeats',
#   'kentucky',
#   'house',
#   'majority',
#   'leader',
#   'gop',
#   'primary'],
#  ['lupe',
#   'valdez',
#   'makes',
#   'history',
#   'texas',
#   'winning',
#   'democratic',
#   'nod',
#   'governor'],
#  ['report',
#   'michael',
#   'cohen',
#   'business',
#   'partner',
#   'cooperating',
#   'prosecutors'],
#  ['brandi', 'chastain', 'totally', 'agrees', 'hall', 'fame', 'plaque'],
#  ['scientists',
#   'turn',
#   'dna',
#   'technology',
#   'search',
#   'loch',
#   'ness',
#   'monster'],
#  ['late', 'night', 'writer', 'vows', 'red', 'hats', 'supporters'],
#  ['julia',
#   'louis',
#   'dreyfus',
#   'receive',
#   'mark',
#   'twain',
#   'prize',
#   'american',
#   'humor'],
#  ['michelle',
#   'obama',
#   'shares',
#   'intimate',
#   'wedding',
#   'photo',
#   'tribute',
#   'husband',
#   'barack'],
#  ['spot',
#   'trevor',
#   'noah',
#   'black',
#   'panther',
#   'daily',
#   'host',
#   'stealth',
#   'cameo',
#   'revealed'],
#  ['donald',
#   'glover',
#   'fans',
#   'execute',
#   'stunning',
#   'coup',
#   'donald',
#   'themed',
#   'reddit',
#   'forum'],
#  ['calls',
#   'boycott',
#   'restaurant',
#   'duty',
#   'cop',
#   'allegedly',
#   'assaults',
#   'black',
#   'women'],
#  ['survivor', 'rwandan', 'genocide', 'country', 'female', 'neurosurgeon'],
#  ['stacey', 'abrams', 'wins', 'democratic', 'primary', 'georgia', 'governor'],
#  ['trevor', 'noah', 'reveals', 'question', 'donald', 'dared'],
#  ['michelle',
#   'obama',
#   'reflects',
#   'scary',
#   'time',
#   'princeton',
#   'sweet',
#   'throwback',
#   'snap'],
#  ['reasons', 'started', 'conversation', 'responsible', 'finishing'],
#  ['lourdes',
#   'leon',
#   'major',
#   'madonna',
#   'vibes',
#   'moody',
#   'ad',
#   'campaign',
#   'pics'],
#  ['ways', 'netflix', 'tricks', 'watching', 'shows', 'movies'],
#  ['brad',
#   'pitt',
#   'ryan',
#   'reynolds',
#   'demeaning',
#   'thing',
#   'exchange',
#   'deadpool',
#   'cameo'],
#  ['robert', 'niro', 'bans', 'nobu', 'restaurant'],
#  ['ariana',
#   'grande',
#   'shuts',
#   'fan',
#   'blaming',
#   'heartbreaking',
#   'mac',
#   'miller',
#   'split'],
#  ['parents',
#   'slam',
#   'dogs',
#   'scenes',
#   'grooming',
#   'children',
#   'sexual',
#   'abuse'],
#  ['dave', 'grohl', 'apologize', 'world', 'massive', 'jerk'],
#  ['emilia',
#   'clarke',
#   'introduced',
#   'prince',
#   'william',
#   'pretty',
#   'embarrassing'],
#  ['sarah', 'paulson', 'takes', 'impressions', 'level', 'tonight'],
#  ['ready', 'party'],
#  ['gina',
#   'ortiz',
#   'jones',
#   'wins',
#   'democratic',
#   'runoff',
#   'texas',
#   'congressional',
#   'race'],
#  ['fighter',
#   'pilot',
#   'amy',
#   'mcgrath',
#   'wins',
#   'democratic',
#   'primary',
#   'kentucky',
#   'swing',
#   'district'],
#  ['rallies', 'conservatives', 'promise', 'abortion', 'curbs'],
#  ['aclu', 'suing', 'strike', 'ohio', 'congressional', 'map'],
#  ['latest', 'school', 'shooting', 'hasn', 'stirred', 'gun', 'debate'],
#  ['donald', 'tweet', 'rescues', 'roseanne', 'family', 'season', 'finale'],
#  ['ellen', 'grills', 'mark', 'wahlberg', 'shirtless', 'instagram', 'selfies'],
#  ['idris', 'elba', 'star', 'hunchback', 'notre', 'dame', 'netflix'],
#  ['maryland',
#   'police',
#   'charge',
#   'church',
#   'leaders',
#   'past',
#   'abuse',
#   'risk',
#   'teen',
#   'girls'],
#  ['nfl', 'bans', 'kneeling', 'national', 'anthem'],
#  ['conan', 'brien', 'muscles', 'royal', 'wedding', 'spoof', 'ads'],
#  ['house', 'republicans', 'report', 'progress', 'immigration', 'deal'],
#  ['democrats',
#   'weren',
#   'invited',
#   'review',
#   'classified',
#   'documents',
#   'fbi',
#   'informant'],
#  ['gop',
#   'candidate',
#   'pointed',
#   'gun',
#   'teenager',
#   'advances',
#   'georgia',
#   'governor',
#   'primary',
#   'runoff'],
#  ['walking',
#   'definition',
#   'entitled',
#   'millennial',
#   'swears',
#   'entitled',
#   'millennial'],
#  ['democrats',
#   'push',
#   'included',
#   'classified',
#   'briefing',
#   'fbi',
#   'informant'],
#  ['machines',
#   'don',
#   'steal',
#   'jobs',
#   'increasingly',
#   'rob',
#   'work',
#   'humanity'],
#  ['praises',
#   'tomi',
#   'lahren',
#   'restaurant',
#   'crowd',
#   'tosses',
#   'water',
#   'insults'],
#  ['sarah', 'sanders', 'bothers', 'called', 'liar'],
#  ['blocking', 'people', 'twitter', 'judge', 'rules'],
#  ['christian',
#   'militia',
#   'won',
#   'iraqi',
#   'christians',
#   'parliamentary',
#   'seats',
#   'christians',
#   'intervene'],
#  ['tulsi',
#   'gabbard',
#   'syria',
#   'views',
#   'cost',
#   'support',
#   'hawaii',
#   'teachers',
#   'union'],
#  ['jared', 'kushner', 'received', 'security', 'clearance', 'reports'],
#  ['arizona',
#   'gop',
#   'congressional',
#   'candidate',
#   'compares',
#   'abortion',
#   'holocaust'],
#  ['gun',
#   'reform',
#   'advocate',
#   'lucy',
#   'mcbath',
#   'heads',
#   'runoff',
#   'georgia',
#   'house',
#   'seat'],
#  ['star',
#   'wars',
#   'burlesque',
#   'storms',
#   'west',
#   'coast',
#   'sexy',
#   'stormtroopers'],
#  ['establishment',
#   'backed',
#   'moderate',
#   'wins',
#   'heated',
#   'democratic',
#   'house',
#   'primary',
#   'texas'],
#  ['senators', 'unveil', 'crack', 'sexual', 'harassment'],
#  ['trips', 'york', 'city', 'long', 'weekend'],
#  ['disney',
#   'reveals',
#   'opening',
#   'seasons',
#   'star',
#   'wars',
#   'theme',
#   'park',
#   'lands'],
#  ['latest', 'entries', 'comedy', 'wildlife', 'photo', 'awards', 'cheer'],
#  ['bad', 'lip', 'reading', 'reveals', 'royal', 'wedding'],
#  ['australian',
#   'archbishop',
#   'convicted',
#   'covering',
#   'child',
#   'sex',
#   'abuse'],
#  ['commander',
#   'iran',
#   'people',
#   'respond',
#   'pompeo',
#   'threats',
#   'punch',
#   'mouth'],
#  ['mark',
#   'zuckerberg',
#   'extends',
#   'facebook',
#   'apology',
#   'tour',
#   'european',
#   'gig'],
#  ['ariana',
#   'grande',
#   'tweets',
#   'message',
#   'support',
#   'manchester',
#   'bombing',
#   'anniversary'],
#  ['katy', 'perry', 'single', 'american', 'idol'],
#  ['cops', 'watch', 'powerful', 'monologue', 'racism'],
#  ['amazon',
#   'selling',
#   'cops',
#   'facial',
#   'recognition',
#   'tool',
#   'bad',
#   'potentially',
#   'racist'],
#  ['miley',
#   'cyrus',
#   'wrecking',
#   'ball',
#   'prank',
#   'sleeping',
#   'jimmy',
#   'kimmel'],
#  ['vanessa', 'bayer', 'feared', 'porn', 'stars', 'skit', 'donald', 'snl'],
#  ['adam', 'rippon', 'wins', 'dancing', 'stars', 'destined'],
#  ['emilia', 'clarke', 'imitate', 'chewbacca'],
#  ['maddie',
#   'poppe',
#   'wins',
#   'american',
#   'idol',
#   'runner',
#   'reveals',
#   'dating'],
#  ['colbert', 'resist', 'turning', 'nickname', 'pee', 'tape', 'joke'],
#  ['seth',
#   'meyers',
#   'forced',
#   'tweak',
#   'donald',
#   'latest',
#   'twitter',
#   'rant',
#   'time'],
#  ['boy', 'teacher', 'told', 'fault', 'police', 'shoot', 'age'],
#  ['cops', 'accused', 'racism', 'detaining', 'black', 'man', 'vegetation'],
#  ['white', 'cop', 'shouts', 'black', 'suspect', 'pretend', 'shoot'],
#  ['florida',
#   'police',
#   'report',
#   'dead',
#   'standoff',
#   'panama',
#   'city',
#   'apartment',
#   'complex'],
#  ['donald', 'glover', 'board', 'lando', 'calrissian', 'pansexuality', 'solo'],
#  ['charlize', 'theron', 'play', 'megyn', 'kelly', 'film', 'roger', 'ailes'],
#  ['shoppers',
#   'boycott',
#   'publix',
#   'store',
#   'donations',
#   'nra',
#   'backed',
#   'candidate'],
#  ['blasio',
#   'tells',
#   'nypd',
#   'stop',
#   'arresting',
#   'people',
#   'smoking',
#   'pot',
#   'street'],
#  ['dhs', 'head', 'unaware', 'intel', 'russia', 'interference', 'boost'],
#  ['lawmaker', 'introduces', 'crowdfunding', 'pay', 'border', 'wall'],
#  ['gop',
#   'lawmakers',
#   'allowed',
#   'review',
#   'classified',
#   'info',
#   'russia',
#   'investigation'],
#  ['james', 'corden', 'reveals', 'worst', 'royal', 'wedding', 'ceremony'],
#  ['ariana',
#   'grande',
#   'reportedly',
#   'dating',
#   'snl',
#   'star',
#   'pete',
#   'davidson'],
#  ['jim',
#   'carrey',
#   'pens',
#   'pledge',
#   'allegiance',
#   'students',
#   'bullet',
#   'riddled',
#   'schools'],
#  ['ellen', 'david', 'spade', 'open', 'dating', 'younger', 'women'],
#  ['ceasefire',
#   'jimmy',
#   'kimmel',
#   'shreds',
#   'sean',
#   'hannity',
#   'dummies',
#   'fox',
#   'friends'],
#  ['spoof', 'royal', 'wedding', 'video', 'sees', 'ceremony', 'taking', 'turn'],
#  ['georgia', 'gop', 'governor', 'primary', 'focuses', 'guns', 'immigration'],
#  ['glaad',
#   'movie',
#   'report',
#   'finds',
#   'troubling',
#   'drop',
#   'lgbtq',
#   'representation'],
#  ['sephora',
#   'offers',
#   'store',
#   'beauty',
#   'classes',
#   'trans',
#   'nonbinary',
#   'community'],
#  ['georgia',
#   'governor',
#   'primary',
#   'highlights',
#   'competing',
#   'visions',
#   'democratic',
#   'party'],
#  ['california',
#   'moves',
#   'schools',
#   'workers',
#   'red',
#   'flag',
#   'dangerous',
#   'gun',
#   'owners'],
#  ['talking',
#   'grievance',
#   'health',
#   'care',
#   'outsider',
#   'kentucky',
#   'dem',
#   'inside',
#   'track'],
#  ['problems', 'commemorative', 'kim', 'jong', 'coin'],
#  ['giuliani', 'stance', 'russian', 'collusion', 'illegal'],
#  ['onion',
#   'hilariously',
#   'trolls',
#   'michael',
#   'cohen',
#   'cease',
#   'desist',
#   'note'],
#  ['democrats', 'boost', 'school', 'funding', 'address', 'teacher', 'walkouts'],
#  ['emails', 'lawmakers', 'shrug', 'lax', 'cellphone', 'security'],
#  ['stink', 'bug', 'flavored', 'jelly', 'bellys', 'don'],
#  ['power',
#   'outage',
#   'triggers',
#   'extreme',
#   'zombie',
#   'activity',
#   'alert',
#   'florida',
#   'city'],
#  ['congress', 'wall', 'street', 'favor', 'banks', 'post', 'record', 'profits'],
#  ['white', 'house', 'sinkhole', 'metaphor'],
#  ['reporter', 'shoved', 'barred', 'epa', 'meeting', 'water', 'contaminants'],
#  ['garry', 'kasparov', 'donald', 'russian', 'connections', 'aeroflot'],
#  ['lonely', 'planet', 'european', 'destinations', 'aim', 'overtourism'],
#  ['attorney',
#   'aaron',
#   'schlossberg',
#   'insists',
#   'anti',
#   'spanish',
#   'rant',
#   'person'],
#  ['minutes', 'reporter', 'reveals', 'chilling', 'reason', 'slamming', 'press'],
#  ['reportedly', 'rejects', 'phone', 'security', 'measures', 'inconvenient'],
#  ['federal',
#   'court',
#   'sides',
#   'transgender',
#   'teen',
#   'gavin',
#   'grimm',
#   'bathroom',
#   'fight'],
#  ['adviser',
#   'calls',
#   'president',
#   'claims',
#   'informant',
#   'spied',
#   'campaign',
#   'embarrassing'],
#  ['vietnam', 'test', 'abandons', 'climate', 'diplomacy'],
#  ['americans', 'successfully', 'draining', 'swamp'],
#  ['msnbc',
#   'host',
#   'hugh',
#   'hewitt',
#   'suggests',
#   'trench',
#   'coat',
#   'control',
#   'gun',
#   'control'],
#  ['bishop',
#   'michael',
#   'curry',
#   'harry',
#   'meghan',
#   'love',
#   'brought',
#   'worlds'],
#  ['sarah',
#   'paulson',
#   'unapologetic',
#   'year',
#   'age',
#   'gap',
#   'girlfriend',
#   'holland',
#   'taylor'],
#  ['texans', 'sides', 'gun', 'debate', 'agree', 'safe', 'storage', 'support'],
#  ['family',
#   'gay',
#   'man',
#   'critically',
#   'injured',
#   'amtrak',
#   'route',
#   'answers'],
#  ['caitlyn', 'jenner', 'worst', 'president', 'lgbtq', 'rights'],
#  ['boy',
#   'scout',
#   'allegedly',
#   'booted',
#   'store',
#   'company',
#   'won',
#   'support',
#   'homos'],
#  ['instagram', 'adding', 'mute', 'button', 'sake', 'sanity'],
#  ['publix', 'censors', 'teen', 'summa', 'cum', 'laude', 'graduation', 'cake'],
#  ['sexist', 'passengers', 'female', 'pilot', 'perfect', 'response'],
#  ['time',
#   'takes',
#   'aim',
#   'mcdonald',
#   'walmart',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['venezuela',
#   'socialist',
#   'leader',
#   'nicolas',
#   'maduro',
#   'elected',
#   'amid',
#   'allegations',
#   'irregularities'],
#  ['iran',
#   'europe',
#   'support',
#   'nuclear',
#   'deal',
#   'isn',
#   'america',
#   'withdrawal'],
#  ['mob', 'attacks', 'year', 'liberal', 'greek', 'mayor'],
#  ['shawn',
#   'mendes',
#   'khalid',
#   'perform',
#   'parkland',
#   'survivors',
#   'billboard',
#   'music',
#   'awards'],
#  ['tamir',
#   'rice',
#   'mother',
#   'opening',
#   'youth',
#   'center',
#   'honor',
#   'son',
#   'memory'],
#  ['judge',
#   'orders',
#   'texas',
#   'make',
#   'voter',
#   'registration',
#   'easier',
#   'updating',
#   'dmv',
#   'info'],
#  ['kelly',
#   'clarkson',
#   'calls',
#   'moments',
#   'action',
#   'honor',
#   'texas',
#   'shooting',
#   'victims',
#   'billboard',
#   'awards'],
#  ['kendrick', 'lamar', 'stops', 'white', 'fan', 'rapping', 'word', 'onstage'],
#  ['gay', 'man', 'pope', 'francis', 'told', 'god', 'loves'],
#  ['unusual', 'asteroid', 'interstellar', 'guest', 'solar'],
#  ['started', 'suicide', 'prevention', 'site', 'age', 'strong'],
#  ['roger', 'stone', 'prepared', 'conjured', 'mueller', 'indictment'],
#  ['hillary', 'clinton', 'endorse', 'andrew', 'cuomo', 'election'],
#  ['supreme', 'court', 'lot', 'harder', 'sue', 'employer'],
#  ['blake', 'farenthold', 'hired', 'illegally', 'lobbyist', 'job'],
#  ['konigsberg', 'explores', 'gay', 'experience', 'latest', 'book'],
#  ['game',
#   'shows',
#   'biggest',
#   'hurdles',
#   'lgbtq',
#   'athletes',
#   'exist',
#   'field'],
#  ['chrissy', 'teigen', 'real', 'life', 'childbirth'],
#  ['suits',
#   'creator',
#   'pens',
#   'heartfelt',
#   'open',
#   'letter',
#   'attending',
#   'royal',
#   'wedding'],
#  ['movies', 'coming', 'netflix', 'week'],
#  ['obamas', 'coming', 'netflix', 'queue'],
#  ['ben', 'affleck', 'make', 'justin', 'theroux', 'giant', 'rat', 'tattoo'],
#  ['hillary',
#   'clinton',
#   'tips',
#   'russian',
#   'hat',
#   'yale',
#   'commencement',
#   'speech'],
#  ['giuliani', 'mueller', 'talk', 'hears', 'fbi', 'source'],
#  ['democrats', 'plan', 'big', 'anti', 'corruption', 'theme', 'midterms'],
#  ['kelly',
#   'clarkson',
#   'rejects',
#   'moment',
#   'silence',
#   'calls',
#   'change',
#   'billboard',
#   'music',
#   'awards'],
#  ['asked', 'american', 'public', 'settle', 'internet', 'dumbest', 'debates'],
#  ['fox',
#   'news',
#   'viewers',
#   'don',
#   'lifelong',
#   'republican',
#   'robert',
#   'mueller'],
#  ['team', 'moves', 'lift', 'ban', 'extreme', 'hunting', 'tactics', 'alaska'],
#  ['howard',
#   'stern',
#   'tells',
#   'sexualized',
#   'ivanka',
#   'makes',
#   'david',
#   'letterman',
#   'cringe'],
#  ['supreme', 'court', 'helping', 'companies', 'sexual', 'harassment'],
#  ['deadpool',
#   'steals',
#   'spot',
#   'box',
#   'office',
#   'avengers',
#   'infinity',
#   'war'],
#  ['westworld', 'subtly', 'tease', 'baby', 'theory'],
#  ['donald',
#   'glover',
#   'tells',
#   'ellen',
#   'circle',
#   'star',
#   'wars',
#   'moment',
#   'son'],
#  ['marvel', 'exec', 'stop', 'jarring', 'infinity', 'war', 'death'],
#  ['jake', 'gyllenhaal', 'set', 'star', 'villain', 'spider', 'man', 'sequel'],
#  ['janet',
#   'jackson',
#   'black',
#   'woman',
#   'receive',
#   'billboard',
#   'icon',
#   'award'],
#  ['isn', 'pakistan', 'bitch', 'video', 'captures', 'driver', 'racist', 'rant'],
#  ['grey',
#   'gardens',
#   'ladies',
#   'unwitting',
#   'godmothers',
#   'reality',
#   'tv',
#   'archetypes'],
#  ['year', 'boy', 'superhero', 'alabama', 'homeless', 'population'],
#  ['john', 'oliver', 'time', 'mocking', 'royal', 'wedding'],
#  ['john',
#   'oliver',
#   'needles',
#   'dangerously',
#   'unregulated',
#   'rehab',
#   'industry'],
#  ['jemele', 'hill', 'honored', 'nabj', 'journalist', 'year'],
#  ['french', 'digital', 'minister', 'gay', 'fight', 'homophobia'],
#  ['belgian',
#   'transgender',
#   'ballet',
#   'drama',
#   'wins',
#   'big',
#   'cannes',
#   'film',
#   'festival'],
#  ['year', 'gay', 'man', 'proves', 'attend', 'pride'],
#  ['super',
#   'pacs',
#   'meddled',
#   'west',
#   'virginia',
#   'senate',
#   'primary',
#   'didn',
#   'receive',
#   'penny',
#   'west',
#   'virginians'],
#  ['airline',
#   'passenger',
#   'arrested',
#   'allegedly',
#   'harassing',
#   'woman',
#   'peeing',
#   'seat'],
#  ['mike', 'pompeo', 'promises', 'crush', 'iran', 'achieve', 'deal'],
#  ['majestic', 'islands', 'europe', 'tourists', 'don'],
#  ['cuba', 'confirms', 'killed', 'country', 'deadliest', 'plane', 'crash'],
#  ['china', 'putting', 'trade', 'war', 'hold', 'treasury', 'steve', 'mnuchin'],
#  ['economic', 'adviser', 'amazon', 'threats', 'lane'],
#  ['dems',
#   'admin',
#   'common',
#   'ground',
#   'helping',
#   'victims',
#   'myanmar',
#   'genocide'],
#  ['giuliani',
#   'mueller',
#   'wrap',
#   'obstruction',
#   'probe',
#   'september',
#   'report'],
#  ['german',
#   'broadcaster',
#   'criticized',
#   'racist',
#   'coverage',
#   'royal',
#   'wedding'],
#  ['kathryn', 'newton', 'boldest', 'teen', 'tv', 'ready', 'grow'],
#  ['stephanie', 'kelton', 'biggest', 'idea', 'washington'],
#  ['texas',
#   'gov',
#   'campaign',
#   'cancels',
#   'shotgun',
#   'giveaway',
#   'santa',
#   'fe',
#   'school',
#   'shooting'],
#  ['tina', 'fey', 'sarah', 'palin', 'leads', 'snl', 'chorus', 'lamenting'],
#  ['day', 'american', 'gushing', 'snl', 'smart', 'aleck', 'royal', 'wedding'],
#  ['starbucks', 'sit', 'cafes', 'buying'],
#  ['alec',
#   'baldwin',
#   'faces',
#   'ominous',
#   'sopranos',
#   'scenario',
#   'snl',
#   'finale'],
#  ['asia',
#   'argento',
#   'fiery',
#   'speech',
#   'closes',
#   'cannes',
#   'raped',
#   'harvey',
#   'weinstein'],
#  ['tina', 'fey', 'girls', 'musical', 'snl'],
#  ['parents',
#   'school',
#   'shooting',
#   'victims',
#   'decry',
#   'moronic',
#   'gop',
#   'platitudes'],
#  ['real', 'americans', 'tough', 'russia', 'probe'],
#  ['chrissy',
#   'teigen',
#   'john',
#   'legend',
#   'announce',
#   'baby',
#   'boy',
#   'adorable',
#   'photo'],
#  ['texas', 'lt', 'gov', 'dan', 'patrick', 'touts', 'arm', 'teachers'],
#  ['david',
#   'hogg',
#   'calls',
#   'media',
#   'stop',
#   'naming',
#   'santa',
#   'fe',
#   'school',
#   'shooter'],
#  ['sets', 'showdown', 'doj', 'claims', 'campaign', 'surveillance'],
#  ['jim',
#   'carrey',
#   'latest',
#   'painting',
#   'slams',
#   'kent',
#   'state',
#   'goldilocks',
#   'ar'],
#  ['oliver', 'north', 'blames', 'school', 'shootings', 'ritalin'],
#  ['jimmy',
#   'kimmel',
#   'tricks',
#   'royal',
#   'fans',
#   'reviewing',
#   'wedding',
#   'big',
#   'day'],
#  ['jimmy', 'fallon', 'reveals', 'viewers', 'biggest', 'wedding', 'fails'],
#  ['protesters',
#   'throw',
#   'fiesta',
#   'razz',
#   'lawyer',
#   'ranted',
#   'spanish',
#   'speakers'],
#  ['watch', 'amazon', 'prime', 'week'],
#  ['ferrell', 'molly', 'shannon', 'cover', 'royal', 'wedding', 'cord', 'tish'],
#  ['artist', 'cedric', 'entertainer', 'arrived'],
#  ['mark', 'kelly', 'rolled', 'nra', 'guns', 'parkland'],
#  ['gop',
#   'candidate',
#   'set',
#   'trust',
#   'pays',
#   'kids',
#   'marrying',
#   'white',
#   'people'],
#  ['houston', 'police', 'chief', 'sick', 'inaction', 'gun', 'control'],
#  ['history', 'national', 'anthem', 'sports'],
#  ['bbc', 'trolls', 'president', 'bigly', 'huge', 'royal', 'wedding', 'crowd'],
#  ['victims', 'santa', 'fe', 'high', 'school', 'shooting'],
#  ['ceo', 'pay', 'cut', 'employees', 'year', 'battling', 'amazon'],
#  ['jr',
#   'met',
#   'emissary',
#   'gulf',
#   'princes',
#   'offering',
#   'campaign',
#   'report'],
#  ['misspells', 'melania', 'home', 'tweet', 'twitter', 'roars'],
#  ['jimmy',
#   'kimmel',
#   'shreds',
#   'cowardly',
#   'lawmakers',
#   'texas',
#   'school',
#   'shooting'],
#  ['maher', 'reveals', 'things', 'don', 'michael', 'cohen'],
#  ['watch', 'hulu', 'week'],
#  ['students',
#   'stage',
#   'sit',
#   'gun',
#   'control',
#   'paul',
#   'ryan',
#   'office',
#   'arrested'],
#  ['knew', 'scary', 'appearance', 'gates', 'daughter'],
#  ['russian',
#   'spy',
#   'sergei',
#   'skripal',
#   'discharged',
#   'uk',
#   'hospital',
#   'poisoning',
#   'incident'],
#  ['cuba', 'plane', 'crash', 'reportedly', 'kills'],
#  ['reassures', 'north', 'korea', 'threatens', 'total', 'decimation', 'deal'],
#  ['ariana', 'grande', 'fans', 'singing', 'time', 'surprise', 'lives'],
#  ['cambridge',
#   'analytica',
#   'files',
#   'chapter',
#   'bankruptcy',
#   'facebook',
#   'privacy',
#   'row'],
#  ['santa',
#   'fe',
#   'high',
#   'schoolers',
#   'held',
#   'gun',
#   'violence',
#   'protest',
#   'month',
#   'shooting'],
#  ['michelle', 'wolf', 'netflix', 'trailer', 'closer'],
#  ['jeff',
#   'sessions',
#   'exceptional',
#   'power',
#   'immigration',
#   'courts',
#   'limit',
#   'judges',
#   'authority'],
#  ['gop',
#   'rep',
#   'introduces',
#   'demand',
#   'white',
#   'house',
#   'apologize',
#   'mccain'],
#  ['colbert', 'super', 'graphic', 'describing', 'deep', 'mueller', 'probe'],
#  ['jack', 'osbourne', 'wife', 'files', 'divorce'],
#  ['meek', 'backs', 'event', 'prison', 'reform'],
#  ['rule', 'cut', 'federal', 'funds', 'clinics', 'providing', 'abortions'],
#  ['twitter', 'users', 'joke', 'prison', 'reform', 'headed'],
#  ['single',
#   'chilean',
#   'bishop',
#   'offers',
#   'resign',
#   'country',
#   'sex',
#   'abuse',
#   'scandal'],
#  ['ariana',
#   'grande',
#   'calls',
#   'manchester',
#   'attack',
#   'worst',
#   'humanity',
#   'year'],
#  ['chrissy', 'teigen', 'spills', 'details', 'baby', 'boy', 'love'],
#  ['alec', 'baldwin', 'wife', 'hilaria', 'baby', 'boy'],
#  ['kate', 'mckinnon', 'breaks', 'impression', 'rudy', 'giuliani'],
#  ['smallville', 'allison', 'mack', 'involved', 'sex', 'cult', 'place'],
#  ['white',
#   'house',
#   'kills',
#   'yanny',
#   'laurel',
#   'debate',
#   'ridiculous',
#   'clip'],
#  ['jennifer', 'aniston', 'play', 'lesbian', 'president', 'netflix', 'ladies'],
#  ['break', 'book', 'shadows', 'charmed', 'reboot', 'trailer'],
#  ['dave',
#   'matthews',
#   'band',
#   'violinist',
#   'boyd',
#   'tinsley',
#   'accused',
#   'sexual',
#   'misconduct'],
#  ['people', 'single', 'book', 'jimmy', 'kimmel'],
#  ['ellen',
#   'degeneres',
#   'hilariously',
#   'explains',
#   'saved',
#   'meghan',
#   'markle',
#   'life'],
#  ['lawyer',
#   'ranted',
#   'spanish',
#   'speakers',
#   'faces',
#   'office',
#   'eviction',
#   'disciplinary',
#   'complaint'],
#  ['hannity',
#   'flips',
#   'mueller',
#   'probe',
#   'direct',
#   'threat',
#   'american',
#   'republic'],
#  ['democrats',
#   'answers',
#   'global',
#   'health',
#   'security',
#   'head',
#   'sudden',
#   'departure'],
#  ['gun', 'owners', 'gun', 'owners', 'agree', 'lot', 'gun', 'reforms'],
#  ['twitter',
#   'users',
#   'pan',
#   'ted',
#   'cruz',
#   'tweets',
#   'prayers',
#   'santa',
#   'fe',
#   'school',
#   'shooting',
#   'victims'],
#  ['states', 'ban', 'bump', 'stocks', 'enforce', 'law'],
#  ['liberal', 'billionaire', 'tom', 'steyer', 'base'],
#  ['sen',
#   'dean',
#   'heller',
#   'campaign',
#   'paid',
#   'social',
#   'media',
#   'influencer',
#   'son'],
#  ['interior',
#   'dept',
#   'dodges',
#   'watchdog',
#   'questions',
#   'zinke',
#   'alaska',
#   'senators'],
#  ['blake',
#   'lively',
#   'teases',
#   'ryan',
#   'reynolds',
#   'hugh',
#   'jackman',
#   'bromance'],
#  ['happytime', 'murders', 'adult', 'themed', 'movie', 'puppets'],
#  ['photo',
#   'daniel',
#   'radcliffe',
#   'holding',
#   'guns',
#   'crazy',
#   'slippers',
#   'magical',
#   'meme'],
#  ['gates', 'didn', 'difference', 'hpv', 'hiv'],
#  ['bachelorette', 'bios', 'terrible'],
#  ['steven',
#   'tyler',
#   'admits',
#   'hitting',
#   'daughter',
#   'liv',
#   'famous',
#   'pal',
#   'watched'],
#  ['hospice',
#   'overdosed',
#   'patients',
#   'hasten',
#   'deaths',
#   'health',
#   'care',
#   'executive',
#   'admits'],
#  ['kimmel', 'brings', 'house', 'giving', 'latest', 'tweet', 'ending'],
#  ['wwf', 'wrestler', 'severely', 'beaten', 'california', 'home'],
#  ['robert', 'wilkie', 'picked', 'va', 'secretary', 'surprise', 'announcement'],
#  ['domestic', 'gag', 'rule', 'strip', 'funds', 'planned', 'parenthood'],
#  ['rudy',
#   'giuliani',
#   'reverses',
#   'team',
#   'position',
#   'president',
#   'obstruct',
#   'justice'],
#  ['social', 'anxiety', 'doesn', 'attention', 'deserves'],
#  ['deadpool', 'breaking', 'box', 'office', 'records'],
#  ['obamacare', 'premiums', 'higher', 'year', 'didn'],
#  ['comprehensive', 'list', 'don', 'jr', 'doesn', 'infamous', 'meeting'],
#  ['report',
#   'manafort',
#   'son',
#   'law',
#   'cuts',
#   'plea',
#   'deal',
#   'cooperate',
#   'government'],
#  ['briefly', 'responds', 'santa', 'fe', 'school', 'shooting', 'pivoting'],
#  ['late', 'night', 'writer', 'shreds', 'roseanne', 'racist'],
#  ['nasa', 'chief', 'apparently', 'changed', 'tune', 'climate', 'change'],
#  ['freedom',
#   'caucus',
#   'sinks',
#   'key',
#   'paul',
#   'ryan',
#   'welfare',
#   'reform',
#   'agenda'],
#  ['transphobic',
#   'congressional',
#   'hopeful',
#   'berates',
#   'person',
#   'inside',
#   'public',
#   'restroom'],
#  ['singer', 'ryan', 'amador', 'loverboy', 'coming'],
#  ['newest', 'head', 'cracker', 'hear', 'brainstorm', 'green', 'needle'],
#  ['meditation', 'human', 'clearing', 'browser', 'cache'],
#  ['funniest', 'tweets', 'women', 'week'],
#  ['italy', 'befriend', 'russia', 'populist', 'parties', 'form', 'government'],
#  ['business',
#   'groups',
#   'quietly',
#   'killing',
#   'bring',
#   'sexual',
#   'abuse',
#   'claims',
#   'light'],
#  ['kushner', 'family', 'reportedly', 'close', 'bailout', 'flagship', 'tower'],
#  ['ll', 'charity', 'royal', 'wedding', 'll'],
#  ['federal', 'prosecutors', 'turn', 'inauguration', 'protesters', 'felons'],
#  ['republican', 'immigration', 'fight', 'derails', 'food', 'stamp'],
#  ['retiring',
#   'lawmakers',
#   'added',
#   'million',
#   'campaign',
#   'treasuries',
#   'election'],
#  ['facing', 'farm', 'vote', 'problems', 'gop', 'leaders', 'make', 'deal'],
#  ['methodists',
#   'surprise',
#   'gay',
#   'minister',
#   'world',
#   'pastor',
#   'certificates',
#   'theft',
#   'diploma'],
#  ['china', 'marks', 'milestone', 'quest', 'space', 'superpower'],
#  ['stephen', 'colbert', 'mueller', 'special', 'anniversary', 'gift'],
#  ['stormy',
#   'daniels',
#   'disclosure',
#   'leaves',
#   'questions',
#   'payments',
#   'cohen'],
#  ['enjoy', 'animated', 'history', 'tina', 'fey', 'snl', 'return'],
#  ['controversial',
#   'california',
#   'schools',
#   'handling',
#   'students',
#   'misbehavior'],
#  ['deaf',
#   'activist',
#   'points',
#   'marvel',
#   'diversity',
#   'problem',
#   'isn',
#   'race'],
#  ['magnum', 'trailer', 'lots', 'close', 'shaves', 'big', 'mustache'],
#  ['gina', 'haspel', 'confirmed', 'cia', 'director', 'aid', 'democrats'],
#  ['boulder',
#   'city',
#   'council',
#   'unanimously',
#   'votes',
#   'ban',
#   'assault',
#   'weapons',
#   'high',
#   'capacity',
#   'magazines'],
#  ['chrissy', 'teigen', 'john', 'legend', 'baby', 'boy'],
#  ['terrifying', 'clip', 'shows', 'run', 'tree', 'thunderstorms'],
#  ['mitch',
#   'mcconnell',
#   'taps',
#   'anti',
#   'lgbtq',
#   'bigot',
#   'religious',
#   'freedom',
#   'panel'],
#  ['seth', 'meyers', 'donald', 'unexpected', 'advice', 'north', 'korea'],
#  ['devin',
#   'nunes',
#   'fundraising',
#   'fbi',
#   'attacks',
#   'tells',
#   'potential',
#   'donors',
#   'hero'],
#  ['mexican', 'president', 'warns', 'donald', 've', 'st'],
#  ['fox',
#   'news',
#   'female',
#   'ceo',
#   'named',
#   'sexual',
#   'harassment',
#   'complaints'],
#  ['battle', 'save', 'dying', 'soil'],
#  ['latino',
#   'man',
#   'insulted',
#   'starbucks',
#   'barista',
#   'writes',
#   'slur',
#   'cup'],
#  ['snl',
#   'cast',
#   'member',
#   'claims',
#   'faked',
#   'bizarre',
#   'phone',
#   'rehearsals'],
#  ['jimmy', 'kimmel', 'clean', 'owe', 'donald', 'apology'],
#  ['trevor',
#   'noah',
#   'skewers',
#   'betsy',
#   'devos',
#   'fake',
#   'profit',
#   'university',
#   'ad'],
#  ['serena', 'williams', 'explains', 'father', 'didn', 'walk', 'aisle'],
#  ['star',
#   'wars',
#   'writer',
#   'confirms',
#   'donald',
#   'glover',
#   'character',
#   'pansexual',
#   'solo'],
#  ['medical',
#   'professionals',
#   'fact',
#   'check',
#   'grey',
#   'anatomy',
#   'sex',
#   'scenes'],
#  ['amy',
#   'schumer',
#   'nails',
#   'meghan',
#   'markle',
#   'fairytale',
#   'wedding',
#   'sucks'],
#  ['michael',
#   'keaton',
#   'ends',
#   'kent',
#   'state',
#   'commencement',
#   'speech',
#   'batman'],
#  ['black', 'profiled', 'share', 'story'],
#  ['black',
#   'actresses',
#   'cannes',
#   'protest',
#   'racism',
#   'french',
#   'film',
#   'industry'],
#  ['michael', 'jordan', 'denies', 'rumors', 'doesn', 'date', 'black', 'women'],
#  ['scam',
#   'pacs',
#   'ripped',
#   'conservatives',
#   'pro',
#   'police',
#   'anti',
#   'abortion',
#   'messages',
#   'prosecutors'],
#  ['mtv',
#   'suspends',
#   'catfish',
#   'probes',
#   'nev',
#   'schulman',
#   'sexual',
#   'misconduct',
#   'claims'],
#  ['ice', 'increasingly', 'arresting', 'immigrants', 'criminal', 'convictions'],
#  ['special',
#   'counsel',
#   'hits',
#   'roger',
#   'stone',
#   'social',
#   'media',
#   'advisor',
#   'subpoenas'],
#  ['whitney',
#   'houston',
#   'sexually',
#   'abused',
#   'dee',
#   'dee',
#   'warwick',
#   'cannes',
#   'documentary'],
#  ['patton', 'oswalt', 'joker', 'theory', 'change', 'watch', 'dark', 'knight'],
#  ['josh',
#   'holt',
#   'american',
#   'captive',
#   'venezuela',
#   'begs',
#   'prison',
#   'videos'],
#  ['obama',
#   'photographer',
#   'taunts',
#   'donald',
#   'calling',
#   'immigrants',
#   'animals'],
#  ['backstreet', 'boys', 'release', 'song', 'don', 'breaking', 'heart'],
#  ['prince',
#   'knight',
#   'puts',
#   'gay',
#   'inclusive',
#   'twist',
#   'traditional',
#   'fairy',
#   'tales'],
#  ['gay',
#   'conversion',
#   'therapy',
#   'survivor',
#   'recalls',
#   'month',
#   'nightmare',
#   'powerful',
#   'video'],
#  ['gq',
#   'expertly',
#   'spoofs',
#   'vanity',
#   'fair',
#   'annual',
#   'comedy',
#   'issue',
#   'cover'],
#  ['rudy', 'giuliani', 'offers', 'head', 'spinning', 'defense'],
#  ['cynthia',
#   'nixon',
#   'fix',
#   'subway',
#   'ads',
#   'shred',
#   'cuomo',
#   'mta',
#   'commuters',
#   'rejoice'],
#  ['farm', 'huge', 'blow', 'animals'],
#  ['emails',
#   'interior',
#   'expected',
#   'learn',
#   'public',
#   'input',
#   'bears',
#   'ears',
#   'review'],
#  ['whistleblower',
#   'leaked',
#   'michael',
#   'cohen',
#   'financials',
#   'potential',
#   'cover',
#   'report'],
#  ['kidnapper', 'accused', 'alligator', 'hold', 'man', 'captive'],
#  ['miss', 'america', 'pageant', 'headed', 'women', 'email', 'scandal'],
#  ['north',
#   'korea',
#   'threatens',
#   'reconsider',
#   'summit',
#   'cancels',
#   'south',
#   'korea',
#   'talks'],
#  ['chemical', 'weapons', 'syria', 'watchdog', 'finds'],
#  ['hundreds',
#   'israel',
#   'protest',
#   'killings',
#   'palestinians',
#   'gaza',
#   'border'],
#  ['researchers', 'uncover', 'secret', 'pages', 'diary', 'anne', 'frank'],
#  ['stephen',
#   'piscotty',
#   'returns',
#   'bereavement',
#   'hit',
#   'mom',
#   'tribute',
#   'home',
#   'run'],
#  ['senate',
#   'intelligence',
#   'committee',
#   'backs',
#   'gina',
#   'haspel',
#   'lead',
#   'cia'],
#  ['pennsylvania', 'congressional', 'delegation', 'longer', 'men'],
#  ['lando',
#   'calrissian',
#   'star',
#   'wars',
#   'spinoff',
#   'starring',
#   'donald',
#   'glover',
#   'isn',
#   'happening'],
#  ['fake', 'donald', 'sean', 'hannity', 'pillow', 'talk', 'late'],
#  ['rapper', 'arrested', 'disorderly', 'conduct', 'public', 'drunkenness'],
#  ['conservatives',
#   'cook',
#   'farm',
#   'gambit',
#   'vote',
#   'hardline',
#   'immigration'],
#  ['novartis', 'lawyer', 'resigns', 'michael', 'cohen', 'deal'],
#  ['isn', 'birth', 'control', 'emoji'],
#  ['white',
#   'house',
#   'eliminates',
#   'cyber',
#   'czar',
#   'post',
#   'appointee',
#   'leaves'],
#  ['emily',
#   'list',
#   'backed',
#   'lawyer',
#   'wins',
#   'democratic',
#   'primary',
#   'pennsylvania',
#   'swing',
#   'district'],
#  ['robin',
#   'williams',
#   'biographer',
#   'tells',
#   'sweet',
#   'story',
#   'comic',
#   'store',
#   'visit'],
#  ['republicans', 'attacking', 'nancy', 'pelosi', 'house', 'races'],
#  ['empire', 'military', 'takes', 'gates', 'hell'],
#  ['longtime',
#   'lawyer',
#   'slams',
#   'giuliani',
#   'polarizing',
#   'figure',
#   'shouldn',
#   'deal',
#   'mueller'],
#  ['bet', 'awards', 'nominations', 'dj', 'khaled', 'screaming'],
#  ['beirut', 'pride', 'canceled', 'organizer', 'detained', 'authorities'],
#  ['manhattan',
#   'district',
#   'attorney',
#   'vows',
#   'stop',
#   'prosecuting',
#   'minor',
#   'marijuana',
#   'cases'],
#  ['larry',
#   'nassar',
#   'victims',
#   'receive',
#   'million',
#   'michigan',
#   'state',
#   'settlement'],
#  ['jr',
#   'left',
#   'open',
#   'possibility',
#   'dad',
#   'knew',
#   'tower',
#   'meeting',
#   'time'],
#  ['tom',
#   'cruise',
#   'ankle',
#   'break',
#   'scene',
#   'laughs',
#   'mission',
#   'impossible',
#   'trailer'],
#  ['lives', 'steven', 'tyler'],
#  ['louisiana',
#   'lawmakers',
#   'approve',
#   'restoring',
#   'voting',
#   'rights',
#   'people',
#   'probation',
#   'parole'],
#  ['thandie',
#   'newton',
#   'cannes',
#   'dress',
#   'celebration',
#   'black',
#   'star',
#   'wars',
#   'characters'],
#  ['paid', 'cohen', 'financial', 'disclosure', 'confirms'],
#  ['american', 'citizen', 'freed', 'egypt', 'jail'],
#  ['fox', 'news', 'settle', 'group', 'discrimination', 'lawsuits', 'million'],
#  ['tweeters', 'hard', 'pass', 'rnc', 'dinner', 'photo', 'donald', 'prize'],
#  ['facebook', 'removed', 'million', 'fake', 'accounts', 'quarter'],
#  ['pink', 'badass', 'response', 'troll', 'looked'],
#  ['san',
#   'francisco',
#   'adopt',
#   'software',
#   'app',
#   'automatically',
#   'clear',
#   'marijuana',
#   'convictions'],
#  ['younger',
#   'star',
#   'sutton',
#   'foster',
#   'returns',
#   'broadway',
#   'roots',
#   'album'],
#  ['senate',
#   'hot',
#   'seat',
#   'scott',
#   'pruitt',
#   'dodges',
#   'questions',
#   'mounting',
#   'scandals'],
#  ['idaho',
#   'inches',
#   'closer',
#   'electing',
#   'nation',
#   'native',
#   'american',
#   'governor'],
#  ['pro',
#   'abortion',
#   'rights',
#   'progressive',
#   'wins',
#   'nebraska',
#   'democratic',
#   'house',
#   'primary'],
#  ['ryan',
#   'reynolds',
#   'crashes',
#   'colbert',
#   'deadpool',
#   'crack',
#   'rated',
#   'jokes'],
#  ['ryan',
#   'reynolds',
#   'genuinely',
#   'hurt',
#   'trading',
#   'playground',
#   'insults',
#   'josh',
#   'brolin'],
#  ['terry', 'crews', 'movement', 'emancipation', 'proclamation'],
#  ['christopher',
#   'wylie',
#   'warns',
#   'senators',
#   'cambridge',
#   'analytica',
#   'steve',
#   'bannon',
#   'culture',
#   'war'],
#  ['san', 'francisco', 'ban', 'single', 'plastic', 'straws'],
#  ['john',
#   'travolta',
#   'isn',
#   'greased',
#   'lightning',
#   'cannes',
#   'dance',
#   'floor'],
#  ['senate', 'panel', 'releases', 'details', 'tower', 'meeting', 'probe'],
#  ['report',
#   'contradicts',
#   'michigan',
#   'governor',
#   'candidate',
#   'test',
#   'animal',
#   'treatment'],
#  ['republican', 'welfare', 'plan', 'keeping', 'wages'],
#  ['years', 'ago', 'today', 'michael', 'jackson', 'moonwalked', 'tv', 'time'],
#  ['hilary', 'duff', 'publicly', 'drags', 'neighbor', 'night'],
#  ['jim', 'carrey', 'jabs', 'stooge', 'donald', 'north', 'korea', 'artwork'],
#  ['failure',
#   'report',
#   'stormy',
#   'daniels',
#   'payoff',
#   'referred',
#   'prosecutors'],
#  ['bohemian',
#   'rhapsody',
#   'trailer',
#   'slammed',
#   'ignoring',
#   'freddie',
#   'mercury',
#   'sexuality'],
#  ['fergie', 'rides', 'york', 'city', 'subway'],
#  ['pauley',
#   'perrette',
#   'responds',
#   'cbs',
#   'statement',
#   'multiple',
#   'assaults',
#   'claim'],
#  ['refers', 'immigrants', 'animals'],
#  ['angry',
#   'white',
#   'dude',
#   'rant',
#   'people',
#   'speaking',
#   'spanish',
#   'nyc',
#   'viral'],
#  ['democratic',
#   'lawmaker',
#   'scott',
#   'pruitt',
#   'brutal',
#   'reality',
#   'check',
#   'senate',
#   'hearing'],
#  ['picks',
#   'mitch',
#   'mcconnell',
#   'brother',
#   'law',
#   'gordon',
#   'hartogensis',
#   'lead',
#   'pension',
#   'agency'],
#  ['fbi',
#   'search',
#   'cia',
#   'leak',
#   'suspect',
#   'turned',
#   'photos',
#   'sex',
#   'assault',
#   'unconscious',
#   'friend'],
#  ['pick', 'census', 'role', 'citizenship', 'question', 'political'],
#  ['jared',
#   'kushner',
#   'agitated',
#   'infuriated',
#   'meeting',
#   'russians',
#   'focused',
#   'adoptions'],
#  ['sarah',
#   'huckabee',
#   'sanders',
#   'unusually',
#   'honest',
#   'seth',
#   'meyers',
#   'spoof',
#   'briefing'],
#  ['kris', 'jenner', 'assistant', 'kris', 'jenner'],
#  ['chris',
#   'pratt',
#   'bryce',
#   'dallas',
#   'howard',
#   'service',
#   'raptor',
#   'flight'],
#  ['surprise', 'shows', 'coming', 'netflix'],
#  ['rex', 'tillerson', 'warns', 'grads', 'living', 'alternative', 'realities'],
#  ['democrats', 'force', 'vote', 'net', 'neutrality', 'rules'],
#  ['larry',
#   'nassar',
#   'blames',
#   'victims',
#   'victimized',
#   'newly',
#   'released',
#   'videos'],
#  ['video', 'shows', 'year', 'autism', 'taunted', 'abused', 'bus', 'driver'],
#  ['yanny', 'laurel', 'real', 'answer'],
#  ['populist',
#   'cleric',
#   'muqtada',
#   'al',
#   'sadr',
#   'win',
#   'iraq',
#   'parliamentary',
#   'election'],
#  ['palestinian',
#   'family',
#   'month',
#   'died',
#   'israeli',
#   'tear',
#   'gas',
#   'gaza',
#   'protest',
#   'crackdown',
#   'graphic'],
#  ['sichuan', 'airlines', 'pilot', 'sucked', 'halfway', 'broken', 'windshield'],
#  ['retail',
#   'group',
#   'spoofs',
#   'ferris',
#   'bueller',
#   'ad',
#   'bashing',
#   'donald',
#   'tariffs'],
#  ['washington',
#   'officials',
#   'state',
#   'cover',
#   'postage',
#   'mail',
#   'ballots',
#   'year'],
#  ['people', 'civil', 'politics', 'opponents', 'disagree'],
#  ['cambridge',
#   'analytica',
#   'investigated',
#   'justice',
#   'department',
#   'fbi',
#   'report'],
#  ['adorable',
#   'video',
#   'kids',
#   'shows',
#   'activism',
#   'literally',
#   'easy',
#   'pie'],
#  ['white',
#   'house',
#   'blames',
#   'deadly',
#   'gaza',
#   'violence',
#   'hamas',
#   'propaganda'],
#  ['gina', 'haspel', 'cia', 'shouldn', 'conducted', 'interrogation', 'program'],
#  ['tesla',
#   'autopilot',
#   'engaged',
#   'horrific',
#   'mph',
#   'crash',
#   'driver',
#   'tells',
#   'police'],
#  ['selling',
#   'planes',
#   'iran',
#   'saved',
#   'lives',
#   'exiting',
#   'nuclear',
#   'deal',
#   'make',
#   'harder'],
#  ['speech',
#   'fallen',
#   'officers',
#   'touts',
#   'policies',
#   'rails',
#   'sanctuary',
#   'cities'],
#  ['eric', 'greitens', 'team', 'pushes', 'inquiry', 'prosecutor', 'charged'],
#  ['elizabeth',
#   'warren',
#   'pledges',
#   'big',
#   'money',
#   'turn',
#   'heat',
#   'gerrymandering'],
# ...
#   'rio',
#   'cops',
#   'supposedly',
#   'closing',
#   'marielle',
#   'franco',
#   'killers'],
#  ['queer',
#   'eye',
#   'star',
#   'tan',
#   'france',
#   'doesn',
#   'poorly',
#   'dressed',
#   'fans',
#   'style',
#   'advice'],
#  ['women', 'coming', 'eric', 'schneiderman', 'job'],
#  ['man',
#   'pleads',
#   'guilty',
#   'bacon',
#   'vandalism',
#   'tennessee',
#   'islamic',
#   'center'],
#  ['mike', 'pence', 'robert', 'mueller', 'russia', 'probe', 'wrap'],
#  ['ready', 'older', 'kevin', 'justin', 'hartley'],
#  ['net', 'neutrality', 'rules', 'end', 'june', 'fcc'],
#  ['democratic',
#   'candidate',
#   'maryland',
#   'governor',
#   'dies',
#   'cardiac',
#   'arrest'],
#  ['officer',
#   'puts',
#   'man',
#   'chokehold',
#   'north',
#   'carolina',
#   'waffle',
#   'house'],
#  ['trevor', 'noah', 'don', 'blankenship', 'nutty', 'concession', 'speech'],
#  ['brooklyn', 'canceled', 'twitter', 'mourns'],
#  ['quiet', 'struggle', 'chuck', 'schumer', 'left'],
#  ['gabby', 'douglas', 'utterly', 'unrecognizable', 'undercover', 'boss'],
#  ['girls', 'accused', 'plotting', 'kill', 'classmate'],
#  ['curious',
#   'case',
#   'russian',
#   'oligarch',
#   'national',
#   'park',
#   'service',
#   'latrines'],
#  ['watch',
#   'rudy',
#   'giuliani',
#   'completely',
#   'torpedo',
#   'rudy',
#   'giuliani',
#   'arguments'],
#  ['fox',
#   'business',
#   'guest',
#   'defends',
#   'torture',
#   'worked',
#   'john',
#   'mccain'],
#  ['tom', 'abby', 'queer', 'eye', 'remarried'],
#  ['pakistan', 'passes', 'historic', 'transgender', 'rights'],
#  ['phil', 'mudd', 'flips', 'questions', 'cia', 'torture', 'didn', 'america'],
#  ['facebook', 'ads', 'house', 'dems', 'russia', 'ran', 'election'],
#  ['kim', 'kardashian', 'tristan', 'thompson', 'blocked', 'defended', 'khloe'],
#  ['kenan', 'thompson', 'll', 'stay', 'snl', 'long'],
#  ['jennifer',
#   'garner',
#   'mom',
#   'problems',
#   'hilarious',
#   'rap',
#   'video',
#   'ellen'],
#  ['dick',
#   'cheney',
#   'suggests',
#   'restarting',
#   'torture',
#   'interrogation',
#   'program'],
#  ['greta',
#   'gerwig',
#   'loudly',
#   'critiqued',
#   'feel',
#   'pretty',
#   'moviegoer',
#   'live',
#   'tweeted'],
#  ['devin',
#   'nunes',
#   'meeting',
#   'secret',
#   'russia',
#   'probe',
#   'source',
#   'threatening',
#   'doj'],
#  ['queer',
#   'eye',
#   'star',
#   'karamo',
#   'brown',
#   'engaged',
#   'director',
#   'ian',
#   'jordan'],
#  ['jet', 'launched', 'apple', 'store', 'incredible', 'deals'],
#  ['tom', 'hardy', 'completely', 'unrecognizable', 'al', 'capone', 'movie'],
#  ['woman',
#   'alleges',
#   'rapper',
#   'young',
#   'lo',
#   'raped',
#   'trapped',
#   'chris',
#   'brown',
#   'home'],
#  ['republicans', 'court', 'seat', 'denied', 'obama', 'years'],
#  ['man',
#   'wanted',
#   'white',
#   'supremacists',
#   'kill',
#   'black',
#   'neighbor',
#   'burn',
#   'cross',
#   'yard',
#   'fbi'],
#  ['announces', 'details', 'meeting', 'kim', 'jong'],
#  ['samantha',
#   'bee',
#   'delivers',
#   'blistering',
#   'takedown',
#   'ny',
#   'ag',
#   'eric',
#   'schneiderman'],
#  ['jim', 'carrey', 'scathing', 'portrait', 'joker', 'nightmares'],
#  ['michelle', 'wolf', 'renews', 'hostilities', 'sarah', 'huckabee', 'sanders'],
#  ['fans', 'erupt', 'fate', 'elias', 'koteas', 'olinsky', 'chicago'],
#  ['people', 'street', 'apologize', 'teachers', 'jimmy', 'kimmel', 'live'],
#  ['stephen', 'colbert', 'porn', 'star', 'math', 'michael', 'cohen', 'donald'],
#  ['pollen', 'bomb', 'allergy', 'sufferer', 'worst', 'nightmare'],
#  ['jennifer', 'lopez', 'dances', 'danceable', 'songs', 'tonight'],
#  ['white',
#   'yale',
#   'student',
#   'calls',
#   'cops',
#   'black',
#   'schoolmate',
#   'napping',
#   'dorm',
#   'common',
#   'room'],
#  ['rudy', 'giuliani', 'quits', 'law', 'firm', 'wild', 'week', 'interviews'],
#  ['teddy', 'geiger', 'makes', 'public', 'appearance', 'coming', 'transgender'],
#  ['ariana', 'grande', 'mac', 'miller', 'reportedly', 'break'],
#  ['avengers', 'leaks', 'support', 'year', 'interview', 'marvel', 'directors'],
#  ['good', 'excuse', 'racist', 'impact', 'michigan', 'medicaid', 'proposal'],
#  ['fcc', 'complaints', 'minutes', 'interview', 'stormy', 'daniels'],
#  ['americans', 'jailed', 'korea', 'home', 'situation', 'worse'],
#  ['alex', 'strangelove', 'gay', 'teen', 'comedy', 'doesn', 'turn', 'sex'],
#  ['woman', 'home', 'kittens', 'bobcats'],
#  ['video',
#   'bear',
#   'eating',
#   'ice',
#   'cream',
#   'dairy',
#   'queen',
#   'leads',
#   'charges',
#   'zoo',
#   'owners'],
#  ['iranian',
#   'lawmakers',
#   'mock',
#   'mental',
#   'capacity',
#   'burn',
#   'flag',
#   'pulls',
#   'nuke',
#   'deal'],
#  ['europeans', 'scramble', 'save', 'iran', 'deal', 'withdraws'],
#  ['north',
#   'korea',
#   'releases',
#   'american',
#   'political',
#   'prisoners',
#   'advance',
#   'historic',
#   'summit'],
#  ['establishment',
#   'gop',
#   'notches',
#   'win',
#   'ohio',
#   'primary',
#   'vacant',
#   'house',
#   'seat'],
#  ['eric',
#   'schneiderman',
#   'praised',
#   'movement',
#   'days',
#   'abuse',
#   'allegations',
#   'emerged'],
#  ['trevor',
#   'noah',
#   'unloads',
#   'supposed',
#   'advocate',
#   'women',
#   'eric',
#   'schneiderman'],
#  ['year',
#   'comey',
#   'firing',
#   'scope',
#   'mueller',
#   'probe',
#   'expands',
#   'lawyer',
#   'shell',
#   'company'],
#  ['inspired', 'businessman', 'wins', 'indiana', 'gop', 'senate', 'primary'],
#  ['gop',
#   'rival',
#   'tammy',
#   'baldwin',
#   'team',
#   'terrorists',
#   'silence',
#   'cia',
#   'pick'],
#  ['jobs', 'program', 'people', 'work'],
#  ['jim', 'parsons', 'queer', 'stories', 'onscreen'],
#  ['accuser', 'wins', 'democratic', 'nomination', 'ohio', 'legislature'],
#  ['mastermind',
#   'waterboarded',
#   'cia',
#   'information',
#   'share',
#   'gina',
#   'haspel'],
#  ['conservative',
#   'senate',
#   'democrat',
#   'backs',
#   'agenda',
#   'defeats',
#   'progressive',
#   'challenger'],
#  ['taylor', 'swift', 've', 'katy', 'perry', 'kimye', 'feud', 'lives'],
#  ['kim',
#   'kardashian',
#   'make',
#   'history',
#   'fashion',
#   'council',
#   'influencer',
#   'award'],
#  ['nbc',
#   'believes',
#   'matt',
#   'lauer',
#   'accusers',
#   'months',
#   'long',
#   'investigation'],
#  ['russians', 'ability', 'change', 'voter', 'data', 'didn', 'report'],
#  ['elizabeth',
#   'warren',
#   'pick',
#   'wins',
#   'ohio',
#   'democratic',
#   'gubernatorial',
#   'primary'],
#  ['kkk', 'leader', 'guilty', 'firing', 'gun', 'charlottesville', 'rally'],
#  ['protesters',
#   'decrying',
#   'torture',
#   'dragged',
#   'gina',
#   'haspel',
#   'senate',
#   'hearing'],
#  ['hired', 'firm', 'linked', 'michael', 'cohen', 'inside', 'scoop'],
#  ['rnc',
#   'selling',
#   'sickening',
#   'donald',
#   'themed',
#   'merch',
#   'ahead',
#   'mother',
#   'day'],
#  ['don',
#   'blankenship',
#   'defeat',
#   'relief',
#   'families',
#   'upper',
#   'big',
#   'branch',
#   'miners'],
#  ['colbert', 'shreds', 'broken', 'promises', 'talking'],
#  ['ambassador', 'germany', 'offends', 'hosts', 'hours', 'day'],
#  ['jordan', 'peele', 'nightmare', 'coming', 'year'],
#  ['backstreet', 'boys', 'dressed', 'spice', 'girls', 'larger', 'life'],
#  ['seth',
#   'meyers',
#   'decodes',
#   'teen',
#   'slang',
#   'reveals',
#   'giuliani',
#   'means'],
#  ['orlando', 'interim', 'pulse', 'nightclub', 'memorial'],
#  ['trevor', 'noah', 'turns', 'donald', 'knives', 'comment', 'reggae', 'magic'],
#  ['senators',
#   'force',
#   'vote',
#   'ultimately',
#   'reverse',
#   'fcc',
#   'restore',
#   'net',
#   'neutrality'],
#  ['ny',
#   'legislature',
#   'plan',
#   'place',
#   'replacements',
#   'eric',
#   'schneiderman'],
#  ['ambassadors',
#   'write',
#   'letter',
#   'opposing',
#   'gina',
#   'haspel',
#   'nomination'],
#  ['california', 'authority', 'state', 'homes', 'solar', 'powered'],
#  ['ny',
#   'governor',
#   'assigns',
#   'investigation',
#   'eric',
#   'schneiderman',
#   'abuse',
#   'allegations'],
#  ['refugee', 'caravan', 'scapegoat', 'border', 'crackdown'],
#  ['pennsylvania',
#   'latest',
#   'state',
#   'fund',
#   'urban',
#   'gun',
#   'violence',
#   'prevention'],
#  ['denver', 'mayor', 'son', 'caught', 'tape', 'berating', 'cop', 'faggot'],
#  ['progressive', 'prosecutors', 'win', 'primaries', 'north', 'carolina'],
#  ['novartis', 'money', 'paid', 'lawyer'],
#  ['hypocrisy',
#   'melania',
#   'online',
#   'safety',
#   'booklet',
#   'pointed',
#   'page',
#   'page'],
#  ['uninsured', 'rate', 'worsening', 'years', 'obamacare', 'gains'],
#  ['bernie', 'sanders', 'plan', 'revive', 'labor', 'unions'],
#  ['jim',
#   'carrey',
#   'bestows',
#   'scott',
#   'pruitt',
#   'savage',
#   'nickname',
#   'latest',
#   'painting'],
#  ['male', 'allies', 'abusers'],
#  ['mormon',
#   'church',
#   'end',
#   'century',
#   'long',
#   'relationship',
#   'boy',
#   'scouts'],
#  ['snack', 'addiction', 'killing', 'orangutans'],
#  ['pick', 'cia', 'director', 'won', 'torture', 'program', 'morally', 'wrong'],
#  ['anderson',
#   'cooper',
#   'burns',
#   'moronic',
#   'michael',
#   'cohen',
#   'russia',
#   'cash',
#   'claims'],
#  ['pinata',
#   'maker',
#   'apologizes',
#   'hanging',
#   'black',
#   'figures',
#   'likeness',
#   'lynchings'],
#  ['caliphate', 'planet', 'ruins'],
#  ['gay',
#   'marriage',
#   'opponent',
#   'ousted',
#   'gop',
#   'incumbent',
#   'north',
#   'carolina'],
#  ['espn', 'eliminates', 'public', 'editor', 'role', 'calling', 'outdated'],
#  ['michael',
#   'cohen',
#   'selling',
#   'access',
#   'group',
#   'paid',
#   'shell',
#   'company'],
#  ['mitch',
#   'mcconnell',
#   'mocks',
#   'blankenship',
#   'twitter',
#   'big',
#   'cloud',
#   'cocaine'],
#  ['convict',
#   'don',
#   'blankenship',
#   'loses',
#   'patrick',
#   'morrisey',
#   'west',
#   'virginia',
#   'senate',
#   'race'],
#  ['ohio', 'voters', 'pass', 'gerrymandering', 'reform', 'measure'],
#  ['iran', 'deal', 'exit', 'win', 'russia'],
#  ['cynthia', 'nixon', 'yorkers', 'vote', 'homo', 'cuomo'],
#  ['ontario', 'canada', 'issued', 'binary', 'birth', 'certificate'],
#  ['child',
#   'sexual',
#   'predator',
#   'roman',
#   'polanski',
#   'calls',
#   'movement',
#   'total',
#   'hypocrisy'],
#  ['america',
#   'producer',
#   'reveals',
#   'details',
#   'childish',
#   'gambino',
#   'viral',
#   'video'],
#  ['terry', 'crews', 'black', 'men', 'aren', 'allowed', 'victims', 'dead'],
#  ['donald', 'glover', 'america', 'eyes', 'jim', 'crow', 'historian'],
#  ['fox',
#   'news',
#   'judicial',
#   'analyst',
#   'issues',
#   'dark',
#   'warning',
#   'michael',
#   'cohen'],
#  ['black',
#   'women',
#   'bishops',
#   'making',
#   'history',
#   'predominantly',
#   'white',
#   'church'],
#  ['geena', 'davis', 'husband', 'reza', 'jarrahy', 'divorcing'],
#  ['pauley', 'perrette', 'abby', 'heart', 'wrenching', 'farewell', 'ncis'],
#  ['lethal', 'weapon', 'fires', 'clayne', 'crawford', 'character', 'shot'],
#  ['selena', 'gomez', 'pokes', 'fun', 'met', 'gala', 'spray', 'tan', 'mishap'],
#  ['protest',
#   'leader',
#   'nikol',
#   'pashinian',
#   'elected',
#   'prime',
#   'minister',
#   'armenia'],
#  ['kim', 'jong', 'secretly', 'met', 'xi', 'jinping'],
#  ['netanyahu', 'bombastic', 'iran', 'claims', 'perfect', 'audience'],
#  ['netanyahu',
#   'chef',
#   'blasted',
#   'serving',
#   'japan',
#   'prime',
#   'minister',
#   'dessert',
#   'shoe'],
#  ['world', 'leaders', 'condemn', 'withdrawing', 'iran', 'nuclear', 'deal'],
#  ['senate',
#   'republicans',
#   'shun',
#   'don',
#   'blankenship',
#   'day',
#   'west',
#   'virginia',
#   'primary'],
#  ['york',
#   'harvey',
#   'weinstein',
#   'probe',
#   'set',
#   'continue',
#   'attorney',
#   'general',
#   'exit'],
#  ['announce', 'break', 'iran', 'nuclear', 'deal'],
#  ['politicians', 'schneiderman', 'resign', 'physical', 'abuse', 'allegations'],
#  ['joe',
#   'scarborough',
#   'legal',
#   'strategy',
#   'monkey',
#   'throwing',
#   'poo',
#   'wall'],
#  ['kirsten', 'dunst', 'jesse', 'plemons', 'baby', 'boy'],
#  ['holy', 'matrimony', 'proposal', 'met', 'gala'],
#  ['nordstrom',
#   'rack',
#   'president',
#   'apologizes',
#   'store',
#   'accuses',
#   'black',
#   'men',
#   'theft'],
#  ['giuliani',
#   'lawyer',
#   'michael',
#   'cohen',
#   'incriminating',
#   'information',
#   'president'],
#  ['lena', 'waithe', 'stuns', 'met', 'gala', 'queer', 'superhero'],
#  ['kelly', 'accusers', 'permission', 'bathroom'],
#  ['reportedly', 'tells', 'macron', 'pulling', 'iran', 'nuclear', 'deal'],
#  ['deportation', 'crackdown', 'hurting', 'immigrant', 'victims', 'crime'],
#  ['seth', 'meyers', 'michael', 'cohen', 'apologize', 'air'],
#  ['blessing', 'met', 'gala', 'tweets'],
#  ['farm', 'cut', 'food', 'stamps', 'friendly', 'farmers'],
#  ['iran', 'nuclear', 'deal'],
#  ['derby', 'day', 'bet', 'wins', 'thrilled', 'texas', 'woman', 'million'],
#  ['democratic',
#   'meddling',
#   'west',
#   'virginia',
#   'things',
#   'watch',
#   'election',
#   'day'],
#  ['cynthia',
#   'erivo',
#   'met',
#   'gala',
#   'nails',
#   'featured',
#   'sistine',
#   'chapel',
#   'painting',
#   'black',
#   'women'],
#  ['keanu', 'reeves', 'alex', 'winter', 'coming', 'ted', 'years'],
#  ['solange', 'durag', 'true', 'mvp', 'met', 'gala'],
#  ['house',
#   'republican',
#   'threatens',
#   'subpoena',
#   'doj',
#   'official',
#   'census',
#   'citizenship',
#   'request'],
#  ['jimmy', 'kimmel', 'hard', 'make', 'sense', 'rudy', 'latest', 'defense'],
#  ['religious', 'imagery', 'stitched', 'met', 'gala'],
#  ['bob',
#   'marley',
#   'granddaughter',
#   'cops',
#   'racially',
#   'profiled',
#   'checking',
#   'airbnb'],
#  ['melania',
#   'called',
#   'anti',
#   'bullying',
#   'campaign',
#   'ignores',
#   'husband',
#   'actions'],
#  ['trevor', 'noah', 'watching', 'rudy', 'giuliani', 'smoking', 'weed', 'tv'],
#  ['janet',
#   'jackson',
#   'receive',
#   'icon',
#   'award',
#   'billboard',
#   'music',
#   'awards'],
#  ['white',
#   'house',
#   'prepares',
#   'send',
#   'congress',
#   'billion',
#   'spending',
#   'cuts',
#   'package'],
#  ['jared', 'kushner', 'backed', 'shot', 'federal', 'prison', 'reform'],
#  ['george',
#   'zimmerman',
#   'accused',
#   'stalking',
#   'detective',
#   'working',
#   'trayvon',
#   'martin',
#   'film'],
#  ['passengers',
#   'lashing',
#   'scott',
#   'pruitt',
#   'justify',
#   'class',
#   'travel',
#   'epa',
#   'memo'],
#  ['country', 'house', 'district', 'key', 'progressive', 'battleground'],
#  ['mike',
#   'pence',
#   'brother',
#   'wins',
#   'primary',
#   'race',
#   'vice',
#   'president',
#   'house',
#   'seat'],
#  ['marines',
#   'investigating',
#   'avowed',
#   'white',
#   'supremacist',
#   'active',
#   'duty'],
#  ['violate', 'iran', 'nuclear', 'deal', 'vows', 'reimpose', 'sanctions'],
#  ['olympic',
#   'committee',
#   'sexual',
#   'abuse',
#   'complaints',
#   'taekwondo',
#   'stars',
#   'lawsuit'],
#  ['blake', 'lively', 'brought', 'family', 'met', 'gala', 'noticing'],
#  ['reilly',
#   'offers',
#   'stand',
#   'sarah',
#   'sanders',
#   'handle',
#   'line',
#   'reporters'],
#  ['catholic',
#   'priest',
#   'praised',
#   'dressed',
#   'dude',
#   'met',
#   'gala',
#   'living',
#   'life'],
#  ['jimmy', 'kimmel', 'hide', 'seek', 'genius', 'dog', 'heal', 'nation'],
#  ['bank',
#   'america',
#   'appears',
#   'flip',
#   'firearm',
#   'promise',
#   'loan',
#   'remington'],
#  ['gentleman', 'caller', 'presents', 'queer', 'icons', 've'],
#  ['eric', 'schneiderman', 'man'],
#  ['christiane', 'amanpour', 'heading', 'pbs', 'replacing', 'charlie', 'rose'],
#  ['madonna', 'teases', 'song', 'surprise', 'met', 'gala', 'performance'],
#  ['iron',
#   'man',
#   'black',
#   'widow',
#   'captain',
#   'america',
#   'thor',
#   'hawkeye',
#   'matching',
#   'tattoos'],
#  ['michael',
#   'cohen',
#   'accepted',
#   'firm',
#   'tied',
#   'russian',
#   'oligarch',
#   'reports'],
#  ['stephen', 'colbert', 'hits', 'rudy', 'giuliani', 'brutal', 'fact', 'check'],
#  ['katy',
#   'perry',
#   'sends',
#   'olive',
#   'branch',
#   'taylor',
#   'swift',
#   'world',
#   'rejoices'],
#  ['jada', 'pinkett', 'smith', 'real', 'dating', 'smith', 'married'],
#  ['whoops',
#   'mark',
#   'hamill',
#   'spilled',
#   'beans',
#   'major',
#   'cameo',
#   'han',
#   'solo',
#   'movie'],
#  ['shawn',
#   'mendes',
#   'sweetly',
#   'attended',
#   'hailey',
#   'baldwin',
#   'gown',
#   'met',
#   'gala'],
#  ['orrin', 'hatch', 'suggested', 'allowed', 'john', 'mccain', 'funeral'],
#  ['seth', 'meyers', 'perfect', 'line', 'confront', 'donald', 'lies'],
#  ['police', 'hope', 'dna', 'catch', 'zodiac', 'killer'],
#  ['lili',
#   'reinhart',
#   'cole',
#   'sprouse',
#   'finally',
#   'make',
#   'couple',
#   'debut',
#   'met',
#   'gala'],
#  ['sweetbitter', 'captures', 'grit', 'glamour', 'restaurant', 'world'],
#  ['mitch', 'mcconnell', 'bends', 'rules', 'confirm', 'judges'],
#  ['ryan', 'zinke', 'tale', 'fish'],
#  ['ny',
#   'attorney',
#   'general',
#   'eric',
#   'schneiderman',
#   'resigns',
#   'amid',
#   'abuse',
#   'allegations'],
#  ['sanctuary', 'cities', 'working', 'era', 'surprising', 'cost'],
#  ['shepard', 'smith', 'pulled', 'iran', 'deal', 'decision', 'violate'],
#  ['stormy', 'daniels', 'finds', 'crunchy', 'chip'],
#  ['rainbow', 'mountains', 'peru', 'straight', 'dr', 'seuss', 'book'],
#  ...]

# %% [markdown]
# ### Creating n-grams

# %%
def create_bigrams(texts, bigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify bigrams in texts and return the texts with bigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

def create_trigrams(texts, trigram_count=15, threshold=10, convert_sent_to_words=False, as_str=True):
    """Identify trigrams in texts and return the texts with trigrams integrated"""
    if convert_sent_to_words:
        texts = list(sent_to_words(texts))
    
    bigram_model = Phraser(Phrases(texts, min_count=bigram_count, threshold=threshold))
    
    if as_str:
        return [" ".join(bigram_model[t]) for t in texts]

    else:
        return [bigram_model[t] for t in texts]

# %%
texts = create_bigrams(texts)

# %%
texts
# Out:
# ['mass_shootings texas week tv',
#  'smith joins diplo nicky jam world_cup official song',
#  'hugh grant marries time age',
#  'jim_carrey blasts castrato adam schiff democrats artwork',
#  'julianna margulies donald poop bags pick dog',
#  'morgan_freeman devastated sexual_harassment claims undermine legacy',
#  'donald lovin mcdonald jingle tonight bit',
#  'watch amazon prime week',
#  'mike myers reveals fourth austin powers film',
#  'watch hulu week',
#  'justin_timberlake visits texas school_shooting victims',
#  'south_korean president meets north_korea kim_jong talk summit',
#  'life risk remote oyster growing region called robots',
#  'crackdown immigrant parents puts kids strained',
#  'son concerned fbi obtained wiretaps putin ally met jr',
#  'edward_snowden loves vladimir_putin',
#  'booyah obama photographer hilariously trolls spy claim',
#  'ireland votes repeal abortion amendment landslide referendum',
#  'ryan_zinke reel critics grand pivot conservation',
#  'scottish golf resort pays women significantly men report',
#  'weird father_day gifts dad doesn',
#  'twitter universally entertaining',
#  'mystery wolf animal reportedly shot montana baffles wildlife officials',
#  'north_korea open talks cancels summit',
#  'men detonate bomb inside indian restaurant toronto authorities',
#  'thousands travel home ireland vote abortion access',
#  'irish voters set liberalize abortion laws landslide exit poll signals',
#  'warriors coach steve kerr calls nfl ban protests fake patriotism',
#  'historic victory barbados elects female prime_minister',
#  'police killed black americans moment colin_kaepernick protested',
#  'jack johnson pardoned taboo sex criminalized',
#  'bet chairman ceo debra lee stepping',
#  'rachel dolezal faces felony charges welfare fraud',
#  'bishop michael curry joins christian march white_house reclaim jesus',
#  'kanye_west spent photo whitney_houston bathroom album cover',
#  'morgan_freeman dropped marketing campaigns harassment accusations',
#  'chinese exclusion act understand immigration politics today',
#  'maga themed swimwear sinks twitter',
#  'seth_meyers funny regret cancels north_korea summit',
#  'colbert turn nyc subway rides terrible punishment',
#  'man faces charges pulling knife stun gun muslim students mcdonald',
#  'jimmy_kimmel iran supreme leader watches tom jerry',
#  'people injured indiana school_shooting',
#  'people rattled nigerian man chadwick boseman',
#  'david cross proves terrible apologizing',
#  'sesame_street creators sue makers upcoming adult themed puppet film',
#  'missed saddest death avengers_infinity war',
#  'george_takei accuser walks story drugging sexual_assault',
#  'samantha_bee parents america basically war zone',
#  'pete davidson mental_illness doesn ruin romance',
#  'james_corden adam_levine pulled carpool_karaoke',
#  'emilia clarke dishes final game_thrones scene',
#  'hollywood doesn difficult men make great tv',
#  'harvey_weinstein accusers thought arrested',
#  'harvey_weinstein turns police alleged sex crimes',
#  'john_mayer weird low budget video meme worthy masterpiece',
#  'boba fett star_wars movie',
#  'suggests north_korea summit happen',
#  'roger stone pressed damaging emails hillary_clinton wikileaks report',
#  'publix suspends contributions nra backed politician amid protests',
#  'twitter bots delivered donald victory research paper',
#  'bag wet socks apparently living white_house press briefing room',
#  'member proud boys menaced twitter user doorstep',
#  'things nra blamed texas school_shooting',
#  'catholic hospital won save',
#  'executive_orders make easier federal workers',
#  'monsanto bayer set merge care',
#  'joy watching harvey_weinstein perp walk',
#  'funniest_tweets women week',
#  'queer_eye star bobby berk gave desk makeover incredible',
#  'older gay_men gay slang hilarious video',
#  'rupaul_drag race teaching straight people queer culture',
#  'fish market buys freedom fred pound octopus',
#  'north_korea threatens summit warns nuclear showdown',
#  'investigation finds russian missile shot flight mh',
#  'north_korea demolishes tunnels nuclear test site reports',
#  'kim_jong baited canceling north_korea summit',
#  'michelle_obama reveals cover upcoming memoir',
#  'late_night writer breathless royal_wedding recap',
#  'morgan_freeman accused inappropriate behavior sexual_harassment',
#  'jets chairman christopher johnson won fine players anthem protests',
#  'andy_cohen taylor_swift katy_perry drama',
#  'infinity_war writers clear marvel problematic timeline',
#  'david blaine chews glass lets james_corden puncture cheek',
#  'amy_poehler parks recreation revival amazing',
#  'colbert exposes biggest flaw latest conspiracy_theory',
#  'seth_meyers donald valuable marketing advice',
#  'launches auto import probe china vows defend interests',
#  'women pulled stops land dream job',
#  'wife asked husband fenty highlighter pack highlighters hairbrush',
#  'roasted rushing defend tomi_lahren ignoring real victims',
#  'abruptly cancels north_korea summit kim_jong',
#  'devin_nunes linked winery faced suit alleged coke prostitute yacht party',
#  'immigrant children accuse border_patrol abuse neglect report shows',
#  'ireland historic vote legalizing abortion haunted brexit',
#  'lawyer attended doj meeting confidential fbi informant',
#  'senate advances court_pick planned_parenthood kills females year',
#  'rudy_giuliani won interview mueller spygate report',
#  'kentucky attorney running judge dies day primary win',
#  'chrissy_teigen taunts donald twitter blocking ruling',
#  'koch network favorite congressmen',
#  'posthumously pardons boxer jack johnson',
#  'ellen tears ashton_kutcher donates million wildlife fund',
#  'ariana_grande reveals bee tattoo honor manchester attack',
#  'kim_kardashian wished kanye_west happy anniversary fine pretty cute',
#  'chris_hemsworth dances wrecking ball kids living_room',
#  'moses farrow defends woody_allen accuses mia farrow abuse',
#  'gwyneth_paltrow brad_pitt threatened kill harvey_weinstein',
#  'stephen king reveals donald blocked twitter',
#  'fans jessica walter addressed verbal harassment jeffrey tambor',
#  'jessica walter discusses jeffrey tambor alleged harassment male stars brush',
#  'harvey_weinstein expected turn nypd sex crimes',
#  'samantha_bee torches ice shut fk',
#  'scott_pruitt introduced anti_abortion bills giving men property rights fetuses',
#  'twitter critics mercilessly mock canceling summit kim',
#  'civil_rights groups rip senate revising sexual_harassment policy',
#  'alabama sues exclude undocumented_immigrants census count',
#  'cynthia_nixon vows fighting predictably losing party endorsement',
#  'white_house officials reportedly considered ignoring climate research',
#  'read letter kim_jong canceling north_korea summit',
#  'south_korea responds sudden cancellation kim_jong summit',
#  'facebook ad rules prove basically charge regulating elections',
#  'border agent fatally_shoots migrant woman texas',
#  'opens door gun industry sell firearms abroad',
#  'stormy_daniels day declared west hollywood adult star key city',
#  'checkout machine',
#  'ways_make family road_trips easier parents ve',
#  'jake_tapper shreds donald long list conspiracy_theories',
#  'york daily_news rips nfl anthem kneeling ban',
#  'judge ruled immigrant hearing',
#  'house democrats offer internships students affected gun_violence',
#  'tig notaro tells ellen_degeneres sons passion trash',
#  'stormy_daniels wonderful gay dads west hollywood hands keys city',
#  'queer_eye season drops month',
#  'gay man denied marriage license kim_davis loses bid unseat',
#  'anna kournikova dancing bouncing baby cutest thing',
#  'nfl_players unwilling stand anthem shouldn country',
#  'facebook accused reading texts accessing microphones lawsuit',
#  'driving uber fatal accident seconds react crash',
#  'amazon admits alexa device eavesdropped portland family',
#  'man discovers handgun impaled bumper car',
#  'rescue cat hilarious wide eyed expression scan confirms pregnant',
#  'weirdest promposals include teen faked birth',
#  'american stoke hate canada',
#  'anti establishment parties set form italy government',
#  'sarah_silverman sees reason louis continue artist',
#  'southern baptist leader abused women pray removed post',
#  'americans support sex_marriage',
#  'brynn cartelli youngest winner voice',
#  'betsy_devos stirs uproar schools ice undocumented kids',
#  'sandy_hook families fbi agent sue alex_jones defamation',
#  'high_school teacher defeats kentucky house majority leader gop_primary',
#  'lupe valdez makes_history texas winning democratic nod governor',
#  'report michael_cohen business partner cooperating prosecutors',
#  'brandi chastain totally agrees hall_fame plaque',
#  'scientists turn dna technology search loch ness monster',
#  'late_night writer vows red hats supporters',
#  'julia_louis dreyfus receive mark twain prize american humor',
#  'michelle_obama shares intimate wedding photo tribute husband barack',
#  'spot trevor_noah black_panther daily host stealth cameo revealed',
#  'donald glover fans execute stunning coup donald themed reddit forum',
#  'calls boycott restaurant duty cop allegedly assaults black women',
#  'survivor rwandan genocide country female neurosurgeon',
#  'stacey abrams wins democratic_primary georgia governor',
#  'trevor_noah reveals question donald dared',
#  'michelle_obama reflects scary time princeton sweet throwback snap',
#  'reasons started conversation responsible finishing',
#  'lourdes leon major madonna vibes moody ad_campaign pics',
#  'ways netflix tricks watching shows movies',
#  'brad_pitt ryan_reynolds demeaning thing exchange deadpool cameo',
#  'robert_niro bans nobu restaurant',
#  'ariana_grande shuts fan blaming heartbreaking mac miller split',
#  'parents slam dogs scenes grooming children sexual_abuse',
#  'dave grohl apologize world massive jerk',
#  'emilia clarke introduced prince_william pretty embarrassing',
#  'sarah paulson takes impressions level tonight',
#  'ready party',
#  'gina ortiz jones wins democratic runoff texas congressional race',
#  'fighter pilot amy mcgrath wins democratic_primary kentucky swing district',
#  'rallies conservatives promise abortion curbs',
#  'aclu suing strike ohio congressional map',
#  'latest school_shooting hasn stirred gun debate',
#  'donald tweet rescues roseanne family season_finale',
#  'ellen grills mark wahlberg shirtless instagram selfies',
#  'idris_elba star hunchback notre_dame netflix',
#  'maryland police charge church leaders past abuse risk teen girls',
#  'nfl bans kneeling national_anthem',
#  'conan_brien muscles royal_wedding spoof ads',
#  'house_republicans report progress immigration deal',
#  'democrats weren invited review classified documents fbi informant',
#  'gop_candidate pointed gun teenager advances georgia governor primary runoff',
#  'walking definition entitled millennial swears entitled millennial',
#  'democrats push included classified briefing fbi informant',
#  'machines don steal jobs increasingly rob work humanity',
#  'praises tomi_lahren restaurant crowd tosses water insults',
#  'sarah sanders bothers called liar',
#  'blocking people twitter judge_rules',
#  'christian militia won iraqi christians parliamentary seats christians intervene',
#  'tulsi gabbard syria views cost support hawaii teachers union',
#  'jared_kushner received security clearance reports',
#  'arizona gop congressional_candidate compares abortion holocaust',
#  'gun reform advocate lucy mcbath heads runoff georgia house seat',
#  'star_wars burlesque storms west_coast sexy stormtroopers',
#  'establishment backed moderate wins heated democratic house primary texas',
#  'senators unveil crack sexual_harassment',
#  'trips york_city long weekend',
#  'disney reveals opening seasons star_wars theme_park lands',
#  'latest entries comedy wildlife photo awards cheer',
#  'bad lip_reading reveals royal_wedding',
#  'australian archbishop convicted covering child sex_abuse',
#  'commander iran people respond pompeo threats punch mouth',
#  'mark_zuckerberg extends facebook apology tour european gig',
#  'ariana_grande tweets message support manchester bombing anniversary',
#  'katy_perry single american_idol',
#  'cops watch powerful monologue racism',
#  'amazon selling cops facial recognition tool bad potentially racist',
#  'miley_cyrus wrecking ball prank sleeping jimmy_kimmel',
#  'vanessa bayer feared porn stars skit donald snl',
#  'adam_rippon wins dancing_stars destined',
#  'emilia clarke imitate chewbacca',
#  'maddie poppe wins american_idol runner reveals dating',
#  'colbert resist turning nickname pee tape joke',
#  'seth_meyers forced tweak donald latest twitter rant time',
#  'boy teacher told fault police shoot age',
#  'cops accused racism detaining black man vegetation',
#  'white cop shouts black suspect pretend shoot',
#  'florida police report dead standoff panama city apartment complex',
#  'donald glover board lando calrissian pansexuality solo',
#  'charlize_theron play megyn_kelly film roger_ailes',
#  'shoppers boycott publix store donations nra backed candidate',
#  'blasio tells nypd stop arresting people smoking pot street',
#  'dhs head unaware intel russia interference boost',
#  'lawmaker introduces crowdfunding pay border_wall',
#  'gop lawmakers allowed review classified info russia_investigation',
#  'james_corden reveals worst royal_wedding ceremony',
#  'ariana_grande reportedly dating snl star pete davidson',
#  'jim_carrey pens pledge allegiance students bullet riddled schools',
#  'ellen david spade open dating younger women',
#  'ceasefire jimmy_kimmel shreds sean_hannity dummies fox_friends',
#  'spoof royal_wedding video sees ceremony taking turn',
#  'georgia gop governor primary focuses guns immigration',
#  'glaad movie report_finds troubling drop lgbtq representation',
#  'sephora offers store beauty classes trans nonbinary community',
#  'georgia governor primary highlights competing visions democratic_party',
#  'california moves schools workers red flag dangerous gun_owners',
#  'talking grievance health_care outsider kentucky dem inside track',
#  'problems commemorative kim_jong coin',
#  'giuliani stance russian collusion illegal',
#  'onion hilariously trolls michael_cohen cease desist note',
#  'democrats boost school funding address teacher walkouts',
#  'emails lawmakers shrug lax cellphone security',
#  'stink bug flavored jelly bellys don',
#  'power outage triggers extreme zombie activity alert florida city',
#  'congress wall_street favor banks post record profits',
#  'white_house sinkhole metaphor',
#  'reporter shoved barred epa meeting water contaminants',
#  'garry kasparov donald russian connections aeroflot',
#  'lonely planet european destinations aim overtourism',
#  'attorney aaron schlossberg insists anti spanish rant person',
#  'minutes reporter reveals chilling reason slamming press',
#  'reportedly rejects phone security measures inconvenient',
#  'federal_court sides transgender teen gavin grimm bathroom fight',
#  'adviser calls president claims informant spied campaign embarrassing',
#  'vietnam test abandons climate diplomacy',
#  'americans successfully draining swamp',
#  'msnbc host hugh hewitt suggests trench coat control gun_control',
#  'bishop michael curry harry_meghan love brought worlds',
#  'sarah paulson unapologetic year age gap girlfriend holland taylor',
#  'texans sides gun debate agree safe storage support',
#  'family gay man critically injured amtrak route answers',
#  'caitlyn_jenner worst president lgbtq_rights',
#  'boy_scout allegedly booted store company won support homos',
#  'instagram adding mute button sake sanity',
#  'publix censors teen summa cum laude graduation cake',
#  'sexist passengers female pilot perfect_response',
#  'time takes_aim mcdonald walmart sexual_harassment complaints',
#  'venezuela socialist leader nicolas maduro elected amid allegations irregularities',
#  'iran europe support nuclear_deal isn america withdrawal',
#  'mob attacks year liberal greek mayor',
#  'shawn mendes khalid perform parkland survivors billboard_music awards',
#  'tamir_rice mother opening youth center honor son memory',
#  'judge_orders texas make voter_registration easier updating dmv info',
#  'kelly_clarkson calls moments action honor texas shooting_victims billboard awards',
#  'kendrick_lamar stops white fan rapping word onstage',
#  'gay man pope_francis told god loves',
#  'unusual asteroid interstellar guest solar',
#  'started suicide prevention site age strong',
#  'roger stone prepared conjured mueller indictment',
#  'hillary_clinton endorse andrew_cuomo election',
#  'supreme_court lot harder sue employer',
#  'blake farenthold hired illegally lobbyist job',
#  'konigsberg explores gay experience latest book',
#  'game shows biggest hurdles lgbtq athletes exist field',
#  'chrissy_teigen real_life childbirth',
#  'suits creator pens heartfelt open_letter attending royal_wedding',
#  'movies coming netflix week',
#  'obamas coming netflix queue',
#  'ben_affleck make justin_theroux giant rat tattoo',
#  'hillary_clinton tips russian hat yale commencement_speech',
#  'giuliani mueller talk hears fbi source',
#  'democrats plan big anti corruption theme midterms',
#  'kelly_clarkson rejects moment silence calls change billboard_music awards',
#  'asked american public settle internet dumbest debates',
#  'fox_news viewers don lifelong republican robert_mueller',
#  'team moves lift ban extreme hunting tactics alaska',
#  'howard stern tells sexualized ivanka makes david_letterman cringe',
#  'supreme_court helping companies sexual_harassment',
#  'deadpool steals spot box_office avengers_infinity war',
#  'westworld subtly tease baby theory',
#  'donald glover tells ellen circle star_wars moment son',
#  'marvel exec stop jarring infinity_war death',
#  'jake_gyllenhaal set star villain spider_man sequel',
#  'janet_jackson black woman receive billboard icon award',
#  'isn pakistan bitch video captures driver racist rant',
#  'grey gardens ladies unwitting godmothers reality_tv archetypes',
#  'year_boy superhero alabama homeless population',
#  'john_oliver time mocking royal_wedding',
#  'john_oliver needles dangerously unregulated rehab industry',
#  'jemele hill honored nabj journalist year',
#  'french digital minister gay fight homophobia',
#  'belgian transgender ballet drama wins big cannes_film festival',
#  'year gay man proves attend pride',
#  'super_pacs meddled west_virginia senate primary didn receive penny west virginians',
#  'airline passenger arrested_allegedly harassing woman peeing seat',
#  'mike pompeo promises crush iran achieve deal',
#  'majestic islands europe tourists don',
#  'cuba confirms killed country deadliest plane_crash',
#  'china putting trade war hold treasury steve mnuchin',
#  'economic adviser amazon threats lane',
#  'dems admin common ground helping victims myanmar genocide',
#  'giuliani mueller wrap obstruction probe september report',
#  'german broadcaster criticized racist coverage royal_wedding',
#  'kathryn newton boldest teen tv ready grow',
#  'stephanie kelton biggest idea washington',
#  'texas gov campaign cancels shotgun giveaway santa fe school_shooting',
#  'tina_fey sarah_palin leads snl chorus lamenting',
#  'day american gushing snl smart aleck royal_wedding',
#  'starbucks sit cafes buying',
#  'alec_baldwin faces ominous sopranos scenario snl finale',
#  'asia argento fiery speech closes cannes raped harvey_weinstein',
#  'tina_fey girls musical snl',
#  'parents school_shooting victims decry moronic gop platitudes',
#  'real americans tough russia_probe',
#  'chrissy_teigen john_legend announce baby_boy adorable photo',
#  'texas lt gov dan patrick touts arm teachers',
#  'david hogg calls media stop naming santa fe school shooter',
#  'sets showdown doj claims campaign surveillance',
#  'jim_carrey latest painting slams kent state goldilocks ar',
#  'oliver north blames school shootings ritalin',
#  'jimmy_kimmel tricks royal fans reviewing wedding big day',
#  'jimmy_fallon reveals viewers biggest wedding fails',
#  'protesters throw fiesta razz lawyer ranted spanish speakers',
#  'watch amazon prime week',
#  'ferrell molly shannon cover royal_wedding cord tish',
#  'artist cedric entertainer arrived',
#  'mark kelly rolled nra guns parkland',
#  'gop_candidate set trust pays kids marrying white people',
#  'houston police_chief sick inaction gun_control',
#  'history national_anthem sports',
#  'bbc trolls president bigly huge royal_wedding crowd',
#  'victims santa fe high_school shooting',
#  'ceo pay cut employees year battling amazon',
#  'jr met emissary gulf princes offering campaign report',
#  'misspells melania home tweet twitter roars',
#  'jimmy_kimmel shreds cowardly lawmakers texas school_shooting',
#  'maher reveals things don michael_cohen',
#  'watch hulu week',
#  'students stage sit gun_control paul_ryan office arrested',
#  'knew scary appearance gates daughter',
#  'russian spy sergei skripal discharged uk hospital poisoning incident',
#  'cuba plane_crash reportedly kills',
#  'reassures north_korea threatens total decimation deal',
#  'ariana_grande fans singing time surprise lives',
#  'cambridge_analytica files chapter bankruptcy facebook privacy row',
#  'santa fe high schoolers held gun_violence protest month shooting',
#  'michelle_wolf netflix trailer closer',
#  'jeff_sessions exceptional power immigration courts limit judges authority',
#  'gop_rep introduces demand white_house apologize mccain',
#  'colbert super graphic describing deep mueller_probe',
#  'jack osbourne wife files divorce',
#  'meek backs event prison reform',
#  'rule cut federal funds clinics providing abortions',
#  'twitter_users joke prison reform headed',
#  'single chilean bishop offers resign country sex_abuse scandal',
#  'ariana_grande calls manchester attack worst humanity year',
#  'chrissy_teigen spills details baby_boy love',
#  'alec_baldwin wife hilaria baby_boy',
#  'kate_mckinnon breaks impression rudy_giuliani',
#  'smallville allison mack involved sex cult place',
#  'white_house kills yanny laurel debate ridiculous clip',
#  'jennifer_aniston play lesbian president netflix ladies',
#  'break book shadows charmed reboot trailer',
#  'dave matthews band violinist boyd tinsley accused_sexual misconduct',
#  'people single book jimmy_kimmel',
#  'ellen_degeneres hilariously explains saved meghan_markle life',
#  'lawyer ranted spanish speakers faces office eviction disciplinary complaint',
#  'hannity flips mueller_probe direct threat american republic',
#  'democrats answers global health security head sudden departure',
#  'gun_owners gun_owners agree lot gun reforms',
#  'twitter_users pan ted_cruz tweets prayers santa fe school_shooting victims',
#  'states ban bump_stocks enforce law',
#  'liberal billionaire tom steyer base',
#  'sen dean heller campaign paid social_media influencer son',
#  'interior dept dodges watchdog questions zinke alaska senators',
#  'blake_lively teases ryan_reynolds hugh_jackman bromance',
#  'happytime murders adult themed movie puppets',
#  'photo daniel_radcliffe holding guns crazy slippers magical meme',
#  'gates didn difference hpv hiv',
#  'bachelorette bios terrible',
#  'steven tyler admits hitting daughter liv famous pal watched',
#  'hospice overdosed patients hasten deaths health_care executive admits',
#  'kimmel brings house giving latest tweet ending',
#  'wwf wrestler severely beaten california home',
#  'robert wilkie picked va secretary surprise announcement',
#  'domestic gag rule strip funds planned_parenthood',
#  'rudy_giuliani reverses team position president obstruct justice',
#  'social anxiety doesn attention deserves',
#  'deadpool breaking box_office records',
#  'obamacare premiums higher year didn',
#  'comprehensive list don jr doesn infamous meeting',
#  'report manafort son law cuts plea deal cooperate government',
#  'briefly responds santa fe school_shooting pivoting',
#  'late_night writer shreds roseanne racist',
#  'nasa chief apparently changed tune climate_change',
#  'freedom_caucus sinks key paul_ryan welfare reform agenda',
#  'transphobic congressional hopeful berates person inside public restroom',
#  'singer ryan amador loverboy coming',
#  'newest head cracker hear brainstorm green needle',
#  'meditation human clearing browser cache',
#  'funniest_tweets women week',
#  'italy befriend russia populist parties form government',
#  'business groups quietly killing bring sexual_abuse claims light',
#  'kushner family reportedly close bailout flagship tower',
#  'll charity royal_wedding ll',
#  'federal prosecutors turn inauguration protesters felons',
#  'republican immigration fight derails food_stamp',
#  'retiring lawmakers added million campaign treasuries election',
#  'facing farm vote problems gop_leaders make deal',
#  'methodists surprise gay minister world pastor certificates theft diploma',
#  'china marks milestone quest space superpower',
#  'stephen_colbert mueller special anniversary gift',
#  'stormy_daniels disclosure leaves questions payments cohen',
#  'enjoy animated history tina_fey snl return',
#  'controversial california schools handling students misbehavior',
#  'deaf activist points marvel diversity problem isn race',
#  'magnum trailer lots close shaves big mustache',
#  'gina haspel confirmed cia_director aid democrats',
#  'boulder city_council unanimously votes ban assault weapons high capacity magazines',
#  'chrissy_teigen john_legend baby_boy',
#  'terrifying clip shows run tree thunderstorms',
#  'mitch_mcconnell taps anti_lgbtq bigot religious_freedom panel',
#  'seth_meyers donald unexpected advice north_korea',
#  'devin_nunes fundraising fbi attacks tells potential donors hero',
#  'mexican_president warns donald ve st',
#  'fox_news female ceo named sexual_harassment complaints',
#  'battle save dying soil',
#  'latino man insulted starbucks barista writes slur cup',
#  'snl cast member claims faked bizarre phone rehearsals',
#  'jimmy_kimmel clean owe donald apology',
#  'trevor_noah skewers betsy_devos fake profit university ad',
#  'serena_williams explains father didn walk aisle',
#  'star_wars writer confirms donald glover character pansexual solo',
#  'medical professionals fact check grey_anatomy sex scenes',
#  'amy_schumer nails meghan_markle fairytale wedding sucks',
#  'michael keaton ends kent state commencement_speech batman',
#  'black profiled share story',
#  'black actresses cannes protest racism french film industry',
#  'michael_jordan denies rumors doesn date black women',
#  'scam pacs ripped conservatives pro police anti_abortion messages prosecutors',
#  'mtv suspends catfish probes nev schulman sexual_misconduct claims',
#  'ice increasingly arresting immigrants criminal convictions',
#  'special_counsel hits roger stone social_media advisor subpoenas',
#  'whitney_houston sexually abused dee dee warwick cannes documentary',
#  'patton_oswalt joker theory change watch dark_knight',
#  'josh holt american captive venezuela begs prison videos',
#  'obama photographer taunts donald calling immigrants animals',
#  'backstreet boys release song don breaking heart',
#  'prince knight puts gay inclusive twist traditional fairy tales',
#  'gay_conversion therapy survivor recalls month nightmare powerful video',
#  'gq expertly spoofs vanity_fair annual comedy issue cover',
#  'rudy_giuliani offers head spinning defense',
#  'cynthia_nixon fix subway ads shred cuomo mta commuters rejoice',
#  'farm huge blow animals',
#  'emails interior expected learn public input bears ears review',
#  'whistleblower leaked michael_cohen financials potential cover report',
#  'kidnapper accused alligator hold man captive',
#  'miss america pageant headed women email scandal',
#  'north_korea threatens reconsider summit cancels south_korea talks',
#  'chemical_weapons syria watchdog finds',
#  'hundreds israel protest killings palestinians gaza border',
#  'researchers uncover secret pages diary anne frank',
#  'stephen piscotty returns bereavement hit mom tribute home run',
#  'senate intelligence_committee backs gina haspel lead cia',
#  'pennsylvania congressional delegation longer men',
#  'lando calrissian star_wars spinoff starring donald glover isn happening',
#  'fake donald sean_hannity pillow talk late',
#  'rapper arrested disorderly conduct public drunkenness',
#  'conservatives cook farm gambit vote hardline immigration',
#  'novartis lawyer resigns michael_cohen deal',
#  'isn birth_control emoji',
#  'white_house eliminates cyber czar post appointee leaves',
#  'emily list backed lawyer wins democratic_primary pennsylvania swing district',
#  'robin_williams biographer tells sweet story comic store visit',
#  'republicans attacking nancy_pelosi house races',
#  'empire military takes gates hell',
#  'longtime lawyer slams giuliani polarizing figure shouldn deal mueller',
#  'bet_awards nominations dj khaled screaming',
#  'beirut pride canceled organizer detained authorities',
#  'manhattan district attorney vows stop prosecuting minor marijuana cases',
#  'larry_nassar victims receive million michigan_state settlement',
#  'jr left open possibility dad knew tower meeting time',
#  'tom_cruise ankle break scene laughs mission impossible trailer',
#  'lives steven tyler',
#  'louisiana lawmakers approve restoring voting_rights people probation parole',
#  'thandie newton cannes dress celebration black star_wars characters',
#  'paid cohen financial disclosure confirms',
#  'american citizen freed egypt jail',
#  'fox_news settle group discrimination lawsuits million',
#  'tweeters hard pass rnc dinner photo donald prize',
#  'facebook removed million fake accounts quarter',
#  'pink badass response troll looked',
#  'san_francisco adopt software app automatically clear marijuana convictions',
#  'younger star sutton foster returns broadway roots album',
#  'senate hot seat scott_pruitt dodges questions mounting scandals',
#  'idaho inches closer electing nation native_american governor',
#  'pro abortion rights progressive wins nebraska democratic house primary',
#  'ryan_reynolds crashes colbert deadpool crack rated jokes',
#  'ryan_reynolds genuinely hurt trading playground insults josh brolin',
#  'terry crews movement emancipation proclamation',
#  'christopher wylie warns senators cambridge_analytica steve_bannon culture war',
#  'san_francisco ban single plastic straws',
#  'john travolta isn greased lightning cannes dance floor',
#  'senate panel releases details tower meeting probe',
#  'report contradicts michigan governor candidate test animal treatment',
#  'republican welfare plan keeping wages',
#  'years_ago today michael_jackson moonwalked tv time',
#  'hilary_duff publicly drags neighbor night',
#  'jim_carrey jabs stooge donald north_korea artwork',
#  'failure report stormy_daniels payoff referred prosecutors',
#  'bohemian rhapsody trailer slammed ignoring freddie mercury sexuality',
#  'fergie rides york_city subway',
#  'pauley perrette responds cbs statement multiple assaults claim',
#  'refers immigrants animals',
#  'angry white dude rant people speaking spanish nyc viral',
#  'democratic lawmaker scott_pruitt brutal reality_check senate hearing',
#  'picks mitch_mcconnell brother law gordon hartogensis lead pension agency',
#  'fbi search cia leak suspect turned photos sex assault unconscious friend',
#  'pick census role citizenship question political',
#  'jared_kushner agitated infuriated meeting russians focused adoptions',
#  'sarah_huckabee sanders unusually honest seth_meyers spoof briefing',
#  'kris_jenner assistant kris_jenner',
#  'chris_pratt bryce dallas howard service raptor flight',
#  'surprise shows coming netflix',
#  'rex_tillerson warns grads living alternative realities',
#  'democrats force vote net_neutrality rules',
#  'larry_nassar blames victims victimized newly released videos',
#  'video_shows year autism taunted abused bus_driver',
#  'yanny laurel real answer',
#  'populist cleric muqtada al sadr win iraq parliamentary election',
#  'palestinian family month died israeli tear gas gaza protest crackdown graphic',
#  'sichuan airlines pilot sucked halfway broken windshield',
#  'retail group spoofs ferris bueller ad bashing donald tariffs',
#  'washington officials state cover postage mail ballots year',
#  'people civil politics opponents disagree',
#  'cambridge_analytica investigated justice_department fbi report',
#  'adorable video kids shows activism literally easy pie',
#  'white_house blames deadly gaza violence hamas propaganda',
#  'gina haspel cia shouldn conducted interrogation program',
#  'tesla autopilot engaged horrific mph crash driver tells police',
#  'selling planes iran saved lives exiting nuclear_deal make harder',
#  'speech fallen officers touts policies rails sanctuary_cities',
#  'eric greitens team pushes inquiry prosecutor charged',
#  'elizabeth_warren pledges big money turn heat gerrymandering',
#  'gay_conversion therapy illegal maryland',
#  'fox_news judicial analyst defends timeline mueller_probe',
#  'stephen_colbert oprah analogy ridicule hannity bedtime chats',
#  'trailer queen biopic bohemian rhapsody',
#  'seth_meyers shreds scandals drain swamp devoid meaning',
#  'jim_carrey blood dripping portrait takes_aim national disgrace nra',
#  'scott_pruitt security day epa documents',
#  'rabid anti_muslim fbi agent training texas police',
#  'khloe_kardashian explains chose true daughter',
#  'game gina haspel track confirmed cia_director',
#  'topher grace hated preparing play david_duke spike_lee blackkklansman',
#  'sarah paulson deeply nerdy rihanna filming ocean',
#  'blake farenthold won repay sexual_harassment settlement',
#  'spike_lee major love blackkklansman cannes rips',
#  'twitter_users hilariously skewered terrible stock photos jobs',
#  'ivanka jared jerusalem visit slammed twitter',
#  'adam_rippon honors mom stunning dancing_stars performance',
#  'tomi_lahren hits genealogist researched family misses point',
#  'georgia gop gov candidate round immigrants deportation bus',
#  'daddy ghoul york daily_news rips ivanka embassy opening',
#  'death keeven robinson black louisiana man police custody ruled homicide',
#  'colbert savages peace treaty barbie collusion ken embassy opening',
#  'twitter_users roast experts salary saved',
#  'woman challenging white male dominated tech industry inside',
#  'keith richards explains rid years_ago',
#  'damon wayans completely rips clayne crawford twitter outburst',
#  'han solo scoundrel solo star_wars story forgot',
#  'pauley perrette reveals multiple physical assaults ncis exit',
#  'ariana_grande jimmy_fallon make sweet music cardboard instruments',
#  'trevor_noah don watch fox_news',
#  'seattle passes controversial tax city biggest companies combat housing crisis',
#  'uber ends forced arbitration individual cases sexual_assault harassment',
#  'meet openly trans man graduate spelman college',
#  'canceled renewed tv_shows',
#  'teen claims visited heaven death experience',
#  'willow smith tells shocked jada_pinkett smith harmed preteen',
#  'farming technique drastically water catching',
#  'kristen_stewart ditches heels cannes red_carpet defying flats rule',
#  'david duchovny addresses nuttiest fan theories files',
#  'judge overturns california die law',
#  'debbie_wasserman schultz nra shy terrorist organization',
#  'cardi responds girls song controversy apologizes lgbtq_community',
#  'emotional support spider goat banned american_airlines',
#  'people agree voice yanny laurel',
#  'world deepest ocean trench safe plastic bags',
#  'open embassy jerusalem nations prefer wait peace deal',
#  'israeli forces kill dozens palestinians protests intensify embassy jerusalem',
#  'facebook suspends apps amid data misuse investigation',
#  'senator harry_reid diagnosed pancreatic_cancer',
#  'federal regulator takes_aim facebook',
#  'apology white_house dying mccain dig',
#  'south_dakota congressional_candidate terrorist attack win primary',
#  'ryan coogler love women wakanda spinoff',
#  'coffee shop refuses serve man racist rant woman niqab',
#  'supreme_court invalidates federal ban sports gambling',
#  'huge congrats fox_news guest journos peddle bret baier book',
#  'movies coming netflix week',
#  'prosecutor drops felony invasion privacy charge missouri gov eric greitens',
#  'israeli soccer_team beitar jerusalem add',
#  'vermont lawmakers pass gender_neutral bathroom send powerful_message',
#  'rita ora girls deemed tone_deaf harmful lgbtq pop artists',
#  'embassy jerusalem opens doors protests rage nearby',
#  'john_oliver reveals secret figuring mind',
#  'super mario hair people freaked',
#  'channing_tatum mother_day message jenna_dewan love',
#  'star justin hartley sexually_harassed fan',
#  'lois lanes pay_tribute late margot kidder led',
#  'onion story blake farenthold job lobbying congress',
#  'iowa gov slowing signing country strictest abortion ban',
#  'cannes_film festival promises greater gender_equality times activism',
#  'childish gambino america hits spot week',
#  'jon_stewart dave_chappelle perform standup tour',
#  'coach tells hurt ufc fighter continue',
#  'melania recovering kidney surgery',
#  'jon tester vulnerable senate democrat isn voting',
#  'taraji_henson kelvin hayden engaged mother_day',
#  'young dolph baristas fired playing song paid',
#  'bed explores intimacy experiencing sexual_assault',
#  'changed burger order make healthier',
#  'michael avenatti posts photos cohen qatari investor accused bribery',
#  'donald lashes called leaks twitter_users pounce',
#  'orders chinese phone maker china approves money project',
#  'hundreds protest cities poor_people campaign',
#  'rihanna response asked attending royal_wedding',
#  'lifetime harry_meghan royal romance good',
#  'game_changing westworld brain capsule reveal beginning',
#  'margot kidder actress played lois lane superman dead',
#  'tomi_lahren owned genealogist remarks low skilled immigrants',
#  'harrison_ford crashes han solo actor interview life',
#  'kylie_jenner bodyguard tim chung denies stormi father',
#  'seann william scott replaces clayne crawford renewed lethal weapon',
#  'zach woods officially mvp silicon_valley',
#  'ryan_reynolds south_korean singing disguised unicorn',
#  'billie lourd honors tough mother_day photo carrie_fisher',
#  'pink asks year concertgoer sing blown',
#  'pastor thinks jews hell speaks jerusalem embassy opening',
#  'chili hit data breach credit debit card information compromised',
#  'called waffle_house hero james shaw jr disarming shooter',
#  'fox_news host fulfilled biblical prophecy moving embassy jerusalem',
#  'keyless cars killed dozen people report',
#  'rare conjoined fawns scientists double',
#  'killed dozens injured indonesia church bombings',
#  'iran president country remain nuclear_deal',
#  'lindsey_graham officials owe mccain apology disgusting insult',
#  'amy_schumer girl raunch saturday_night live',
#  'americans make iran_deal depends',
#  'attending nra convention fake_news media',
#  'autopilot probed tesla crashes mph',
#  'michael bloomberg slams epidemic political lies danger democracy',
#  'massive cookout thrown park cops called black family bbq',
#  'michael che stepmom melissa_mccarthy embarrasses weekend_update',
#  'handmaid_tale meets sex city funny terrifying snl spoof',
#  'video_shows security guard choking black teen accused shoplifting york',
#  'praises late mom mother_day skips mention melania',
#  'promises chinese company violated sanctions iran',
#  'sarah_huckabee sanders berated staffers mccain leak',
#  'parkland dad pointed message oliver north nra president',
#  'john_bolton sanctions european companies iran',
#  'michelle_obama shares_adorable throwback pic touching mother_day tribute',
#  'tomi_lahren claims low skilled immigrants country based',
#  'stalking cheetahs oblivious family scare exit car safari park',
#  'der spiegel cover portrays finger flipping europe',
#  'italian tribunal lifts ban silvio berlusconi holding public office',
#  'north_korea plans dismantle nuclear test sites end',
#  'knife attack paris leaves_dead injured',
#  'watch hulu week',
#  'watch amazon prime week',
#  'late unveils spoof line themed mother_day gifts',
#  'brooklyn finds tv home stars fans rejoice',
#  'smith shares inspiring tale fresh prince bel air',
#  'lgbtq groups oklahoma adoption law discriminatory',
#  'mueller reportedly investigating foreign linked donors inauguration fund',
#  'stephen_colbert mocks proposal hang pence portraits post offices',
#  'boston dynamics robot dog sale',
#  'southern baptist leader apologizes past hurtful comments women',
#  'george soros progressive groups spend millions elect reformist prosecutors',
#  'incredible photos world protect',
#  'avengers_infinity war directors reveal died survived screen',
#  'uber silences women sexual assaults',
#  'marvel introduces official chinese superheroes',
#  'big_bang theory pays sweetest tribute stephen_hawking deleted scene',
#  'maher shreds donald likens mob boss',
#  'amazon holding seattle hostage',
#  'jim_carrey taunts psycho mike_pence biting portrait',
#  'chadwick boseman lauds student protesters howard commencement_speech',
#  'understand straight incels talk gay',
#  'gathering military spouses puts white white_house',
#  'game host prematurely congratulates contestant mortifying fail',
#  'women cannes red_carpet protest inequality film',
#  'men charged hate_crimes beating gay_couple',
#  'administration rolls protections transgender prison inmates',
#  'michael_cohen reportedly paid advise time_warner merger',
#  'metoo statehouse men harassment culture isn',
#  'austin bars police_department selling guns public',
#  'masterclass parody dubbing movie swear words falcon great',
#  'democrats don regret making easier confirm judges',
#  'donald glover fan cast solo',
#  'seth_meyers skewers idea donald winning nobel_peace prize',
#  'chuck_schumer turns melania campaign donald',
#  'trailer axed tremors reboot kevin bacon offers glimpse',
#  'frightened rabbit singer scott hutchison dead',
#  'suspect custody shooting california high_school injured',
#  'colbert names official job unqualified white_house staffer',
#  'trevor_noah michael_cohen biting breaking_bad themed nickname',
#  'moral atlanta robbin season snatching',
#  'pose character finds community york ball scene',
#  'accused golden_state killer faces additional murder counts',
#  'jimmy_kimmel roasts donald spoof nobel_peace prize ceremony video',
#  'sarah_palin mccain regrets perpetual gut punch',
#  'killed australia worst mass_shooting',
#  'deadpool david_beckham hug feud deadpool teaser',
#  'opposition hot lawyer',
#  'dogs prepare babies cats prepare teenagers',
#  'john_mccain wife rebukes white_house official mocked dying',
#  'rupaul_drag race queens turn time cher rusical',
#  'administration axes funding nasa monitors greenhouse gases',
#  'police search suspected serial_killer dumping ground',
#  'kevin mchale surprise',
#  'pennsylvania house race embodies fight future democratic_party',
#  'hackers breach tennessee county server election_night report',
#  'gay teacher suspended showing photo future wife sues texas district',
#  'school_district allegedly lgbtq student read bible punishment',
#  'launched war christmas people',
#  'elle fanning makes punk music debut talk girls parties',
#  'jake_tapper rips retired gen tom mcinerney insulting john_mccain',
#  'fox cuts_ties guest cited john_mccain defend torture',
#  'attempt make immigrant caravan backfiring',
#  'celebrities reading weird texts moms mother_day treat',
#  'stormy_daniels actress doppelganger',
#  'oldest man america smokes dozen cigars day',
#  'tweeters erupt aide cruel taunt john_mccain dying',
#  'mark_hamill weds sheldon amy big_bang theory fans geek',
#  'epa hid scott_pruitt dinner climate denier accused child sex_abuse',
#  'meghan mccain takes swipe white_house aide mocks father cancer',
#  'talk white people calling cops people color',
#  'woman calls police black family bbqing lake oakland',
#  'tim allen man standing coming year canceled',
#  'joe_biden berates white_house joke john_mccain health',
#  'michael avenatti warns michael_cohen documents release',
#  'fox_friends host mocks ny_times isis coverage unaware beat fox story',
#  'congressional_candidate fk nra tv ad',
#  'tsa tells sikh man remove turban finds canadian politician',
#  'john_stamos shows baby bob saget lori loughlin',
#  'woman texts date love excessive thing',
#  'extortion guy figured stormy_daniels lawyer pretty',
#  'katie porter survived domestic_abuse campaign',
#  'plan prescription drug prices promised',
#  'giuliani cohen spoke big dollar clients',
#  'russian troll facebook ads barely targeted swing states',
#  'ted_cruz staff usaid met group called apartheid called injustice',
#  'plan family_vacation travel experts',
#  'boston dynamics created running robot coming',
#  'cornell student delivers thesis underwear professor questions outfit',
#  'funniest_tweets women week',
#  'israel reportedly fires dozens rockets syria',
#  'israel launches airstrikes syria iranian attacks',
#  'die advocate david goodall ends life listening ode joy',
#  'americans held north_korea return united_states',
#  'dozens dead torrential rains dam burst kenya',
#  'spotify stops promoting kelly music sexual_assault allegations',
#  'kim_jong meet month singapore',
#  'homeland_security denies report secretary drafted resignation letter',
#  'cecile richards running office future',
#  'aclu kris_kobach giving incorrect information voter_registration',
#  'ryan_murphy donate pose profits trans queer groups',
#  'rick morty renewed whopping episodes',
#  'ryan_reynolds warns deadpool fans don fking word',
#  'nurse charged death adviser mcmaster father',
#  'indiana slam joe donnelly don expect democrat hit',
#  'rick moranis netflix sctv documentary',
#  'facing challenge gop_lawmaker pulls support immigration',
#  'john_mccain urges senate reject gina haspel nomination cia',
#  'months rio cops supposedly closing marielle franco killers',
#  'queer_eye star tan france doesn poorly dressed fans style advice',
#  'women coming eric schneiderman job',
#  'man pleads_guilty bacon vandalism tennessee islamic center',
#  'mike_pence robert_mueller russia_probe wrap',
#  'ready older kevin justin hartley',
#  'net_neutrality rules end june fcc',
#  'democratic candidate maryland governor dies cardiac arrest',
#  'officer puts man chokehold north_carolina waffle_house',
#  'trevor_noah don blankenship nutty concession speech',
#  'brooklyn canceled twitter mourns',
#  'quiet struggle chuck_schumer left',
#  'gabby douglas utterly unrecognizable undercover boss',
#  'girls accused plotting kill classmate',
#  'curious case russian oligarch national_park service latrines',
#  'watch rudy_giuliani completely torpedo rudy_giuliani arguments',
#  'fox business guest defends torture worked john_mccain',
#  'tom abby queer_eye remarried',
#  'pakistan passes historic transgender rights',
#  'phil mudd flips questions cia torture didn america',
#  'facebook ads house dems russia ran election',
#  'kim_kardashian tristan thompson blocked defended khloe',
#  'kenan thompson ll stay snl long',
#  'jennifer_garner mom problems hilarious rap video ellen',
#  'dick_cheney suggests restarting torture interrogation program',
#  'greta gerwig loudly critiqued feel pretty moviegoer live tweeted',
#  'devin_nunes meeting secret russia_probe source threatening doj',
#  'queer_eye star karamo brown engaged director ian jordan',
#  'jet launched apple store incredible deals',
#  'tom hardy completely unrecognizable al capone movie',
#  'woman alleges rapper young lo raped trapped chris_brown home',
#  'republicans court seat denied obama years',
#  'man wanted white_supremacists kill black neighbor burn cross yard fbi',
#  'announces details meeting kim_jong',
#  'samantha_bee delivers blistering takedown ny ag eric schneiderman',
#  'jim_carrey scathing portrait joker nightmares',
#  'michelle_wolf renews hostilities sarah_huckabee sanders',
#  'fans erupt fate elias koteas olinsky chicago',
#  'people street apologize teachers jimmy_kimmel live',
#  'stephen_colbert porn_star math michael_cohen donald',
#  'pollen bomb allergy sufferer worst_nightmare',
#  'jennifer_lopez dances danceable songs tonight',
#  'white yale student calls cops black schoolmate napping dorm common room',
#  'rudy_giuliani quits law firm wild week interviews',
#  'teddy geiger makes public appearance coming transgender',
#  'ariana_grande mac miller reportedly break',
#  'avengers leaks support year interview marvel directors',
#  'good excuse racist impact michigan medicaid proposal',
#  'fcc complaints minutes interview stormy_daniels',
#  'americans jailed korea home situation worse',
#  'alex strangelove gay teen comedy doesn turn sex',
#  'woman home kittens bobcats',
#  'video bear eating ice_cream dairy queen leads charges zoo owners',
#  'iranian lawmakers mock mental capacity burn flag pulls nuke deal',
#  'europeans scramble save iran_deal withdraws',
#  'north_korea releases american political prisoners advance historic summit',
#  'establishment gop notches win ohio primary vacant house seat',
#  'eric schneiderman praised movement days abuse_allegations emerged',
#  'trevor_noah unloads supposed advocate women eric schneiderman',
#  'year comey_firing scope mueller_probe expands lawyer shell company',
#  'inspired businessman wins indiana gop senate primary',
#  'gop rival tammy baldwin team terrorists silence cia pick',
#  'jobs program people work',
#  'jim parsons queer stories onscreen',
#  'accuser wins democratic nomination ohio legislature',
#  'mastermind waterboarded cia information share gina haspel',
#  'conservative senate democrat backs agenda defeats progressive challenger',
#  'taylor_swift ve katy_perry kimye feud lives',
#  'kim_kardashian make history fashion council influencer award',
#  'nbc believes matt_lauer accusers months long investigation',
#  'russians ability change voter data didn report',
#  'elizabeth_warren pick wins ohio democratic gubernatorial primary',
#  'kkk leader guilty firing gun charlottesville rally',
#  'protesters decrying torture dragged gina haspel senate hearing',
#  'hired firm linked michael_cohen inside scoop',
#  'rnc selling sickening donald themed merch ahead mother_day',
#  'don blankenship defeat relief families upper big branch miners',
#  'colbert shreds broken promises talking',
#  'ambassador germany offends hosts hours day',
#  'jordan_peele nightmare coming year',
#  'backstreet boys dressed spice girls larger life',
#  'seth_meyers decodes teen slang reveals giuliani means',
#  'orlando interim pulse_nightclub memorial',
#  'trevor_noah turns donald knives comment reggae magic',
#  'senators force vote ultimately reverse fcc restore net_neutrality',
#  'ny legislature plan place replacements eric schneiderman',
#  'ambassadors write letter opposing gina haspel nomination',
#  'california authority state homes solar powered',
#  'ny governor assigns investigation eric schneiderman abuse_allegations',
#  'refugee caravan scapegoat border crackdown',
#  'pennsylvania latest state fund urban gun_violence prevention',
#  'denver mayor son caught_tape berating cop faggot',
#  'progressive prosecutors win primaries north_carolina',
#  'novartis money paid lawyer',
#  'hypocrisy melania online safety booklet pointed page page',
#  'uninsured rate worsening years obamacare gains',
#  'bernie_sanders plan revive labor unions',
#  'jim_carrey bestows scott_pruitt savage nickname latest painting',
#  'male allies abusers',
#  'mormon church end century long relationship boy_scouts',
#  'snack addiction killing orangutans',
#  'pick cia_director won torture program morally wrong',
#  'anderson_cooper burns moronic michael_cohen russia cash claims',
#  'pinata maker apologizes hanging black figures likeness lynchings',
#  'caliphate planet ruins',
#  'gay_marriage opponent ousted gop incumbent north_carolina',
#  'espn eliminates public editor role calling outdated',
#  'michael_cohen selling access group paid shell company',
#  'mitch_mcconnell mocks blankenship twitter big cloud cocaine',
#  'convict don blankenship loses patrick morrisey west_virginia senate_race',
#  'ohio voters pass gerrymandering reform measure',
#  'iran_deal exit win russia',
#  'cynthia_nixon yorkers vote homo cuomo',
#  'ontario canada issued binary birth certificate',
#  'child sexual predator roman polanski calls movement total hypocrisy',
#  'america producer reveals details childish gambino viral_video',
#  'terry crews black men aren allowed victims dead',
#  'donald glover america eyes jim crow historian',
#  'fox_news judicial analyst issues dark warning michael_cohen',
#  'black women bishops making history predominantly white church',
#  'geena davis husband reza jarrahy divorcing',
#  'pauley perrette abby heart wrenching farewell ncis',
#  'lethal weapon fires clayne crawford character shot',
#  'selena_gomez pokes_fun met_gala spray tan mishap',
#  'protest leader nikol pashinian elected prime_minister armenia',
#  'kim_jong secretly met xi jinping',
#  'netanyahu bombastic iran claims perfect audience',
#  'netanyahu chef blasted serving japan prime_minister dessert shoe',
#  'world_leaders condemn withdrawing iran_nuclear deal',
#  'senate_republicans shun don blankenship day west_virginia primary',
#  'york harvey_weinstein probe set continue attorney_general exit',
#  'announce break iran_nuclear deal',
#  'politicians schneiderman resign physical abuse_allegations',
#  'joe_scarborough legal strategy monkey throwing poo wall',
#  'kirsten_dunst jesse plemons baby_boy',
#  'holy matrimony proposal met_gala',
#  'nordstrom rack president apologizes store accuses black men theft',
#  'giuliani lawyer michael_cohen incriminating information president',
#  'lena waithe stuns met_gala queer superhero',
#  'kelly accusers permission bathroom',
#  'reportedly tells macron pulling iran_nuclear deal',
#  'deportation crackdown hurting immigrant victims crime',
#  'seth_meyers michael_cohen apologize air',
#  'blessing met_gala tweets',
#  'farm cut food_stamps friendly farmers',
#  'iran_nuclear deal',
#  'derby day bet wins thrilled texas woman million',
#  'democratic meddling west_virginia things watch election day',
#  'cynthia erivo met_gala nails featured sistine chapel painting black women',
#  'keanu reeves alex winter coming ted years',
#  'solange durag true mvp met_gala',
#  'house republican threatens subpoena doj official census citizenship request',
#  'jimmy_kimmel hard make_sense rudy latest defense',
#  'religious imagery stitched met_gala',
#  'bob marley granddaughter cops racially profiled checking airbnb',
#  'melania called anti bullying campaign ignores husband actions',
#  'trevor_noah watching rudy_giuliani smoking weed tv',
#  'janet_jackson receive icon award billboard_music awards',
#  'white_house prepares send congress billion spending cuts package',
#  'jared_kushner backed shot federal prison reform',
#  'george_zimmerman accused stalking detective working trayvon_martin film',
#  'passengers lashing scott_pruitt justify class travel epa memo',
#  'country house district key progressive battleground',
#  'mike_pence brother wins primary race vice_president house seat',
#  'marines investigating avowed white_supremacist active duty',
#  'violate iran_nuclear deal vows reimpose sanctions',
#  'olympic_committee sexual_abuse complaints taekwondo stars lawsuit',
#  'blake_lively brought family met_gala noticing',
#  'reilly offers stand sarah sanders handle line reporters',
#  'catholic priest praised dressed dude met_gala living life',
#  'jimmy_kimmel hide seek genius dog heal nation',
#  'bank_america appears flip firearm promise loan remington',
#  'gentleman caller presents queer icons ve',
#  'eric schneiderman man',
#  'christiane amanpour heading pbs replacing charlie rose',
#  'madonna teases song surprise met_gala performance',
#  'iron_man black widow captain_america thor hawkeye matching tattoos',
#  'michael_cohen accepted firm tied russian oligarch reports',
#  'stephen_colbert hits rudy_giuliani brutal fact check',
#  'katy_perry sends olive branch taylor_swift world rejoices',
#  'jada_pinkett smith real dating smith married',
#  'whoops mark_hamill spilled beans major cameo han solo movie',
#  'shawn mendes sweetly attended hailey baldwin gown met_gala',
#  'orrin hatch suggested allowed john_mccain funeral',
#  'seth_meyers perfect line confront donald lies',
#  'police hope dna catch zodiac killer',
#  'lili reinhart cole sprouse finally make couple debut met_gala',
#  'sweetbitter captures grit glamour restaurant world',
#  'mitch_mcconnell bends rules confirm judges',
#  'ryan_zinke tale fish',
#  'ny attorney_general eric schneiderman resigns amid abuse_allegations',
#  'sanctuary_cities working era surprising cost',
#  'shepard_smith pulled iran_deal decision violate',
#  'stormy_daniels finds crunchy chip',
#  'rainbow mountains peru straight dr seuss book',
#  ...]

# %% [markdown]
# ### Stemming / Lemmatization & Part-of-Speech filtering

# %% [markdown]
# ***Note***: *if you encounter an error regarding a missing spacy model, head to your CLI and enter*
# ````bash
#     python -m spacy download en_core_web_md
# ````

# %%
def lemmatize_texts(texts, 
                    allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'], 
                    forbidden_postags=[], 
                    as_sentence=False, 
                    get_postags=False, 
                    spacy_model=None):
    """Lemmatize a list of texts.
    
            Please refer to https://spacy.io/api/annotation for details on the allowed
        POS tags.
        @params:
            - texts_in: a list of texts, where each texts is a string
            - allowed_postags: a list of part of speech tags, in the spacy fashion
            - as_sentence: a boolean indicating whether the output should be a list of sentences instead of a list of word lists
        @return:
            - A list of texts where each entry is a list of words list or a list of sentences
        """
    texts_out = []
    
    if allowed_postags and forbidden_postags:
        raise ValueError("Can't specify both allowed and forbidden postags")

    if forbidden_postags:
        allowed_postags = list(set(POS_map.keys()).difference(set(forbidden_postags)))

    if not spacy_model:
        print("Loading spacy model")
        spacy_model = spacy.load('en_core_web_md')

    print("Beginning lemmatization process")
    total_steps = len(texts)

    docs = spacy_model.pipe(texts)

    for i, doc in tqdm(enumerate(docs), total=total_steps):
        if get_postags:
            texts_out.append(["_".join([token.lemma_, token.pos_]) for token in doc if token.pos_ in allowed_postags])
        else:
            texts_out.append(
                [token.lemma_ for token in doc if token.pos_ in allowed_postags])
    
    if as_sentence:
        texts_out = [" ".join(text) for text in texts_out]
        
    return texts_out

# %%
l_texts = lemmatize_texts(texts[:1000],
                allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV', 'X', 'PROPN'], 
                get_postags=False)
# Out:
# Loading spacy model
# Beginning lemmatization process
#   0%|                                                                                                                                                                             | 0/1000 [00:00<?, ?it/s]
#   0%|▏                                                                                                                                                                    | 1/1000 [00:02<34:36,  2.08s/it]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 474.62it/s]

# %%
occurences = compute_word_occurences(l_texts)

# %% [markdown]
# ## Using pre-trained Word2Vec representations from spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

nlp("this is a course")[3].vector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\MAXIME~1.SAZ\AppData\Local\Temp/ipykernel_6796/1759523742.py in <module>
# ----> 1 import spacy
#       2 nlp = spacy.load('en_core_web_sm')
#       3
#       4 nlp("this is a course")[3].vector
#
# ModuleNotFoundError: No module named 'spacy'

# %%
nlp = spacy.load('en_core_web_sm')

# %%
def get_word_embeddings(texts, occurences):
    words = []
    vector_representations = []

    for word in occurences["Word"].head(100):
        words.append(word)
        vector_representations.append(nlp(word)[0].vector)

    pd.DataFrame({"Words": words, "Vector": vector_representations})
# Out:
#         Words                                             Vector
# 0      donald  [4.727399, 1.0132356, 0.833761, -3.2051291, -0...
# 1         man  [4.744825, 0.62399197, -1.4038447, -3.6159914,...
# 2         win  [6.64212, 2.612313, -0.42527348, -4.177225, 1....
# 3       woman  [5.9668517, 1.5909166, 0.039670303, -5.785555,...
# 4        call  [5.7618876, -0.8812548, -0.33859012, -2.108201...
# ..        ...                                                ...
# 95        job  [6.7611356, 0.4908169, 0.003325414, -2.0114737...
# 96        isn  [1.5655665, 4.7968416, 0.027712822, -4.0333457...
# 97  star_wars  [5.068774, 0.19442317, -1.6329279, -2.0051355,...
# 98     public  [-1.8639622, 0.27736288, -0.4556211, -3.300734...
# 99       face  [6.882504, -0.79790187, -1.2470036, -0.6287188...
#
# [100 rows x 2 columns]
